# %%
import pandas as pd
import uproot
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import crystalball
from scipy.optimize import curve_fit,Bounds
from scipy.integrate import simps
import zfit_physics as zphysics
import zfit
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.pyplot as plt
import mplhep
import uncertainties 
from uncertainties import ufloat
import tensorflow as tf

plt.style.use('belle2')
#%jsroot on


# %run /afs/desy.de/user/j/jipatel/MT/MC_fit/Files_After_Acceptance/Signal_Background_thesis_final/Function.ipynb
# Out:
# 2024-09-04 10:06:40.592625: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-04 10:06:40.624799: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-04 10:06:40.625465: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-04 10:06:41.496717: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /afs/desy.de/user/j/jipatel/.local/lib/python3.8/site-packages/zfit/__init__.py:63: UserWarning: TensorFlow warnings are by default suppressed by zfit. In order to show them, set the environment variable ZFIT_DISABLE_TF_WARNINGS=0. In order to suppress the TensorFlow warnings AND this warning, set ZFIT_DISABLE_TF_WARNINGS=1.
#   warnings.warn(

# %% [markdown]
# ## 200

# %%
# Number of iterations
num_iterations = 300

# List to store the signal yields and their errors from each iteration
signal_yields_and_errors = []

for i in range(num_iterations):
    print(f"Running iteration {i + 1}/{num_iterations}...")

    # Process the Monte Carlo data
    mc_mu_signal, mc_mu_only_signal, mc_mu_scf, mc_mu_bkg, mc_mu_signal_weight, mc_mu_only_signal_weight, mc_mu_scf_weight, mc_mu_bkg_weight = process_MC_data_combined(
        file_signal_mu_Bppi0,file_bkg_mu_Bppi0, 'mu', '521', 'pi0', 'mumu', 1, 'rec521', 'weights', 200
    )

    # Fit models for signal, SCF, and background
    Mbc_only_signal_cb_fixed = fit_fixed_without_weight('Mbc', 'mu', 'signal', mc_mu_only_signal["Mbc"],  'cb', 0)
    deltaE_only_signal_cb_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'signal', mc_mu_only_signal["deltaE"], 'cb_gauss', 0)

    Mbc_scf_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'scf', mc_mu_scf["Mbc"],  'argus_gauss', 0)
    deltaE_scf_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'scf', mc_mu_scf["deltaE"], 'poly_gauss', 0)

    Mbc_bkg_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'bkg', mc_mu_bkg["Mbc"],  'argus_gauss', 0)
    deltaE_bkg_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'bkg',  mc_mu_bkg["deltaE"], 'poly', 0)

    # Combine signal and background data
    Signal_Mbc = mc_mu_only_signal["Mbc"]
    Signal_deltaE = mc_mu_only_signal["deltaE"]
    Background_Mbc = pd.concat([mc_mu_scf["Mbc"], mc_mu_bkg["Mbc"]])
    Background_deltaE = pd.concat([mc_mu_scf["deltaE"], mc_mu_bkg["deltaE"]])

    Signal_total = pd.concat([Signal_Mbc, Signal_deltaE], axis=1)
    Background_total = pd.concat([Background_Mbc, Background_deltaE], axis=1)

    MC_signal=len(Signal_total)
    MC_bkg=len(Background_total)

    print(MC_signal)
    print(MC_bkg)


    # Fit the extended model and get the result
    Mbc_signal_pdf, deltaE_signal_pdf, Mbc_background_pdf, deltaE_background_pdf, signal_extended, background_extended, total_model, result = fit_extended_model_scf_without_weight(
        Mbc_only_signal_cb_fixed, Mbc_scf_argus_gauss_fixed, deltaE_only_signal_cb_gauss_fixed, deltaE_scf_poly_gauss_fixed,
        Mbc_bkg_argus_gauss_fixed, deltaE_bkg_poly_gauss_fixed,
        pd.concat([Signal_total, Background_total]), 0.5, 0.5, 100, 100
    )
    result.errors(name='errors')
    print(result.params)
    print(result.valid)

    # Retrieve and store the signal yield and its error
    signal_yield = result.params[signal_extended.get_yield()]['value']
    signal_yield_errors = result.params[signal_extended.get_yield()]['errors']
    signal_yield_error = (signal_yield_errors['upper'] - signal_yield_errors['lower']) / 2

    # Store the signal yield and error as a tuple in the list
    signal_yields_and_errors.append((MC_signal,MC_bkg,signal_yield, signal_yield_error))

    print(f"Iteration {i + 1} - Signal Yield: {signal_yield} ± {signal_yield_error}")

# Convert the list to a DataFrame with two columns: 'Signal_Yield' and 'Signal_Yield_Error'
signal_yields_df = pd.DataFrame(signal_yields_and_errors, columns=['MC_signal','MC_bkg','Signal_Yield', 'Signal_Yield_Error'])

# Save the DataFrame to a CSV file
signal_yields_df.to_csv('Bppi0_q2reg1_decay_mumu_signal_yields_and_errors_200.csv', index=False)

print("Signal yields and errors saved to 'Bppi0_q2reg1_decay_mumu_signal_yields_and_errors_200.csv'")
# Out:
# Running iteration 1/300...
# 200
# 410
# /afs/desy.de/user/j/jipatel/.local/lib/python3.8/site-packages/zfit/core/basepdf.py:585: UserWarning: As `copy` is not yet properly implemented, this may fails (for ProductPDF for example?). Thiswill be fixed in the future.
#   warnings.warn(
# /afs/desy.de/user/j/jipatel/.local/lib/python3.8/site-packages/zfit/minimizers/fitresult.py:1340: FutureWarning: 'minuit_minos' will be changed as the default errors method to a custom implementationwith the same functionality. If you want to make sure that 'minuit_minos' will be used in the future, add it explicitly as in `errors(method='minuit_minos')`
#   warnings.warn(
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1745                 156.469  -     15   +     16       False
# background_yield_0.1745             452.751  -     22   +     24       False
# frac_Mbc_bkg1_0.1745             0.00960272  -  0.056   +  0.057       False
# frac_deltaE_bkg1_0.1745            0.226807  -   0.15   +   0.15       False
# True
# Iteration 1 - Signal Yield: 156.469051598565 ± 15.581551277555212
# Running iteration 2/300...
# 200
# 410
# name                     value  (rounded)               errors    at limit
# ---------------------  ------------------  -------------------  ----------
# signal_yield_0.04                 150.431  -     15   +     16       False
# background_yield_0.04              458.68  -     22   +     24       False
# frac_Mbc_bkg1_0.04              0.0315051  -  0.056   +  0.057       False
# frac_deltaE_bkg1_0.04            0.233316  -   0.15   +   0.15       False
# True
# Iteration 2 - Signal Yield: 150.4307383593251 ± 15.455551918557777
# Running iteration 3/300...
# 200
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1148                 148.764  -     15   +     16       False
# background_yield_0.1148              460.37  -     23   +     24       False
# frac_Mbc_bkg1_0.1148              0.0364021  -  0.057   +  0.057       False
# frac_deltaE_bkg1_0.1148            0.234873  -   0.15   +   0.15       False
# True
# Iteration 3 - Signal Yield: 148.7644751836178 ± 15.473757744816943
# Running iteration 4/300...
# 200
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8565                 150.817  -     15   +     16       False
# background_yield_0.8565             458.226  -     22   +     25       False
# frac_Mbc_bkg1_0.8565              0.0325898  -  0.057   +  0.057       False
# frac_deltaE_bkg1_0.8565             0.21381  -   0.15   +   0.15       False
# True
# Iteration 4 - Signal Yield: 150.8169888476117 ± 15.573593683546083
# Running iteration 5/300...
# 200
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.737                 147.627  -     15   +     16       False
# background_yield_0.737             461.673  -     23   +     24       False
# frac_Mbc_bkg1_0.737              0.0437741  -  0.057   +  0.057       False
# frac_deltaE_bkg1_0.737            0.233639  -   0.15   +   0.15       False
# True
# Iteration 5 - Signal Yield: 147.62675635955563 ± 15.500889654161522
# Running iteration 6/300...
# 200
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1797                 153.398  -     15   +     16       False
# background_yield_0.1797             455.604  -     22   +     25       False
# frac_Mbc_bkg1_0.1797               0.025226  -  0.057   +  0.057       False
# frac_deltaE_bkg1_0.1797             0.20126  -   0.15   +   0.15       False
# True
# Iteration 6 - Signal Yield: 153.3979052409881 ± 15.559651284540054
# Running iteration 7/300...
# 200
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3265                 158.957  -     15   +     16       False
# background_yield_0.3265             451.219  -     23   +     23       False
# frac_Mbc_bkg1_0.3265             0.00165355  -  0.056   +  0.058       False
# frac_deltaE_bkg1_0.3265              0.2278  -   0.15   +   0.15       False
# True
# Iteration 7 - Signal Yield: 158.9567829120229 ± 15.63523621607424
# Running iteration 8/300...
# 200
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.888                 154.303  -     15   +     16       False
# background_yield_0.888             454.983  -     22   +     24       False
# frac_Mbc_bkg1_0.888              0.0185029  -  0.056   +  0.058       False
# frac_deltaE_bkg1_0.888            0.244863  -   0.15   +   0.15       False
# True
# Iteration 8 - Signal Yield: 154.30280526746517 ± 15.59235420137335
# Running iteration 9/300...
# 200
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9543                 151.375  -     15   +     16       False
# background_yield_0.9543             457.619  -     22   +     25       False
# frac_Mbc_bkg1_0.9543              0.0264551  -  0.057   +  0.057       False
# frac_deltaE_bkg1_0.9543             0.23436  -   0.15   +   0.15       False
# True
# Iteration 9 - Signal Yield: 151.37543461807735 ± 15.530734483416246
# Running iteration 10/300...
# 200
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9469                 147.553  -     15   +     16       False
# background_yield_0.9469             461.779  -     23   +     24       False
# frac_Mbc_bkg1_0.9469              0.0458641  -  0.057   +  0.057       False
# frac_deltaE_bkg1_0.9469             0.24732  -   0.15   +   0.15       False
# True
# Iteration 10 - Signal Yield: 147.55247312335217 ± 15.57942971974919
# Running iteration 11/300...
# 200
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7273                 155.734  -     15   +     16       False
# background_yield_0.7273             453.545  -     22   +     24       False
# frac_Mbc_bkg1_0.7273              0.0148162  -  0.057   +  0.058       False
# frac_deltaE_bkg1_0.7273            0.230861  -   0.15   +   0.15       False
# True
# Iteration 11 - Signal Yield: 155.73438181907264 ± 15.644691580831893
# Running iteration 12/300...
# 200
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7941                 154.602  -     15   +     16       False
# background_yield_0.7941             455.357  -     23   +     24       False
# frac_Mbc_bkg1_0.7941              0.0160235  -  0.056   +  0.057       False
# frac_deltaE_bkg1_0.7941            0.232512  -   0.15   +   0.15       False
# True
# Iteration 12 - Signal Yield: 154.60185671002472 ± 15.469707350399002
# Running iteration 13/300...
# 200
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6663                 152.367  -     15   +     16       False
# background_yield_0.6663             456.723  -     22   +     24       False
# frac_Mbc_bkg1_0.6663              0.0252548  -  0.056   +  0.057       False
# frac_deltaE_bkg1_0.6663            0.227601  -   0.15   +   0.15       False
# True
# Iteration 13 - Signal Yield: 152.36681413088587 ± 15.461157254105315
# Running iteration 14/300...
# 200
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9783                 149.724  -     15   +     16       False
# background_yield_0.9783             459.401  -     22   +     24       False
# frac_Mbc_bkg1_0.9783              0.0335841  -  0.056   +  0.057       False
# frac_deltaE_bkg1_0.9783            0.222715  -   0.15   +   0.15       False
# True
# Iteration 14 - Signal Yield: 149.7237805713278 ± 15.435061449669458
# Running iteration 15/300...
# 200
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9287                 155.311  -     15   +     16       False
# background_yield_0.9287             453.807  -     22   +     24       False
# frac_Mbc_bkg1_0.9287              0.0133502  -  0.056   +  0.058       False
# frac_deltaE_bkg1_0.9287             0.23382  -   0.15   +   0.15       False
# True
# Iteration 15 - Signal Yield: 155.3108599745961 ± 15.636852955812895
# Running iteration 16/300...
# 200
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5362                 154.254  -     15   +     16       False
# background_yield_0.5362             455.079  -     22   +     24       False
# frac_Mbc_bkg1_0.5362              0.0172354  -  0.056   +  0.057       False
# frac_deltaE_bkg1_0.5362            0.225236  -   0.15   +   0.15       False
# True
# Iteration 16 - Signal Yield: 154.25372467594968 ± 15.54575774404925
# Running iteration 17/300...
# 200
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3887                 152.587  -     15   +     16       False
# background_yield_0.3887             457.366  -     23   +     24       False
# frac_Mbc_bkg1_0.3887              0.0224226  -  0.057   +  0.057       False
# frac_deltaE_bkg1_0.3887            0.236977  -   0.15   +   0.15       False
# True
# Iteration 17 - Signal Yield: 152.58660629266356 ± 15.529606813075485
# Running iteration 18/300...
# 200
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2586                 148.915  -     15   +     16       False
# background_yield_0.2586             460.319  -     23   +     24       False
# frac_Mbc_bkg1_0.2586              0.0402461  -  0.057   +  0.057       False
# frac_deltaE_bkg1_0.2586            0.240424  -   0.15   +   0.15       False
# True
# Iteration 18 - Signal Yield: 148.91515928752463 ± 15.537437523449778
# Running iteration 19/300...
# 200
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0203                 151.812  -     15   +     16       False
# background_yield_0.0203              457.25  -     22   +     24       False
# frac_Mbc_bkg1_0.0203              0.0267961  -  0.056   +  0.057       False
# frac_deltaE_bkg1_0.0203            0.223597  -   0.15   +   0.15       False
# True
# Iteration 19 - Signal Yield: 151.81179280692632 ± 15.41888031802623
# Running iteration 20/300...
# 200
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9029                 155.175  -     15   +     16       False
# background_yield_0.9029             454.067  -     22   +     24       False
# frac_Mbc_bkg1_0.9029              0.0159977  -  0.056   +  0.058       False
# frac_deltaE_bkg1_0.9029            0.257314  -   0.15   +   0.15       False
# True
# Iteration 20 - Signal Yield: 155.17508251874284 ± 15.61500915291247
# Running iteration 21/300...
# 200
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4618                 157.758  -     15   +     16       False
# background_yield_0.4618             452.303  -     23   +     24       False
# frac_Mbc_bkg1_0.4618             0.00553289  -  0.057   +  0.058       False
# frac_deltaE_bkg1_0.4618            0.243587  -   0.15   +   0.15       False
# True
# Iteration 21 - Signal Yield: 157.75823051037517 ± 15.764229952694253
# Running iteration 22/300...
# 200
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8618                 151.786  -     15   +     16       False
# background_yield_0.8618             458.172  -     23   +     24       False
# frac_Mbc_bkg1_0.8618              0.0264843  -  0.057   +  0.057       False
# frac_deltaE_bkg1_0.8618            0.238455  -   0.15   +   0.15       False
# True
# Iteration 22 - Signal Yield: 151.78612830114835 ± 15.543161304422114
# Running iteration 23/300...
# 200
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2532                 148.233  -     15   +     16       False
# background_yield_0.2532             461.468  -     23   +     24       False
# frac_Mbc_bkg1_0.2532               0.043675  -  0.054   +  0.059       False
# frac_deltaE_bkg1_0.2532            0.233626  -   0.15   +   0.15       False
# True
# Iteration 23 - Signal Yield: 148.23333338408014 ± 15.396991824435144
# Running iteration 24/300...
# 200
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9508                 148.786  -     15   +     16       False
# background_yield_0.9508             460.344  -     23   +     24       False
# frac_Mbc_bkg1_0.9508              0.0379342  -  0.057   +  0.057       False
# frac_deltaE_bkg1_0.9508            0.229639  -   0.15   +   0.15       False
# True
# Iteration 24 - Signal Yield: 148.78636292329153 ± 15.50412773842972
# Running iteration 25/300...
# 200
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9299                 148.916  -     15   +     16       False
# background_yield_0.9299              460.41  -     23   +     24       False
# frac_Mbc_bkg1_0.9299               0.038748  -  0.057   +  0.057       False
# frac_deltaE_bkg1_0.9299            0.223083  -   0.15   +   0.15       False
# True
# Iteration 25 - Signal Yield: 148.91574208108779 ± 15.428040842661972
# Running iteration 26/300...
# 200
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7058                 147.247  -     15   +     16       False
# background_yield_0.7058             461.997  -     23   +     24       False
# frac_Mbc_bkg1_0.7058              0.0444241  -  0.057   +  0.057       False
# frac_deltaE_bkg1_0.7058            0.240764  -   0.15   +   0.15       False
# True
# Iteration 26 - Signal Yield: 147.24706520524464 ± 15.545262304158719
# Running iteration 27/300...
# 200
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8779                 160.002  -     15   +     16       False
# background_yield_0.8779             450.003  -     23   +     23       False
# frac_Mbc_bkg1_0.8779            -0.00124375  -  0.057   +  0.057       False
# frac_deltaE_bkg1_0.8779            0.236537  -   0.15   +   0.15       False
# True
# Iteration 27 - Signal Yield: 160.00222479704587 ± 15.680319506408264
# Running iteration 28/300...
# 200
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1647                 148.321  -     15   +     16       False
# background_yield_0.1647             460.817  -     23   +     25       False
# frac_Mbc_bkg1_0.1647              0.0387693  -  0.057   +  0.057       False
# frac_deltaE_bkg1_0.1647             0.23414  -   0.15   +   0.15       False
# True
# Iteration 28 - Signal Yield: 148.32153068070014 ± 15.50651214007107
# Running iteration 29/300...
# 200
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1292                 144.814  -     15   +     16       False
# background_yield_0.1292             464.912  -     23   +     24       False
# frac_Mbc_bkg1_0.1292              0.0534331  -  0.057   +  0.057       False
# frac_deltaE_bkg1_0.1292            0.237075  -   0.15   +   0.15       False
# True
# Iteration 29 - Signal Yield: 144.81430097588452 ± 15.432156069797806
# Running iteration 30/300...
# 200
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7815                  159.65  -     15   +     16       False
# background_yield_0.7815             450.434  -     23   +     23       False
# frac_Mbc_bkg1_0.7815            -0.00581147  -  0.057   +  0.057       False
# frac_deltaE_bkg1_0.7815            0.222436  -   0.15   +   0.15       False
# True
# Iteration 30 - Signal Yield: 159.64976133659854 ± 15.66541732717765
# Running iteration 31/300...
# 200
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9408                  150.79  -     15   +     16       False
# background_yield_0.9408              458.36  -     22   +     24       False
# frac_Mbc_bkg1_0.9408              0.0361367  -  0.057   +  0.057       False
# frac_deltaE_bkg1_0.9408            0.226764  -   0.15   +   0.15       False
# True
# Iteration 31 - Signal Yield: 150.7895625078007 ± 15.504526251099506
# Running iteration 32/300...
# 200
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2127                 154.401  -     15   +     16       False
# background_yield_0.2127             455.549  -     23   +     24       False
# frac_Mbc_bkg1_0.2127              0.0157879  -  0.056   +  0.057       False
# frac_deltaE_bkg1_0.2127            0.200678  -   0.15   +   0.15       False
# True
# Iteration 32 - Signal Yield: 154.40131386911702 ± 15.416765448926485
# Running iteration 33/300...
# 200
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.982                 154.845  -     15   +     16       False
# background_yield_0.982             454.425  -     22   +     24       False
# frac_Mbc_bkg1_0.982              0.0194134  -  0.056   +  0.058       False
# frac_deltaE_bkg1_0.982            0.258132  -   0.15   +   0.15       False
# True
# Iteration 33 - Signal Yield: 154.84504619404896 ± 15.684832553362156
# Running iteration 34/300...
# 200
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0954                 155.296  -     15   +     16       False
# background_yield_0.0954             453.948  -     22   +     24       False
# frac_Mbc_bkg1_0.0954              0.0152676  -  0.056   +  0.058       False
# frac_deltaE_bkg1_0.0954            0.213017  -   0.15   +   0.15       False
# True
# Iteration 34 - Signal Yield: 155.29627508052053 ± 15.616251255449173
# Running iteration 35/300...
# ---------------------------------------------------------------------------
# NameAlreadyTakenError                     Traceback (most recent call last)
# /tmp/ipykernel_1884237/289603530.py in <module>
#      21
#      22     Mbc_bkg_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'bkg', mc_mu_bkg["Mbc"],  'argus_gauss', 0)
# ---> 23     deltaE_bkg_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'bkg',  mc_mu_bkg["deltaE"], 'poly', 0)
#      24
#      25     # Combine signal and background data
#
# /tmp/ipykernel_1884237/759158232.py in fit_fixed_without_weight(label, particle_type, dataset_name, mc_label_particle_type_dataset_name_data, model_type, q2_reg)
#     149
#     150         # Polynomial
# --> 151         coeff0_particle_type_label_dataset_name_poly = zfit.Parameter(f'coeff0_{particle_type}_{label}_{dataset_name}_poly_{r}', parameter_df[f"coeff0_{particle_type}_{label}_{dataset_name}_poly"].values[0],floating=False)
#     152         coeff1_particle_type_label_dataset_name_poly = zfit.Parameter(f'coeff1_{particle_type}_{label}_{dataset_name}_poly_{r}', parameter_df[f"coeff1_{particle_type}_{label}_{dataset_name}_poly"].values[0], floating=False)
#     153
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
#     155       del filtered_tb
#
# ~/.local/lib/python3.8/site-packages/zfit/core/parameter.py in __init__(self, name, value, lower, upper, step_size, floating, dtype, lower_limit, upper_limit)
#     416             )
#     417
# --> 418         super().__init__(
#     419             initial_value=value,
#     420             dtype=dtype,
#
# ~/.local/lib/python3.8/site-packages/zfit/core/parameter.py in __init__(self, name, **kwargs)
#     282     def __init__(self, name, **kwargs):
#     283         if name in self._existing_params:
# --> 284             raise NameAlreadyTakenError(
#     285                 "Another parameter is already named {}. "
#     286                 "Use a different, unique one.".format(name)
#
# NameAlreadyTakenError: Another parameter is already named coeff0_mu_deltaE_bkg_poly_0.9612. Use a different, unique one.

# %% [markdown]
# ## 150

# %%
# Number of iterations
num_iterations = 300

# List to store the signal yields and their errors from each iteration
signal_yields_and_errors = []

for i in range(num_iterations):
    print(f"Running iteration {i + 1}/{num_iterations}...")

    # Process the Monte Carlo data
    mc_mu_signal, mc_mu_only_signal, mc_mu_scf, mc_mu_bkg, mc_mu_signal_weight, mc_mu_only_signal_weight, mc_mu_scf_weight, mc_mu_bkg_weight = process_MC_data_combined(
        file_signal_mu_Bppi0,file_bkg_mu_Bppi0, 'mu', '521', 'pi0', 'mumu', 1, 'rec521', 'weights', 150
    )

    # Fit models for signal, SCF, and background
    Mbc_only_signal_cb_fixed = fit_fixed_without_weight('Mbc', 'mu', 'signal', mc_mu_only_signal["Mbc"], 'cb', 0)
    deltaE_only_signal_cb_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'signal', mc_mu_only_signal["deltaE"],  'cb_gauss', 0)

    Mbc_scf_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'scf', mc_mu_scf["Mbc"], 'argus_gauss', 0)
    deltaE_scf_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'scf', mc_mu_scf["deltaE"], 'poly_gauss', 0)

    Mbc_bkg_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'bkg', mc_mu_bkg["Mbc"], 'argus_gauss', 0)
    deltaE_bkg_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'bkg',  mc_mu_bkg["deltaE"], 'poly', 0)

    # Combine signal and background data
    Signal_Mbc = mc_mu_only_signal["Mbc"]
    Signal_deltaE = mc_mu_only_signal["deltaE"]
    Background_Mbc = pd.concat([mc_mu_scf["Mbc"], mc_mu_bkg["Mbc"]])
    Background_deltaE = pd.concat([mc_mu_scf["deltaE"], mc_mu_bkg["deltaE"]])

    Signal_total = pd.concat([Signal_Mbc, Signal_deltaE], axis=1)
    Background_total = pd.concat([Background_Mbc, Background_deltaE], axis=1)

    MC_signal=len(Signal_total)
    MC_bkg=len(Background_total)

    print(MC_signal)
    print(MC_bkg)
    
    # Fit the extended model and get the result
    Mbc_signal_pdf, deltaE_signal_pdf, Mbc_background_pdf, deltaE_background_pdf, signal_extended, background_extended, total_model, result = fit_extended_model_scf_without_weight(
        Mbc_only_signal_cb_fixed, Mbc_scf_argus_gauss_fixed, deltaE_only_signal_cb_gauss_fixed, deltaE_scf_poly_gauss_fixed,
        Mbc_bkg_argus_gauss_fixed, deltaE_bkg_poly_gauss_fixed,
        pd.concat([Signal_total, Background_total]), 0.5, 0.5, 100, 100
    )
    result.errors(name='errors')
    print(result.params)
    print(result.valid)

    # Retrieve and store the signal yield and its error
    signal_yield = result.params[signal_extended.get_yield()]['value']
    signal_yield_errors = result.params[signal_extended.get_yield()]['errors']
    signal_yield_error = (signal_yield_errors['upper'] - signal_yield_errors['lower']) / 2

    # Store the signal yield and error as a tuple in the list
    signal_yields_and_errors.append((MC_signal,MC_bkg,signal_yield, signal_yield_error))

    print(f"Iteration {i + 1} - Signal Yield: {signal_yield} ± {signal_yield_error}")

# Convert the list to a DataFrame with two columns: 'Signal_Yield' and 'Signal_Yield_Error'
signal_yields_df = pd.DataFrame(signal_yields_and_errors, columns=['MC_signal','MC_bkg','Signal_Yield', 'Signal_Yield_Error'])

# Save the DataFrame to a CSV file
signal_yields_df.to_csv('Bppi0_q2reg1_decay_mumu_signal_yields_and_errors_150.csv', index=False)

print("Signal yields and errors saved to 'Bppi0_q2reg1_decay_mumu_signal_yields_and_errors_150.csv'")
# Out:
# Running iteration 1/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9317                 116.204  -     13   +     14       False
# background_yield_0.9317             443.527  -     22   +     23       False
# frac_Mbc_bkg1_0.9317             -0.0259309  -  0.054   +  0.055       False
# frac_deltaE_bkg1_0.9317             0.23492  -   0.15   +   0.15       False
# True
# Iteration 1 - Signal Yield: 116.20445923360496 ± 13.588245581875775
# Running iteration 2/300...
# 150
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.033                  107.38  -     13   +     14       False
# background_yield_0.033              452.25  -     22   +     24       False
# frac_Mbc_bkg1_0.033             0.00754392  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.033            0.247573  -   0.15   +   0.15       False
# True
# Iteration 2 - Signal Yield: 107.37968885413275 ± 13.484536548879248
# Running iteration 3/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0834                 114.664  -     13   +     14       False
# background_yield_0.0834             445.009  -     22   +     23       False
# frac_Mbc_bkg1_0.0834             -0.0212158  -  0.055   +  0.056       False
# frac_deltaE_bkg1_0.0834             0.23561  -   0.15   +   0.15       False
# True
# Iteration 3 - Signal Yield: 114.6641611163952 ± 13.70344549756205
# Running iteration 4/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0471                 109.744  -     13   +     14       False
# background_yield_0.0471             449.871  -     22   +     24       False
# frac_Mbc_bkg1_0.0471            -0.00456735  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.0471            0.208792  -   0.15   +   0.15       False
# True
# Iteration 4 - Signal Yield: 109.74369350881777 ± 13.55914239570058
# Running iteration 5/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8976                 106.418  -     13   +     14       False
# background_yield_0.8976             453.222  -     22   +     24       False
# frac_Mbc_bkg1_0.8976              0.0126833  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.8976            0.234908  -   0.15   +   0.15       False
# True
# Iteration 5 - Signal Yield: 106.41828363029295 ± 13.401993374720673
# Running iteration 6/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8449                 121.337  -     13   +     14       False
# background_yield_0.8449             438.461  -     22   +     23       False
# frac_Mbc_bkg1_0.8449             -0.0415215  -  0.053   +  0.055       False
# frac_deltaE_bkg1_0.8449             0.18818  -   0.15   +   0.15       False
# True
# Iteration 6 - Signal Yield: 121.33689627714469 ± 13.596303376217406
# Running iteration 7/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8415                 124.067  -     13   +     14       False
# background_yield_0.8415              435.63  -     22   +     23       False
# frac_Mbc_bkg1_0.8415             -0.0552342  -  0.053   +  0.056       False
# frac_deltaE_bkg1_0.8415            0.241834  -   0.15   +   0.15       False
# True
# Iteration 7 - Signal Yield: 124.06665871405585 ± 13.831795472037197
# Running iteration 8/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9638                 115.947  -     13   +     14       False
# background_yield_0.9638             443.743  -     22   +     23       False
# frac_Mbc_bkg1_0.9638             -0.0286262  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.9638            0.244073  -   0.15   +   0.15       False
# True
# Iteration 8 - Signal Yield: 115.9465769209574 ± 13.602947504423488
# Running iteration 9/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5091                 114.199  -     13   +     14       False
# background_yield_0.5091             445.433  -     22   +     23       False
# frac_Mbc_bkg1_0.5091              -0.025586  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.5091            0.244655  -   0.15   +   0.15       False
# True
# Iteration 9 - Signal Yield: 114.19858074001722 ± 13.602047282358317
# Running iteration 10/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4244                 106.903  -     13   +     14       False
# background_yield_0.4244             452.766  -     22   +     24       False
# frac_Mbc_bkg1_0.4244             0.00983927  -  0.055   +  0.056       False
# frac_deltaE_bkg1_0.4244             0.26316  -   0.15   +   0.15       False
# True
# Iteration 10 - Signal Yield: 106.90284058018106 ± 13.541342126165208
# Running iteration 11/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2667                 113.284  -     13   +     14       False
# background_yield_0.2667              446.47  -     22   +     23       False
# frac_Mbc_bkg1_0.2667            -0.00923203  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.2667            0.244147  -   0.15   +   0.15       False
# True
# Iteration 11 - Signal Yield: 113.28447617670705 ± 13.671579000410164
# Running iteration 12/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8911                 111.033  -     13   +     14       False
# background_yield_0.8911             448.688  -     22   +     24       False
# frac_Mbc_bkg1_0.8911            -0.00297206  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.8911            0.256847  -   0.15   +   0.15       False
# True
# Iteration 12 - Signal Yield: 111.03295481633094 ± 13.61887446479146
# Running iteration 13/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3258                 113.895  -     13   +     14       False
# background_yield_0.3258             445.915  -     22   +     23       False
# frac_Mbc_bkg1_0.3258             -0.0161513  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.3258            0.242986  -   0.15   +   0.15       False
# True
# Iteration 13 - Signal Yield: 113.89511668413522 ± 13.534089583101402
# Running iteration 14/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0081                 117.314  -     13   +     14       False
# background_yield_0.0081             442.464  -     22   +     23       False
# frac_Mbc_bkg1_0.0081             -0.0298444  -  0.053   +  0.055       False
# frac_deltaE_bkg1_0.0081            0.204362  -   0.15   +   0.15       False
# True
# Iteration 14 - Signal Yield: 117.3138142561051 ± 13.471017587386893
# Running iteration 15/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1207                 115.293  -     13   +     14       False
# background_yield_0.1207             444.506  -     22   +     23       False
# frac_Mbc_bkg1_0.1207             -0.0173141  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.1207            0.248961  -   0.15   +   0.15       False
# True
# Iteration 15 - Signal Yield: 115.29344773377211 ± 13.674549848803707
# Running iteration 16/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6903                 115.933  -     13   +     14       False
# background_yield_0.6903             443.757  -     22   +     23       False
# frac_Mbc_bkg1_0.6903             -0.0299948  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.6903            0.229724  -   0.15   +   0.15       False
# True
# Iteration 16 - Signal Yield: 115.93247141297728 ± 13.546375022300538
# Running iteration 17/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8353                 118.982  -     13   +     14       False
# background_yield_0.8353             440.825  -     22   +     23       False
# frac_Mbc_bkg1_0.8353             -0.0305518  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.8353            0.191237  -   0.15   +   0.15       False
# True
# Iteration 17 - Signal Yield: 118.9816068136076 ± 13.724908019629577
# Running iteration 18/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3814                 112.938  -     13   +     14       False
# background_yield_0.3814             446.807  -     22   +     23       False
# frac_Mbc_bkg1_0.3814            -0.00753949  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.3814            0.230303  -   0.15   +   0.15       False
# True
# Iteration 18 - Signal Yield: 112.93815361795328 ± 13.572703189613453
# Running iteration 19/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7492                 113.541  -     13   +     14       False
# background_yield_0.7492             446.085  -     22   +     23       False
# frac_Mbc_bkg1_0.7492             -0.0175526  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.7492            0.220274  -   0.15   +   0.15       False
# True
# Iteration 19 - Signal Yield: 113.540768616001 ± 13.592808028678235
# Running iteration 20/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4592                  113.54  -     13   +     14       False
# background_yield_0.4592             446.223  -     22   +     23       False
# frac_Mbc_bkg1_0.4592             -0.0125808  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.4592             0.24418  -   0.15   +   0.15       False
# True
# Iteration 20 - Signal Yield: 113.54028407847314 ± 13.649927776305908
# Running iteration 21/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3635                  116.39  -     14   +     14       False
# background_yield_0.3635             443.296  -     22   +     24       False
# frac_Mbc_bkg1_0.3635             -0.0184797  -  0.055   +  0.056       False
# frac_deltaE_bkg1_0.3635            0.256966  -   0.15   +   0.15       False
# True
# Iteration 21 - Signal Yield: 116.39012760781007 ± 13.931240172377716
# Running iteration 22/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0154                 114.031  -     13   +     14       False
# background_yield_0.0154             445.609  -     22   +     23       False
# frac_Mbc_bkg1_0.0154             -0.0239812  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.0154            0.224597  -   0.15   +   0.15       False
# True
# Iteration 22 - Signal Yield: 114.03089857598682 ± 13.579389020253895
# Running iteration 23/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5886                 109.353  -     13   +     14       False
# background_yield_0.5886               451.1  -     23   +     23       False
# frac_Mbc_bkg1_0.5886             0.00384527  -  0.053   +  0.056       False
# frac_deltaE_bkg1_0.5886            0.205295  -   0.15   +   0.15       False
# True
# Iteration 23 - Signal Yield: 109.35313854096866 ± 13.43413295487757
# Running iteration 24/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8284                 108.395  -     13   +     14       False
# background_yield_0.8284              451.26  -     22   +     24       False
# frac_Mbc_bkg1_0.8284             0.00746536  -  0.055   +  0.057       False
# frac_deltaE_bkg1_0.8284            0.245061  -   0.15   +   0.15       False
# True
# Iteration 24 - Signal Yield: 108.39492666206706 ± 13.684621067477753
# Running iteration 25/300...
# 150
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.131                 110.876  -     13   +     14       False
# background_yield_0.131             448.834  -     22   +     23       False
# frac_Mbc_bkg1_0.131            -0.00322639  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.131            0.218663  -   0.15   +   0.15       False
# True
# Iteration 25 - Signal Yield: 110.8765271759264 ± 13.50896526688584
# Running iteration 26/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3103                  114.49  -     13   +     14       False
# background_yield_0.3103             445.159  -     22   +     23       False
# frac_Mbc_bkg1_0.3103             -0.0230754  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.3103            0.250116  -   0.15   +   0.15       False
# True
# Iteration 26 - Signal Yield: 114.49014424235901 ± 13.705159183570304
# Running iteration 27/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7694                 115.774  -     13   +     14       False
# background_yield_0.7694             443.978  -     22   +     23       False
# frac_Mbc_bkg1_0.7694             -0.0226409  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.7694            0.212696  -   0.15   +   0.15       False
# True
# Iteration 27 - Signal Yield: 115.77387480885187 ± 13.606451145375647
# Running iteration 28/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2061                 108.172  -     13   +     14       False
# background_yield_0.2061             451.407  -     22   +     24       False
# frac_Mbc_bkg1_0.2061            -0.00127347  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.2061            0.230028  -   0.15   +   0.15       False
# True
# Iteration 28 - Signal Yield: 108.17231508602265 ± 13.38095726364119
# Running iteration 29/300...
# 150
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.826                 103.546  -     13   +     14       False
# background_yield_0.826             456.444  -     23   +     23       False
# frac_Mbc_bkg1_0.826              0.0255905  -  0.054   +  0.055       False
# frac_deltaE_bkg1_0.826            0.219205  -   0.15   +   0.15       False
# True
# Iteration 29 - Signal Yield: 103.54648417082714 ± 13.327965258957924
# Running iteration 30/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2353                 117.423  -     13   +     14       False
# background_yield_0.2353             442.222  -     22   +     23       False
# frac_Mbc_bkg1_0.2353             -0.0351563  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.2353            0.235128  -   0.15   +   0.15       False
# True
# Iteration 30 - Signal Yield: 117.42309539114343 ± 13.684866271218636
# Running iteration 31/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9695                 115.796  -     13   +     14       False
# background_yield_0.9695             443.931  -     22   +     23       False
# frac_Mbc_bkg1_0.9695             -0.0170614  -  0.055   +  0.056       False
# frac_deltaE_bkg1_0.9695            0.254478  -   0.15   +   0.15       False
# True
# Iteration 31 - Signal Yield: 115.79595561681872 ± 13.766579494180185
# Running iteration 32/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4891                 119.208  -     13   +     14       False
# background_yield_0.4891             440.585  -     22   +     23       False
# frac_Mbc_bkg1_0.4891             -0.0410037  -  0.053   +  0.055       False
# frac_deltaE_bkg1_0.4891            0.188157  -   0.15   +   0.15       False
# True
# Iteration 32 - Signal Yield: 119.20764921101163 ± 13.444469940363682
# Running iteration 33/300...
# 150
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.338                 122.845  -     14   +     14       False
# background_yield_0.338             436.707  -     22   +     23       False
# frac_Mbc_bkg1_0.338             -0.0473264  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.338             0.26572  -   0.15   +   0.15       False
# True
# Iteration 33 - Signal Yield: 122.84471634963339 ± 14.017271978383501
# Running iteration 34/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4362                 114.051  -     13   +     14       False
# background_yield_0.4362             445.688  -     22   +     23       False
# frac_Mbc_bkg1_0.4362             -0.0151897  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.4362             0.20802  -   0.15   +   0.15       False
# True
# Iteration 34 - Signal Yield: 114.05088861546356 ± 13.565938194236711
# Running iteration 35/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1592                 113.413  -     13   +     14       False
# background_yield_0.1592             446.283  -     22   +     23       False
# frac_Mbc_bkg1_0.1592             -0.0173713  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.1592            0.198802  -   0.15   +   0.15       False
# True
# Iteration 35 - Signal Yield: 113.4126265934271 ± 13.449392631084471
# Running iteration 36/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4951                 111.603  -     13   +     14       False
# background_yield_0.4951             448.171  -     22   +     23       False
# frac_Mbc_bkg1_0.4951            -0.00507497  -  0.054   +  0.055       False
# frac_deltaE_bkg1_0.4951            0.227409  -   0.15   +   0.15       False
# True
# Iteration 36 - Signal Yield: 111.6031702871384 ± 13.440367377700497
# Running iteration 37/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0474                 113.459  -     13   +     14       False
# background_yield_0.0474             446.212  -     22   +     23       False
# frac_Mbc_bkg1_0.0474             -0.0227469  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.0474            0.224639  -   0.15   +   0.15       False
# True
# Iteration 37 - Signal Yield: 113.4586663881352 ± 13.50870545709066
# Running iteration 38/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2778                   112.6  -     13   +     14       False
# background_yield_0.2778             447.077  -     22   +     23       False
# frac_Mbc_bkg1_0.2778             -0.0130323  -  0.054   +  0.055       False
# frac_deltaE_bkg1_0.2778            0.180379  -   0.15   +   0.15       False
# True
# Iteration 38 - Signal Yield: 112.59991037233333 ± 13.450016766534624
# Running iteration 39/300...
# 150
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.117                 106.073  -     13   +     14       False
# background_yield_0.117             453.532  -     22   +     24       False
# frac_Mbc_bkg1_0.117              0.0140355  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.117             0.23675  -   0.15   +   0.15       False
# True
# Iteration 39 - Signal Yield: 106.0725684484334 ± 13.418773505953611
# Running iteration 40/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8468                  108.11  -     13   +     14       False
# background_yield_0.8468             451.483  -     22   +     24       False
# frac_Mbc_bkg1_0.8468             0.00274868  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.8468            0.226794  -   0.15   +   0.15       False
# True
# Iteration 40 - Signal Yield: 108.11040824271375 ± 13.507060684477157
# Running iteration 41/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3881                 113.734  -     13   +     14       False
# background_yield_0.3881             446.043  -     22   +     23       False
# frac_Mbc_bkg1_0.3881             -0.0154408  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.3881            0.220059  -   0.15   +   0.15       False
# True
# Iteration 41 - Signal Yield: 113.73395551600733 ± 13.55895535343371
# Running iteration 42/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5907                 119.394  -     13   +     14       False
# background_yield_0.5907             440.227  -     22   +     23       False
# frac_Mbc_bkg1_0.5907             -0.0371712  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.5907            0.217785  -   0.15   +   0.15       False
# True
# Iteration 42 - Signal Yield: 119.39389557052344 ± 13.776410003585806
# Running iteration 43/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8486                 116.498  -     13   +     14       False
# background_yield_0.8486              443.18  -     22   +     23       False
# frac_Mbc_bkg1_0.8486             -0.0307961  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.8486            0.209892  -   0.15   +   0.15       False
# True
# Iteration 43 - Signal Yield: 116.4974613720148 ± 13.600551969038397
# Running iteration 44/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4577                 115.185  -     13   +     14       False
# background_yield_0.4577             444.628  -     22   +     23       False
# frac_Mbc_bkg1_0.4577             -0.0183306  -  0.053   +  0.055       False
# frac_deltaE_bkg1_0.4577            0.198723  -   0.15   +   0.15       False
# True
# Iteration 44 - Signal Yield: 115.1847345302269 ± 13.49090655080564
# Running iteration 45/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3248                 110.592  -     13   +     14       False
# background_yield_0.3248             449.091  -     22   +     23       False
# frac_Mbc_bkg1_0.3248            -0.00789245  -  0.054   +  0.055       False
# frac_deltaE_bkg1_0.3248            0.244152  -   0.15   +   0.15       False
# True
# Iteration 45 - Signal Yield: 110.5915858525173 ± 13.361807434712414
# Running iteration 46/300...
# 150
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.004                 120.686  -     13   +     14       False
# background_yield_0.004             439.124  -     22   +     23       False
# frac_Mbc_bkg1_0.004             -0.0380505  -  0.054   +  0.055       False
# frac_deltaE_bkg1_0.004            0.252386  -   0.15   +   0.15       False
# True
# Iteration 46 - Signal Yield: 120.6861173580491 ± 13.716094583608815
# Running iteration 47/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0199                 111.453  -     13   +     14       False
# background_yield_0.0199             448.199  -     22   +     24       False
# frac_Mbc_bkg1_0.0199            -0.00848972  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.0199            0.224418  -   0.15   +   0.15       False
# True
# Iteration 47 - Signal Yield: 111.45308304604922 ± 13.516570566795007
# Running iteration 48/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6957                 113.815  -     13   +     14       False
# background_yield_0.6957             445.914  -     22   +     23       False
# frac_Mbc_bkg1_0.6957             -0.0124036  -  0.055   +  0.056       False
# frac_deltaE_bkg1_0.6957             0.23205  -   0.15   +   0.15       False
# True
# Iteration 48 - Signal Yield: 113.81495986491153 ± 13.709897018228522
# Running iteration 49/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6348                 116.122  -     13   +     14       False
# background_yield_0.6348             443.646  -     22   +     23       False
# frac_Mbc_bkg1_0.6348             -0.0289247  -  0.053   +  0.055       False
# frac_deltaE_bkg1_0.6348            0.198934  -   0.15   +   0.15       False
# True
# Iteration 49 - Signal Yield: 116.12177501277391 ± 13.390281789877854
# Running iteration 50/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6915                 113.629  -     13   +     14       False
# background_yield_0.6915             446.143  -     22   +     23       False
# frac_Mbc_bkg1_0.6915             -0.0157592  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.6915            0.224907  -   0.15   +   0.15       False
# True
# Iteration 50 - Signal Yield: 113.62887022687676 ± 13.559618722432319
# Running iteration 51/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8712                 116.435  -     13   +     14       False
# background_yield_0.8712             443.242  -     22   +     23       False
# frac_Mbc_bkg1_0.8712             -0.0278025  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.8712            0.253142  -   0.15   +   0.15       False
# True
# Iteration 51 - Signal Yield: 116.43533116692099 ± 13.74186166319506
# Running iteration 52/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2879                 115.165  -     13   +     14       False
# background_yield_0.2879             444.551  -     22   +     23       False
# frac_Mbc_bkg1_0.2879             -0.0247015  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.2879             0.24003  -   0.15   +   0.15       False
# True
# Iteration 52 - Signal Yield: 115.16508051456381 ± 13.605463190433746
# Running iteration 53/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6083                 116.591  -     13   +     14       False
# background_yield_0.6083             443.116  -     22   +     23       False
# frac_Mbc_bkg1_0.6083             -0.0352296  -  0.053   +  0.055       False
# frac_deltaE_bkg1_0.6083             0.21763  -   0.15   +   0.15       False
# True
# Iteration 53 - Signal Yield: 116.5915185446842 ± 13.45566189355855
# Running iteration 54/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2366                 108.264  -     13   +     14       False
# background_yield_0.2366             451.474  -     22   +     24       False
# frac_Mbc_bkg1_0.2366             0.00956375  -  0.054   +  0.055       False
# frac_deltaE_bkg1_0.2366            0.252188  -   0.15   +   0.15       False
# True
# Iteration 54 - Signal Yield: 108.2640826086977 ± 13.392119611604421
# Running iteration 55/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1239                 114.335  -     13   +     14       False
# background_yield_0.1239             445.435  -     22   +     23       False
# frac_Mbc_bkg1_0.1239             -0.0207464  -  0.053   +  0.055       False
# frac_deltaE_bkg1_0.1239            0.226488  -   0.15   +   0.15       False
# True
# Iteration 55 - Signal Yield: 114.33457695698426 ± 13.426447204897961
# Running iteration 56/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0155                 115.116  -     13   +     14       False
# background_yield_0.0155             444.632  -     22   +     23       False
# frac_Mbc_bkg1_0.0155             -0.0194444  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.0155            0.209755  -   0.15   +   0.15       False
# True
# Iteration 56 - Signal Yield: 115.11585774879102 ± 13.663549498733598
# Running iteration 57/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5907                 119.175  -     13   +     14       False
# background_yield_0.5907             440.521  -     22   +     23       False
# frac_Mbc_bkg1_0.5907             -0.0391473  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.5907            0.203362  -   0.15   +   0.15       False
# True
# Iteration 57 - Signal Yield: 119.1749163843707 ± 13.650897103426217
# Running iteration 58/300...
# 150
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.579                 120.172  -     13   +     14       False
# background_yield_0.579             439.536  -     22   +     23       False
# frac_Mbc_bkg1_0.579             -0.0443397  -  0.053   +  0.056       False
# frac_deltaE_bkg1_0.579            0.236517  -   0.15   +   0.15       False
# True
# Iteration 58 - Signal Yield: 120.1717866888055 ± 13.701436072293724
# Running iteration 59/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3356                   112.1  -     13   +     14       False
# background_yield_0.3356             447.606  -     22   +     24       False
# frac_Mbc_bkg1_0.3356            -0.00928983  -  0.055   +  0.056       False
# frac_deltaE_bkg1_0.3356            0.239826  -   0.15   +   0.15       False
# True
# Iteration 59 - Signal Yield: 112.09991036853995 ± 13.63447861832211
# Running iteration 60/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9212                 116.295  -     13   +     14       False
# background_yield_0.9212             443.406  -     22   +     23       False
# frac_Mbc_bkg1_0.9212             -0.0326905  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.9212            0.245737  -   0.15   +   0.15       False
# True
# Iteration 60 - Signal Yield: 116.29533655866491 ± 13.562372331363086
# Running iteration 61/300...
# 150
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.727                 112.842  -     13   +     14       False
# background_yield_0.727             446.887  -     22   +     23       False
# frac_Mbc_bkg1_0.727              -0.012827  -  0.053   +  0.055       False
# frac_deltaE_bkg1_0.727            0.206252  -   0.15   +   0.15       False
# True
# Iteration 61 - Signal Yield: 112.84228801233783 ± 13.41321341586021
# Running iteration 62/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7157                 108.702  -     13   +     14       False
# background_yield_0.7157             451.752  -     23   +     23       False
# frac_Mbc_bkg1_0.7157             0.00538389  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.7157            0.237015  -   0.15   +   0.15       False
# True
# Iteration 62 - Signal Yield: 108.70213524878055 ± 13.510855800188862
# Running iteration 63/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6496                 119.044  -     13   +     14       False
# background_yield_0.6496             440.694  -     22   +     23       False
# frac_Mbc_bkg1_0.6496             -0.0371312  -  0.053   +  0.055       False
# frac_deltaE_bkg1_0.6496            0.197202  -   0.15   +   0.15       False
# True
# Iteration 63 - Signal Yield: 119.0444313572562 ± 13.620964177492485
# Running iteration 64/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1125                 111.323  -     13   +     14       False
# background_yield_0.1125             448.405  -     22   +     23       False
# frac_Mbc_bkg1_0.1125             -0.0044311  -  0.054   +  0.055       False
# frac_deltaE_bkg1_0.1125            0.240994  -   0.15   +   0.15       False
# True
# Iteration 64 - Signal Yield: 111.32286001838081 ± 13.485607578799897
# Running iteration 65/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3602                 115.677  -     13   +     14       False
# background_yield_0.3602             444.128  -     22   +     23       False
# frac_Mbc_bkg1_0.3602              -0.021688  -  0.054   +  0.055       False
# frac_deltaE_bkg1_0.3602            0.202366  -   0.15   +   0.15       False
# True
# Iteration 65 - Signal Yield: 115.67667753984921 ± 13.48151821783637
# Running iteration 66/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4499                 109.146  -     13   +     14       False
# background_yield_0.4499             450.482  -     22   +     24       False
# frac_Mbc_bkg1_0.4499             -0.0032393  -  0.055   +  0.056       False
# frac_deltaE_bkg1_0.4499             0.27445  -   0.15   +   0.15       False
# True
# Iteration 66 - Signal Yield: 109.14556018068305 ± 13.540828889057039
# Running iteration 67/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7722                 112.815  -     13   +     14       False
# background_yield_0.7722             446.929  -     22   +     23       False
# frac_Mbc_bkg1_0.7722             -0.0062522  -  0.055   +  0.056       False
# frac_deltaE_bkg1_0.7722            0.252036  -   0.15   +   0.15       False
# True
# Iteration 67 - Signal Yield: 112.81536844036393 ± 13.712856557840112
# Running iteration 68/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5156                 111.611  -     13   +     14       False
# background_yield_0.5156                 448  -     22   +     24       False
# frac_Mbc_bkg1_0.5156             -0.0110978  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.5156            0.215059  -   0.15   +   0.15       False
# True
# Iteration 68 - Signal Yield: 111.61068335333961 ± 13.563652629756973
# Running iteration 69/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2008                 105.296  -     13   +     14       False
# background_yield_0.2008             454.343  -     22   +     24       False
# frac_Mbc_bkg1_0.2008              0.0180186  -  0.055   +  0.057       False
# frac_deltaE_bkg1_0.2008            0.257259  -   0.15   +   0.15       False
# True
# Iteration 69 - Signal Yield: 105.29621139580935 ± 13.634416893002548
# Running iteration 70/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6354                 113.198  -     13   +     14       False
# background_yield_0.6354             446.532  -     22   +     23       False
# frac_Mbc_bkg1_0.6354             -0.0124583  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.6354            0.217628  -   0.15   +   0.15       False
# True
# Iteration 70 - Signal Yield: 113.1976367498615 ± 13.561345453355216
# Running iteration 71/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4502                 114.264  -     13   +     14       False
# background_yield_0.4502             445.399  -     22   +     24       False
# frac_Mbc_bkg1_0.4502             -0.0123064  -  0.055   +  0.056       False
# frac_deltaE_bkg1_0.4502            0.234128  -   0.15   +   0.15       False
# True
# Iteration 71 - Signal Yield: 114.2642859931653 ± 13.833396287754432
# Running iteration 72/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1199                 111.343  -     13   +     14       False
# background_yield_0.1199             448.396  -     22   +     23       False
# frac_Mbc_bkg1_0.1199            -0.00426369  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.1199            0.223829  -   0.15   +   0.15       False
# True
# Iteration 72 - Signal Yield: 111.34263452149864 ± 13.471541309893926
# Running iteration 73/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4047                 121.213  -     13   +     14       False
# background_yield_0.4047             438.505  -     22   +     23       False
# frac_Mbc_bkg1_0.4047             -0.0487336  -  0.053   +  0.055       False
# frac_deltaE_bkg1_0.4047            0.217593  -   0.15   +   0.15       False
# True
# Iteration 73 - Signal Yield: 121.21313588376934 ± 13.599198964288249
# Running iteration 74/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5973                 112.528  -     13   +     14       False
# background_yield_0.5973             447.219  -     22   +     23       False
# frac_Mbc_bkg1_0.5973            -0.00649937  -  0.055   +  0.056       False
# frac_deltaE_bkg1_0.5973            0.234559  -   0.15   +   0.15       False
# True
# Iteration 74 - Signal Yield: 112.52849045538773 ± 13.692366415899553
# Running iteration 75/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8986                 110.685  -     13   +     14       False
# background_yield_0.8986             449.035  -     22   +     23       False
# frac_Mbc_bkg1_0.8986            -0.00299546  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.8986            0.240045  -   0.15   +   0.15       False
# True
# Iteration 75 - Signal Yield: 110.68506973640483 ± 13.515103709689452
# Running iteration 76/300...
# 150
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.541                 115.436  -     13   +     14       False
# background_yield_0.541             444.277  -     22   +     23       False
# frac_Mbc_bkg1_0.541             -0.0252422  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.541            0.236173  -   0.15   +   0.15       False
# True
# Iteration 76 - Signal Yield: 115.43617299315525 ± 13.63422205905428
# Running iteration 77/300...
# 150
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.454                 118.894  -     13   +     14       False
# background_yield_0.454             440.859  -     22   +     23       False
# frac_Mbc_bkg1_0.454             -0.0329543  -  0.053   +  0.056       False
# frac_deltaE_bkg1_0.454            0.193117  -   0.15   +   0.15       False
# True
# Iteration 77 - Signal Yield: 118.89346311807209 ± 13.647253142155385
# Running iteration 78/300...
# 150
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.461                 116.111  -     13   +     14       False
# background_yield_0.461             443.666  -     22   +     23       False
# frac_Mbc_bkg1_0.461             -0.0232814  -  0.053   +  0.055       False
# frac_deltaE_bkg1_0.461            0.215374  -   0.15   +   0.15       False
# True
# Iteration 78 - Signal Yield: 116.1108624353264 ± 13.504005824402755
# Running iteration 79/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9152                     116  -     13   +     14       False
# background_yield_0.9152             443.669  -     22   +     23       False
# frac_Mbc_bkg1_0.9152             -0.0300939  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.9152            0.214636  -   0.15   +   0.15       False
# True
# Iteration 79 - Signal Yield: 115.99992752369263 ± 13.606005602190752
# Running iteration 80/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4089                 109.456  -     13   +     14       False
# background_yield_0.4089             450.174  -     22   +     24       False
# frac_Mbc_bkg1_0.4089            -0.00202634  -  0.054   +  0.055       False
# frac_deltaE_bkg1_0.4089            0.198365  -   0.15   +   0.15       False
# True
# Iteration 80 - Signal Yield: 109.45593281247218 ± 13.421762924294178
# Running iteration 81/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9409                 119.473  -     13   +     14       False
# background_yield_0.9409             440.139  -     22   +     23       False
# frac_Mbc_bkg1_0.9409             -0.0439435  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.9409            0.219226  -   0.15   +   0.15       False
# True
# Iteration 81 - Signal Yield: 119.47263707144646 ± 13.726912467894032
# Running iteration 82/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0695                 115.949  -     13   +     14       False
# background_yield_0.0695              443.87  -     22   +     23       False
# frac_Mbc_bkg1_0.0695             -0.0199794  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.0695            0.254629  -   0.15   +   0.15       False
# True
# Iteration 82 - Signal Yield: 115.94881831323829 ± 13.729399500417113
# Running iteration 83/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7494                 115.097  -     13   +     14       False
# background_yield_0.7494             444.633  -     22   +     23       False
# frac_Mbc_bkg1_0.7494              -0.018443  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.7494            0.207123  -   0.15   +   0.15       False
# True
# Iteration 83 - Signal Yield: 115.09754379260345 ± 13.589650555967644
# Running iteration 84/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3093                 117.666  -     13   +     14       False
# background_yield_0.3093             441.953  -     22   +     23       False
# frac_Mbc_bkg1_0.3093             -0.0371582  -  0.054   +  0.055       False
# frac_deltaE_bkg1_0.3093            0.226096  -   0.15   +   0.15       False
# True
# Iteration 84 - Signal Yield: 117.66633901375819 ± 13.602332014205118
# Running iteration 85/300...
# 150
# 410
# ...
# signal_yield_0.8155                 120.097  -     13   +     14       False
# background_yield_0.8155             439.662  -     22   +     23       False
# frac_Mbc_bkg1_0.8155             -0.0361334  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.8155            0.225684  -   0.15   +   0.15       False
# True
# Iteration 273 - Signal Yield: 120.09698555051541 ± 13.72359342566184
# Running iteration 274/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9133                 108.446  -     13   +     14       False
# background_yield_0.9133             451.215  -     22   +     24       False
# frac_Mbc_bkg1_0.9133              0.0068939  -  0.054   +  0.055       False
# frac_deltaE_bkg1_0.9133            0.215015  -   0.15   +   0.15       False
# True
# Iteration 274 - Signal Yield: 108.44584508687032 ± 13.361282213514302
# Running iteration 275/300...
# 150
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.088                 116.144  -     13   +     14       False
# background_yield_0.088             443.648  -     22   +     23       False
# frac_Mbc_bkg1_0.088             -0.0232881  -  0.053   +  0.055       False
# frac_deltaE_bkg1_0.088            0.210346  -   0.15   +   0.15       False
# True
# Iteration 275 - Signal Yield: 116.14384722832162 ± 13.431080050955842
# Running iteration 276/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0512                 117.722  -     13   +     14       False
# background_yield_0.0512             442.097  -     22   +     23       False
# frac_Mbc_bkg1_0.0512             -0.0299593  -  0.053   +  0.055       False
# frac_deltaE_bkg1_0.0512            0.234555  -   0.15   +   0.15       False
# True
# Iteration 276 - Signal Yield: 117.72220414883462 ± 13.56507186893312
# Running iteration 277/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2464                 117.572  -     13   +     14       False
# background_yield_0.2464             442.147  -     22   +     23       False
# frac_Mbc_bkg1_0.2464             -0.0373776  -  0.053   +  0.055       False
# frac_deltaE_bkg1_0.2464            0.228796  -   0.15   +   0.15       False
# True
# Iteration 277 - Signal Yield: 117.5718489651464 ± 13.462119426521456
# Running iteration 278/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0829                 113.012  -     13   +     14       False
# background_yield_0.0829             446.658  -     22   +     24       False
# frac_Mbc_bkg1_0.0829             -0.0140801  -  0.055   +  0.056       False
# frac_deltaE_bkg1_0.0829            0.258104  -   0.15   +   0.15       False
# True
# Iteration 278 - Signal Yield: 113.01199155133251 ± 13.66017796852952
# Running iteration 279/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1631                 119.294  -     13   +     14       False
# background_yield_0.1631             440.501  -     22   +     23       False
# frac_Mbc_bkg1_0.1631             -0.0334498  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.1631            0.234307  -   0.15   +   0.15       False
# True
# Iteration 279 - Signal Yield: 119.29437988224129 ± 13.762807149159473
# Running iteration 280/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9597                 106.807  -     13   +     14       False
# background_yield_0.9597             452.777  -     22   +     24       False
# frac_Mbc_bkg1_0.9597             0.00345202  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.9597            0.250763  -   0.15   +   0.15       False
# True
# Iteration 280 - Signal Yield: 106.80733688505993 ± 13.347494382864795
# Running iteration 281/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4125                 119.344  -     13   +     14       False
# background_yield_0.4125              440.33  -     22   +     23       False
# frac_Mbc_bkg1_0.4125             -0.0408594  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.4125            0.223445  -   0.15   +   0.15       False
# True
# Iteration 281 - Signal Yield: 119.34367794123392 ± 13.730958101763857
# Running iteration 282/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1662                  110.11  -     13   +     14       False
# background_yield_0.1662             449.685  -     22   +     24       False
# frac_Mbc_bkg1_0.1662              0.0087213  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.1662            0.224906  -   0.15   +   0.15       False
# True
# Iteration 282 - Signal Yield: 110.10992398406525 ± 13.628054717656529
# Running iteration 283/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1844                 109.707  -     13   +     14       False
# background_yield_0.1844             449.976  -     22   +     23       False
# frac_Mbc_bkg1_0.1844            0.000198101  -  0.054   +  0.055       False
# frac_deltaE_bkg1_0.1844            0.220712  -   0.15   +   0.15       False
# True
# Iteration 283 - Signal Yield: 109.70727592182564 ± 13.38104960089209
# Running iteration 284/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8863                 112.355  -     13   +     14       False
# background_yield_0.8863             447.349  -     22   +     23       False
# frac_Mbc_bkg1_0.8863             -0.0110653  -  0.053   +  0.055       False
# frac_deltaE_bkg1_0.8863            0.242172  -   0.15   +   0.15       False
# True
# Iteration 284 - Signal Yield: 112.35537502727746 ± 13.43690074993306
# Running iteration 285/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4745                 112.942  -     13   +     14       False
# background_yield_0.4745             446.781  -     22   +     23       False
# frac_Mbc_bkg1_0.4745             -0.0170668  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.4745            0.246949  -   0.15   +   0.15       False
# True
# Iteration 285 - Signal Yield: 112.94170761903091 ± 13.603901115925623
# Running iteration 286/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3373                 116.489  -     13   +     14       False
# background_yield_0.3373             443.289  -     22   +     23       False
# frac_Mbc_bkg1_0.3373              -0.025693  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.3373            0.259713  -   0.15   +   0.15       False
# True
# Iteration 286 - Signal Yield: 116.48904015861258 ± 13.664374557389399
# Running iteration 287/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4332                 118.334  -     13   +     14       False
# background_yield_0.4332             441.423  -     22   +     23       False
# frac_Mbc_bkg1_0.4332             -0.0279912  -  0.054   +  0.055       False
# frac_deltaE_bkg1_0.4332            0.212764  -   0.15   +   0.15       False
# True
# Iteration 287 - Signal Yield: 118.33424928183018 ± 13.67542522855846
# Running iteration 288/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9004                 116.274  -     13   +     14       False
# background_yield_0.9004             443.421  -     22   +     23       False
# frac_Mbc_bkg1_0.9004             -0.0255478  -  0.054   +  0.055       False
# frac_deltaE_bkg1_0.9004            0.214747  -   0.15   +   0.15       False
# True
# Iteration 288 - Signal Yield: 116.2736642617229 ± 13.580476766153197
# Running iteration 289/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5296                  110.54  -     13   +     13       False
# background_yield_0.5296             449.161  -     22   +     23       False
# frac_Mbc_bkg1_0.5296            -0.00250733  -  0.053   +  0.055       False
# frac_deltaE_bkg1_0.5296            0.189715  -   0.15   +   0.15       False
# True
# Iteration 289 - Signal Yield: 110.54006454910132 ± 13.194929917111978
# Running iteration 290/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8466                 111.203  -     13   +     14       False
# background_yield_0.8466             448.599  -     22   +     23       False
# frac_Mbc_bkg1_0.8466            0.000508461  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.8466            0.238254  -   0.15   +   0.15       False
# True
# Iteration 290 - Signal Yield: 111.2032172306123 ± 13.580729173470727
# Running iteration 291/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1008                 108.204  -     13   +     14       False
# background_yield_0.1008             451.393  -     22   +     24       False
# frac_Mbc_bkg1_0.1008            0.000720187  -  0.053   +  0.056       False
# frac_deltaE_bkg1_0.1008            0.212059  -   0.15   +   0.15       False
# True
# Iteration 291 - Signal Yield: 108.20447080549727 ± 13.305985792139307
# Running iteration 292/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3484                 111.699  -     13   +     14       False
# background_yield_0.3484             447.978  -     22   +     24       False
# frac_Mbc_bkg1_0.3484             -0.0103545  -  0.055   +  0.056       False
# frac_deltaE_bkg1_0.3484            0.255744  -   0.15   +   0.15       False
# True
# Iteration 292 - Signal Yield: 111.69863556355857 ± 13.66077006033519
# Running iteration 293/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0721                 112.978  -     13   +     14       False
# background_yield_0.0721              446.76  -     22   +     23       False
# frac_Mbc_bkg1_0.0721             -0.0115866  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.0721            0.214797  -   0.15   +   0.15       False
# True
# Iteration 293 - Signal Yield: 112.97819827851805 ± 13.540544194667767
# Running iteration 294/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3689                 112.273  -     13   +     14       False
# background_yield_0.3689             447.441  -     22   +     23       False
# frac_Mbc_bkg1_0.3689             -0.0119871  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.3689            0.203345  -   0.15   +   0.15       False
# True
# Iteration 294 - Signal Yield: 112.27280642545401 ± 13.436049509830276
# Running iteration 295/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9707                 118.987  -     13   +     14       False
# background_yield_0.9707             440.796  -     22   +     23       False
# frac_Mbc_bkg1_0.9707             -0.0306544  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.9707            0.212648  -   0.15   +   0.15       False
# True
# Iteration 295 - Signal Yield: 118.98737626880799 ± 13.74395811921079
# Running iteration 296/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7562                 117.048  -     13   +     14       False
# background_yield_0.7562             442.696  -     22   +     23       False
# frac_Mbc_bkg1_0.7562             -0.0337633  -  0.053   +  0.055       False
# frac_deltaE_bkg1_0.7562            0.204205  -   0.15   +   0.15       False
# True
# Iteration 296 - Signal Yield: 117.04795681976046 ± 13.45982718853696
# Running iteration 297/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0842                 108.786  -     13   +     14       False
# background_yield_0.0842             450.892  -     22   +     24       False
# frac_Mbc_bkg1_0.0842              0.0058079  -  0.054   +  0.055       False
# frac_deltaE_bkg1_0.0842            0.226998  -   0.15   +   0.15       False
# True
# Iteration 297 - Signal Yield: 108.78621539963115 ± 13.352382738098346
# Running iteration 298/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8253                 118.271  -     13   +     14       False
# background_yield_0.8253             441.434  -     22   +     23       False
# frac_Mbc_bkg1_0.8253             -0.0371399  -  0.054   +  0.055       False
# frac_deltaE_bkg1_0.8253            0.204902  -   0.15   +   0.15       False
# True
# Iteration 298 - Signal Yield: 118.27091816971749 ± 13.5669932143128
# Running iteration 299/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8163                  113.49  -     13   +     14       False
# background_yield_0.8163             446.171  -     22   +     24       False
# frac_Mbc_bkg1_0.8163             -0.0110234  -  0.055   +  0.056       False
# frac_deltaE_bkg1_0.8163            0.218302  -   0.15   +   0.15       False
# True
# Iteration 299 - Signal Yield: 113.49045229717424 ± 13.743334874386669
# Running iteration 300/300...
# 150
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6628                 112.178  -     13   +     14       False
# background_yield_0.6628              447.51  -     22   +     24       False
# frac_Mbc_bkg1_0.6628             -0.0101947  -  0.054   +  0.056       False
# frac_deltaE_bkg1_0.6628            0.225337  -   0.15   +   0.15       False
# True
# Iteration 300 - Signal Yield: 112.17814491277535 ± 13.608655829835847
# Signal yields and errors saved to 'Bppi0_q2reg1_decay_mumu_signal_yields_and_errors_150.csv'

# %% [markdown]
# ## 100

# %%
# Number of iterations
num_iterations = 300

# List to store the signal yields and their errors from each iteration
signal_yields_and_errors = []

for i in range(num_iterations):
    print(f"Running iteration {i + 1}/{num_iterations}...")

    # Process the Monte Carlo data
    mc_mu_signal, mc_mu_only_signal, mc_mu_scf, mc_mu_bkg, mc_mu_signal_weight, mc_mu_only_signal_weight, mc_mu_scf_weight, mc_mu_bkg_weight = process_MC_data_combined(
        file_signal_mu_Bppi0,file_bkg_mu_Bppi0, 'mu', '521', 'pi0', 'mumu', 1, 'rec521', 'weights', 100
    )

    # Fit models for signal, SCF, and background
    Mbc_only_signal_cb_fixed = fit_fixed_without_weight('Mbc', 'mu', 'signal', mc_mu_only_signal["Mbc"], 'cb', 0)
    deltaE_only_signal_cb_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'signal', mc_mu_only_signal["deltaE"],  'cb_gauss', 0)

    Mbc_scf_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'scf', mc_mu_scf["Mbc"], 'argus_gauss', 0)
    deltaE_scf_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'scf', mc_mu_scf["deltaE"], 'poly_gauss', 0)

    Mbc_bkg_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'bkg', mc_mu_bkg["Mbc"], 'argus_gauss', 0)
    deltaE_bkg_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'bkg', mc_mu_bkg["deltaE"], 'poly', 0)

    # Combine signal and background data
    Signal_Mbc = mc_mu_only_signal["Mbc"]
    Signal_deltaE = mc_mu_only_signal["deltaE"]
    Background_Mbc = pd.concat([mc_mu_scf["Mbc"], mc_mu_bkg["Mbc"]])
    Background_deltaE = pd.concat([mc_mu_scf["deltaE"], mc_mu_bkg["deltaE"]])

    Signal_total = pd.concat([Signal_Mbc, Signal_deltaE], axis=1)
    Background_total = pd.concat([Background_Mbc, Background_deltaE], axis=1)

    MC_signal=len(Signal_total)
    MC_bkg=len(Background_total)

    print(MC_signal)
    print(MC_bkg)
    
    # Fit the extended model and get the result
    Mbc_signal_pdf, deltaE_signal_pdf, Mbc_background_pdf, deltaE_background_pdf, signal_extended, background_extended, total_model, result = fit_extended_model_scf_without_weight(
        Mbc_only_signal_cb_fixed, Mbc_scf_argus_gauss_fixed, deltaE_only_signal_cb_gauss_fixed, deltaE_scf_poly_gauss_fixed,
        Mbc_bkg_argus_gauss_fixed, deltaE_bkg_poly_gauss_fixed,
        pd.concat([Signal_total, Background_total]), 0.5, 0.5, 100, 100
    )
    result.errors(name='errors')
    print(result.params)
    print(result.valid)

    # Retrieve and store the signal yield and its error
    signal_yield = result.params[signal_extended.get_yield()]['value']
    signal_yield_errors = result.params[signal_extended.get_yield()]['errors']
    signal_yield_error = (signal_yield_errors['upper'] - signal_yield_errors['lower']) / 2

    # Store the signal yield and error as a tuple in the list
    signal_yields_and_errors.append((MC_signal,MC_bkg,signal_yield, signal_yield_error))

    print(f"Iteration {i + 1} - Signal Yield: {signal_yield} ± {signal_yield_error}")

# Convert the list to a DataFrame with two columns: 'Signal_Yield' and 'Signal_Yield_Error'
signal_yields_df = pd.DataFrame(signal_yields_and_errors, columns=['MC_signal','MC_bkg','Signal_Yield', 'Signal_Yield_Error'])


# Save the DataFrame to a CSV file
signal_yields_df.to_csv('Bppi0_q2reg1_decay_mumu_signal_yields_and_errors_100.csv', index=False)

print("Signal yields and errors saved to 'Bppi0_q2reg1_decay_mumu_signal_yields_and_errors_100.csv'")
# Out:
# Running iteration 1/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8214                 83.1887  -     11   +     12       False
# background_yield_0.8214              426.92  -     22   +     22       False
# frac_Mbc_bkg1_0.8214             -0.0926163  -  0.049   +  0.052       False
# frac_deltaE_bkg1_0.8214            0.228452  -   0.15   +   0.15       False
# True
# Iteration 1 - Signal Yield: 83.1887236524625 ± 11.379419764075056
# Running iteration 2/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8455                 66.9746  -     11   +     11       False
# background_yield_0.8455             442.761  -     22   +     23       False
# frac_Mbc_bkg1_0.8455             -0.0285311  -  0.052   +  0.054       False
# frac_deltaE_bkg1_0.8455            0.229549  -   0.15   +   0.15       False
# True
# Iteration 2 - Signal Yield: 66.9745988277893 ± 11.122569617421249
# Running iteration 3/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2626                 74.6238  -     11   +     12       False
# background_yield_0.2626             435.217  -     21   +     23       False
# frac_Mbc_bkg1_0.2626             -0.0551944  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.2626             0.20419  -   0.15   +   0.15       False
# True
# Iteration 3 - Signal Yield: 74.6238209265125 ± 11.223832547726612
# Running iteration 4/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3421                   74.74  -     11   +     12       False
# background_yield_0.3421             435.086  -     22   +     23       False
# frac_Mbc_bkg1_0.3421             -0.0569094  -  0.052   +  0.053       False
# frac_deltaE_bkg1_0.3421            0.224421  -   0.15   +   0.15       False
# True
# Iteration 4 - Signal Yield: 74.74003134459068 ± 11.358444550501698
# Running iteration 5/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4675                  74.951  -     11   +     12       False
# background_yield_0.4675              434.88  -     21   +     23       False
# frac_Mbc_bkg1_0.4675             -0.0522504  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.4675            0.234264  -   0.15   +   0.15       False
# True
# Iteration 5 - Signal Yield: 74.95101692564336 ± 11.226683385366506
# Running iteration 6/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7719                 76.5609  -     11   +     11       False
# background_yield_0.7719             433.377  -     21   +     22       False
# frac_Mbc_bkg1_0.7719             -0.0666745  -   0.05   +  0.052       False
# frac_deltaE_bkg1_0.7719            0.200744  -   0.15   +   0.15       False
# True
# Iteration 6 - Signal Yield: 76.56086395618736 ± 11.161000728047306
# Running iteration 7/300...
# 100
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.287                   82.16  -     11   +     12       False
# background_yield_0.287             428.055  -     22   +     22       False
# frac_Mbc_bkg1_0.287             -0.0856898  -  0.048   +  0.053       False
# frac_deltaE_bkg1_0.287            0.215402  -   0.15   +   0.15       False
# True
# Iteration 7 - Signal Yield: 82.16003615647561 ± 11.31692966724382
# Running iteration 8/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9093                 77.0144  -     11   +     12       False
# background_yield_0.9093              433.01  -     22   +     22       False
# frac_Mbc_bkg1_0.9093             -0.0707087  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.9093            0.214702  -   0.15   +   0.15       False
# True
# Iteration 8 - Signal Yield: 77.01443440622833 ± 11.333895411723184
# Running iteration 9/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6704                 81.4305  -     11   +     12       False
# background_yield_0.6704             428.695  -     22   +     22       False
# frac_Mbc_bkg1_0.6704               -0.10079  -  0.049   +  0.052       False
# frac_deltaE_bkg1_0.6704            0.197117  -   0.15   +   0.15       False
# True
# Iteration 9 - Signal Yield: 81.43048891935058 ± 11.146724633659908
# Running iteration 10/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2031                 62.0937  -     10   +     11       False
# background_yield_0.2031             447.893  -     22   +     23       False
# frac_Mbc_bkg1_0.2031             -0.0107682  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.2031            0.229096  -   0.15   +   0.15       False
# True
# Iteration 10 - Signal Yield: 62.0937331198147 ± 10.766134176342703
# Running iteration 11/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4205                 81.8664  -     11   +     12       False
# background_yield_0.4205             428.108  -     22   +     22       False
# frac_Mbc_bkg1_0.4205             -0.0881401  -  0.051   +  0.054       False
# frac_deltaE_bkg1_0.4205            0.212658  -   0.15   +   0.15       False
# True
# Iteration 11 - Signal Yield: 81.86644411711076 ± 11.648343434536532
# Running iteration 12/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3855                 73.7732  -     11   +     12       False
# background_yield_0.3855             436.011  -     21   +     23       False
# frac_Mbc_bkg1_0.3855             -0.0508628  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.3855            0.238437  -   0.15   +   0.15       False
# True
# Iteration 12 - Signal Yield: 73.77322185789278 ± 11.289409012280874
# Running iteration 13/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8854                 78.0225  -     11   +     11       False
# background_yield_0.8854             431.969  -     21   +     22       False
# frac_Mbc_bkg1_0.8854              -0.071101  -   0.05   +  0.052       False
# frac_deltaE_bkg1_0.8854            0.216606  -   0.15   +   0.15       False
# True
# Iteration 13 - Signal Yield: 78.02250985887073 ± 11.189111468263224
# Running iteration 14/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4965                 79.2665  -     11   +     12       False
# background_yield_0.4965             430.722  -     22   +     22       False
# frac_Mbc_bkg1_0.4965             -0.0797102  -   0.05   +  0.052       False
# frac_deltaE_bkg1_0.4965              0.1859  -   0.15   +   0.15       False
# True
# Iteration 14 - Signal Yield: 79.26652292419978 ± 11.162510992458097
# Running iteration 15/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6081                 72.7811  -     11   +     12       False
# background_yield_0.6081             436.933  -     22   +     23       False
# frac_Mbc_bkg1_0.6081             -0.0442398  -  0.052   +  0.053       False
# frac_deltaE_bkg1_0.6081            0.220256  -   0.15   +   0.15       False
# True
# Iteration 15 - Signal Yield: 72.78105779072992 ± 11.213622732544842
# Running iteration 16/300...
# 100
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.234                 77.1556  -     11   +     12       False
# background_yield_0.234             433.295  -     22   +     22       False
# frac_Mbc_bkg1_0.234             -0.0755248  -   0.05   +  0.053       False
# frac_deltaE_bkg1_0.234            0.199709  -   0.15   +   0.15       False
# True
# Iteration 16 - Signal Yield: 77.15562339129008 ± 11.224759904657539
# Running iteration 17/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7432                 77.6187  -     11   +     12       False
# background_yield_0.7432             432.298  -     21   +     22       False
# frac_Mbc_bkg1_0.7432             -0.0658945  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.7432            0.201866  -   0.15   +   0.15       False
# True
# Iteration 17 - Signal Yield: 77.61872707138826 ± 11.31169850903731
# Running iteration 18/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3739                 71.1751  -     11   +     12       False
# background_yield_0.3739             438.293  -     21   +     23       False
# frac_Mbc_bkg1_0.3739             -0.0395701  -  0.052   +  0.052       False
# frac_deltaE_bkg1_0.3739            0.201747  -   0.15   +   0.15       False
# True
# Iteration 18 - Signal Yield: 71.17509763332113 ± 11.125709962443501
# Running iteration 19/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0531                 75.1013  -     11   +     11       False
# background_yield_0.0531             435.212  -     22   +     22       False
# frac_Mbc_bkg1_0.0531             -0.0688491  -   0.05   +  0.053       False
# frac_deltaE_bkg1_0.0531            0.204202  -   0.15   +   0.15       False
# True
# Iteration 19 - Signal Yield: 75.1012599145716 ± 11.158388592094543
# Running iteration 20/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3657                 79.4792  -     11   +     12       False
# background_yield_0.3657             430.635  -     22   +     22       False
# frac_Mbc_bkg1_0.3657             -0.0772848  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.3657            0.218692  -   0.15   +   0.15       False
# True
# Iteration 20 - Signal Yield: 79.47924818762307 ± 11.457776821104872
# Running iteration 21/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1363                 82.5451  -     11   +     12       False
# background_yield_0.1363               427.5  -     22   +     22       False
# frac_Mbc_bkg1_0.1363             -0.0852031  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.1363            0.241853  -   0.15   +   0.15       False
# True
# Iteration 21 - Signal Yield: 82.5451069635821 ± 11.573310908601051
# Running iteration 22/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0701                  74.289  -     11   +     11       False
# background_yield_0.0701             435.585  -     22   +     23       False
# frac_Mbc_bkg1_0.0701             -0.0617305  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.0701            0.220429  -   0.15   +   0.15       False
# True
# Iteration 22 - Signal Yield: 74.28900072337596 ± 11.178982338255235
# Running iteration 23/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2728                 72.9844  -     11   +     11       False
# background_yield_0.2728             436.647  -     21   +     23       False
# frac_Mbc_bkg1_0.2728             -0.0482678  -   0.05   +  0.052       False
# frac_deltaE_bkg1_0.2728            0.182193  -   0.15   +   0.15       False
# True
# Iteration 23 - Signal Yield: 72.98437694444003 ± 10.94838372918551
# Running iteration 24/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0711                 72.9687  -     11   +     12       False
# background_yield_0.0711             436.764  -     22   +     23       False
# frac_Mbc_bkg1_0.0711              -0.043373  -  0.052   +  0.054       False
# frac_deltaE_bkg1_0.0711            0.236606  -   0.15   +   0.15       False
# True
# Iteration 24 - Signal Yield: 72.96873756615793 ± 11.447194734364372
# Running iteration 25/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5882                 75.5437  -     11   +     12       False
# background_yield_0.5882             434.311  -     21   +     23       False
# frac_Mbc_bkg1_0.5882             -0.0575469  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.5882            0.217712  -   0.15   +   0.15       False
# True
# Iteration 25 - Signal Yield: 75.54369674899446 ± 11.236359279057954
# Running iteration 26/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4028                 80.6457  -     11   +     12       False
# background_yield_0.4028             429.365  -     22   +     22       False
# frac_Mbc_bkg1_0.4028             -0.0788162  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.4028            0.229103  -   0.15   +   0.15       False
# True
# Iteration 26 - Signal Yield: 80.64569961481675 ± 11.502994653905038
# Running iteration 27/300...
# 100
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.728                 78.8853  -     11   +     12       False
# background_yield_0.728             431.309  -     22   +     22       False
# frac_Mbc_bkg1_0.728             -0.0754188  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.728            0.198395  -   0.15   +   0.15       False
# True
# Iteration 27 - Signal Yield: 78.88529178984808 ± 11.40623485859648
# Running iteration 28/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4737                 67.3777  -     10   +     11       False
# background_yield_0.4737             442.308  -     22   +     23       False
# frac_Mbc_bkg1_0.4737             -0.0330203  -  0.051   +  0.052       False
# frac_deltaE_bkg1_0.4737            0.188988  -   0.15   +   0.15       False
# True
# Iteration 28 - Signal Yield: 67.37768362789058 ± 10.84393257517316
# Running iteration 29/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7839                 62.2557  -     10   +     11       False
# background_yield_0.7839             447.045  -     22   +     23       False
# frac_Mbc_bkg1_0.7839             -0.0032044  -  0.052   +  0.052       False
# frac_deltaE_bkg1_0.7839            0.230282  -   0.15   +   0.14       False
# True
# Iteration 29 - Signal Yield: 62.25565761667971 ± 10.826003093815789
# Running iteration 30/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6068                 84.9741  -     11   +     12       False
# background_yield_0.6068              425.07  -     21   +     22       False
# frac_Mbc_bkg1_0.6068              -0.110178  -  0.049   +  0.052       False
# frac_deltaE_bkg1_0.6068            0.226066  -   0.15   +   0.15       False
# True
# Iteration 30 - Signal Yield: 84.97412799240391 ± 11.451077867856466
# Running iteration 31/300...
# 100
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.013                 84.1426  -     11   +     12       False
# background_yield_0.013             425.713  -     21   +     22       False
# frac_Mbc_bkg1_0.013             -0.0928638  -  0.051   +  0.051       False
# frac_deltaE_bkg1_0.013            0.245012  -   0.15   +   0.15       False
# True
# Iteration 31 - Signal Yield: 84.14257154937893 ± 11.540670738597367
# Running iteration 32/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1391                 74.4463  -     11   +     12       False
# background_yield_0.1391             434.965  -     21   +     23       False
# frac_Mbc_bkg1_0.1391             -0.0480252  -  0.051   +  0.052       False
# frac_deltaE_bkg1_0.1391            0.214402  -   0.15   +   0.15       False
# True
# Iteration 32 - Signal Yield: 74.4463171903412 ± 11.169106328060487
# Running iteration 33/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8211                 81.3322  -     11   +     12       False
# background_yield_0.8211             428.655  -     22   +     22       False
# frac_Mbc_bkg1_0.8211             -0.0792788  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.8211            0.256163  -   0.15   +   0.15       False
# True
# Iteration 33 - Signal Yield: 81.33219586125219 ± 11.605520869251034
# Running iteration 34/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2394                 77.4422  -     11   +     12       False
# background_yield_0.2394             432.557  -     22   +     22       False
# frac_Mbc_bkg1_0.2394             -0.0742691  -   0.05   +  0.053       False
# frac_deltaE_bkg1_0.2394            0.160638  -   0.15   +   0.15       False
# True
# Iteration 34 - Signal Yield: 77.44216820477348 ± 11.231597326360717
# Running iteration 35/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3046                 83.0452  -     11   +     12       False
# background_yield_0.3046              427.29  -     22   +     22       False
# frac_Mbc_bkg1_0.3046             -0.0937315  -   0.05   +  0.052       False
# frac_deltaE_bkg1_0.3046            0.194992  -   0.15   +   0.15       False
# True
# Iteration 35 - Signal Yield: 83.04519287107556 ± 11.346721026473293
# Running iteration 36/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4284                 69.9592  -     11   +     11       False
# background_yield_0.4284               439.8  -     22   +     23       False
# frac_Mbc_bkg1_0.4284             -0.0363628  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.4284            0.221224  -   0.15   +   0.15       False
# True
# Iteration 36 - Signal Yield: 69.9592043066125 ± 11.115026590990709
# Running iteration 37/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5157                 67.4873  -     11   +     11       False
# background_yield_0.5157             442.322  -     22   +     23       False
# frac_Mbc_bkg1_0.5157             -0.0312938  -  0.051   +  0.054       False
# frac_deltaE_bkg1_0.5157            0.210063  -   0.15   +   0.15       False
# True
# Iteration 37 - Signal Yield: 67.48726380070879 ± 11.000337072829073
# Running iteration 38/300...
# 100
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.306                 76.7725  -     11   +     12       False
# background_yield_0.306             433.381  -     22   +     22       False
# frac_Mbc_bkg1_0.306             -0.0664043  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.306            0.179736  -   0.15   +   0.15       False
# True
# Iteration 38 - Signal Yield: 76.77246219205978 ± 11.352264616486138
# Running iteration 39/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0911                 64.8125  -     10   +     11       False
# background_yield_0.0911             444.628  -     21   +     23       False
# frac_Mbc_bkg1_0.0911             -0.0169756  -  0.051   +  0.051       False
# frac_deltaE_bkg1_0.0911            0.220836  -   0.15   +   0.14       False
# True
# Iteration 39 - Signal Yield: 64.81245705719168 ± 10.700606709296217
# Running iteration 40/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3229                 73.5738  -     11   +     11       False
# background_yield_0.3229             436.232  -     21   +     23       False
# frac_Mbc_bkg1_0.3229             -0.0539456  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.3229             0.22427  -   0.15   +   0.15       False
# True
# Iteration 40 - Signal Yield: 73.57385394178938 ± 11.1763944642535
# Running iteration 41/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7466                  79.991  -     11   +     12       False
# background_yield_0.7466             430.002  -     22   +     22       False
# frac_Mbc_bkg1_0.7466             -0.0783845  -   0.05   +  0.053       False
# frac_deltaE_bkg1_0.7466            0.206867  -   0.15   +   0.15       False
# True
# Iteration 41 - Signal Yield: 79.9909722104657 ± 11.40660124172512
# Running iteration 42/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1447                 76.3332  -     11   +     12       False
# background_yield_0.1447             433.541  -     21   +     23       False
# frac_Mbc_bkg1_0.1447             -0.0585488  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.1447            0.193194  -   0.15   +   0.15       False
# True
# Iteration 42 - Signal Yield: 76.33317656602738 ± 11.284969861401686
# Running iteration 43/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4967                 76.6563  -     11   +     12       False
# background_yield_0.4967             433.312  -     22   +     22       False
# frac_Mbc_bkg1_0.4967             -0.0683664  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.4967            0.209387  -   0.15   +   0.15       False
# True
# Iteration 43 - Signal Yield: 76.65627374727764 ± 11.390157214534248
# Running iteration 44/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8816                 75.9955  -     11   +     11       False
# background_yield_0.8816             433.886  -     21   +     23       False
# frac_Mbc_bkg1_0.8816             -0.0590878  -   0.05   +  0.052       False
# frac_deltaE_bkg1_0.8816            0.191035  -   0.15   +   0.15       False
# True
# Iteration 44 - Signal Yield: 75.99551310377285 ± 11.170357488583237
# Running iteration 45/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0115                 79.4264  -     11   +     12       False
# background_yield_0.0115             430.541  -     22   +     22       False
# frac_Mbc_bkg1_0.0115             -0.0774692  -   0.05   +  0.052       False
# frac_deltaE_bkg1_0.0115            0.216201  -   0.15   +   0.15       False
# True
# Iteration 45 - Signal Yield: 79.42641613863864 ± 11.241532979496906
# Running iteration 46/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9511                 84.6287  -     11   +     12       False
# background_yield_0.9511             425.453  -     21   +     22       False
# frac_Mbc_bkg1_0.9511             -0.0919625  -   0.05   +  0.052       False
# frac_deltaE_bkg1_0.9511            0.244396  -   0.15   +   0.15       False
# True
# Iteration 46 - Signal Yield: 84.62866072005656 ± 11.483533818431448
# Running iteration 47/300...
# 100
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.619                 76.7654  -     11   +     11       False
# background_yield_0.619             433.682  -     22   +     22       False
# frac_Mbc_bkg1_0.619             -0.0738781  -  0.049   +  0.053       False
# frac_deltaE_bkg1_0.619            0.215598  -   0.15   +   0.15       False
# True
# Iteration 47 - Signal Yield: 76.765419429763 ± 11.143284919972533
# Running iteration 48/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6878                 80.1711  -     11   +     12       False
# background_yield_0.6878             430.164  -     22   +     22       False
# frac_Mbc_bkg1_0.6878             -0.0807968  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.6878            0.232924  -   0.14   +   0.15       False
# True
# Iteration 48 - Signal Yield: 80.17109116857942 ± 11.521824149408035
# Running iteration 49/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2493                 77.4921  -     11   +     11       False
# background_yield_0.2493              432.45  -     21   +     22       False
# frac_Mbc_bkg1_0.2493             -0.0659199  -   0.05   +  0.052       False
# frac_deltaE_bkg1_0.2493            0.169571  -   0.15   +   0.15       False
# True
# Iteration 49 - Signal Yield: 77.49207982682168 ± 11.109430148219136
# Running iteration 50/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5308                 76.9926  -     11   +     12       False
# background_yield_0.5308             432.927  -     21   +     22       False
# frac_Mbc_bkg1_0.5308             -0.0654967  -   0.05   +  0.053       False
# frac_deltaE_bkg1_0.5308            0.190501  -   0.15   +   0.15       False
# True
# Iteration 50 - Signal Yield: 76.99264404694205 ± 11.222235968562838
# Running iteration 51/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6252                 79.8214  -     11   +     12       False
# background_yield_0.6252             430.745  -     22   +     22       False
# frac_Mbc_bkg1_0.6252             -0.0781365  -  0.049   +  0.054       False
# frac_deltaE_bkg1_0.6252            0.236812  -   0.15   +   0.15       False
# True
# Iteration 51 - Signal Yield: 79.82141769106717 ± 11.434181387183415
# Running iteration 52/300...
# 100
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.815                 75.6429  -     11   +     11       False
# background_yield_0.815             434.663  -     22   +     22       False
# frac_Mbc_bkg1_0.815             -0.0707255  -   0.05   +  0.053       False
# frac_deltaE_bkg1_0.815            0.214574  -   0.15   +   0.15       False
# True
# Iteration 52 - Signal Yield: 75.64289255085056 ± 11.225240099304866
# Running iteration 53/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4575                 80.2029  -     11   +     12       False
# background_yield_0.4575             430.287  -     22   +     22       False
# frac_Mbc_bkg1_0.4575             -0.0893132  -   0.05   +  0.052       False
# frac_deltaE_bkg1_0.4575            0.225125  -   0.15   +   0.15       False
# True
# Iteration 53 - Signal Yield: 80.20294386422154 ± 11.2822308648511
# Running iteration 54/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4465                 61.9299  -     11   +     11       False
# background_yield_0.4465             448.058  -     22   +     23       False
# frac_Mbc_bkg1_0.4465            -0.00149067  -  0.052   +  0.053       False
# frac_deltaE_bkg1_0.4465            0.242738  -   0.15   +   0.15       False
# True
# Iteration 54 - Signal Yield: 61.92990840057031 ± 10.985975882605143
# Running iteration 55/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5549                 77.9575  -     11   +     12       False
# background_yield_0.5549             432.051  -     22   +     22       False
# frac_Mbc_bkg1_0.5549             -0.0751789  -   0.05   +  0.053       False
# frac_deltaE_bkg1_0.5549            0.223062  -   0.15   +   0.15       False
# True
# Iteration 55 - Signal Yield: 77.95747529787022 ± 11.242869581637642
# Running iteration 56/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9376                 76.9881  -     11   +     12       False
# background_yield_0.9376             433.208  -     22   +     22       False
# frac_Mbc_bkg1_0.9376             -0.0689866  -   0.05   +  0.053       False
# frac_deltaE_bkg1_0.9376            0.210548  -   0.15   +   0.15       False
# True
# Iteration 56 - Signal Yield: 76.9881012068342 ± 11.326742099044383
# Running iteration 57/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0223                 77.5172  -     11   +     12       False
# background_yield_0.0223             432.541  -     22   +     22       False
# frac_Mbc_bkg1_0.0223             -0.0708956  -   0.05   +  0.053       False
# frac_deltaE_bkg1_0.0223            0.195307  -   0.15   +   0.15       False
# True
# Iteration 57 - Signal Yield: 77.51722097677121 ± 11.24582424310269
# Running iteration 58/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9075                 78.9106  -     11   +     12       False
# background_yield_0.9075             431.093  -     22   +     22       False
# frac_Mbc_bkg1_0.9075              -0.076758  -   0.05   +  0.053       False
# frac_deltaE_bkg1_0.9075            0.219639  -   0.15   +   0.15       False
# True
# Iteration 58 - Signal Yield: 78.9105616829575 ± 11.322801906681491
# Running iteration 59/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6759                 74.4421  -     11   +     12       False
# background_yield_0.6759             435.439  -     22   +     23       False
# frac_Mbc_bkg1_0.6759              -0.060539  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.6759            0.232113  -   0.15   +   0.15       False
# True
# Iteration 59 - Signal Yield: 74.44213485626932 ± 11.21462769534844
# Running iteration 60/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8746                 71.9605  -     11   +     11       False
# background_yield_0.8746             437.846  -     22   +     23       False
# frac_Mbc_bkg1_0.8746             -0.0563516  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.8746            0.236798  -   0.15   +   0.15       False
# True
# Iteration 60 - Signal Yield: 71.96046526735161 ± 11.12385891790517
# Running iteration 61/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5883                 80.2851  -     11   +     12       False
# background_yield_0.5883             429.752  -     21   +     22       False
# frac_Mbc_bkg1_0.5883             -0.0819191  -   0.05   +  0.052       False
# frac_deltaE_bkg1_0.5883            0.193934  -   0.15   +   0.15       False
# True
# Iteration 61 - Signal Yield: 80.28508205817369 ± 11.252606095976644
# Running iteration 62/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0941                  79.718  -     11   +     12       False
# background_yield_0.0941             430.494  -     22   +     22       False
# frac_Mbc_bkg1_0.0941             -0.0708742  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.0941            0.222476  -   0.15   +   0.15       False
# True
# Iteration 62 - Signal Yield: 79.71800541479273 ± 11.485202406953753
# Running iteration 63/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5747                 78.5832  -     11   +     12       False
# background_yield_0.5747             431.466  -     22   +     22       False
# frac_Mbc_bkg1_0.5747             -0.0720822  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.5747            0.191858  -   0.15   +   0.15       False
# True
# Iteration 63 - Signal Yield: 78.5832141303138 ± 11.425742273480811
# Running iteration 64/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3759                 72.7127  -     11   +     11       False
# background_yield_0.3759             437.089  -     21   +     23       False
# frac_Mbc_bkg1_0.3759             -0.0496252  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.3759            0.231383  -   0.15   +   0.15       False
# True
# Iteration 64 - Signal Yield: 72.71274547745277 ± 11.136129692805486
# Running iteration 65/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8103                 80.4374  -     11   +     11       False
# background_yield_0.8103              429.84  -     22   +     22       False
# frac_Mbc_bkg1_0.8103             -0.0782019  -   0.05   +  0.053       False
# frac_deltaE_bkg1_0.8103            0.207852  -   0.15   +   0.15       False
# True
# Iteration 65 - Signal Yield: 80.43738082949422 ± 11.377203045129535
# Running iteration 66/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9366                 70.0742  -     11   +     12       False
# background_yield_0.9366             439.423  -     22   +     23       False
# frac_Mbc_bkg1_0.9366             -0.0379108  -  0.052   +  0.053       False
# frac_deltaE_bkg1_0.9366            0.270478  -   0.15   +   0.15       False
# True
# Iteration 66 - Signal Yield: 70.07417127993519 ± 11.179316043404075
# Running iteration 67/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1818                 79.6544  -     11   +     12       False
# background_yield_0.1818             430.425  -     22   +     22       False
# frac_Mbc_bkg1_0.1818             -0.0734419  -  0.051   +  0.054       False
# frac_deltaE_bkg1_0.1818            0.222545  -   0.15   +   0.15       False
# True
# Iteration 67 - Signal Yield: 79.65443325944872 ± 11.608757552413826
# Running iteration 68/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5437                 72.7058  -     11   +     12       False
# background_yield_0.5437             437.427  -     22   +     23       False
# frac_Mbc_bkg1_0.5437              -0.057815  -  0.052   +  0.054       False
# frac_deltaE_bkg1_0.5437            0.245788  -   0.15   +   0.15       False
# True
# Iteration 68 - Signal Yield: 72.70578254044966 ± 11.425334753256653
# Running iteration 69/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9448                 65.6677  -     11   +     11       False
# background_yield_0.9448             444.182  -     22   +     23       False
# frac_Mbc_bkg1_0.9448             -0.0233102  -  0.052   +  0.054       False
# frac_deltaE_bkg1_0.9448             0.25859  -   0.15   +   0.15       False
# True
# Iteration 69 - Signal Yield: 65.66774436104829 ± 11.13356562440838
# Running iteration 70/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4059                 77.6602  -     11   +     12       False
# background_yield_0.4059             432.589  -     22   +     22       False
# frac_Mbc_bkg1_0.4059             -0.0697089  -   0.05   +  0.053       False
# frac_deltaE_bkg1_0.4059            0.229516  -   0.15   +   0.15       False
# True
# Iteration 70 - Signal Yield: 77.66017866688692 ± 11.366628236694783
# Running iteration 71/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5144                 74.9591  -     11   +     12       False
# background_yield_0.5144             434.959  -     22   +     23       False
# frac_Mbc_bkg1_0.5144             -0.0557952  -  0.052   +  0.054       False
# frac_deltaE_bkg1_0.5144            0.248017  -   0.15   +   0.15       False
# True
# Iteration 71 - Signal Yield: 74.95910486611564 ± 11.555784288347613
# Running iteration 72/300...
# 100
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.974                 69.3366  -     11   +     12       False
# background_yield_0.974             439.964  -     22   +     23       False
# frac_Mbc_bkg1_0.974             -0.0300485  -  0.053   +  0.053       False
# frac_deltaE_bkg1_0.974              0.2555  -   0.15   +   0.15       False
# True
# Iteration 72 - Signal Yield: 69.33659994885667 ± 11.331838461021851
# Running iteration 73/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3607                 77.4369  -     11   +     12       False
# background_yield_0.3607             432.752  -     22   +     22       False
# frac_Mbc_bkg1_0.3607             -0.0710505  -   0.05   +  0.053       False
# frac_deltaE_bkg1_0.3607            0.233402  -   0.15   +   0.15       False
# True
# Iteration 73 - Signal Yield: 77.43688333756732 ± 11.285321877052521
# Running iteration 74/300...
# 100
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.844                 77.3696  -     11   +     12       False
# background_yield_0.844             432.993  -     22   +     22       False
# frac_Mbc_bkg1_0.844             -0.0686029  -  0.051   +  0.054       False
# frac_deltaE_bkg1_0.844            0.213621  -   0.15   +   0.15       False
# True
# Iteration 74 - Signal Yield: 77.36958762550081 ± 11.413148548415709
# Running iteration 75/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5686                 66.5732  -     11   +     12       False
# background_yield_0.5686             443.103  -     22   +     23       False
# frac_Mbc_bkg1_0.5686             -0.0284045  -  0.053   +  0.054       False
# frac_deltaE_bkg1_0.5686            0.252635  -   0.15   +   0.15       False
# True
# Iteration 75 - Signal Yield: 66.57321417984134 ± 11.180751465617004
# Running iteration 76/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0787                 76.7096  -     11   +     12       False
# background_yield_0.0787             433.664  -     22   +     22       False
# frac_Mbc_bkg1_0.0787               -0.07068  -   0.05   +  0.053       False
# frac_deltaE_bkg1_0.0787             0.23854  -   0.15   +   0.15       False
# True
# Iteration 76 - Signal Yield: 76.70958143934826 ± 11.274589274455053
# Running iteration 77/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0124                 76.9956  -     11   +     12       False
# background_yield_0.0124              433.14  -     22   +     22       False
# frac_Mbc_bkg1_0.0124             -0.0669475  -   0.05   +  0.053       False
# frac_deltaE_bkg1_0.0124            0.210313  -   0.15   +   0.15       False
# True
# Iteration 77 - Signal Yield: 76.99565379953108 ± 11.335829764666606
# Running iteration 78/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0558                 72.8526  -     11   +     11       False
# background_yield_0.0558             436.938  -     21   +     23       False
# frac_Mbc_bkg1_0.0558             -0.0445477  -  0.051   +  0.052       False
# frac_deltaE_bkg1_0.0558            0.220067  -   0.15   +   0.15       False
# True
# Iteration 78 - Signal Yield: 72.85262097389423 ± 11.099585648746785
# Running iteration 79/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2795                 76.1676  -     11   +     12       False
# background_yield_0.2795             434.352  -     22   +     22       False
# frac_Mbc_bkg1_0.2795             -0.0656455  -   0.05   +  0.054       False
# frac_deltaE_bkg1_0.2795            0.201804  -   0.15   +   0.15       False
# True
# Iteration 79 - Signal Yield: 76.16762403312441 ± 11.395492373101824
# Running iteration 80/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7792                 81.4476  -     11   +     12       False
# background_yield_0.7792             428.667  -     21   +     22       False
# frac_Mbc_bkg1_0.7792             -0.0843104  -   0.05   +  0.052       False
# frac_deltaE_bkg1_0.7792            0.190601  -   0.15   +   0.15       False
# True
# Iteration 80 - Signal Yield: 81.44759649265933 ± 11.306413832901383
# Running iteration 81/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1769                 76.5057  -     11   +     12       False
# background_yield_0.1769             433.517  -     22   +     22       False
# frac_Mbc_bkg1_0.1769             -0.0629351  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.1769            0.209466  -   0.15   +   0.15       False
# True
# Iteration 81 - Signal Yield: 76.5056941510036 ± 11.391264067164729
# Running iteration 82/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9439                 79.1079  -     11   +     12       False
# background_yield_0.9439             430.948  -     22   +     22       False
# frac_Mbc_bkg1_0.9439              -0.078414  -   0.05   +  0.053       False
# frac_deltaE_bkg1_0.9439            0.233659  -   0.15   +   0.15       False
# True
# Iteration 82 - Signal Yield: 79.10788630546887 ± 11.335197162180247
# Running iteration 83/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8912                 77.7704  -     11   +     12       False
# background_yield_0.8912             432.315  -     22   +     22       False
# frac_Mbc_bkg1_0.8912             -0.0688255  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.8912            0.220143  -   0.15   +   0.15       False
# True
# Iteration 83 - Signal Yield: 77.77038448510665 ± 11.474145404821488
# Running iteration 84/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9029                 80.5659  -     11   +     12       False
# background_yield_0.9029             429.413  -     21   +     22       False
# frac_Mbc_bkg1_0.9029             -0.0859886  -  0.049   +  0.052       False
# frac_deltaE_bkg1_0.9029            0.219866  -   0.15   +   0.15       False
# True
# Iteration 84 - Signal Yield: 80.56591969240944 ± 11.196182424075317
# Running iteration 85/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# ...
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9161                 75.6547  -     11   +     12       False
# background_yield_0.9161             434.235  -     22   +     23       False
# frac_Mbc_bkg1_0.9161             -0.0591293  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.9161            0.228036  -   0.15   +   0.15       False
# True
# Iteration 273 - Signal Yield: 75.6547035416774 ± 11.359894649653224
# Running iteration 274/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4743                 77.7455  -     11   +     11       False
# background_yield_0.4743             432.218  -     21   +     22       False
# frac_Mbc_bkg1_0.4743             -0.0672325  -   0.05   +  0.052       False
# frac_deltaE_bkg1_0.4743             0.18775  -   0.15   +   0.15       False
# True
# Iteration 274 - Signal Yield: 77.74552984721473 ± 11.168792732562208
# Running iteration 275/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8129                 76.8846  -     11   +     11       False
# background_yield_0.8129             433.054  -     21   +     22       False
# frac_Mbc_bkg1_0.8129             -0.0646749  -   0.05   +  0.052       False
# frac_deltaE_bkg1_0.8129             0.21679  -   0.15   +   0.15       False
# True
# Iteration 275 - Signal Yield: 76.88463497899428 ± 11.141557854236535
# Running iteration 276/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3993                 82.5793  -     11   +     12       False
# background_yield_0.3993             427.721  -     22   +     22       False
# frac_Mbc_bkg1_0.3993             -0.0934215  -   0.05   +  0.052       False
# frac_deltaE_bkg1_0.3993            0.208757  -   0.15   +   0.15       False
# True
# Iteration 276 - Signal Yield: 82.57927521264868 ± 11.333618001727954
# Running iteration 277/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7674                 78.8118  -     11   +     12       False
# background_yield_0.7674             431.499  -     22   +     22       False
# frac_Mbc_bkg1_0.7674             -0.0745368  -  0.049   +  0.053       False
# frac_deltaE_bkg1_0.7674             0.21478  -   0.15   +   0.15       False
# True
# Iteration 277 - Signal Yield: 78.81179215474027 ± 11.201106888311973
# Running iteration 278/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1665                 79.7032  -     11   +     12       False
# background_yield_0.1665             430.555  -     22   +     22       False
# frac_Mbc_bkg1_0.1665             -0.0730718  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.1665            0.222515  -   0.15   +   0.15       False
# True
# Iteration 278 - Signal Yield: 79.70319101815879 ± 11.447303163792313
# Running iteration 279/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9502                 77.0821  -     11   +     12       False
# background_yield_0.9502             432.785  -     22   +     23       False
# frac_Mbc_bkg1_0.9502             -0.0603806  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.9502            0.230957  -   0.15   +   0.15       False
# True
# Iteration 279 - Signal Yield: 77.08205844084227 ± 11.464484007830944
# Running iteration 280/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2469                 78.1739  -     11   +     12       False
# background_yield_0.2469              431.86  -     22   +     22       False
# frac_Mbc_bkg1_0.2469             -0.0782064  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.2469            0.220269  -   0.15   +   0.15       False
# True
# Iteration 280 - Signal Yield: 78.17393775237007 ± 11.36383306843467
# Running iteration 281/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2099                 82.8356  -     11   +     12       False
# background_yield_0.2099             427.136  -     21   +     22       False
# frac_Mbc_bkg1_0.2099             -0.0953517  -   0.05   +  0.053       False
# frac_deltaE_bkg1_0.2099            0.237243  -   0.15   +   0.15       False
# True
# Iteration 281 - Signal Yield: 82.83558260814729 ± 11.533564488719263
# Running iteration 282/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5022                  68.951  -     11   +     11       False
# background_yield_0.5022             440.934  -     22   +     23       False
# frac_Mbc_bkg1_0.5022             -0.0283639  -  0.052   +  0.054       False
# frac_deltaE_bkg1_0.5022            0.227025  -   0.15   +   0.15       False
# True
# Iteration 282 - Signal Yield: 68.95099776437137 ± 11.192382268078433
# Running iteration 283/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1417                 77.4807  -     11   +     11       False
# background_yield_0.1417             432.611  -     22   +     22       False
# frac_Mbc_bkg1_0.1417             -0.0717347  -   0.05   +  0.052       False
# frac_deltaE_bkg1_0.1417            0.182914  -   0.15   +   0.15       False
# True
# Iteration 283 - Signal Yield: 77.48071559479659 ± 11.127072195008854
# Running iteration 284/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9401                 71.2188  -     10   +     12       False
# background_yield_0.9401             438.055  -     21   +     23       False
# frac_Mbc_bkg1_0.9401             -0.0452271  -  0.051   +  0.051       False
# frac_deltaE_bkg1_0.9401            0.247028  -   0.15   +   0.15       False
# True
# Iteration 284 - Signal Yield: 71.21877222271345 ± 11.00164773629525
# Running iteration 285/300...
# 100
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.843                 74.6215  -     11   +     11       False
# background_yield_0.843             435.225  -     21   +     23       False
# frac_Mbc_bkg1_0.843             -0.0620319  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.843            0.228136  -   0.15   +   0.15       False
# True
# Iteration 285 - Signal Yield: 74.6215180898485 ± 11.203561828900849
# Running iteration 286/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0797                 74.9454  -     11   +     11       False
# background_yield_0.0797             434.932  -     21   +     23       False
# frac_Mbc_bkg1_0.0797             -0.0625786  -   0.05   +  0.052       False
# frac_deltaE_bkg1_0.0797            0.246052  -   0.15   +   0.15       False
# True
# Iteration 286 - Signal Yield: 74.94540313189925 ± 11.08591187770005
# Running iteration 287/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2813                 81.7042  -     11   +     12       False
# background_yield_0.2813             428.202  -     21   +     22       False
# frac_Mbc_bkg1_0.2813             -0.0867521  -  0.051   +  0.052       False
# frac_deltaE_bkg1_0.2813            0.219598  -   0.15   +   0.15       False
# True
# Iteration 287 - Signal Yield: 81.70421967336482 ± 11.480775583202144
# Running iteration 288/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8591                 75.4169  -     11   +     11       False
# background_yield_0.8591             434.494  -     21   +     22       False
# frac_Mbc_bkg1_0.8591             -0.0629336  -   0.05   +  0.052       False
# frac_deltaE_bkg1_0.8591            0.183208  -   0.15   +   0.15       False
# True
# Iteration 288 - Signal Yield: 75.41695131623283 ± 11.095000982013765
# Running iteration 289/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1482                 74.3193  -     10   +     11       False
# background_yield_0.1482             435.382  -     21   +     22       False
# frac_Mbc_bkg1_0.1482             -0.0538997  -   0.05   +  0.051       False
# frac_deltaE_bkg1_0.1482            0.170416  -   0.15   +   0.15       False
# True
# Iteration 289 - Signal Yield: 74.31925712443986 ± 10.895767621952745
# Running iteration 290/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9263                 73.1312  -     11   +     12       False
# background_yield_0.9263             436.665  -     21   +     23       False
# frac_Mbc_bkg1_0.9263             -0.0475121  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.9263            0.229325  -   0.15   +   0.15       False
# True
# Iteration 290 - Signal Yield: 73.13118966822461 ± 11.236876874691525
# Running iteration 291/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1189                  67.265  -     11   +     11       False
# background_yield_0.1189             442.605  -     22   +     23       False
# frac_Mbc_bkg1_0.1189             -0.0313468  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.1189            0.193352  -   0.15   +   0.15       False
# True
# Iteration 291 - Signal Yield: 67.2650169868624 ± 10.884201999615637
# Running iteration 292/300...
# 100
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.488                 69.0749  -     11   +     11       False
# background_yield_0.488             440.733  -     22   +     23       False
# frac_Mbc_bkg1_0.488             -0.0315922  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.488            0.209801  -   0.15   +   0.15       False
# True
# Iteration 292 - Signal Yield: 69.07491853011213 ± 11.050576765497809
# Running iteration 293/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8101                 78.1793  -     11   +     12       False
# background_yield_0.8101             431.812  -     22   +     22       False
# frac_Mbc_bkg1_0.8101              -0.075257  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.8101            0.211864  -   0.15   +   0.15       False
# True
# Iteration 293 - Signal Yield: 78.17933594559003 ± 11.421908030586007
# Running iteration 294/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6302                 73.9462  -     11   +     11       False
# background_yield_0.6302             435.919  -     22   +     23       False
# frac_Mbc_bkg1_0.6302             -0.0618736  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.6302            0.227657  -   0.15   +   0.15       False
# True
# Iteration 294 - Signal Yield: 73.94616320684148 ± 11.13778571631536
# Running iteration 295/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1991                 77.8213  -     11   +     12       False
# background_yield_0.1991             432.172  -     22   +     22       False
# frac_Mbc_bkg1_0.1991             -0.0740057  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.1991            0.202485  -   0.15   +   0.15       False
# True
# Iteration 295 - Signal Yield: 77.82131754496346 ± 11.331755032774119
# Running iteration 296/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1022                  83.182  -     11   +     12       False
# background_yield_0.1022             426.943  -     21   +     22       False
# frac_Mbc_bkg1_0.1022             -0.0989756  -  0.049   +  0.052       False
# frac_deltaE_bkg1_0.1022            0.197885  -   0.15   +   0.15       False
# True
# Iteration 296 - Signal Yield: 83.18197533776409 ± 11.205850602015527
# Running iteration 297/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5116                 79.3442  -     11   +     12       False
# background_yield_0.5116             431.152  -     22   +     22       False
# frac_Mbc_bkg1_0.5116             -0.0776991  -  0.049   +  0.053       False
# frac_deltaE_bkg1_0.5116            0.202752  -   0.15   +   0.15       False
# True
# Iteration 297 - Signal Yield: 79.34424083548527 ± 11.236716132978053
# Running iteration 298/300...
# 100
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.965                 74.4425  -     11   +     12       False
# background_yield_0.965              435.48  -     22   +     23       False
# frac_Mbc_bkg1_0.965             -0.0613688  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.965            0.213333  -   0.15   +   0.15       False
# True
# Iteration 298 - Signal Yield: 74.44247397498741 ± 11.19335055895883
# Running iteration 299/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1654                  75.805  -     11   +     12       False
# background_yield_0.1654             434.204  -     22   +     22       False
# frac_Mbc_bkg1_0.1654             -0.0642604  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.1654            0.195439  -   0.15   +   0.15       False
# True
# Iteration 299 - Signal Yield: 75.80495818424279 ± 11.346475448523137
# Running iteration 300/300...
# 100
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6969                 71.9375  -     11   +     12       False
# background_yield_0.6969             438.063  -     22   +     23       False
# frac_Mbc_bkg1_0.6969             -0.0453296  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.6969            0.216096  -   0.15   +   0.15       False
# True
# Iteration 300 - Signal Yield: 71.93749850928103 ± 11.21896429228041
# Signal yields and errors saved to 'Bppi0_q2reg1_decay_mumu_signal_yields_and_errors_100.csv'

# %% [markdown]
# ## 75

# %%
# Number of iterations
num_iterations = 300

# List to store the signal yields and their errors from each iteration
signal_yields_and_errors = []

for i in range(num_iterations):
    print(f"Running iteration {i + 1}/{num_iterations}...")

    # Process the Monte Carlo data
    mc_mu_signal, mc_mu_only_signal, mc_mu_scf, mc_mu_bkg, mc_mu_signal_weight, mc_mu_only_signal_weight, mc_mu_scf_weight, mc_mu_bkg_weight = process_MC_data_combined(
        file_signal_mu_Bppi0,file_bkg_mu_Bppi0, 'mu', '521', 'pi0', 'mumu', 1, 'rec521', 'weights', 75
    )

    # Fit models for signal, SCF, and background
    Mbc_only_signal_cb_fixed = fit_fixed_without_weight('Mbc', 'mu', 'signal', mc_mu_only_signal["Mbc"], 'cb', 0)
    deltaE_only_signal_cb_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'signal', mc_mu_only_signal["deltaE"],  'cb_gauss', 0)

    Mbc_scf_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'scf', mc_mu_scf["Mbc"], 'argus_gauss', 0)
    deltaE_scf_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'scf', mc_mu_scf["deltaE"], 'poly_gauss', 0)

    Mbc_bkg_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'bkg', mc_mu_bkg["Mbc"], 'argus_gauss', 0)
    deltaE_bkg_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'bkg', mc_mu_bkg["deltaE"], 'poly', 0)

    # Combine signal and background data
    Signal_Mbc = mc_mu_only_signal["Mbc"]
    Signal_deltaE = mc_mu_only_signal["deltaE"]
    Background_Mbc = pd.concat([mc_mu_scf["Mbc"], mc_mu_bkg["Mbc"]])
    Background_deltaE = pd.concat([mc_mu_scf["deltaE"], mc_mu_bkg["deltaE"]])

    Signal_total = pd.concat([Signal_Mbc, Signal_deltaE], axis=1)
    Background_total = pd.concat([Background_Mbc, Background_deltaE], axis=1)

    MC_signal=len(Signal_total)
    MC_bkg=len(Background_total)

    print(MC_signal)
    print(MC_bkg)
    # Fit the extended model and get the result
    Mbc_signal_pdf, deltaE_signal_pdf, Mbc_background_pdf, deltaE_background_pdf, signal_extended, background_extended, total_model, result = fit_extended_model_scf_without_weight(
        Mbc_only_signal_cb_fixed, Mbc_scf_argus_gauss_fixed, deltaE_only_signal_cb_gauss_fixed, deltaE_scf_poly_gauss_fixed,
        Mbc_bkg_argus_gauss_fixed, deltaE_bkg_poly_gauss_fixed,
        pd.concat([Signal_total, Background_total]), 0.5, 0.5, 100, 100
    )
    result.errors(name='errors')
    print(result.params)
    print(result.valid)

    # Retrieve and store the signal yield and its error
    signal_yield = result.params[signal_extended.get_yield()]['value']
    signal_yield_errors = result.params[signal_extended.get_yield()]['errors']
    signal_yield_error = (signal_yield_errors['upper'] - signal_yield_errors['lower']) / 2

    # Store the signal yield and error as a tuple in the list
    signal_yields_and_errors.append((MC_signal,MC_bkg,signal_yield, signal_yield_error))

    print(f"Iteration {i + 1} - Signal Yield: {signal_yield} ± {signal_yield_error}")

# Convert the list to a DataFrame with two columns: 'Signal_Yield' and 'Signal_Yield_Error'
signal_yields_df = pd.DataFrame(signal_yields_and_errors, columns=['MC_signal','MC_bkg','Signal_Yield', 'Signal_Yield_Error'])


# Save the DataFrame to a CSV file
signal_yields_df.to_csv('Bppi0_q2reg1_decay_mumu_signal_yields_and_errors_75.csv', index=False)

print("Signal yields and errors saved to 'Bppi0_q2reg1_decay_mumu_signal_yields_and_errors_75.csv'")
# Out:
# Running iteration 1/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3982                 61.3881  -    9.8   +     10       False
# background_yield_0.3982             423.959  -     21   +     22       False
# frac_Mbc_bkg1_0.3982              -0.107875  -  0.047   +   0.05       False
# frac_deltaE_bkg1_0.3982            0.211927  -   0.15   +   0.15       False
# True
# Iteration 1 - Signal Yield: 61.388063814623955 ± 9.96299865869244
# Running iteration 2/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6096                 53.7615  -    9.5   +     10       False
# background_yield_0.6096             431.232  -     21   +     22       False
# frac_Mbc_bkg1_0.6096             -0.0766186  -  0.049   +  0.052       False
# frac_deltaE_bkg1_0.6096             0.22482  -   0.15   +   0.15       False
# True
# Iteration 2 - Signal Yield: 53.761535951625966 ± 9.840424696489979
# Running iteration 3/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6762                 54.1321  -    9.5   +     10       False
# background_yield_0.6762             430.849  -     21   +     22       False
# frac_Mbc_bkg1_0.6762             -0.0721775  -  0.049   +  0.051       False
# frac_deltaE_bkg1_0.6762            0.209057  -   0.15   +   0.15       False
# True
# Iteration 3 - Signal Yield: 54.13211403084093 ± 9.858968215760433
# Running iteration 4/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9473                 58.6888  -    9.7   +     11       False
# background_yield_0.9473             426.418  -     21   +     22       False
# frac_Mbc_bkg1_0.9473             -0.0960958  -  0.049   +  0.051       False
# frac_deltaE_bkg1_0.9473            0.232306  -   0.15   +   0.15       False
# True
# Iteration 4 - Signal Yield: 58.688800255581434 ± 10.1117455091156
# Running iteration 5/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9398                 56.9721  -    9.7   +     10       False
# background_yield_0.9398              428.04  -     21   +     22       False
# frac_Mbc_bkg1_0.9398             -0.0809883  -  0.049   +  0.051       False
# frac_deltaE_bkg1_0.9398            0.227822  -   0.15   +   0.15       False
# True
# Iteration 5 - Signal Yield: 56.972058698697865 ± 10.003481704254591
# Running iteration 6/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9252                 55.8704  -    9.4   +     10       False
# background_yield_0.9252             429.127  -     21   +     22       False
# frac_Mbc_bkg1_0.9252             -0.0852993  -  0.048   +  0.051       False
# frac_deltaE_bkg1_0.9252            0.210682  -   0.15   +   0.15       False
# True
# Iteration 6 - Signal Yield: 55.87037649157725 ± 9.76784185014878
# Running iteration 7/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8328                 59.8238  -    9.6   +     10       False
# background_yield_0.8328             425.357  -     21   +     22       False
# frac_Mbc_bkg1_0.8328             -0.0920639  -  0.048   +   0.05       False
# frac_deltaE_bkg1_0.8328            0.221374  -   0.15   +   0.15       False
# True
# Iteration 7 - Signal Yield: 59.82378535456754 ± 9.981544651024763
# Running iteration 8/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1661                 58.2901  -    9.5   +     10       False
# background_yield_0.1661             426.523  -     21   +     22       False
# frac_Mbc_bkg1_0.1661              -0.102139  -  0.049   +  0.051       False
# frac_deltaE_bkg1_0.1661            0.212109  -   0.15   +   0.15       False
# True
# Iteration 8 - Signal Yield: 58.29005763799716 ± 9.985844374908725
# Running iteration 9/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4913                 59.6964  -    9.6   +     10       False
# background_yield_0.4913             425.977  -     22   +     21       False
# frac_Mbc_bkg1_0.4913              -0.110241  -  0.048   +   0.05       False
# frac_deltaE_bkg1_0.4913            0.205342  -   0.15   +   0.15       False
# True
# Iteration 9 - Signal Yield: 59.69636340863547 ± 9.868311124669738
# Running iteration 10/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1179                 44.0415  -      9   +    9.7       False
# background_yield_0.1179             440.757  -     21   +     23       False
# frac_Mbc_bkg1_0.1179             -0.0353936  -   0.05   +  0.051       False
# frac_deltaE_bkg1_0.1179            0.203862  -   0.14   +   0.15       False
# True
# Iteration 10 - Signal Yield: 44.04149097937272 ± 9.371310365017326
# Running iteration 11/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0749                 61.9128  -    9.9   +     11       False
# background_yield_0.0749             423.415  -     22   +     22       False
# frac_Mbc_bkg1_0.0749              -0.107566  -  0.049   +  0.051       False
# frac_deltaE_bkg1_0.0749            0.204577  -   0.15   +   0.15       False
# True
# Iteration 11 - Signal Yield: 61.912814905178564 ± 10.284318945057631
# Running iteration 12/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7495                 55.3192  -    9.6   +     10       False
# background_yield_0.7495             429.701  -     21   +     22       False
# frac_Mbc_bkg1_0.7495             -0.0836399  -  0.049   +  0.052       False
# frac_deltaE_bkg1_0.7495            0.250346  -   0.15   +   0.15       False
# True
# Iteration 12 - Signal Yield: 55.31918227620363 ± 9.981620410082513
# Running iteration 13/300...
# 75
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.006                 58.0604  -    9.6   +     10       False
# background_yield_0.006              426.88  -     21   +     22       False
# frac_Mbc_bkg1_0.006             -0.0899883  -  0.049   +   0.05       False
# frac_deltaE_bkg1_0.006            0.217791  -   0.15   +   0.15       False
# True
# Iteration 13 - Signal Yield: 58.0603876311865 ± 9.884104431500692
# Running iteration 14/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1729                 60.0966  -    9.4   +     10       False
# background_yield_0.1729             424.954  -     21   +     22       False
# frac_Mbc_bkg1_0.1729               -0.10152  -  0.047   +   0.05       False
# frac_deltaE_bkg1_0.1729             0.16718  -   0.15   +   0.15       False
# True
# Iteration 14 - Signal Yield: 60.096588661078755 ± 9.81378455444776
# Running iteration 15/300...
# 75
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.304                 49.9125  -    9.3   +     10       False
# background_yield_0.304             435.111  -     22   +     22       False
# frac_Mbc_bkg1_0.304             -0.0551238  -  0.048   +  0.052       False
# frac_deltaE_bkg1_0.304            0.220923  -   0.15   +   0.15       False
# True
# Iteration 15 - Signal Yield: 49.91250813373545 ± 9.67546124419309
# Running iteration 16/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9728                 58.1931  -    9.5   +     10       False
# background_yield_0.9728             426.872  -     21   +     22       False
# frac_Mbc_bkg1_0.9728              -0.101029  -  0.048   +   0.05       False
# frac_deltaE_bkg1_0.9728            0.203888  -   0.15   +   0.15       False
# True
# Iteration 16 - Signal Yield: 58.19313372148964 ± 9.81851997646497
# Running iteration 17/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9063                 58.6576  -    9.7   +     10       False
# background_yield_0.9063             426.291  -     21   +     22       False
# frac_Mbc_bkg1_0.9063             -0.0921639  -  0.049   +   0.05       False
# frac_deltaE_bkg1_0.9063            0.193583  -   0.15   +   0.15       False
# True
# Iteration 17 - Signal Yield: 58.65755451119489 ± 9.930010926789105
# Running iteration 18/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9344                 50.2557  -    9.2   +    9.9       False
# background_yield_0.9344             434.816  -     22   +     22       False
# frac_Mbc_bkg1_0.9344             -0.0583286  -  0.048   +  0.052       False
# frac_deltaE_bkg1_0.9344            0.208659  -   0.15   +   0.15       False
# True
# Iteration 18 - Signal Yield: 50.2557110421406 ± 9.573136093249557
# Running iteration 19/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9768                 55.4308  -    9.6   +     10       False
# background_yield_0.9768             428.814  -     21   +     23       False
# frac_Mbc_bkg1_0.9768             -0.0817279  -  0.049   +  0.051       False
# frac_deltaE_bkg1_0.9768            0.212114  -   0.15   +   0.15       False
# True
# Iteration 19 - Signal Yield: 55.43081420943294 ± 9.860873744052508
# Running iteration 20/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8525                  58.654  -    9.9   +     11       False
# background_yield_0.8525              426.71  -     22   +     22       False
# frac_Mbc_bkg1_0.8525              -0.087943  -  0.049   +  0.051       False
# frac_deltaE_bkg1_0.8525            0.228859  -   0.15   +   0.15       False
# True
# Iteration 20 - Signal Yield: 58.653981819696256 ± 10.21662694493607
# Running iteration 21/300...
# 75
# 410
# name                     value  (rounded)               errors    at limit
# ---------------------  ------------------  -------------------  ----------
# signal_yield_0.88                 58.5662  -    9.6   +     10       False
# background_yield_0.88             426.443  -     21   +     22       False
# frac_Mbc_bkg1_0.88             -0.0898194  -  0.049   +  0.051       False
# frac_deltaE_bkg1_0.88            0.243608  -   0.15   +   0.15       False
# True
# Iteration 21 - Signal Yield: 58.56615853948343 ± 10.027440723633429
# Running iteration 22/300...
# 75
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.698                 54.8571  -    9.5   +     10       False
# background_yield_0.698             430.182  -     21   +     22       False
# frac_Mbc_bkg1_0.698             -0.0827988  -  0.049   +  0.051       False
# frac_deltaE_bkg1_0.698            0.211513  -   0.15   +   0.15       False
# True
# Iteration 22 - Signal Yield: 54.85706015517992 ± 9.825328196480339
# Running iteration 23/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9139                 50.2237  -      9   +    9.7       False
# background_yield_0.9139             434.837  -     21   +     22       False
# frac_Mbc_bkg1_0.9139              -0.058223  -  0.047   +  0.051       False
# frac_deltaE_bkg1_0.9139             0.17629  -   0.15   +   0.15       False
# True
# Iteration 23 - Signal Yield: 50.22369882720123 ± 9.354802946706148
# Running iteration 24/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9276                 54.1728  -    9.8   +     11       False
# background_yield_0.9276             430.766  -     22   +     22       False
# frac_Mbc_bkg1_0.9276             -0.0650402  -   0.05   +  0.052       False
# frac_deltaE_bkg1_0.9276            0.216318  -   0.15   +   0.15       False
# True
# Iteration 24 - Signal Yield: 54.17277667611408 ± 10.151248832234618
# Running iteration 25/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4475                 57.7378  -    9.6   +     10       False
# background_yield_0.4475             427.267  -     21   +     22       False
# frac_Mbc_bkg1_0.4475             -0.0886963  -  0.048   +  0.051       False
# frac_deltaE_bkg1_0.4475            0.231191  -   0.15   +   0.15       False
# True
# Iteration 25 - Signal Yield: 57.737770125923696 ± 9.989461215824031
# Running iteration 26/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9656                  60.951  -    9.8   +     10       False
# background_yield_0.9656              424.51  -     22   +     22       False
# frac_Mbc_bkg1_0.9656              -0.101082  -  0.048   +  0.051       False
# frac_deltaE_bkg1_0.9656            0.219259  -   0.15   +   0.15       False
# True
# Iteration 26 - Signal Yield: 60.950988505072786 ± 10.061463103262458
# Running iteration 27/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2153                  58.853  -    9.6   +     10       False
# background_yield_0.2153             426.249  -     21   +     22       False
# frac_Mbc_bkg1_0.2153             -0.0957542  -  0.049   +  0.051       False
# frac_deltaE_bkg1_0.2153            0.201886  -   0.15   +   0.15       False
# True
# Iteration 27 - Signal Yield: 58.852991825214396 ± 10.018637262611607
# Running iteration 28/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5693                 49.4112  -      9   +    9.6       False
# background_yield_0.5693             435.524  -     21   +     22       False
# frac_Mbc_bkg1_0.5693             -0.0612972  -  0.048   +   0.05       False
# frac_deltaE_bkg1_0.5693            0.149167  -   0.14   +   0.15       False
# True
# Iteration 28 - Signal Yield: 49.41123720467649 ± 9.26694166299533
# Running iteration 29/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4617                 48.1229  -    9.2   +    9.7       False
# background_yield_0.4617             437.033  -     22   +     22       False
# frac_Mbc_bkg1_0.4617             -0.0455571  -  0.048   +  0.051       False
# frac_deltaE_bkg1_0.4617            0.222913  -   0.15   +   0.15       False
# True
# Iteration 29 - Signal Yield: 48.12292805865345 ± 9.433730664181539
# Running iteration 30/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6323                 62.1886  -    9.6   +     10       False
# background_yield_0.6323             422.918  -     21   +     22       False
# frac_Mbc_bkg1_0.6323              -0.116998  -  0.047   +   0.05       False
# frac_deltaE_bkg1_0.6323            0.222243  -   0.15   +   0.15       False
# True
# Iteration 30 - Signal Yield: 62.18862224659788 ± 9.97838107098583
# Running iteration 31/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9895                 60.9825  -    9.8   +     10       False
# background_yield_0.9895             423.947  -     21   +     22       False
# frac_Mbc_bkg1_0.9895              -0.100946  -  0.048   +   0.05       False
# frac_deltaE_bkg1_0.9895            0.236353  -   0.15   +   0.15       False
# True
# Iteration 31 - Signal Yield: 60.982460098626895 ± 10.073772131872506
# Running iteration 32/300...
# 75
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.551                 56.1918  -    9.5   +     10       False
# background_yield_0.551              428.73  -     21   +     22       False
# frac_Mbc_bkg1_0.551              -0.079036  -  0.049   +   0.05       False
# frac_deltaE_bkg1_0.551            0.217513  -   0.15   +   0.15       False
# True
# Iteration 32 - Signal Yield: 56.19179277304541 ± 9.816864751902031
# Running iteration 33/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6097                 57.2748  -     10   +     10       False
# background_yield_0.6097             428.037  -     22   +     22       False
# frac_Mbc_bkg1_0.6097             -0.0805323  -   0.05   +  0.051       False
# frac_deltaE_bkg1_0.6097            0.270646  -   0.15   +   0.15       False
# True
# Iteration 33 - Signal Yield: 57.274780837685014 ± 10.22995477915935
# Running iteration 34/300...
# 75
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.495                 54.5491  -    9.5   +     10       False
# background_yield_0.495             430.459  -     21   +     22       False
# frac_Mbc_bkg1_0.495             -0.0771005  -  0.049   +  0.051       False
# frac_deltaE_bkg1_0.495            0.174095  -   0.15   +   0.15       False
# True
# Iteration 34 - Signal Yield: 54.5490814040537 ± 9.845319203257606
# Running iteration 35/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8552                 64.3675  -    9.8   +     10       False
# background_yield_0.8552             420.199  -     21   +     22       False
# frac_Mbc_bkg1_0.8552              -0.115937  -  0.047   +  0.051       False
# frac_deltaE_bkg1_0.8552            0.208638  -   0.15   +   0.15       False
# True
# Iteration 35 - Signal Yield: 64.36749320298611 ± 10.163921705435214
# Running iteration 36/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5642                 54.8736  -    9.4   +     11       False
# background_yield_0.5642             429.941  -     21   +     22       False
# frac_Mbc_bkg1_0.5642             -0.0778711  -  0.049   +  0.051       False
# frac_deltaE_bkg1_0.5642            0.226059  -   0.15   +   0.15       False
# True
# Iteration 36 - Signal Yield: 54.873606544563565 ± 9.993330892505856
# Running iteration 37/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0882                 50.8095  -    9.3   +     10       False
# background_yield_0.0882             434.138  -     21   +     22       False
# frac_Mbc_bkg1_0.0882              -0.064325  -  0.049   +  0.051       False
# frac_deltaE_bkg1_0.0882            0.208484  -   0.15   +   0.15       False
# True
# Iteration 37 - Signal Yield: 50.80946387270008 ± 9.625966988662277
# Running iteration 38/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3002                 57.3808  -    9.6   +     10       False
# background_yield_0.3002             427.613  -     21   +     22       False
# frac_Mbc_bkg1_0.3002             -0.0914134  -  0.049   +  0.051       False
# frac_deltaE_bkg1_0.3002            0.176245  -   0.15   +   0.15       False
# True
# Iteration 38 - Signal Yield: 57.38082889987127 ± 9.943045963261218
# Running iteration 39/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2222                 46.0792  -    9.1   +    9.7       False
# background_yield_0.2222             438.894  -     22   +     22       False
# frac_Mbc_bkg1_0.2222             -0.0390453  -  0.049   +  0.051       False
# frac_deltaE_bkg1_0.2222            0.226213  -   0.15   +   0.15       False
# True
# Iteration 39 - Signal Yield: 46.07921274915162 ± 9.395043481136007
# Running iteration 40/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7846                 52.9701  -    9.4   +     10       False
# background_yield_0.7846              431.95  -     21   +     22       False
# frac_Mbc_bkg1_0.7846             -0.0757885  -  0.049   +  0.051       False
# frac_deltaE_bkg1_0.7846            0.212373  -   0.15   +   0.15       False
# True
# Iteration 40 - Signal Yield: 52.970069846767025 ± 9.68841071842251
# Running iteration 41/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1253                 59.6961  -    9.7   +     10       False
# background_yield_0.1253             425.576  -     21   +     22       False
# frac_Mbc_bkg1_0.1253             -0.0954399  -  0.048   +   0.05       False
# frac_deltaE_bkg1_0.1253             0.21215  -   0.15   +   0.15       False
# True
# Iteration 41 - Signal Yield: 59.69608441650903 ± 10.005647587204637
# Running iteration 42/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0179                 57.7564  -    9.5   +     10       False
# background_yield_0.0179             427.172  -     21   +     22       False
# frac_Mbc_bkg1_0.0179             -0.0838597  -  0.048   +   0.05       False
# frac_deltaE_bkg1_0.0179            0.181414  -   0.15   +   0.15       False
# True
# Iteration 42 - Signal Yield: 57.75636413089358 ± 9.844836968390851
# Running iteration 43/300...
# 75
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.885                 62.5613  -    9.7   +     10       False
# background_yield_0.885             423.138  -     22   +     21       False
# frac_Mbc_bkg1_0.885              -0.118459  -  0.048   +   0.05       False
# frac_deltaE_bkg1_0.885             0.19323  -   0.15   +   0.15       False
# True
# Iteration 43 - Signal Yield: 62.56131563877098 ± 10.06991134120149
# Running iteration 44/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7515                 59.5257  -    9.7   +     10       False
# background_yield_0.7515              426.17  -     22   +     21       False
# frac_Mbc_bkg1_0.7515             -0.0946261  -  0.048   +   0.05       False
# frac_deltaE_bkg1_0.7515            0.187473  -   0.15   +   0.15       False
# True
# Iteration 44 - Signal Yield: 59.525741657141424 ± 9.948215794560763
# Running iteration 45/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5263                 57.2965  -    9.5   +     10       False
# background_yield_0.5263             427.627  -     21   +     22       False
# frac_Mbc_bkg1_0.5263              -0.084389  -  0.048   +   0.05       False
# frac_deltaE_bkg1_0.5263            0.207192  -   0.15   +   0.15       False
# True
# Iteration 45 - Signal Yield: 57.29652532607725 ± 9.859516987453524
# Running iteration 46/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5104                 63.6737  -    9.7   +     10       False
# background_yield_0.5104             421.343  -     21   +     22       False
# frac_Mbc_bkg1_0.5104              -0.109478  -  0.047   +   0.05       False
# frac_deltaE_bkg1_0.5104            0.220843  -   0.15   +   0.15       False
# True
# Iteration 46 - Signal Yield: 63.67370268575124 ± 10.039905332270763
# Running iteration 47/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9428                 56.7857  -    9.3   +     10       False
# background_yield_0.9428             428.142  -     21   +     22       False
# frac_Mbc_bkg1_0.9428             -0.0979257  -  0.048   +   0.05       False
# frac_deltaE_bkg1_0.9428            0.202898  -   0.15   +   0.15       False
# True
# Iteration 47 - Signal Yield: 56.785732021128254 ± 9.768879250080975
# Running iteration 48/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6523                 60.5597  -    9.9   +     10       False
# background_yield_0.6523             424.177  -     21   +     22       False
# frac_Mbc_bkg1_0.6523              -0.104418  -  0.048   +  0.051       False
# frac_deltaE_bkg1_0.6523            0.232053  -   0.15   +   0.15       False
# True
# Iteration 48 - Signal Yield: 60.55973573910386 ± 10.144021098449796
# Running iteration 49/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4472                 56.0725  -    9.5   +     10       False
# background_yield_0.4472             428.901  -     21   +     22       False
# frac_Mbc_bkg1_0.4472             -0.0783305  -  0.049   +  0.051       False
# frac_deltaE_bkg1_0.4472            0.162131  -   0.15   +   0.15       False
# True
# Iteration 49 - Signal Yield: 56.072507365277325 ± 9.838119167594586
# Running iteration 50/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5709                 58.7309  -    9.7   +     10       False
# background_yield_0.5709             426.497  -     21   +     22       False
# frac_Mbc_bkg1_0.5709             -0.0898226  -  0.048   +  0.051       False
# frac_deltaE_bkg1_0.5709            0.208829  -   0.15   +   0.15       False
# True
# Iteration 50 - Signal Yield: 58.730860577177516 ± 10.002554467250864
# Running iteration 51/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0371                 56.0983  -    9.6   +     10       False
# background_yield_0.0371             428.894  -     21   +     22       False
# frac_Mbc_bkg1_0.0371             -0.0807238  -  0.049   +  0.051       False
# frac_deltaE_bkg1_0.0371            0.232949  -   0.15   +   0.15       False
# True
# Iteration 51 - Signal Yield: 56.098252760478196 ± 10.019750710729685
# Running iteration 52/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7069                 58.0779  -    9.6   +     10       False
# background_yield_0.7069             427.009  -     21   +     22       False
# frac_Mbc_bkg1_0.7069             -0.0985825  -  0.048   +  0.051       False
# frac_deltaE_bkg1_0.7069            0.225821  -   0.15   +   0.15       False
# True
# Iteration 52 - Signal Yield: 58.07794138361825 ± 9.966615179427158
# Running iteration 53/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6189                 64.3696  -    9.8   +     10       False
# background_yield_0.6189             420.631  -     21   +     22       False
# frac_Mbc_bkg1_0.6189              -0.121609  -  0.048   +   0.05       False
# frac_deltaE_bkg1_0.6189            0.212243  -   0.15   +   0.14       False
# True
# Iteration 53 - Signal Yield: 64.36957230941589 ± 10.136335785406192
# Running iteration 54/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8548                 48.4063  -    9.3   +    9.9       False
# background_yield_0.8548             436.598  -     22   +     22       False
# frac_Mbc_bkg1_0.8548             -0.0485679  -  0.049   +  0.051       False
# frac_deltaE_bkg1_0.8548            0.216167  -   0.15   +   0.15       False
# True
# Iteration 54 - Signal Yield: 48.40627410817982 ± 9.582293298648935
# Running iteration 55/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1887                 64.2644  -    9.7   +     10       False
# background_yield_0.1887             421.073  -     21   +     21       False
# frac_Mbc_bkg1_0.1887              -0.123843  -  0.047   +  0.049       False
# frac_deltaE_bkg1_0.1887            0.222426  -   0.15   +   0.14       False
# True
# Iteration 55 - Signal Yield: 64.26439682011336 ± 10.000135601987246
# Running iteration 56/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8098                 58.8164  -    9.5   +     10       False
# background_yield_0.8098             426.286  -     21   +     22       False
# frac_Mbc_bkg1_0.8098             -0.0976898  -  0.048   +   0.05       False
# frac_deltaE_bkg1_0.8098            0.201044  -   0.15   +   0.15       False
# True
# Iteration 56 - Signal Yield: 58.8163710307272 ± 9.945855334723412
# Running iteration 57/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8387                 58.3025  -    9.6   +     10       False
# background_yield_0.8387             426.747  -     21   +     22       False
# frac_Mbc_bkg1_0.8387             -0.0957491  -  0.049   +  0.051       False
# frac_deltaE_bkg1_0.8387             0.19747  -   0.15   +   0.15       False
# True
# Iteration 57 - Signal Yield: 58.3025299504108 ± 9.96841041372676
# Running iteration 58/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3347                 58.6066  -    9.6   +     10       False
# background_yield_0.3347             426.498  -     21   +     22       False
# frac_Mbc_bkg1_0.3347             -0.0942703  -  0.048   +  0.051       False
# frac_deltaE_bkg1_0.3347              0.2396  -   0.15   +   0.15       False
# True
# Iteration 58 - Signal Yield: 58.60658828812243 ± 10.013724247666019
# Running iteration 59/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6676                 55.0035  -    9.2   +     10       False
# background_yield_0.6676             429.834  -     21   +     22       False
# frac_Mbc_bkg1_0.6676             -0.0840034  -  0.048   +  0.051       False
# frac_deltaE_bkg1_0.6676            0.218586  -   0.15   +   0.15       False
# True
# Iteration 59 - Signal Yield: 55.00346199503686 ± 9.788534182636333
# Running iteration 60/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0676                 52.2594  -    9.5   +     10       False
# background_yield_0.0676             432.731  -     21   +     22       False
# frac_Mbc_bkg1_0.0676             -0.0721559  -   0.05   +  0.052       False
# frac_deltaE_bkg1_0.0676            0.265682  -   0.15   +   0.15       False
# True
# Iteration 60 - Signal Yield: 52.259422913501794 ± 9.856805328510422
# Running iteration 61/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2769                 55.8548  -    9.4   +     10       False
# background_yield_0.2769             429.179  -     21   +     22       False
# frac_Mbc_bkg1_0.2769             -0.0843994  -  0.048   +   0.05       False
# frac_deltaE_bkg1_0.2769            0.189891  -   0.15   +   0.15       False
# True
# Iteration 61 - Signal Yield: 55.854826207247555 ± 9.72240279088582
# Running iteration 62/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6629                 57.6286  -    9.7   +     10       False
# background_yield_0.6629               427.8  -     22   +     22       False
# frac_Mbc_bkg1_0.6629             -0.0855633  -  0.049   +  0.051       False
# frac_deltaE_bkg1_0.6629            0.203751  -   0.15   +   0.14       False
# True
# Iteration 62 - Signal Yield: 57.628633653349716 ± 9.959826882758955
# Running iteration 63/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2591                 60.0003  -    9.7   +     10       False
# background_yield_0.2591              425.44  -     22   +     22       False
# frac_Mbc_bkg1_0.2591              -0.101519  -  0.049   +   0.05       False
# frac_deltaE_bkg1_0.2591            0.192265  -   0.15   +   0.15       False
# True
# Iteration 63 - Signal Yield: 60.00032589037696 ± 10.070521493561117
# Running iteration 64/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9314                 60.1066  -    9.7   +     10       False
# background_yield_0.9314             425.139  -     21   +     22       False
# frac_Mbc_bkg1_0.9314             -0.0968964  -  0.048   +   0.05       False
# frac_deltaE_bkg1_0.9314            0.240166  -   0.15   +   0.15       False
# True
# Iteration 64 - Signal Yield: 60.106580296122594 ± 9.976919207303602
# Running iteration 65/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9373                 58.0114  -    9.6   +     10       False
# background_yield_0.9373             426.906  -     21   +     22       False
# frac_Mbc_bkg1_0.9373             -0.0899154  -  0.049   +   0.05       False
# frac_deltaE_bkg1_0.9373            0.201025  -   0.15   +   0.15       False
# True
# Iteration 65 - Signal Yield: 58.011442820971816 ± 9.911706723270992
# Running iteration 66/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4005                 53.9792  -    9.4   +     10       False
# background_yield_0.4005             431.018  -     21   +     22       False
# frac_Mbc_bkg1_0.4005             -0.0768755  -  0.048   +  0.052       False
# frac_deltaE_bkg1_0.4005            0.232803  -   0.15   +   0.15       False
# True
# Iteration 66 - Signal Yield: 53.97923613939037 ± 9.780096925768515
# Running iteration 67/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8263                 62.9073  -     10   +     11       False
# background_yield_0.8263             421.789  -     21   +     22       False
# frac_Mbc_bkg1_0.8263              -0.108973  -  0.049   +  0.051       False
# frac_deltaE_bkg1_0.8263            0.222607  -   0.15   +   0.15       False
# True
# Iteration 67 - Signal Yield: 62.907313246085884 ± 10.276132868712354
# Running iteration 68/300...
# 75
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.554                 52.6148  -    9.5   +     10       False
# background_yield_0.554              432.37  -     22   +     22       False
# frac_Mbc_bkg1_0.554              -0.077345  -   0.05   +  0.052       False
# frac_deltaE_bkg1_0.554            0.225876  -   0.15   +   0.15       False
# True
# Iteration 68 - Signal Yield: 52.614851713826674 ± 9.910854998884542
# Running iteration 69/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9483                 48.1417  -    9.4   +     10       False
# background_yield_0.9483              436.86  -     22   +     22       False
# frac_Mbc_bkg1_0.9483             -0.0521512  -   0.05   +  0.052       False
# frac_deltaE_bkg1_0.9483            0.245151  -   0.15   +   0.15       False
# True
# Iteration 69 - Signal Yield: 48.141679903166796 ± 9.722662073120318
# Running iteration 70/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9288                 55.8294  -    9.5   +     10       False
# background_yield_0.9288             429.175  -     21   +     22       False
# frac_Mbc_bkg1_0.9288             -0.0830467  -  0.049   +  0.051       False
# frac_deltaE_bkg1_0.9288            0.219981  -   0.15   +   0.15       False
# True
# Iteration 70 - Signal Yield: 55.82935935423131 ± 9.887685351959515
# Running iteration 71/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2721                  52.512  -    9.9   +     11       False
# background_yield_0.2721             432.472  -     22   +     22       False
# frac_Mbc_bkg1_0.2721             -0.0621733  -  0.051   +  0.053       False
# frac_deltaE_bkg1_0.2721            0.261285  -   0.15   +   0.15       False
# True
# Iteration 71 - Signal Yield: 52.51199435188049 ± 10.228097105709326
# Running iteration 72/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8592                 54.9739  -    9.8   +     10       False
# background_yield_0.8592             429.962  -     21   +     22       False
# frac_Mbc_bkg1_0.8592             -0.0752693  -  0.049   +  0.051       False
# frac_deltaE_bkg1_0.8592            0.248272  -   0.15   +   0.15       False
# True
# Iteration 72 - Signal Yield: 54.973915855193 ± 10.011467452811473
# Running iteration 73/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6775                 63.6707  -    9.6   +     10       False
# background_yield_0.6775             421.651  -     21   +     21       False
# frac_Mbc_bkg1_0.6775              -0.118103  -  0.047   +   0.05       False
# frac_deltaE_bkg1_0.6775            0.201457  -   0.15   +   0.15       False
# True
# Iteration 73 - Signal Yield: 63.67065639068471 ± 10.020941162535292
# Running iteration 74/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0446                 54.3105  -    9.6   +     10       False
# background_yield_0.0446             430.657  -     21   +     22       False
# frac_Mbc_bkg1_0.0446             -0.0757051  -  0.049   +  0.051       False
# frac_deltaE_bkg1_0.0446            0.224117  -   0.15   +   0.15       False
# True
# Iteration 74 - Signal Yield: 54.310531559008545 ± 9.934012250981244
# Running iteration 75/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0714                 51.9277  -    9.5   +     10       False
# background_yield_0.0714             433.065  -     22   +     22       False
# frac_Mbc_bkg1_0.0714             -0.0759442  -   0.05   +  0.052       False
# frac_deltaE_bkg1_0.0714             0.26507  -   0.15   +   0.15       False
# True
# Iteration 75 - Signal Yield: 51.927685796595256 ± 9.86806624872473
# Running iteration 76/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5647                 58.0067  -    9.8   +     10       False
# background_yield_0.5647             427.024  -     21   +     22       False
# frac_Mbc_bkg1_0.5647             -0.0968602  -  0.049   +  0.052       False
# frac_deltaE_bkg1_0.5647            0.231768  -   0.15   +   0.15       False
# True
# Iteration 76 - Signal Yield: 58.006663507521665 ± 10.081714474322938
# Running iteration 77/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8643                 55.1394  -    9.6   +     10       False
# background_yield_0.8643             429.664  -     21   +     22       False
# frac_Mbc_bkg1_0.8643             -0.0818376  -  0.049   +  0.051       False
# frac_deltaE_bkg1_0.8643            0.222943  -   0.15   +   0.15       False
# True
# Iteration 77 - Signal Yield: 55.13939534115124 ± 9.991366652217359
# Running iteration 78/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3429                 49.0882  -    9.2   +    9.8       False
# background_yield_0.3429             436.038  -     22   +     22       False
# frac_Mbc_bkg1_0.3429             -0.0498177  -  0.048   +  0.052       False
# frac_deltaE_bkg1_0.3429            0.207873  -   0.15   +   0.15       False
# True
# Iteration 78 - Signal Yield: 49.088169482921536 ± 9.46142314967043
# Running iteration 79/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5952                  57.964  -    9.5   +     10       False
# background_yield_0.5952             426.731  -     21   +     22       False
# frac_Mbc_bkg1_0.5952             -0.0969738  -  0.049   +  0.051       False
# frac_deltaE_bkg1_0.5952             0.19644  -   0.15   +   0.15       False
# True
# Iteration 79 - Signal Yield: 57.964032800353415 ± 9.951311995173677
# Running iteration 80/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1271                 64.7347  -    9.7   +     10       False
# background_yield_0.1271             419.687  -     20   +     22       False
# frac_Mbc_bkg1_0.1271              -0.122514  -  0.046   +   0.05       False
# frac_deltaE_bkg1_0.1271            0.168009  -   0.15   +   0.15       False
# True
# Iteration 80 - Signal Yield: 64.73471685506748 ± 9.992556164619842
# Running iteration 81/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0329                 60.9189  -    9.7   +     10       False
# background_yield_0.0329             424.262  -     21   +     22       False
# frac_Mbc_bkg1_0.0329               -0.10704  -  0.048   +  0.051       False
# frac_deltaE_bkg1_0.0329            0.199323  -   0.15   +   0.15       False
# True
# Iteration 81 - Signal Yield: 60.91887015065767 ± 10.066042618496397
# Running iteration 82/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1504                 60.7796  -    9.8   +     10       False
# background_yield_0.1504             424.788  -     22   +     21       False
# frac_Mbc_bkg1_0.1504              -0.101796  -  0.048   +  0.051       False
# frac_deltaE_bkg1_0.1504            0.232045  -   0.15   +   0.15       False
# True
# Iteration 82 - Signal Yield: 60.779616680932165 ± 10.054720262840316
# Running iteration 83/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9882                 58.8509  -     10   +     11       False
# background_yield_0.9882             426.763  -     22   +     22       False
# frac_Mbc_bkg1_0.9882             -0.0916627  -   0.05   +  0.052       False
# frac_deltaE_bkg1_0.9882            0.235427  -   0.15   +   0.15       False
# True
# Iteration 83 - Signal Yield: 58.85084789436678 ± 10.280866028051257
# Running iteration 84/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8463                 61.0715  -    9.6   +     10       False
# background_yield_0.8463             424.308  -     22   +     21       False
# frac_Mbc_bkg1_0.8463              -0.109746  -  0.048   +  0.049       False
# frac_deltaE_bkg1_0.8463            0.228625  -   0.15   +   0.15       False
# True
# Iteration 84 - Signal Yield: 61.07145737472608 ± 9.95341585256428
# Running iteration 85/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# ...
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4501                 57.8471  -    9.8   +     10       False
# background_yield_0.4501             427.574  -     22   +     22       False
# frac_Mbc_bkg1_0.4501             -0.0842833  -  0.049   +  0.051       False
# frac_deltaE_bkg1_0.4501            0.224628  -   0.15   +   0.15       False
# True
# Iteration 273 - Signal Yield: 57.84704848372399 ± 10.107971324861765
# Running iteration 274/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2577                 50.5882  -    9.3   +     10       False
# background_yield_0.2577             434.459  -     22   +     22       False
# frac_Mbc_bkg1_0.2577             -0.0556425  -  0.048   +  0.052       False
# frac_deltaE_bkg1_0.2577            0.204319  -   0.15   +   0.15       False
# True
# Iteration 274 - Signal Yield: 50.58818095063407 ± 9.638594722312078
# Running iteration 275/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6063                 62.4882  -    9.5   +     10       False
# background_yield_0.6063             422.481  -     21   +     22       False
# frac_Mbc_bkg1_0.6063              -0.111431  -  0.047   +  0.049       False
# frac_deltaE_bkg1_0.6063            0.194002  -   0.15   +   0.15       False
# True
# Iteration 275 - Signal Yield: 62.48817317464089 ± 9.901664185989494
# Running iteration 276/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2826                 61.2248  -    9.7   +     10       False
# background_yield_0.2826             423.666  -     21   +     22       False
# frac_Mbc_bkg1_0.2826              -0.111138  -  0.047   +   0.05       False
# frac_deltaE_bkg1_0.2826            0.206315  -   0.15   +   0.15       False
# True
# Iteration 276 - Signal Yield: 61.22482959101597 ± 9.957478007243278
# Running iteration 277/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4963                 61.2233  -    9.7   +     10       False
# background_yield_0.4963             424.227  -     22   +     22       False
# frac_Mbc_bkg1_0.4963               -0.10264  -  0.048   +   0.05       False
# frac_deltaE_bkg1_0.4963            0.226296  -   0.15   +   0.15       False
# True
# Iteration 277 - Signal Yield: 61.22331073981411 ± 9.99486374741523
# Running iteration 278/300...
# 75
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.461                 59.3448  -    9.6   +     10       False
# background_yield_0.461             425.735  -     21   +     22       False
# frac_Mbc_bkg1_0.461              -0.095103  -  0.048   +  0.051       False
# frac_deltaE_bkg1_0.461              0.2201  -   0.15   +   0.15       False
# True
# Iteration 278 - Signal Yield: 59.34482084141574 ± 10.03398210845232
# Running iteration 279/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9189                 57.1553  -    9.7   +     10       False
# background_yield_0.9189             427.849  -     21   +     22       False
# frac_Mbc_bkg1_0.9189              -0.083483  -  0.049   +  0.052       False
# frac_deltaE_bkg1_0.9189            0.220773  -   0.15   +   0.15       False
# True
# Iteration 279 - Signal Yield: 57.15526752605982 ± 10.07917503514009
# Running iteration 280/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5988                 54.5808  -    9.6   +     10       False
# background_yield_0.5988             430.399  -     21   +     22       False
# frac_Mbc_bkg1_0.5988             -0.0786992  -  0.049   +  0.052       False
# frac_deltaE_bkg1_0.5988            0.248397  -   0.15   +   0.15       False
# True
# Iteration 280 - Signal Yield: 54.58081288929341 ± 9.961826252927114
# Running iteration 281/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8549                 60.5307  -    9.7   +     11       False
# background_yield_0.8549             424.374  -     21   +     22       False
# frac_Mbc_bkg1_0.8549              -0.106978  -   0.05   +   0.05       False
# frac_deltaE_bkg1_0.8549            0.245791  -   0.15   +   0.15       False
# True
# Iteration 281 - Signal Yield: 60.53065090098616 ± 10.222577190908948
# Running iteration 282/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1739                 52.9864  -    9.3   +     10       False
# background_yield_0.1739             431.883  -     21   +     22       False
# frac_Mbc_bkg1_0.1739             -0.0671095  -  0.049   +   0.05       False
# frac_deltaE_bkg1_0.1739            0.191463  -   0.15   +   0.15       False
# True
# Iteration 282 - Signal Yield: 52.986418216754686 ± 9.607345820040775
# Running iteration 283/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7939                 58.2762  -    9.4   +     10       False
# background_yield_0.7939             426.729  -     21   +     22       False
# frac_Mbc_bkg1_0.7939             -0.0950804  -  0.048   +   0.05       False
# frac_deltaE_bkg1_0.7939            0.168152  -   0.15   +   0.15       False
# True
# Iteration 283 - Signal Yield: 58.27616813864086 ± 9.791381402380585
# Running iteration 284/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4893                 57.2348  -    9.4   +     10       False
# background_yield_0.4893             427.757  -     21   +     22       False
# frac_Mbc_bkg1_0.4893             -0.0867494  -  0.048   +   0.05       False
# frac_deltaE_bkg1_0.4893            0.242816  -   0.15   +   0.15       False
# True
# Iteration 284 - Signal Yield: 57.234833084311134 ± 9.78697599196613
# Running iteration 285/300...
# 75
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.234                 53.6365  -    9.6   +     10       False
# background_yield_0.234             431.375  -     21   +     22       False
# frac_Mbc_bkg1_0.234             -0.0767401  -  0.049   +  0.052       False
# frac_deltaE_bkg1_0.234             0.21964  -   0.15   +   0.15       False
# True
# Iteration 285 - Signal Yield: 53.63650890616925 ± 9.92963427072197
# Running iteration 286/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1248                 57.7824  -    9.4   +     10       False
# background_yield_0.1248             427.239  -     21   +     22       False
# frac_Mbc_bkg1_0.1248             -0.0955288  -  0.048   +   0.05       False
# frac_deltaE_bkg1_0.1248            0.246796  -   0.15   +   0.15       False
# True
# Iteration 286 - Signal Yield: 57.78243029552698 ± 9.78499291039757
# Running iteration 287/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1596                 58.8704  -    9.6   +     10       False
# background_yield_0.1596             426.233  -     21   +     22       False
# frac_Mbc_bkg1_0.1596             -0.0960422  -  0.049   +  0.051       False
# frac_deltaE_bkg1_0.1596            0.218734  -   0.15   +   0.15       False
# True
# Iteration 287 - Signal Yield: 58.8704329675779 ± 10.021338709140519
# Running iteration 288/300...
# 75
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.132                 52.7391  -    9.4   +     10       False
# background_yield_0.132             432.171  -     21   +     22       False
# frac_Mbc_bkg1_0.132             -0.0728844  -  0.049   +  0.051       False
# frac_deltaE_bkg1_0.132            0.177821  -   0.15   +   0.15       False
# True
# Iteration 288 - Signal Yield: 52.73908937386943 ± 9.701008842247553
# Running iteration 289/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7988                  51.246  -    9.1   +    9.7       False
# background_yield_0.7988             433.669  -     21   +     22       False
# frac_Mbc_bkg1_0.7988             -0.0636022  -  0.048   +   0.05       False
# frac_deltaE_bkg1_0.7988            0.170164  -   0.15   +   0.15       False
# True
# Iteration 289 - Signal Yield: 51.24597162387116 ± 9.39829796416753
# Running iteration 290/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5543                 50.2733  -    9.4   +     10       False
# background_yield_0.5543             434.747  -     22   +     22       False
# frac_Mbc_bkg1_0.5543             -0.0588924  -  0.049   +  0.052       False
# frac_deltaE_bkg1_0.5543            0.227266  -   0.15   +   0.15       False
# True
# Iteration 290 - Signal Yield: 50.27330673478134 ± 9.775479258869009
# Running iteration 291/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0984                 54.7814  -    9.3   +     10       False
# background_yield_0.0984             430.164  -     21   +     22       False
# frac_Mbc_bkg1_0.0984             -0.0842177  -  0.048   +  0.051       False
# frac_deltaE_bkg1_0.0984            0.189644  -   0.15   +   0.15       False
# True
# Iteration 291 - Signal Yield: 54.7813893119524 ± 9.730922354022645
# Running iteration 292/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9394                 53.8919  -    9.3   +     10       False
# background_yield_0.9394              431.04  -     21   +     22       False
# frac_Mbc_bkg1_0.9394             -0.0718169  -  0.048   +   0.05       False
# frac_deltaE_bkg1_0.9394             0.19779  -   0.15   +   0.15       False
# True
# Iteration 292 - Signal Yield: 53.891896677190644 ± 9.695733510272724
# Running iteration 293/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5172                 56.4231  -    9.7   +     10       False
# background_yield_0.5172             428.585  -     21   +     22       False
# frac_Mbc_bkg1_0.5172             -0.0863059  -  0.049   +  0.052       False
# frac_deltaE_bkg1_0.5172             0.23204  -   0.15   +   0.15       False
# True
# Iteration 293 - Signal Yield: 56.423072011528376 ± 10.06951071624891
# Running iteration 294/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0358                  54.616  -    9.5   +     10       False
# background_yield_0.0358             430.405  -     21   +     22       False
# frac_Mbc_bkg1_0.0358             -0.0852565  -  0.049   +  0.052       False
# frac_deltaE_bkg1_0.0358            0.214402  -   0.15   +   0.15       False
# True
# Iteration 294 - Signal Yield: 54.616032789048354 ± 9.82654471115963
# Running iteration 295/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4541                 61.1708  -    9.8   +     11       False
# background_yield_0.4541             424.291  -     22   +     21       False
# frac_Mbc_bkg1_0.4541              -0.107691  -  0.049   +  0.051       False
# frac_deltaE_bkg1_0.4541            0.234135  -   0.15   +   0.15       False
# True
# Iteration 295 - Signal Yield: 61.17084403889338 ± 10.190823769808926
# Running iteration 296/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6081                 65.0497  -    9.7   +     10       False
# background_yield_0.6081              419.98  -     21   +     22       False
# frac_Mbc_bkg1_0.6081              -0.129449  -  0.047   +   0.05       False
# frac_deltaE_bkg1_0.6081            0.218112  -   0.15   +   0.15       False
# True
# Iteration 296 - Signal Yield: 65.04970838939028 ± 10.088387862049155
# Running iteration 297/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7784                 59.3261  -    9.5   +     10       False
# background_yield_0.7784             425.739  -     21   +     22       False
# frac_Mbc_bkg1_0.7784             -0.0972841  -  0.048   +   0.05       False
# frac_deltaE_bkg1_0.7784            0.199198  -   0.15   +   0.15       False
# True
# Iteration 297 - Signal Yield: 59.32609534993928 ± 9.87831915954348
# Running iteration 298/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4337                 56.1194  -    9.6   +     10       False
# background_yield_0.4337             428.719  -     21   +     22       False
# frac_Mbc_bkg1_0.4337             -0.0812738  -  0.049   +   0.05       False
# frac_deltaE_bkg1_0.4337            0.202749  -   0.15   +   0.15       False
# True
# Iteration 298 - Signal Yield: 56.11939655763404 ± 9.884097731424692
# Running iteration 299/300...
# 75
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6291                 56.0605  -    9.8   +     10       False
# background_yield_0.6291             428.877  -     21   +     22       False
# frac_Mbc_bkg1_0.6291             -0.0829954  -   0.05   +  0.051       False
# frac_deltaE_bkg1_0.6291            0.200371  -   0.15   +   0.15       False
# True
# Iteration 299 - Signal Yield: 56.06049816510853 ± 10.071465093774044
# Running iteration 300/300...
# 75
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.428                 49.7508  -    9.4   +     10       False
# background_yield_0.428             435.256  -     22   +     22       False
# frac_Mbc_bkg1_0.428               -0.05799  -   0.05   +  0.052       False
# frac_deltaE_bkg1_0.428             0.21236  -   0.15   +   0.15       False
# True
# Iteration 300 - Signal Yield: 49.750842917138286 ± 9.795671550480645
# Signal yields and errors saved to 'Bppi0_q2reg1_decay_mumu_signal_yields_and_errors_75.csv'

# %% [markdown]
# ## 50

# %%
# Number of iterations
num_iterations = 300

# List to store the signal yields and their errors from each iteration
signal_yields_and_errors = []

for i in range(num_iterations):
    print(f"Running iteration {i + 1}/{num_iterations}...")

    # Process the Monte Carlo data
    mc_mu_signal, mc_mu_only_signal, mc_mu_scf, mc_mu_bkg, mc_mu_signal_weight, mc_mu_only_signal_weight, mc_mu_scf_weight, mc_mu_bkg_weight = process_MC_data_combined(
        file_signal_mu_Bppi0,file_bkg_mu_Bppi0, 'mu', '521', 'pi0', 'mumu', 1, 'rec521', 'weights', 50
    )

    # Fit models for signal, SCF, and background
    Mbc_only_signal_cb_fixed = fit_fixed_without_weight('Mbc', 'mu', 'signal', mc_mu_only_signal["Mbc"], 'cb', 0)
    deltaE_only_signal_cb_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'signal', mc_mu_only_signal["deltaE"],  'cb_gauss', 0)

    Mbc_scf_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'scf', mc_mu_scf["Mbc"], 'argus_gauss', 0)
    deltaE_scf_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'scf', mc_mu_scf["deltaE"], 'poly_gauss', 0)

    Mbc_bkg_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'bkg', mc_mu_bkg["Mbc"], 'argus_gauss', 0)
    deltaE_bkg_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'bkg', mc_mu_bkg["deltaE"], 'poly', 0)

    # Combine signal and background data
    Signal_Mbc = mc_mu_only_signal["Mbc"]
    Signal_deltaE = mc_mu_only_signal["deltaE"]
    Background_Mbc = pd.concat([mc_mu_scf["Mbc"], mc_mu_bkg["Mbc"]])
    Background_deltaE = pd.concat([mc_mu_scf["deltaE"], mc_mu_bkg["deltaE"]])

    Signal_total = pd.concat([Signal_Mbc, Signal_deltaE], axis=1)
    Background_total = pd.concat([Background_Mbc, Background_deltaE], axis=1)

    MC_signal=len(Signal_total)
    MC_bkg=len(Background_total)

    print(MC_signal)
    print(MC_bkg)
    # Fit the extended model and get the result
    Mbc_signal_pdf, deltaE_signal_pdf, Mbc_background_pdf, deltaE_background_pdf, signal_extended, background_extended, total_model, result = fit_extended_model_scf_without_weight(
        Mbc_only_signal_cb_fixed, Mbc_scf_argus_gauss_fixed, deltaE_only_signal_cb_gauss_fixed, deltaE_scf_poly_gauss_fixed,
        Mbc_bkg_argus_gauss_fixed, deltaE_bkg_poly_gauss_fixed,
        pd.concat([Signal_total, Background_total]), 0.5, 0.5, 100, 100
    )
    result.errors(name='errors')
    print(result.params)
    print(result.valid)

    # Retrieve and store the signal yield and its error
    signal_yield = result.params[signal_extended.get_yield()]['value']
    signal_yield_errors = result.params[signal_extended.get_yield()]['errors']
    signal_yield_error = (signal_yield_errors['upper'] - signal_yield_errors['lower']) / 2

    # Store the signal yield and error as a tuple in the list
    signal_yields_and_errors.append((MC_signal,MC_bkg,signal_yield, signal_yield_error))

    print(f"Iteration {i + 1} - Signal Yield: {signal_yield} ± {signal_yield_error}")

# Convert the list to a DataFrame with two columns: 'Signal_Yield' and 'Signal_Yield_Error'
signal_yields_df = pd.DataFrame(signal_yields_and_errors, columns=['MC_signal','MC_bkg','Signal_Yield', 'Signal_Yield_Error'])

# Save the DataFrame to a CSV file
signal_yields_df.to_csv('Bppi0_q2reg1_decay_mumu_signal_yields_and_errors_50.csv', index=False)

print("Signal yields and errors saved to 'Bppi0_q2reg1_decay_mumu_signal_yields_and_errors_50.csv'")
# Out:
# Running iteration 1/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3637                 42.0877  -    8.3   +    8.8       False
# background_yield_0.3637             418.425  -     21   +     21       False
# frac_Mbc_bkg1_0.3637              -0.133403  -  0.044   +  0.049       False
# frac_deltaE_bkg1_0.3637            0.207592  -   0.15   +   0.15       False
# True
# Iteration 1 - Signal Yield: 42.087730872363906 ± 8.564148334859471
# Running iteration 2/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0657                 34.9208  -    7.9   +    8.7       False
# background_yield_0.0657             425.042  -     21   +     22       False
# frac_Mbc_bkg1_0.0657             -0.0965259  -  0.047   +  0.049       False
# frac_deltaE_bkg1_0.0657            0.224577  -   0.15   +   0.15       False
# True
# Iteration 2 - Signal Yield: 34.92077375816035 ± 8.277418232232794
# Running iteration 3/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2091                 37.1553  -      8   +    8.8       False
# background_yield_0.2091             422.869  -     21   +     22       False
# frac_Mbc_bkg1_0.2091              -0.101337  -  0.046   +  0.049       False
# frac_deltaE_bkg1_0.2091            0.209034  -   0.15   +   0.15       False
# True
# Iteration 3 - Signal Yield: 37.15530893439018 ± 8.388069314802376
# Running iteration 4/300...
# 50
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.872                 40.5925  -      8   +    8.8       False
# background_yield_0.872             419.353  -     21   +     22       False
# frac_Mbc_bkg1_0.872              -0.127785  -  0.045   +  0.048       False
# frac_deltaE_bkg1_0.872            0.215275  -   0.15   +   0.15       False
# True
# Iteration 4 - Signal Yield: 40.5924600510769 ± 8.436040939793052
# Running iteration 5/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5195                 40.9947  -    8.1   +    8.8       False
# background_yield_0.5195             419.012  -     21   +     22       False
# frac_Mbc_bkg1_0.5195              -0.117535  -  0.045   +  0.048       False
# frac_deltaE_bkg1_0.5195            0.203307  -   0.15   +   0.15       False
# True
# Iteration 5 - Signal Yield: 40.99473858728085 ± 8.431873644009542
# Running iteration 6/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5882                 36.9289  -    7.8   +    8.7       False
# background_yield_0.5882             422.932  -     21   +     22       False
# frac_Mbc_bkg1_0.5882              -0.109326  -  0.046   +  0.048       False
# frac_deltaE_bkg1_0.5882            0.223876  -   0.15   +   0.15       False
# True
# Iteration 6 - Signal Yield: 36.928892840165375 ± 8.250645183601367
# Running iteration 7/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5633                 41.6305  -    7.9   +    8.7       False
# background_yield_0.5633             418.937  -     21   +     21       False
# frac_Mbc_bkg1_0.5633              -0.122397  -  0.045   +  0.046       False
# frac_deltaE_bkg1_0.5633            0.211928  -   0.15   +   0.15       False
# True
# Iteration 7 - Signal Yield: 41.63048999142113 ± 8.310916535853494
# Running iteration 8/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1511                  37.296  -    8.1   +    8.8       False
# background_yield_0.1511             422.732  -     21   +     22       False
# frac_Mbc_bkg1_0.1511              -0.114369  -  0.046   +  0.049       False
# frac_deltaE_bkg1_0.1511            0.218483  -   0.15   +   0.15       False
# True
# Iteration 8 - Signal Yield: 37.29597384299315 ± 8.433373004248903
# Running iteration 9/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5509                 36.6446  -    7.7   +    8.6       False
# background_yield_0.5509             423.154  -     21   +     22       False
# frac_Mbc_bkg1_0.5509              -0.120256  -  0.046   +  0.048       False
# frac_deltaE_bkg1_0.5509            0.202063  -   0.15   +   0.15       False
# True
# Iteration 9 - Signal Yield: 36.64464401790612 ± 8.161859994771259
# Running iteration 10/300...
# 50
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.539                 30.0355  -    7.5   +    7.9       False
# background_yield_0.539               430.1  -     21   +     22       False
# frac_Mbc_bkg1_0.539              -0.087444  -  0.045   +  0.049       False
# frac_deltaE_bkg1_0.539            0.167727  -   0.15   +   0.15       False
# True
# Iteration 10 - Signal Yield: 30.035447664638898 ± 7.669757047708162
# Running iteration 11/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2997                 39.5472  -    8.2   +    8.9       False
# background_yield_0.2997              420.45  -     21   +     22       False
# frac_Mbc_bkg1_0.2997              -0.116208  -  0.046   +  0.049       False
# frac_deltaE_bkg1_0.2997             0.18063  -   0.15   +   0.15       False
# True
# Iteration 11 - Signal Yield: 39.547194158401254 ± 8.553909834869408
# Running iteration 12/300...
# 50
# 410
# name                     value  (rounded)               errors    at limit
# ---------------------  ------------------  -------------------  ----------
# signal_yield_0.91                 39.0129  -      8   +    8.7       False
# background_yield_0.91             421.006  -     21   +     22       False
# frac_Mbc_bkg1_0.91              -0.117221  -  0.045   +  0.048       False
# frac_deltaE_bkg1_0.91            0.224383  -   0.15   +   0.15       False
# True
# Iteration 12 - Signal Yield: 39.01290201700252 ± 8.347792706692928
# Running iteration 13/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1688                  38.183  -    7.9   +    8.7       False
# background_yield_0.1688             421.761  -     21   +     22       False
# frac_Mbc_bkg1_0.1688              -0.112395  -  0.046   +  0.048       False
# frac_deltaE_bkg1_0.1688            0.221108  -   0.15   +   0.15       False
# True
# Iteration 13 - Signal Yield: 38.18295751086152 ± 8.28015134608295
# Running iteration 14/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8088                 40.9322  -      8   +    8.8       False
# background_yield_0.8088             419.013  -     21   +     22       False
# frac_Mbc_bkg1_0.8088              -0.129246  -  0.045   +  0.048       False
# frac_deltaE_bkg1_0.8088            0.175574  -   0.15   +   0.15       False
# True
# Iteration 14 - Signal Yield: 40.932204665228674 ± 8.395830595068862
# Running iteration 15/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2964                 31.2184  -    7.5   +    8.2       False
# background_yield_0.2964             428.819  -     21   +     22       False
# frac_Mbc_bkg1_0.2964             -0.0829373  -  0.046   +  0.049       False
# frac_deltaE_bkg1_0.2964            0.197698  -   0.15   +   0.15       False
# True
# Iteration 15 - Signal Yield: 31.21835083590758 ± 7.816741479897809
# Running iteration 16/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5951                 42.0907  -      8   +    8.8       False
# background_yield_0.5951             417.813  -     21   +     22       False
# frac_Mbc_bkg1_0.5951              -0.135025  -  0.045   +  0.047       False
# frac_deltaE_bkg1_0.5951            0.185926  -   0.15   +   0.15       False
# True
# Iteration 16 - Signal Yield: 42.09074455162251 ± 8.364887582230358
# Running iteration 17/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0586                 42.2824  -    8.1   +    8.8       False
# background_yield_0.0586             418.219  -     21   +     21       False
# frac_Mbc_bkg1_0.0586              -0.130107  -  0.045   +  0.048       False
# frac_deltaE_bkg1_0.0586            0.200822  -   0.15   +   0.15       False
# True
# Iteration 17 - Signal Yield: 42.28243112061275 ± 8.462342939462353
# Running iteration 18/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0956                 33.5452  -    7.4   +    8.3       False
# background_yield_0.0956             426.243  -     21   +     22       False
# frac_Mbc_bkg1_0.0956             -0.0943678  -  0.045   +  0.048       False
# frac_deltaE_bkg1_0.0956            0.179403  -   0.15   +   0.15       False
# True
# Iteration 18 - Signal Yield: 33.545211520940605 ± 7.874409112836845
# Running iteration 19/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7241                 35.7036  -    7.9   +    8.7       False
# background_yield_0.7241             424.219  -     21   +     22       False
# frac_Mbc_bkg1_0.7241              -0.107977  -  0.046   +  0.049       False
# frac_deltaE_bkg1_0.7241            0.236008  -   0.15   +   0.15       False
# True
# Iteration 19 - Signal Yield: 35.70360784132978 ± 8.291231333395558
# Running iteration 20/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5009                  37.426  -    8.1   +    8.8       False
# background_yield_0.5009             422.607  -     21   +     22       False
# frac_Mbc_bkg1_0.5009              -0.105128  -  0.046   +  0.049       False
# frac_deltaE_bkg1_0.5009            0.214525  -   0.15   +   0.15       False
# True
# Iteration 20 - Signal Yield: 37.42596524322117 ± 8.479960634542877
# Running iteration 21/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8238                 41.4634  -    8.1   +    8.8       False
# background_yield_0.8238             418.535  -     21   +     22       False
# frac_Mbc_bkg1_0.8238               -0.12701  -  0.045   +  0.048       False
# frac_deltaE_bkg1_0.8238            0.197548  -   0.15   +   0.15       False
# True
# Iteration 21 - Signal Yield: 41.4633551098414 ± 8.431442238106307
# Running iteration 22/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3747                  32.609  -    7.7   +    8.6       False
# background_yield_0.3747             427.212  -     21   +     22       False
# frac_Mbc_bkg1_0.3747             -0.0908775  -  0.047   +  0.049       False
# frac_deltaE_bkg1_0.3747            0.205395  -   0.15   +   0.15       False
# True
# Iteration 22 - Signal Yield: 32.60898283656734 ± 8.134137725771069
# Running iteration 23/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1656                 36.9292  -    7.7   +    8.5       False
# background_yield_0.1656              422.95  -     21   +     22       False
# frac_Mbc_bkg1_0.1656              -0.108717  -  0.045   +  0.048       False
# frac_deltaE_bkg1_0.1656            0.193841  -   0.15   +   0.15       False
# True
# Iteration 23 - Signal Yield: 36.92922488088564 ± 8.087362814877462
# Running iteration 24/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4338                 39.6541  -    8.2   +    8.9       False
# background_yield_0.4338             420.361  -     21   +     22       False
# frac_Mbc_bkg1_0.4338              -0.113953  -  0.046   +  0.049       False
# frac_deltaE_bkg1_0.4338            0.215978  -   0.15   +   0.15       False
# True
# Iteration 24 - Signal Yield: 39.65406485487247 ± 8.548801216386064
# Running iteration 25/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3684                 39.0241  -    8.1   +    8.8       False
# background_yield_0.3684             421.008  -     21   +     22       False
# frac_Mbc_bkg1_0.3684              -0.111563  -  0.046   +  0.049       False
# frac_deltaE_bkg1_0.3684            0.217217  -   0.15   +   0.15       False
# True
# Iteration 25 - Signal Yield: 39.02404818233727 ± 8.425259017801412
# Running iteration 26/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5446                 41.9101  -    8.1   +    8.8       False
# background_yield_0.5446              418.04  -     21   +     22       False
# frac_Mbc_bkg1_0.5446              -0.131629  -  0.045   +  0.048       False
# frac_deltaE_bkg1_0.5446            0.208778  -   0.15   +   0.15       False
# True
# Iteration 26 - Signal Yield: 41.91010375672193 ± 8.44170374705461
# Running iteration 27/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4405                  40.259  -      8   +    8.7       False
# background_yield_0.4405             419.699  -     21   +     22       False
# frac_Mbc_bkg1_0.4405              -0.123466  -  0.045   +  0.048       False
# frac_deltaE_bkg1_0.4405             0.20381  -   0.15   +   0.15       False
# True
# Iteration 27 - Signal Yield: 40.25897476426777 ± 8.34572008941918
# Running iteration 28/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0547                 34.4811  -    7.5   +    8.4       False
# background_yield_0.0547             425.334  -     21   +     22       False
# frac_Mbc_bkg1_0.0547              -0.104058  -  0.046   +  0.048       False
# frac_deltaE_bkg1_0.0547            0.169113  -   0.15   +   0.15       False
# True
# Iteration 28 - Signal Yield: 34.481103797743145 ± 7.965621053520192
# Running iteration 29/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6166                 33.9267  -    7.5   +    8.4       False
# background_yield_0.6166             425.946  -     21   +     22       False
# frac_Mbc_bkg1_0.6166             -0.0883557  -  0.046   +  0.048       False
# frac_deltaE_bkg1_0.6166            0.209233  -   0.15   +   0.15       False
# True
# Iteration 29 - Signal Yield: 33.92673157290385 ± 7.979696779741941
# Running iteration 30/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1432                 44.7578  -      8   +    8.7       False
# background_yield_0.1432             415.167  -     21   +     21       False
# frac_Mbc_bkg1_0.1432              -0.150484  -  0.043   +  0.046       False
# frac_deltaE_bkg1_0.1432            0.196227  -   0.15   +   0.15       False
# True
# Iteration 30 - Signal Yield: 44.757797834600936 ± 8.328874789989108
# Running iteration 31/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3917                 43.3646  -    8.1   +    8.9       False
# background_yield_0.3917             416.586  -     21   +     21       False
# frac_Mbc_bkg1_0.3917              -0.132165  -  0.045   +  0.047       False
# frac_deltaE_bkg1_0.3917            0.204468  -   0.15   +   0.15       False
# True
# Iteration 31 - Signal Yield: 43.36455317356243 ± 8.466638195806256
# Running iteration 32/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8123                 35.4632  -    7.8   +    8.6       False
# background_yield_0.8123             424.459  -     21   +     22       False
# frac_Mbc_bkg1_0.8123              -0.102005  -  0.046   +  0.049       False
# frac_deltaE_bkg1_0.8123            0.239308  -   0.15   +   0.15       False
# True
# Iteration 32 - Signal Yield: 35.46322812270996 ± 8.236025062937234
# Running iteration 33/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8403                 39.0393  -    8.2   +    8.9       False
# background_yield_0.8403             420.969  -     21   +     22       False
# frac_Mbc_bkg1_0.8403              -0.112715  -  0.046   +  0.049       False
# frac_deltaE_bkg1_0.8403            0.240308  -   0.15   +   0.15       False
# True
# Iteration 33 - Signal Yield: 39.03925492937542 ± 8.57719532429363
# Running iteration 34/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6556                 40.0603  -    8.1   +    8.8       False
# background_yield_0.6556             419.937  -     21   +     22       False
# frac_Mbc_bkg1_0.6556              -0.118173  -  0.046   +  0.048       False
# frac_deltaE_bkg1_0.6556            0.181749  -   0.15   +   0.15       False
# True
# Iteration 34 - Signal Yield: 40.060306676619064 ± 8.474136504833266
# Running iteration 35/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7612                 42.2381  -    8.1   +      9       False
# background_yield_0.7612             417.837  -     21   +     21       False
# frac_Mbc_bkg1_0.7612              -0.130451  -  0.046   +  0.047       False
# frac_deltaE_bkg1_0.7612            0.206953  -   0.15   +   0.15       False
# True
# Iteration 35 - Signal Yield: 42.23810343855134 ± 8.528015644494998
# Running iteration 36/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2214                 40.9589  -    8.1   +    8.8       False
# background_yield_0.2214             419.008  -     21   +     22       False
# frac_Mbc_bkg1_0.2214              -0.124191  -  0.045   +  0.048       False
# frac_deltaE_bkg1_0.2214             0.21827  -   0.15   +   0.15       False
# True
# Iteration 36 - Signal Yield: 40.95894104542994 ± 8.467176910702968
# Running iteration 37/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4874                 28.7999  -    7.6   +    8.4       False
# background_yield_0.4874             431.223  -     21   +     22       False
# frac_Mbc_bkg1_0.4874             -0.0717411  -  0.047   +   0.05       False
# frac_deltaE_bkg1_0.4874            0.220507  -   0.15   +   0.15       False
# True
# Iteration 37 - Signal Yield: 28.799890461058407 ± 8.014852800128097
# Running iteration 38/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3042                 40.6112  -    8.1   +    8.9       False
# background_yield_0.3042              419.32  -     21   +     22       False
# frac_Mbc_bkg1_0.3042              -0.124285  -  0.046   +  0.048       False
# frac_deltaE_bkg1_0.3042            0.179162  -   0.15   +   0.15       False
# True
# Iteration 38 - Signal Yield: 40.61118800947554 ± 8.482743762642265
# Running iteration 39/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1941                 32.2242  -    7.7   +    8.5       False
# background_yield_0.1941             427.719  -     21   +     22       False
# frac_Mbc_bkg1_0.1941             -0.0816753  -  0.047   +  0.049       False
# frac_deltaE_bkg1_0.1941            0.222023  -   0.15   +   0.15       False
# True
# Iteration 39 - Signal Yield: 32.22416263939799 ± 8.07710160694206
# Running iteration 40/300...
# 50
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.361                 35.8105  -    7.7   +    8.5       False
# background_yield_0.361             424.099  -     21   +     22       False
# frac_Mbc_bkg1_0.361              -0.107791  -  0.046   +  0.048       False
# frac_deltaE_bkg1_0.361            0.223944  -   0.15   +   0.15       False
# True
# Iteration 40 - Signal Yield: 35.81052471780539 ± 8.093082542626416
# Running iteration 41/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0531                 39.3676  -      8   +    8.8       False
# background_yield_0.0531             420.576  -     21   +     22       False
# frac_Mbc_bkg1_0.0531              -0.115882  -  0.046   +  0.048       False
# frac_deltaE_bkg1_0.0531            0.212728  -   0.15   +   0.15       False
# True
# Iteration 41 - Signal Yield: 39.36764830088809 ± 8.405829968857336
# Running iteration 42/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5448                 39.5831  -    8.1   +    8.8       False
# background_yield_0.5448             420.373  -     21   +     22       False
# frac_Mbc_bkg1_0.5448              -0.112399  -  0.046   +  0.048       False
# frac_deltaE_bkg1_0.5448            0.205146  -   0.15   +   0.15       False
# True
# Iteration 42 - Signal Yield: 39.58314234489569 ± 8.452365652927345
# Running iteration 43/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4645                 40.9051  -    8.1   +    8.9       False
# background_yield_0.4645             418.979  -     21   +     22       False
# frac_Mbc_bkg1_0.4645              -0.133774  -  0.046   +  0.048       False
# frac_deltaE_bkg1_0.4645            0.213408  -   0.15   +   0.15       False
# True
# Iteration 43 - Signal Yield: 40.90511237972581 ± 8.479796176190192
# Running iteration 44/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0938                 41.5074  -    8.1   +    8.8       False
# background_yield_0.0938             418.371  -     21   +     22       False
# frac_Mbc_bkg1_0.0938              -0.125099  -  0.044   +  0.048       False
# frac_deltaE_bkg1_0.0938            0.182476  -   0.15   +   0.15       False
# True
# Iteration 44 - Signal Yield: 41.50735415899544 ± 8.43252238949163
# Running iteration 45/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4311                  38.048  -    7.8   +    8.6       False
# background_yield_0.4311              421.87  -     21   +     22       False
# frac_Mbc_bkg1_0.4311              -0.113889  -  0.046   +  0.048       False
# frac_deltaE_bkg1_0.4311            0.203039  -   0.15   +   0.15       False
# True
# Iteration 45 - Signal Yield: 38.048005839996996 ± 8.244773814672781
# Running iteration 46/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3564                 43.2562  -    8.1   +    8.8       False
# background_yield_0.3564             416.742  -     21   +     21       False
# frac_Mbc_bkg1_0.3564              -0.134241  -  0.044   +  0.047       False
# frac_deltaE_bkg1_0.3564            0.196261  -   0.15   +   0.15       False
# True
# Iteration 46 - Signal Yield: 43.25615796119175 ± 8.431163143570679
# Running iteration 47/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2352                 37.2238  -    7.9   +    8.7       False
# background_yield_0.2352             422.678  -     21   +     22       False
# frac_Mbc_bkg1_0.2352              -0.115962  -  0.046   +  0.048       False
# frac_deltaE_bkg1_0.2352            0.214582  -   0.15   +   0.15       False
# True
# Iteration 47 - Signal Yield: 37.22375671651322 ± 8.301311348440684
# Running iteration 48/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8614                  41.617  -    8.2   +    8.9       False
# background_yield_0.8614             418.412  -     21   +     22       False
# frac_Mbc_bkg1_0.8614              -0.134423  -  0.046   +  0.049       False
# frac_deltaE_bkg1_0.8614            0.213511  -   0.15   +   0.15       False
# True
# Iteration 48 - Signal Yield: 41.616993746922596 ± 8.57827926573814
# Running iteration 49/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1017                 35.3944  -    7.8   +    8.6       False
# background_yield_0.1017             424.548  -     21   +     22       False
# frac_Mbc_bkg1_0.1017              -0.100029  -  0.046   +  0.049       False
# frac_deltaE_bkg1_0.1017            0.173576  -   0.15   +   0.15       False
# True
# Iteration 49 - Signal Yield: 35.39443155727356 ± 8.21154395305685
# Running iteration 50/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0964                 39.9379  -    8.2   +      9       False
# background_yield_0.0964             420.061  -     21   +     22       False
# frac_Mbc_bkg1_0.0964               -0.11651  -  0.046   +  0.049       False
# frac_deltaE_bkg1_0.0964            0.202016  -   0.15   +   0.15       False
# True
# Iteration 50 - Signal Yield: 39.9379255248743 ± 8.586439882017363
# Running iteration 51/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9956                 43.3023  -    8.2   +    9.1       False
# background_yield_0.9956             416.156  -     20   +     22       False
# frac_Mbc_bkg1_0.9956              -0.133178  -  0.045   +  0.049       False
# frac_deltaE_bkg1_0.9956            0.201316  -   0.15   +   0.15       False
# True
# Iteration 51 - Signal Yield: 43.30225689971413 ± 8.671389614502992
# Running iteration 52/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8665                 33.8079  -    7.6   +    8.5       False
# background_yield_0.8665             426.049  -     21   +     22       False
# frac_Mbc_bkg1_0.8665              -0.103933  -  0.046   +  0.048       False
# frac_deltaE_bkg1_0.8665            0.221311  -   0.15   +   0.15       False
# True
# Iteration 52 - Signal Yield: 33.80785890156137 ± 8.053576597839356
# Running iteration 53/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2101                 44.5596  -    8.1   +    8.8       False
# background_yield_0.2101             415.432  -     21   +     21       False
# frac_Mbc_bkg1_0.2101              -0.147863  -  0.044   +  0.047       False
# frac_deltaE_bkg1_0.2101            0.188094  -   0.15   +   0.15       False
# True
# Iteration 53 - Signal Yield: 44.559635199512 ± 8.439416215617129
# Running iteration 54/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4931                 32.7315  -    7.6   +    8.4       False
# background_yield_0.4931              427.14  -     21   +     22       False
# frac_Mbc_bkg1_0.4931             -0.0873565  -  0.046   +  0.049       False
# frac_deltaE_bkg1_0.4931            0.199189  -   0.15   +   0.15       False
# True
# Iteration 54 - Signal Yield: 32.7315482694837 ± 8.005257328584733
# Running iteration 55/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2567                 43.4284  -    8.1   +    8.7       False
# background_yield_0.2567             416.815  -     21   +     21       False
# frac_Mbc_bkg1_0.2567              -0.142667  -  0.044   +  0.047       False
# frac_deltaE_bkg1_0.2567            0.214856  -   0.15   +   0.15       False
# True
# Iteration 55 - Signal Yield: 43.42843232867967 ± 8.395906661155891
# Running iteration 56/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4662                 41.4732  -      8   +    8.8       False
# background_yield_0.4662             418.459  -     21   +     22       False
# frac_Mbc_bkg1_0.4662              -0.130577  -  0.045   +  0.048       False
# frac_deltaE_bkg1_0.4662            0.208129  -   0.15   +   0.15       False
# True
# Iteration 56 - Signal Yield: 41.47317341263759 ± 8.425006509209787
# Running iteration 57/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3193                 40.2556  -    7.9   +    8.7       False
# background_yield_0.3193             419.756  -     21   +     22       False
# frac_Mbc_bkg1_0.3193              -0.128153  -  0.045   +  0.048       False
# frac_deltaE_bkg1_0.3193             0.19013  -   0.15   +   0.15       False
# True
# Iteration 57 - Signal Yield: 40.25557408084548 ± 8.30342208215363
# Running iteration 58/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2997                 36.5994  -      8   +    8.8       False
# background_yield_0.2997             423.433  -     21   +     22       False
# frac_Mbc_bkg1_0.2997              -0.105488  -  0.046   +  0.049       False
# frac_deltaE_bkg1_0.2997            0.226905  -   0.15   +   0.15       False
# True
# Iteration 58 - Signal Yield: 36.59944420502628 ± 8.397023713260545
# Running iteration 59/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9947                  35.295  -    7.7   +    8.6       False
# background_yield_0.9947              424.56  -     21   +     22       False
# frac_Mbc_bkg1_0.9947              -0.106121  -  0.046   +  0.049       False
# frac_deltaE_bkg1_0.9947            0.207614  -   0.15   +   0.15       False
# True
# Iteration 59 - Signal Yield: 35.295044552353104 ± 8.127726108977864
# Running iteration 60/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3304                 36.8233  -    8.1   +    8.8       False
# background_yield_0.3304             423.198  -     21   +     22       False
# frac_Mbc_bkg1_0.3304              -0.108168  -  0.047   +  0.049       False
# frac_deltaE_bkg1_0.3304             0.26053  -   0.15   +   0.15       False
# True
# Iteration 60 - Signal Yield: 36.823249046417 ± 8.47707766182237
# Running iteration 61/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6435                 33.8147  -    7.5   +    8.4       False
# background_yield_0.6435             426.026  -     21   +     22       False
# frac_Mbc_bkg1_0.6435               -0.10059  -  0.046   +  0.048       False
# frac_deltaE_bkg1_0.6435             0.18917  -   0.15   +   0.15       False
# True
# Iteration 61 - Signal Yield: 33.81471591026105 ± 7.938291445677942
# Running iteration 62/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9505                 39.8468  -    8.1   +    8.8       False
# background_yield_0.9505             420.166  -     21   +     22       False
# frac_Mbc_bkg1_0.9505              -0.117788  -  0.046   +  0.048       False
# frac_deltaE_bkg1_0.9505            0.191002  -   0.15   +   0.15       False
# True
# Iteration 62 - Signal Yield: 39.846748489786975 ± 8.469156141062573
# Running iteration 63/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4706                 41.3075  -    8.2   +    9.1       False
# background_yield_0.4706             418.903  -     21   +     21       False
# frac_Mbc_bkg1_0.4706              -0.126999  -  0.047   +  0.047       False
# frac_deltaE_bkg1_0.4706             0.19733  -   0.15   +   0.15       False
# True
# Iteration 63 - Signal Yield: 41.30749844664638 ± 8.6610889641133
# Running iteration 64/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8192                 40.9883  -      8   +    8.8       False
# background_yield_0.8192             418.972  -     21   +     22       False
# frac_Mbc_bkg1_0.8192               -0.12497  -  0.045   +  0.048       False
# frac_deltaE_bkg1_0.8192            0.240238  -   0.15   +   0.15       False
# True
# Iteration 64 - Signal Yield: 40.98831651756338 ± 8.433334796279599
# Running iteration 65/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9768                 40.7386  -    8.1   +    8.8       False
# background_yield_0.9768              419.23  -     21   +     22       False
# frac_Mbc_bkg1_0.9768              -0.122477  -  0.046   +  0.048       False
# frac_deltaE_bkg1_0.9768            0.194057  -   0.15   +   0.15       False
# True
# Iteration 65 - Signal Yield: 40.73857653808116 ± 8.45746972288983
# Running iteration 66/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6823                 35.6116  -    7.8   +    8.6       False
# background_yield_0.6823             424.321  -     21   +     22       False
# frac_Mbc_bkg1_0.6823              -0.099299  -  0.046   +  0.049       False
# frac_deltaE_bkg1_0.6823             0.23852  -   0.15   +   0.15       False
# True
# Iteration 66 - Signal Yield: 35.611567151129414 ± 8.210342525615394
# Running iteration 67/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7168                 45.1582  -    8.4   +    8.9       False
# background_yield_0.7168             415.614  -     21   +     21       False
# frac_Mbc_bkg1_0.7168              -0.143854  -  0.045   +  0.048       False
# frac_deltaE_bkg1_0.7168            0.205765  -   0.15   +   0.15       False
# True
# Iteration 67 - Signal Yield: 45.15819621627777 ± 8.652761165582643
# Running iteration 68/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3672                 36.3352  -    8.1   +    8.8       False
# background_yield_0.3672             423.714  -     21   +     22       False
# frac_Mbc_bkg1_0.3672              -0.112985  -  0.047   +   0.05       False
# frac_deltaE_bkg1_0.3672            0.241568  -   0.15   +   0.15       False
# True
# Iteration 68 - Signal Yield: 36.335210440102934 ± 8.496905374362917
# Running iteration 69/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7749                 33.4787  -      8   +    8.8       False
# background_yield_0.7749              426.44  -     21   +     22       False
# frac_Mbc_bkg1_0.7749             -0.0981332  -  0.048   +   0.05       False
# frac_deltaE_bkg1_0.7749            0.240266  -   0.15   +   0.15       False
# True
# Iteration 69 - Signal Yield: 33.478683091008136 ± 8.400105607268157
# Running iteration 70/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9741                  37.894  -    7.9   +    8.7       False
# background_yield_0.9741             421.942  -     21   +     22       False
# frac_Mbc_bkg1_0.9741              -0.118278  -  0.046   +  0.048       False
# frac_deltaE_bkg1_0.9741            0.205613  -   0.15   +   0.15       False
# True
# Iteration 70 - Signal Yield: 37.894001953706464 ± 8.277284501203816
# Running iteration 71/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3895                 38.6536  -    8.4   +    9.1       False
# background_yield_0.3895             421.353  -     21   +     22       False
# frac_Mbc_bkg1_0.3895              -0.112657  -  0.047   +   0.05       False
# frac_deltaE_bkg1_0.3895            0.243809  -   0.15   +   0.15       False
# True
# Iteration 71 - Signal Yield: 38.6536494662891 ± 8.732020070184827
# Running iteration 72/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2486                 36.5523  -      8   +    8.8       False
# background_yield_0.2486              423.47  -     21   +     22       False
# frac_Mbc_bkg1_0.2486             -0.0994556  -  0.046   +  0.049       False
# frac_deltaE_bkg1_0.2486            0.239907  -   0.15   +   0.15       False
# True
# Iteration 72 - Signal Yield: 36.552338025558534 ± 8.381815987748547
# Running iteration 73/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7783                 41.4091  -      8   +    8.9       False
# background_yield_0.7783             418.653  -     21   +     21       False
# frac_Mbc_bkg1_0.7783              -0.121561  -  0.046   +  0.047       False
# frac_deltaE_bkg1_0.7783            0.199179  -   0.15   +   0.15       False
# True
# Iteration 73 - Signal Yield: 41.409059131022396 ± 8.446281860579223
# Running iteration 74/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9046                 34.8729  -    7.8   +    8.6       False
# background_yield_0.9046             425.066  -     21   +     22       False
# frac_Mbc_bkg1_0.9046             -0.0986179  -  0.046   +  0.049       False
# frac_deltaE_bkg1_0.9046            0.217871  -   0.15   +   0.15       False
# True
# Iteration 74 - Signal Yield: 34.872923375555466 ± 8.241265402271083
# Running iteration 75/300...
# 50
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.507                 34.6689  -    7.8   +    8.7       False
# background_yield_0.507             424.976  -     21   +     22       False
# frac_Mbc_bkg1_0.507              -0.110912  -  0.047   +  0.049       False
# frac_deltaE_bkg1_0.507            0.246391  -   0.15   +   0.15       False
# True
# Iteration 75 - Signal Yield: 34.668856228978306 ± 8.244286722760073
# Running iteration 76/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6801                 36.6221  -    8.1   +    8.8       False
# background_yield_0.6801             423.394  -     21   +     22       False
# frac_Mbc_bkg1_0.6801              -0.106537  -  0.047   +  0.049       False
# frac_deltaE_bkg1_0.6801            0.239383  -   0.15   +   0.15       False
# True
# Iteration 76 - Signal Yield: 36.622082068884374 ± 8.442357651110065
# Running iteration 77/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1714                 32.9626  -    7.7   +    8.5       False
# background_yield_0.1714             426.969  -     21   +     22       False
# frac_Mbc_bkg1_0.1714             -0.0902174  -  0.047   +  0.049       False
# frac_deltaE_bkg1_0.1714            0.220293  -   0.15   +   0.15       False
# True
# Iteration 77 - Signal Yield: 32.96257447568376 ± 8.130733836713226
# Running iteration 78/300...
# 50
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.067                 31.5307  -    7.6   +    8.4       False
# background_yield_0.067             428.467  -     21   +     22       False
# frac_Mbc_bkg1_0.067             -0.0831711  -  0.047   +  0.049       False
# frac_deltaE_bkg1_0.067            0.240744  -   0.15   +   0.15       False
# True
# Iteration 78 - Signal Yield: 31.530710604163296 ± 8.013928907823486
# Running iteration 79/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7152                 43.8847  -    8.2   +    8.9       False
# background_yield_0.7152             415.981  -     21   +     22       False
# frac_Mbc_bkg1_0.7152              -0.143634  -  0.045   +  0.048       False
# frac_deltaE_bkg1_0.7152            0.182775  -   0.15   +   0.15       False
# True
# Iteration 79 - Signal Yield: 43.88467931480661 ± 8.559435993252382
# Running iteration 80/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5002                 43.2848  -    7.9   +    8.6       False
# background_yield_0.5002             416.714  -     21   +     21       False
# frac_Mbc_bkg1_0.5002              -0.137471  -  0.044   +  0.047       False
# frac_deltaE_bkg1_0.5002            0.163568  -   0.15   +   0.15       False
# True
# Iteration 80 - Signal Yield: 43.28480948700993 ± 8.278994876447788
# Running iteration 81/300...
# 50
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.483                  40.265  -      8   +    8.8       False
# background_yield_0.483             419.724  -     21   +     22       False
# frac_Mbc_bkg1_0.483              -0.119907  -  0.045   +  0.048       False
# frac_deltaE_bkg1_0.483            0.184055  -   0.15   +   0.15       False
# True
# Iteration 81 - Signal Yield: 40.26502836270613 ± 8.410396244613631
# Running iteration 82/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3575                 41.8333  -    8.2   +    8.9       False
# background_yield_0.3575             418.821  -     21   +     21       False
# frac_Mbc_bkg1_0.3575               -0.12904  -  0.046   +  0.048       False
# frac_deltaE_bkg1_0.3575             0.21522  -   0.15   +   0.15       False
# True
# Iteration 82 - Signal Yield: 41.83330415078908 ± 8.544967113398014
# Running iteration 83/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1944                 40.2336  -    8.2   +    8.9       False
# background_yield_0.1944              419.76  -     21   +     22       False
# frac_Mbc_bkg1_0.1944              -0.117507  -  0.046   +  0.049       False
# frac_deltaE_bkg1_0.1944            0.199296  -   0.15   +   0.15       False
# True
# Iteration 83 - Signal Yield: 40.23358448182493 ± 8.520470376151614
# Running iteration 84/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7131                  40.174  -    7.9   +    8.7       False
# background_yield_0.7131             419.763  -     21   +     22       False
# frac_Mbc_bkg1_0.7131              -0.128383  -  0.044   +  0.047       False
# frac_deltaE_bkg1_0.7131            0.223093  -   0.15   +   0.15       False
# True
# Iteration 84 - Signal Yield: 40.174003814260196 ± 8.253826071376764
# Running iteration 85/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0456                 37.9315  -    7.9   +    8.7       False
# ...
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0918                 40.5292  -      8   +    8.8       False
# background_yield_0.0918             419.452  -     21   +     22       False
# frac_Mbc_bkg1_0.0918              -0.119658  -  0.045   +  0.048       False
# frac_deltaE_bkg1_0.0918            0.196004  -   0.15   +   0.15       False
# True
# Iteration 273 - Signal Yield: 40.52919478434576 ± 8.399180759286477
# Running iteration 274/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5635                 32.9202  -    7.6   +    8.5       False
# background_yield_0.5635              426.93  -     21   +     22       False
# frac_Mbc_bkg1_0.5635             -0.0867056  -  0.046   +  0.048       False
# frac_deltaE_bkg1_0.5635            0.185782  -   0.15   +   0.15       False
# True
# Iteration 274 - Signal Yield: 32.9201725892441 ± 8.03973506231111
# Running iteration 275/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6673                 44.7078  -    8.2   +    8.9       False
# background_yield_0.6673             415.234  -     21   +     21       False
# frac_Mbc_bkg1_0.6673               -0.13742  -  0.044   +  0.047       False
# frac_deltaE_bkg1_0.6673            0.194125  -   0.15   +   0.15       False
# True
# Iteration 275 - Signal Yield: 44.70775814068695 ± 8.568532481297135
# Running iteration 276/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9528                 46.1128  -    8.2   +    8.9       False
# background_yield_0.9528             413.887  -     21   +     21       False
# frac_Mbc_bkg1_0.9528              -0.156775  -  0.044   +  0.047       False
# frac_deltaE_bkg1_0.9528            0.206912  -   0.15   +   0.15       False
# True
# Iteration 276 - Signal Yield: 46.11280521443952 ± 8.547500645954466
# Running iteration 277/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7789                 40.6578  -      8   +    8.8       False
# background_yield_0.7789             419.359  -     21   +     22       False
# frac_Mbc_bkg1_0.7789              -0.116254  -  0.045   +  0.048       False
# frac_deltaE_bkg1_0.7789            0.206611  -   0.15   +   0.15       False
# True
# Iteration 277 - Signal Yield: 40.65777202806937 ± 8.404729533493043
# Running iteration 278/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1216                  39.637  -      8   +    8.8       False
# background_yield_0.1216             420.387  -     21   +     22       False
# frac_Mbc_bkg1_0.1216              -0.116865  -  0.045   +  0.048       False
# frac_deltaE_bkg1_0.1216            0.218737  -   0.15   +   0.15       False
# True
# Iteration 278 - Signal Yield: 39.63698175869071 ± 8.383618951279203
# Running iteration 279/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1735                 34.7921  -      8   +    8.7       False
# background_yield_0.1735             425.164  -     21   +     22       False
# frac_Mbc_bkg1_0.1735             -0.0937879  -  0.047   +  0.049       False
# frac_deltaE_bkg1_0.1735            0.220366  -   0.15   +   0.15       False
# True
# Iteration 279 - Signal Yield: 34.79210794835342 ± 8.34683834611336
# Running iteration 280/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0543                 41.3212  -    8.3   +    8.8       False
# background_yield_0.0543             419.128  -     21   +     21       False
# frac_Mbc_bkg1_0.0543              -0.125706  -  0.045   +  0.049       False
# frac_deltaE_bkg1_0.0543            0.220564  -   0.15   +   0.15       False
# True
# Iteration 280 - Signal Yield: 41.32125025408305 ± 8.555071252814603
# Running iteration 281/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0164                 40.3931  -    8.1   +    8.9       False
# background_yield_0.0164              419.55  -     21   +     22       False
# frac_Mbc_bkg1_0.0164              -0.122683  -  0.046   +  0.048       False
# frac_deltaE_bkg1_0.0164            0.228521  -   0.15   +   0.15       False
# True
# Iteration 281 - Signal Yield: 40.39311506523687 ± 8.541059503383948
# Running iteration 282/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0021                 32.9794  -    7.5   +    8.3       False
# background_yield_0.0021              426.94  -     21   +     22       False
# frac_Mbc_bkg1_0.0021             -0.0876542  -  0.046   +  0.048       False
# frac_deltaE_bkg1_0.0021            0.187629  -   0.15   +   0.15       False
# True
# Iteration 282 - Signal Yield: 32.97940237508321 ± 7.851233188956805
# Running iteration 283/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5572                  43.174  -    8.1   +    8.9       False
# background_yield_0.5572             416.835  -     21   +     21       False
# frac_Mbc_bkg1_0.5572              -0.133461  -  0.045   +  0.048       False
# frac_deltaE_bkg1_0.5572            0.181611  -   0.15   +   0.15       False
# True
# Iteration 283 - Signal Yield: 43.17399418033715 ± 8.501790047773612
# Running iteration 284/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1165                 38.8138  -    7.9   +    8.7       False
# background_yield_0.1165             421.207  -     21   +     22       False
# frac_Mbc_bkg1_0.1165              -0.110769  -  0.045   +  0.048       False
# frac_deltaE_bkg1_0.1165             0.21915  -   0.15   +   0.15       False
# True
# Iteration 284 - Signal Yield: 38.81375689536012 ± 8.300588174539884
# Running iteration 285/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4766                 30.4345  -    7.7   +    8.4       False
# background_yield_0.4766             429.563  -     21   +     22       False
# frac_Mbc_bkg1_0.4766             -0.0846684  -  0.047   +   0.05       False
# frac_deltaE_bkg1_0.4766            0.218802  -   0.15   +   0.15       False
# True
# Iteration 285 - Signal Yield: 30.43446873383085 ± 8.055748121527408
# Running iteration 286/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8218                 37.3752  -    7.8   +    8.6       False
# background_yield_0.8218             422.508  -     21   +     22       False
# frac_Mbc_bkg1_0.8218              -0.114383  -  0.046   +  0.048       False
# frac_deltaE_bkg1_0.8218            0.237582  -   0.15   +   0.15       False
# True
# Iteration 286 - Signal Yield: 37.37517703874459 ± 8.236964553890516
# Running iteration 287/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7584                 42.9759  -    8.2   +    8.9       False
# background_yield_0.7584             416.781  -     21   +     22       False
# frac_Mbc_bkg1_0.7584              -0.137444  -  0.044   +  0.048       False
# frac_deltaE_bkg1_0.7584            0.200744  -   0.15   +   0.15       False
# True
# Iteration 287 - Signal Yield: 42.9758550411575 ± 8.545140143272555
# Running iteration 288/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0199                 38.0992  -      8   +    8.7       False
# background_yield_0.0199             421.892  -     21   +     22       False
# frac_Mbc_bkg1_0.0199              -0.109179  -  0.046   +  0.048       False
# frac_deltaE_bkg1_0.0199            0.164923  -   0.15   +   0.15       False
# True
# Iteration 288 - Signal Yield: 38.09915647812494 ± 8.372954459923516
# Running iteration 289/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2976                 37.9493  -    7.8   +    8.6       False
# background_yield_0.2976             421.962  -     21   +     22       False
# frac_Mbc_bkg1_0.2976              -0.106437  -  0.045   +  0.048       False
# frac_deltaE_bkg1_0.2976            0.185162  -   0.15   +   0.15       False
# True
# Iteration 289 - Signal Yield: 37.9493295647077 ± 8.159525477382774
# Running iteration 290/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7923                 36.0643  -    8.1   +    8.8       False
# background_yield_0.7923             423.949  -     21   +     22       False
# frac_Mbc_bkg1_0.7923                -0.1013  -  0.046   +  0.049       False
# frac_deltaE_bkg1_0.7923            0.213561  -   0.15   +   0.15       False
# True
# Iteration 290 - Signal Yield: 36.06434425670545 ± 8.42876693403468
# Running iteration 291/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2004                 35.7277  -    7.9   +    8.7       False
# background_yield_0.2004             424.191  -     21   +     22       False
# frac_Mbc_bkg1_0.2004              -0.104132  -  0.047   +  0.049       False
# frac_deltaE_bkg1_0.2004            0.209116  -   0.15   +   0.15       False
# True
# Iteration 291 - Signal Yield: 35.72771576144178 ± 8.331095514810118
# Running iteration 292/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8739                 33.8466  -    7.6   +    8.4       False
# background_yield_0.8739             426.078  -     21   +     22       False
# frac_Mbc_bkg1_0.8739             -0.0899281  -  0.046   +  0.048       False
# frac_deltaE_bkg1_0.8739            0.194632  -   0.15   +   0.15       False
# True
# Iteration 292 - Signal Yield: 33.84659147161928 ± 8.037750984816899
# Running iteration 293/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3118                 36.5338  -    8.1   +    8.8       False
# background_yield_0.3118             423.495  -     21   +     22       False
# frac_Mbc_bkg1_0.3118              -0.099037  -  0.047   +  0.049       False
# frac_deltaE_bkg1_0.3118            0.210258  -   0.15   +   0.15       False
# True
# Iteration 293 - Signal Yield: 36.53376587041719 ± 8.447413320973585
# Running iteration 294/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1141                 36.2581  -      8   +    8.8       False
# background_yield_0.1141             423.633  -     21   +     22       False
# frac_Mbc_bkg1_0.1141              -0.109575  -  0.047   +  0.049       False
# frac_deltaE_bkg1_0.1141            0.219095  -   0.15   +   0.15       False
# True
# Iteration 294 - Signal Yield: 36.258057845572395 ± 8.39394046393375
# Running iteration 295/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6427                 41.1971  -    8.3   +    9.1       False
# background_yield_0.6427             418.566  -     21   +     22       False
# frac_Mbc_bkg1_0.6427              -0.125818  -  0.046   +  0.049       False
# frac_deltaE_bkg1_0.6427            0.231938  -   0.15   +   0.15       False
# True
# Iteration 295 - Signal Yield: 41.197081434044854 ± 8.694552618517982
# Running iteration 296/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4457                 45.1634  -    8.2   +      9       False
# background_yield_0.4457             414.766  -     21   +     21       False
# frac_Mbc_bkg1_0.4457              -0.150339  -  0.044   +  0.047       False
# frac_deltaE_bkg1_0.4457            0.209041  -   0.15   +   0.15       False
# True
# Iteration 296 - Signal Yield: 45.16341739245396 ± 8.595830061684065
# Running iteration 297/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1065                 41.9198  -    8.1   +    8.9       False
# background_yield_0.1065             417.985  -     21   +     22       False
# frac_Mbc_bkg1_0.1065              -0.132795  -  0.045   +  0.048       False
# frac_deltaE_bkg1_0.1065            0.183802  -   0.15   +   0.15       False
# True
# Iteration 297 - Signal Yield: 41.9197740810202 ± 8.474330647261429
# Running iteration 298/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3132                  37.734  -    7.9   +    8.7       False
# background_yield_0.3132             422.226  -     21   +     22       False
# frac_Mbc_bkg1_0.3132              -0.109478  -  0.046   +  0.048       False
# frac_deltaE_bkg1_0.3132            0.199569  -   0.15   +   0.15       False
# True
# Iteration 298 - Signal Yield: 37.733979779329474 ± 8.2651133257705
# Running iteration 299/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2034                 38.7277  -      8   +    8.7       False
# background_yield_0.2034               421.3  -     21   +     22       False
# frac_Mbc_bkg1_0.2034              -0.116329  -  0.045   +  0.048       False
# frac_deltaE_bkg1_0.2034            0.181663  -   0.15   +   0.15       False
# True
# Iteration 299 - Signal Yield: 38.72773486485656 ± 8.365581159803687
# Running iteration 300/300...
# 50
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7963                  33.874  -    7.8   +    8.7       False
# background_yield_0.7963             426.019  -     21   +     22       False
# frac_Mbc_bkg1_0.7963             -0.0911894  -  0.046   +  0.049       False
# frac_deltaE_bkg1_0.7963            0.209867  -   0.15   +   0.15       False
# True
# Iteration 300 - Signal Yield: 33.87402626757573 ± 8.222907844038659
# Signal yields and errors saved to 'Bppi0_q2reg1_decay_mumu_signal_yields_and_errors_50.csv'

# %% [markdown]
# ## 25

# %%
# Number of iterations
num_iterations = 300

# List to store the signal yields and their errors from each iteration
signal_yields_and_errors = []

for i in range(num_iterations):
    print(f"Running iteration {i + 1}/{num_iterations}...")

    # Process the Monte Carlo data
    mc_mu_signal, mc_mu_only_signal, mc_mu_scf, mc_mu_bkg, mc_mu_signal_weight, mc_mu_only_signal_weight, mc_mu_scf_weight, mc_mu_bkg_weight = process_MC_data_combined(
        file_signal_mu_Bppi0,file_bkg_mu_Bppi0, 'mu', '521', 'pi0', 'mumu', 1, 'rec521', 'weights', 25
    )

    # Fit models for signal, SCF, and background
    Mbc_only_signal_cb_fixed = fit_fixed_without_weight('Mbc', 'mu', 'signal', mc_mu_only_signal["Mbc"], 'cb', 0)
    deltaE_only_signal_cb_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'signal', mc_mu_only_signal["deltaE"],  'cb_gauss', 0)

    Mbc_scf_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'scf', mc_mu_scf["Mbc"], 'argus_gauss', 0)
    deltaE_scf_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'scf', mc_mu_scf["deltaE"], 'poly_gauss', 0)

    Mbc_bkg_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'bkg', mc_mu_bkg["Mbc"], 'argus_gauss', 0)
    deltaE_bkg_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'bkg', mc_mu_bkg["deltaE"], 'poly', 0)

    # Combine signal and background data
    Signal_Mbc = mc_mu_only_signal["Mbc"]
    Signal_deltaE = mc_mu_only_signal["deltaE"]
    Background_Mbc = pd.concat([mc_mu_scf["Mbc"], mc_mu_bkg["Mbc"]])
    Background_deltaE = pd.concat([mc_mu_scf["deltaE"], mc_mu_bkg["deltaE"]])

    Signal_total = pd.concat([Signal_Mbc, Signal_deltaE], axis=1)
    Background_total = pd.concat([Background_Mbc, Background_deltaE], axis=1)

    MC_signal=len(Signal_total)
    MC_bkg=len(Background_total)

    print(MC_signal)
    print(MC_bkg)
    # Fit the extended model and get the result
    Mbc_signal_pdf, deltaE_signal_pdf, Mbc_background_pdf, deltaE_background_pdf, signal_extended, background_extended, total_model, result = fit_extended_model_scf_without_weight(
        Mbc_only_signal_cb_fixed, Mbc_scf_argus_gauss_fixed, deltaE_only_signal_cb_gauss_fixed, deltaE_scf_poly_gauss_fixed,
        Mbc_bkg_argus_gauss_fixed, deltaE_bkg_poly_gauss_fixed,
        pd.concat([Signal_total, Background_total]), 0.5, 0.5, 100, 100
    )
    result.errors(name='errors')
    print(result.params)
    print(result.valid)

    # Retrieve and store the signal yield and its error
    signal_yield = result.params[signal_extended.get_yield()]['value']
    signal_yield_errors = result.params[signal_extended.get_yield()]['errors']
    signal_yield_error = (signal_yield_errors['upper'] - signal_yield_errors['lower']) / 2

    # Store the signal yield and error as a tuple in the list
    signal_yields_and_errors.append((MC_signal,MC_bkg,signal_yield, signal_yield_error))

    print(f"Iteration {i + 1} - Signal Yield: {signal_yield} ± {signal_yield_error}")

# Convert the list to a DataFrame with two columns: 'Signal_Yield' and 'Signal_Yield_Error'
signal_yields_df = pd.DataFrame(signal_yields_and_errors, columns=['MC_signal','MC_bkg','Signal_Yield', 'Signal_Yield_Error'])


# Save the DataFrame to a CSV file
signal_yields_df.to_csv('Bppi0_q2reg1_decay_mumu_signal_yields_and_errors_25.csv', index=False)

print("Signal yields and errors saved to 'Bppi0_q2reg1_decay_mumu_signal_yields_and_errors_25.csv'")
# Out:
# Running iteration 1/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7391                 24.9674  -    6.5   +    7.3       False
# background_yield_0.7391             410.014  -     20   +     21       False
# frac_Mbc_bkg1_0.7391              -0.167641  -  0.042   +  0.045       False
# frac_deltaE_bkg1_0.7391            0.221972  -   0.15   +   0.15       False
# True
# Iteration 1 - Signal Yield: 24.967378292577965 ± 6.896515325159939
# Running iteration 2/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0632                 17.4176  -    5.9   +    6.6       False
# background_yield_0.0632              417.61  -     21   +     21       False
# frac_Mbc_bkg1_0.0632               -0.12846  -  0.043   +  0.046       False
# frac_deltaE_bkg1_0.0632            0.177343  -   0.15   +   0.15       False
# True
# Iteration 2 - Signal Yield: 17.41758459997669 ± 6.249836608224263
# Running iteration 3/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7258                 22.4379  -    6.2   +      7       False
# background_yield_0.7258             412.368  -     20   +     21       False
# frac_Mbc_bkg1_0.7258              -0.151173  -  0.042   +  0.045       False
# frac_deltaE_bkg1_0.7258            0.195181  -   0.15   +   0.15       False
# True
# Iteration 3 - Signal Yield: 22.437899057010494 ± 6.612117869455359
# Running iteration 4/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3713                 19.8116  -    6.1   +    6.7       False
# background_yield_0.3713             415.233  -     20   +     21       False
# frac_Mbc_bkg1_0.3713              -0.152226  -  0.041   +  0.046       False
# frac_deltaE_bkg1_0.3713            0.195641  -   0.15   +   0.15       False
# True
# Iteration 4 - Signal Yield: 19.811581243548233 ± 6.370744511172379
# Running iteration 5/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4256                 22.2697  -    6.2   +    6.9       False
# background_yield_0.4256             412.758  -     20   +     21       False
# frac_Mbc_bkg1_0.4256              -0.146585  -  0.041   +  0.045       False
# frac_deltaE_bkg1_0.4256            0.204182  -   0.15   +   0.15       False
# True
# Iteration 5 - Signal Yield: 22.26972716532231 ± 6.571577379520896
# Running iteration 6/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0647                 21.6436  -    6.2   +      7       False
# background_yield_0.0647             413.117  -     20   +     21       False
# frac_Mbc_bkg1_0.0647              -0.153602  -  0.043   +  0.044       False
# frac_deltaE_bkg1_0.0647            0.211431  -   0.15   +   0.15       False
# True
# Iteration 6 - Signal Yield: 21.643590900928352 ± 6.565636178971104
# Running iteration 7/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0262                 20.8562  -    5.9   +    6.7       False
# background_yield_0.0262             414.207  -     21   +     21       False
# frac_Mbc_bkg1_0.0262              -0.145742  -  0.041   +  0.044       False
# frac_deltaE_bkg1_0.0262            0.188751  -   0.15   +   0.15       False
# True
# Iteration 7 - Signal Yield: 20.85621125557825 ± 6.301970845280495
# Running iteration 8/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1553                 22.1248  -    6.1   +    7.1       False
# background_yield_0.1553             412.626  -     20   +     21       False
# frac_Mbc_bkg1_0.1553              -0.156997  -  0.042   +  0.045       False
# frac_deltaE_bkg1_0.1553            0.215633  -   0.15   +   0.15       False
# True
# Iteration 8 - Signal Yield: 22.12484221909097 ± 6.602486257005879
# Running iteration 9/300...
# 25
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.876                 19.9466  -      6   +    6.7       False
# background_yield_0.876             415.001  -     20   +     21       False
# frac_Mbc_bkg1_0.876              -0.149606  -  0.042   +  0.045       False
# frac_deltaE_bkg1_0.876            0.175719  -   0.15   +   0.15       False
# True
# Iteration 9 - Signal Yield: 19.946628249813006 ± 6.346869867735406
# Running iteration 10/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6643                  18.356  -    5.8   +    6.6       False
# background_yield_0.6643             416.682  -     21   +     21       False
# frac_Mbc_bkg1_0.6643              -0.136151  -  0.042   +  0.045       False
# frac_deltaE_bkg1_0.6643            0.200012  -   0.15   +   0.15       False
# True
# Iteration 10 - Signal Yield: 18.356022427361523 ± 6.2224663947529555
# Running iteration 11/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5077                 17.6103  -    6.1   +    6.6       False
# background_yield_0.5077             417.429  -     21   +     21       False
# frac_Mbc_bkg1_0.5077              -0.131576  -  0.043   +  0.046       False
# frac_deltaE_bkg1_0.5077              0.1727  -   0.15   +   0.15       False
# True
# Iteration 11 - Signal Yield: 17.61034358777465 ± 6.361237322030194
# Running iteration 12/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1714                 26.4603  -    6.5   +    7.2       False
# background_yield_0.1714             408.521  -     20   +     21       False
# frac_Mbc_bkg1_0.1714               -0.17075  -  0.041   +  0.044       False
# frac_deltaE_bkg1_0.1714             0.20367  -   0.15   +   0.15       False
# True
# Iteration 12 - Signal Yield: 26.46029265864124 ± 6.825427208581541
# Running iteration 13/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8992                 20.2698  -    6.1   +    6.9       False
# background_yield_0.8992             414.737  -     21   +     21       False
# frac_Mbc_bkg1_0.8992              -0.143362  -  0.042   +  0.045       False
# frac_deltaE_bkg1_0.8992            0.190945  -   0.15   +   0.15       False
# True
# Iteration 13 - Signal Yield: 20.269774155978684 ± 6.518041326574526
# Running iteration 14/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0684                 25.7131  -    6.3   +      7       False
# background_yield_0.0684             409.892  -     21   +     20       False
# frac_Mbc_bkg1_0.0684              -0.174039  -   0.04   +  0.044       False
# frac_deltaE_bkg1_0.0684            0.170684  -   0.15   +   0.15       False
# True
# Iteration 14 - Signal Yield: 25.713121274350293 ± 6.641638001520991
# Running iteration 15/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8708                 17.4403  -    5.7   +    6.5       False
# background_yield_0.8708             417.554  -     21   +     21       False
# frac_Mbc_bkg1_0.8708              -0.134578  -  0.042   +  0.045       False
# frac_deltaE_bkg1_0.8708            0.183241  -   0.15   +   0.15       False
# True
# Iteration 15 - Signal Yield: 17.44034760526177 ± 6.1040237508328214
# Running iteration 16/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0994                 21.8763  -    6.1   +    6.8       False
# background_yield_0.0994             413.126  -     20   +     21       False
# frac_Mbc_bkg1_0.0994              -0.151545  -  0.041   +  0.044       False
# frac_deltaE_bkg1_0.0994            0.189862  -   0.15   +   0.15       False
# True
# Iteration 16 - Signal Yield: 21.876295574755762 ± 6.4422432915596755
# Running iteration 17/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9783                 22.8948  -    6.5   +    7.1       False
# background_yield_0.9783             412.645  -     21   +     21       False
# frac_Mbc_bkg1_0.9783              -0.156057  -  0.042   +  0.046       False
# frac_deltaE_bkg1_0.9783            0.200599  -   0.15   +   0.15       False
# True
# Iteration 17 - Signal Yield: 22.89476179005761 ± 6.790260677317065
# Running iteration 18/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4852                 17.1903  -    5.8   +    6.5       False
# background_yield_0.4852             417.804  -     21   +     21       False
# frac_Mbc_bkg1_0.4852              -0.131328  -  0.042   +  0.045       False
# frac_deltaE_bkg1_0.4852             0.19595  -   0.15   +   0.15       False
# True
# Iteration 18 - Signal Yield: 17.190262854505246 ± 6.130808900745284
# Running iteration 19/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1092                 16.9577  -    5.9   +    6.5       False
# background_yield_0.1092             417.595  -     20   +     22       False
# frac_Mbc_bkg1_0.1092              -0.137778  -  0.043   +  0.046       False
# frac_deltaE_bkg1_0.1092            0.243477  -   0.15   +   0.15       False
# True
# Iteration 19 - Signal Yield: 16.95767983988505 ± 6.219267125414917
# Running iteration 20/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3155                 18.8475  -    5.9   +    6.7       False
# background_yield_0.3155             416.174  -     21   +     21       False
# frac_Mbc_bkg1_0.3155              -0.137695  -  0.042   +  0.045       False
# frac_deltaE_bkg1_0.3155            0.206169  -   0.15   +   0.15       False
# True
# Iteration 20 - Signal Yield: 18.847520435415568 ± 6.31378253371668
# Running iteration 21/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8737                 23.5781  -    6.3   +      7       False
# background_yield_0.8737             411.655  -     21   +     21       False
# frac_Mbc_bkg1_0.8737              -0.161703  -  0.041   +  0.045       False
# frac_deltaE_bkg1_0.8737            0.207575  -   0.15   +   0.15       False
# True
# Iteration 21 - Signal Yield: 23.578093037454778 ± 6.649882230211249
# Running iteration 22/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3957                 15.9942  -    5.7   +    6.5       False
# background_yield_0.3957             419.031  -     21   +     21       False
# frac_Mbc_bkg1_0.3957              -0.127052  -  0.043   +  0.046       False
# frac_deltaE_bkg1_0.3957            0.190093  -   0.15   +   0.15       False
# True
# Iteration 22 - Signal Yield: 15.994180867585772 ± 6.086572692096347
# Running iteration 23/300...
# 25
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.841                 20.5357  -    5.9   +    6.7       False
# background_yield_0.841              414.44  -     20   +     21       False
# frac_Mbc_bkg1_0.841              -0.144819  -  0.042   +  0.045       False
# frac_deltaE_bkg1_0.841            0.192169  -   0.15   +   0.15       False
# True
# Iteration 23 - Signal Yield: 20.535742182197996 ± 6.339959453692815
# Running iteration 24/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4589                 17.9279  -      6   +    6.8       False
# background_yield_0.4589             417.141  -     21   +     21       False
# frac_Mbc_bkg1_0.4589              -0.127494  -  0.043   +  0.046       False
# frac_deltaE_bkg1_0.4589            0.221914  -   0.15   +   0.15       False
# True
# Iteration 24 - Signal Yield: 17.927917050864675 ± 6.412544748931079
# Running iteration 25/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5609                 17.2634  -    5.8   +    6.6       False
# background_yield_0.5609             417.744  -     21   +     21       False
# frac_Mbc_bkg1_0.5609              -0.129645  -  0.043   +  0.045       False
# frac_deltaE_bkg1_0.5609            0.196181  -   0.15   +   0.15       False
# True
# Iteration 25 - Signal Yield: 17.263408833299515 ± 6.216787744817722
# Running iteration 26/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5353                  16.988  -    5.6   +    6.4       False
# background_yield_0.5353             418.059  -     21   +     21       False
# frac_Mbc_bkg1_0.5353               -0.13417  -  0.042   +  0.045       False
# frac_deltaE_bkg1_0.5353            0.199555  -   0.15   +   0.15       False
# True
# Iteration 26 - Signal Yield: 16.988020311749676 ± 6.014594500192768
# Running iteration 27/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0957                 24.7388  -    6.3   +    7.1       False
# background_yield_0.0957             410.252  -     20   +     21       False
# frac_Mbc_bkg1_0.0957               -0.16236  -  0.041   +  0.044       False
# frac_deltaE_bkg1_0.0957            0.191027  -   0.15   +   0.15       False
# True
# Iteration 27 - Signal Yield: 24.738784116050322 ± 6.705614800654773
# Running iteration 28/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2755                 18.7164  -    5.9   +    6.9       False
# background_yield_0.2755             416.414  -     21   +     21       False
# frac_Mbc_bkg1_0.2755              -0.136732  -  0.043   +  0.045       False
# frac_deltaE_bkg1_0.2755             0.18248  -   0.15   +   0.15       False
# True
# Iteration 28 - Signal Yield: 18.71643590554412 ± 6.388022258757323
# Running iteration 29/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5579                  14.867  -    5.7   +    6.6       False
# background_yield_0.5579             420.101  -     21   +     21       False
# frac_Mbc_bkg1_0.5579              -0.112713  -  0.043   +  0.046       False
# frac_deltaE_bkg1_0.5579            0.221268  -   0.15   +   0.15       False
# True
# Iteration 29 - Signal Yield: 14.867032006062663 ± 6.13948634514956
# Running iteration 30/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1617                 26.8475  -    6.5   +    7.3       False
# background_yield_0.1617             408.132  -     20   +     21       False
# frac_Mbc_bkg1_0.1617              -0.173466  -  0.041   +  0.044       False
# frac_deltaE_bkg1_0.1617             0.19695  -   0.15   +   0.15       False
# True
# Iteration 30 - Signal Yield: 26.847480638583296 ± 6.923792272506018
# Running iteration 31/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7461                 21.0476  -    6.2   +    6.9       False
# background_yield_0.7461             413.986  -     20   +     21       False
# frac_Mbc_bkg1_0.7461              -0.143605  -  0.041   +  0.046       False
# frac_deltaE_bkg1_0.7461            0.210918  -   0.15   +   0.15       False
# True
# Iteration 31 - Signal Yield: 21.047623094369154 ± 6.558223017176525
# Running iteration 32/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3174                  20.267  -    6.1   +    6.9       False
# background_yield_0.3174             414.739  -     21   +     21       False
# frac_Mbc_bkg1_0.3174              -0.141774  -  0.042   +  0.045       False
# frac_deltaE_bkg1_0.3174            0.229406  -   0.15   +   0.15       False
# True
# Iteration 32 - Signal Yield: 20.266969185591382 ± 6.483893831075496
# Running iteration 33/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7811                 17.3972  -    6.2   +    6.7       False
# background_yield_0.7811             417.597  -     21   +     22       False
# frac_Mbc_bkg1_0.7811              -0.126828  -  0.042   +  0.047       False
# frac_deltaE_bkg1_0.7811            0.223597  -   0.15   +   0.15       False
# True
# Iteration 33 - Signal Yield: 17.39724119871491 ± 6.458572184321003
# Running iteration 34/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3005                 20.7168  -      6   +    6.8       False
# background_yield_0.3005               414.3  -     21   +     21       False
# frac_Mbc_bkg1_0.3005              -0.145617  -  0.041   +  0.045       False
# frac_deltaE_bkg1_0.3005            0.173627  -   0.15   +   0.15       False
# True
# Iteration 34 - Signal Yield: 20.716745176984237 ± 6.411202065279618
# Running iteration 35/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2601                 19.9129  -    6.2   +    6.9       False
# background_yield_0.2601             415.135  -     21   +     21       False
# frac_Mbc_bkg1_0.2601              -0.141134  -  0.043   +  0.045       False
# frac_deltaE_bkg1_0.2601            0.212161  -   0.15   +   0.15       False
# True
# Iteration 35 - Signal Yield: 19.912878240436385 ± 6.550372090113901
# Running iteration 36/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9198                 23.9876  -    6.4   +    7.1       False
# background_yield_0.9198             411.718  -     21   +     21       False
# frac_Mbc_bkg1_0.9198              -0.164322  -  0.041   +  0.045       False
# frac_deltaE_bkg1_0.9198            0.210169  -   0.15   +   0.15       False
# True
# Iteration 36 - Signal Yield: 23.98761755290078 ± 6.74775256758525
# Running iteration 37/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7748                 16.2404  -    5.7   +    6.6       False
# background_yield_0.7748             418.772  -     21   +     21       False
# frac_Mbc_bkg1_0.7748              -0.122963  -  0.043   +  0.046       False
# frac_deltaE_bkg1_0.7748            0.180336  -   0.15   +   0.15       False
# True
# Iteration 37 - Signal Yield: 16.24038490477438 ± 6.170435097992991
# Running iteration 38/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7339                 19.1596  -      6   +    6.7       False
# background_yield_0.7339             415.867  -     21   +     21       False
# frac_Mbc_bkg1_0.7339              -0.141743  -  0.042   +  0.045       False
# frac_deltaE_bkg1_0.7339             0.15079  -   0.15   +   0.15       False
# True
# Iteration 38 - Signal Yield: 19.159565214627712 ± 6.3430129804904265
# Running iteration 39/300...
# 25
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.988                 16.8611  -    5.8   +    6.6       False
# background_yield_0.988             418.163  -     21   +     21       False
# frac_Mbc_bkg1_0.988              -0.125688  -  0.043   +  0.045       False
# frac_deltaE_bkg1_0.988            0.217111  -   0.15   +   0.15       False
# True
# Iteration 39 - Signal Yield: 16.86114930847495 ± 6.170076049152598
# Running iteration 40/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1229                 19.3974  -    5.8   +    6.6       False
# background_yield_0.1229             415.613  -     21   +     21       False
# frac_Mbc_bkg1_0.1229              -0.146352  -  0.042   +  0.044       False
# frac_deltaE_bkg1_0.1229            0.198161  -   0.15   +   0.15       False
# True
# Iteration 40 - Signal Yield: 19.39740643223777 ± 6.202168065941654
# Running iteration 41/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3365                 24.8247  -    6.3   +    7.1       False
# background_yield_0.3365             410.173  -     20   +     21       False
# frac_Mbc_bkg1_0.3365              -0.163527  -  0.041   +  0.044       False
# frac_deltaE_bkg1_0.3365            0.208065  -   0.15   +   0.15       False
# True
# Iteration 41 - Signal Yield: 24.824690341057476 ± 6.7124291023421385
# Running iteration 42/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5137                 24.5007  -    6.4   +      7       False
# background_yield_0.5137             410.993  -     21   +     21       False
# frac_Mbc_bkg1_0.5137              -0.163093  -  0.041   +  0.045       False
# frac_deltaE_bkg1_0.5137            0.202678  -   0.15   +   0.15       False
# True
# Iteration 42 - Signal Yield: 24.500691517321126 ± 6.712364288133312
# Running iteration 43/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4687                 21.0681  -    6.2   +    6.8       False
# background_yield_0.4687             414.503  -     21   +     21       False
# frac_Mbc_bkg1_0.4687              -0.157087  -  0.042   +  0.045       False
# frac_deltaE_bkg1_0.4687            0.202831  -   0.15   +   0.15       False
# True
# Iteration 43 - Signal Yield: 21.06812897803499 ± 6.49082027500565
# Running iteration 44/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4378                  22.798  -    6.2   +    6.6       False
# background_yield_0.4378             412.167  -     20   +     21       False
# frac_Mbc_bkg1_0.4378              -0.154372  -  0.041   +  0.044       False
# frac_deltaE_bkg1_0.4378            0.179751  -   0.15   +   0.15       False
# True
# Iteration 44 - Signal Yield: 22.797947782648407 ± 6.406552175239195
# Running iteration 45/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5776                 17.1149  -    5.6   +    6.5       False
# background_yield_0.5776             418.666  -     21   +     20       False
# frac_Mbc_bkg1_0.5776               -0.13703  -  0.042   +  0.045       False
# frac_deltaE_bkg1_0.5776            0.203429  -   0.15   +   0.15       False
# True
# Iteration 45 - Signal Yield: 17.114938744798728 ± 6.04672717592439
# Running iteration 46/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4517                 26.0428  -    6.3   +    7.1       False
# background_yield_0.4517             408.942  -     20   +     21       False
# frac_Mbc_bkg1_0.4517              -0.174043  -   0.04   +  0.044       False
# frac_deltaE_bkg1_0.4517            0.198723  -   0.15   +   0.15       False
# True
# Iteration 46 - Signal Yield: 26.042818644214307 ± 6.706588229625643
# Running iteration 47/300...
# 25
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.251                 21.3339  -    6.3   +    6.9       False
# background_yield_0.251              413.72  -     21   +     21       False
# frac_Mbc_bkg1_0.251               -0.14386  -  0.042   +  0.046       False
# frac_deltaE_bkg1_0.251            0.204427  -   0.15   +   0.15       False
# True
# Iteration 47 - Signal Yield: 21.333921022477643 ± 6.584951611155512
# Running iteration 48/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4127                  19.878  -    6.3   +    6.8       False
# background_yield_0.4127             415.122  -     20   +     21       False
# frac_Mbc_bkg1_0.4127              -0.143178  -  0.041   +  0.048       False
# frac_deltaE_bkg1_0.4127            0.232654  -   0.15   +   0.15       False
# True
# Iteration 48 - Signal Yield: 19.87799629751936 ± 6.537881321364741
# Running iteration 49/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3495                 15.4419  -    5.9   +    6.6       False
# background_yield_0.3495             419.802  -     21   +     21       False
# frac_Mbc_bkg1_0.3495              -0.116988  -  0.043   +  0.046       False
# frac_deltaE_bkg1_0.3495            0.200851  -   0.15   +   0.15       False
# True
# Iteration 49 - Signal Yield: 15.441876618589697 ± 6.223058456843379
# Running iteration 50/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6818                 21.2138  -    6.2   +    6.8       False
# background_yield_0.6818             413.853  -     20   +     21       False
# frac_Mbc_bkg1_0.6818              -0.144304  -  0.041   +  0.046       False
# frac_deltaE_bkg1_0.6818            0.180021  -   0.15   +   0.15       False
# True
# Iteration 50 - Signal Yield: 21.213756508482213 ± 6.530638476692172
# Running iteration 51/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8584                 21.4194  -    6.3   +    6.9       False
# background_yield_0.8584             413.619  -     21   +     21       False
# frac_Mbc_bkg1_0.8584              -0.144403  -  0.042   +  0.046       False
# frac_deltaE_bkg1_0.8584            0.214037  -   0.15   +   0.15       False
# True
# Iteration 51 - Signal Yield: 21.419381108223263 ± 6.588342490699427
# Running iteration 52/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3522                 18.1816  -      6   +    6.8       False
# background_yield_0.3522             416.848  -     21   +     21       False
# frac_Mbc_bkg1_0.3522              -0.142264  -  0.043   +  0.046       False
# frac_deltaE_bkg1_0.3522            0.226314  -   0.15   +   0.15       False
# True
# Iteration 52 - Signal Yield: 18.181552506912602 ± 6.414086723431756
# Running iteration 53/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8592                 23.7334  -    6.1   +      7       False
# background_yield_0.8592              410.89  -     20   +     21       False
# frac_Mbc_bkg1_0.8592              -0.168031  -  0.041   +  0.044       False
# frac_deltaE_bkg1_0.8592            0.183516  -   0.15   +   0.15       False
# True
# Iteration 53 - Signal Yield: 23.733391888462958 ± 6.533433646058576
# Running iteration 54/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7427                 18.1975  -      6   +    6.7       False
# background_yield_0.7427             416.608  -     20   +     22       False
# frac_Mbc_bkg1_0.7427              -0.133284  -  0.043   +  0.046       False
# frac_deltaE_bkg1_0.7427            0.212333  -   0.15   +   0.15       False
# True
# Iteration 54 - Signal Yield: 18.19754790408369 ± 6.360075317605164
# Running iteration 55/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8742                 22.2685  -      6   +    6.8       False
# background_yield_0.8742             412.784  -     21   +     21       False
# frac_Mbc_bkg1_0.8742              -0.155076  -  0.041   +  0.044       False
# frac_deltaE_bkg1_0.8742            0.210662  -   0.15   +   0.15       False
# True
# Iteration 55 - Signal Yield: 22.26850473827774 ± 6.444633545645218
# Running iteration 56/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5964                 22.7591  -    6.1   +      7       False
# background_yield_0.5964             412.047  -     20   +     21       False
# frac_Mbc_bkg1_0.5964               -0.15529  -  0.042   +  0.044       False
# frac_deltaE_bkg1_0.5964            0.206384  -   0.15   +   0.15       False
# True
# Iteration 56 - Signal Yield: 22.759116194390835 ± 6.55813977351206
# Running iteration 57/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5009                 21.9209  -    6.1   +    6.9       False
# background_yield_0.5009             412.814  -     20   +     21       False
# frac_Mbc_bkg1_0.5009              -0.152514  -  0.043   +  0.044       False
# frac_deltaE_bkg1_0.5009            0.207994  -   0.15   +   0.15       False
# True
# Iteration 57 - Signal Yield: 21.92092628996559 ± 6.520254574793787
# Running iteration 58/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7756                 18.9773  -      6   +    6.8       False
# background_yield_0.7756             416.043  -     21   +     21       False
# frac_Mbc_bkg1_0.7756              -0.139412  -  0.042   +  0.045       False
# frac_deltaE_bkg1_0.7756            0.215073  -   0.15   +   0.15       False
# True
# Iteration 58 - Signal Yield: 18.977261932555347 ± 6.4040183246008215
# Running iteration 59/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3169                 20.6796  -    6.1   +    6.8       False
# background_yield_0.3169             414.344  -     21   +     21       False
# frac_Mbc_bkg1_0.3169              -0.149163  -  0.042   +  0.045       False
# frac_deltaE_bkg1_0.3169            0.211153  -   0.15   +   0.15       False
# True
# Iteration 59 - Signal Yield: 20.679587046601785 ± 6.423213172295682
# Running iteration 60/300...
# 25
# 410
# name                     value  (rounded)               errors    at limit
# ---------------------  ------------------  -------------------  ----------
# signal_yield_0.34                 13.3161  -    5.7   +    6.6       False
# background_yield_0.34             421.704  -     21   +     21       False
# frac_Mbc_bkg1_0.34              -0.109965  -  0.044   +  0.047       False
# frac_deltaE_bkg1_0.34            0.250085  -   0.15   +   0.15       False
# True
# Iteration 60 - Signal Yield: 13.316071329782192 ± 6.147896856660045
# Running iteration 61/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1686                 18.9342  -    5.9   +    6.6       False
# background_yield_0.1686             416.084  -     21   +     21       False
# frac_Mbc_bkg1_0.1686              -0.141202  -  0.042   +  0.045       False
# frac_deltaE_bkg1_0.1686            0.183438  -   0.15   +   0.15       False
# True
# Iteration 61 - Signal Yield: 18.9342420040889 ± 6.24812376910503
# Running iteration 62/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6191                 21.3181  -    6.1   +      7       False
# background_yield_0.6191             413.624  -     20   +     21       False
# frac_Mbc_bkg1_0.6191               -0.14865  -  0.042   +  0.045       False
# frac_deltaE_bkg1_0.6191            0.186992  -   0.15   +   0.15       False
# True
# Iteration 62 - Signal Yield: 21.31813086486813 ± 6.555423222600659
# Running iteration 63/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4382                 26.3168  -    6.5   +    7.3       False
# background_yield_0.4382              408.66  -     20   +     21       False
# frac_Mbc_bkg1_0.4382              -0.171164  -  0.041   +  0.044       False
# frac_deltaE_bkg1_0.4382            0.211884  -   0.15   +   0.15       False
# True
# Iteration 63 - Signal Yield: 26.316780705255763 ± 6.911240287257316
# Running iteration 64/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9269                 22.6438  -    6.2   +      7       False
# background_yield_0.9269             412.405  -     21   +     21       False
# frac_Mbc_bkg1_0.9269              -0.147297  -  0.043   +  0.043       False
# frac_deltaE_bkg1_0.9269            0.197069  -   0.15   +   0.15       False
# True
# Iteration 64 - Signal Yield: 22.643797328996314 ± 6.58703113914231
# Running iteration 65/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9995                 19.0541  -      6   +    6.8       False
# background_yield_0.9995              415.94  -     21   +     21       False
# frac_Mbc_bkg1_0.9995              -0.136425  -  0.043   +  0.046       False
# frac_deltaE_bkg1_0.9995            0.192847  -   0.15   +   0.15       False
# True
# Iteration 65 - Signal Yield: 19.054058509535505 ± 6.419199654618375
# Running iteration 66/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0188                 16.0918  -    5.8   +    6.7       False
# background_yield_0.0188             418.921  -     21   +     21       False
# frac_Mbc_bkg1_0.0188              -0.121407  -  0.043   +  0.046       False
# frac_deltaE_bkg1_0.0188             0.23432  -   0.15   +   0.15       False
# True
# Iteration 66 - Signal Yield: 16.09181988654679 ± 6.257551629702423
# Running iteration 67/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9631                 24.7881  -    6.4   +    7.2       False
# background_yield_0.9631             410.199  -     20   +     21       False
# frac_Mbc_bkg1_0.9631              -0.162792  -  0.042   +  0.045       False
# frac_deltaE_bkg1_0.9631            0.188942  -   0.15   +   0.15       False
# True
# Iteration 67 - Signal Yield: 24.788056936593883 ± 6.797548861431144
# Running iteration 68/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2721                 20.5011  -    6.2   +    7.2       False
# background_yield_0.2721             414.266  -     20   +     21       False
# frac_Mbc_bkg1_0.2721              -0.147468  -  0.043   +  0.045       False
# frac_deltaE_bkg1_0.2721            0.222856  -   0.15   +   0.15       False
# True
# Iteration 68 - Signal Yield: 20.501108887519383 ± 6.65845602508956
# Running iteration 69/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9636                 19.0085  -      6   +    6.8       False
# background_yield_0.9636              416.04  -     21   +     21       False
# frac_Mbc_bkg1_0.9636              -0.137961  -  0.043   +  0.046       False
# frac_deltaE_bkg1_0.9636            0.183078  -   0.15   +   0.15       False
# True
# Iteration 69 - Signal Yield: 19.008514968682938 ± 6.394847834600975
# Running iteration 70/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5096                 25.2838  -    6.3   +    6.9       False
# background_yield_0.5096             409.843  -     20   +     21       False
# frac_Mbc_bkg1_0.5096              -0.173398  -  0.041   +  0.043       False
# frac_deltaE_bkg1_0.5096            0.195675  -   0.15   +   0.15       False
# True
# Iteration 70 - Signal Yield: 25.283790231509663 ± 6.5995173828669325
# Running iteration 71/300...
# 25
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.212                 20.5373  -    6.3   +    7.3       False
# background_yield_0.212             414.156  -     20   +     22       False
# frac_Mbc_bkg1_0.212              -0.145962  -  0.043   +  0.046       False
# frac_deltaE_bkg1_0.212            0.212191  -   0.15   +   0.15       False
# True
# Iteration 71 - Signal Yield: 20.537247319741063 ± 6.796711404128423
# Running iteration 72/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9772                  16.802  -    5.9   +    6.7       False
# background_yield_0.9772             418.207  -     21   +     21       False
# frac_Mbc_bkg1_0.9772              -0.123359  -  0.043   +  0.046       False
# frac_deltaE_bkg1_0.9772            0.224662  -   0.15   +   0.15       False
# True
# Iteration 72 - Signal Yield: 16.80200476882733 ± 6.290436382236148
# Running iteration 73/300...
# 25
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.223                  26.004  -    6.6   +    7.3       False
# background_yield_0.223             408.973  -     20   +     21       False
# frac_Mbc_bkg1_0.223               -0.16857  -  0.042   +  0.045       False
# frac_deltaE_bkg1_0.223            0.203286  -   0.15   +   0.15       False
# True
# Iteration 73 - Signal Yield: 26.00403920132925 ± 6.930650585111457
# Running iteration 74/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2798                  17.514  -    6.1   +    6.8       False
# background_yield_0.2798             417.567  -     21   +     21       False
# frac_Mbc_bkg1_0.2798              -0.130113  -  0.043   +  0.046       False
# frac_deltaE_bkg1_0.2798            0.203886  -   0.15   +   0.15       False
# True
# Iteration 74 - Signal Yield: 17.514028426427387 ± 6.432094143778804
# Running iteration 75/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6152                 20.1412  -    6.2   +      7       False
# background_yield_0.6152             414.907  -     21   +     21       False
# frac_Mbc_bkg1_0.6152               -0.15018  -  0.043   +  0.045       False
# frac_deltaE_bkg1_0.6152            0.207043  -   0.15   +   0.15       False
# True
# Iteration 75 - Signal Yield: 20.141168193159125 ± 6.575997830816129
# Running iteration 76/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3113                 21.0355  -      6   +      7       False
# background_yield_0.3113             413.952  -     21   +     21       False
# frac_Mbc_bkg1_0.3113              -0.143719  -  0.043   +  0.044       False
# frac_deltaE_bkg1_0.3113            0.213579  -   0.15   +   0.15       False
# True
# Iteration 76 - Signal Yield: 21.03551054308271 ± 6.478426640977354
# Running iteration 77/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3971                 20.2354  -      6   +    6.9       False
# background_yield_0.3971               414.7  -     21   +     21       False
# frac_Mbc_bkg1_0.3971              -0.136667  -  0.042   +  0.045       False
# frac_deltaE_bkg1_0.3971            0.214747  -   0.15   +   0.14       False
# True
# Iteration 77 - Signal Yield: 20.235351555005757 ± 6.474934350123057
# Running iteration 78/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8498                 19.4642  -      6   +    6.8       False
# background_yield_0.8498             415.555  -     21   +     21       False
# frac_Mbc_bkg1_0.8498              -0.140012  -  0.042   +  0.045       False
# frac_deltaE_bkg1_0.8498            0.223757  -   0.15   +   0.15       False
# True
# Iteration 78 - Signal Yield: 19.464227963812704 ± 6.400579543907584
# Running iteration 79/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1609                 24.3172  -      6   +      7       False
# background_yield_0.1609             410.283  -     20   +     21       False
# frac_Mbc_bkg1_0.1609              -0.169155  -   0.04   +  0.044       False
# frac_deltaE_bkg1_0.1609            0.159421  -   0.15   +   0.15       False
# True
# Iteration 79 - Signal Yield: 24.317241893933264 ± 6.506987665083169
# Running iteration 80/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3132                 24.8626  -      6   +    6.9       False
# background_yield_0.3132             409.909  -     20   +     21       False
# frac_Mbc_bkg1_0.3132              -0.167498  -   0.04   +  0.043       False
# frac_deltaE_bkg1_0.3132            0.176517  -   0.15   +   0.15       False
# True
# Iteration 80 - Signal Yield: 24.86259456055354 ± 6.481759406099947
# Running iteration 81/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7582                 15.8904  -    5.7   +    6.6       False
# background_yield_0.7582             419.042  -     21   +     21       False
# frac_Mbc_bkg1_0.7582              -0.120903  -  0.043   +  0.046       False
# frac_deltaE_bkg1_0.7582            0.167142  -   0.15   +   0.15       False
# True
# Iteration 81 - Signal Yield: 15.890414847858843 ± 6.184241042038206
# Running iteration 82/300...
# 25
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.186                 22.0469  -    6.4   +    7.1       False
# background_yield_0.186             412.866  -     20   +     21       False
# frac_Mbc_bkg1_0.186              -0.149201  -  0.042   +  0.046       False
# frac_deltaE_bkg1_0.186            0.214426  -   0.15   +   0.15       False
# True
# Iteration 82 - Signal Yield: 22.04691410813886 ± 6.758131538294657
# Running iteration 83/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8828                 20.3243  -    6.3   +    6.9       False
# background_yield_0.8828             414.752  -     21   +     21       False
# frac_Mbc_bkg1_0.8828               -0.14101  -  0.042   +  0.047       False
# frac_deltaE_bkg1_0.8828            0.177593  -   0.15   +   0.15       False
# True
# Iteration 83 - Signal Yield: 20.32428546982537 ± 6.612435079720843
# Running iteration 84/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0742                 18.8013  -    5.7   +    6.5       False
# background_yield_0.0742             416.217  -     21   +     21       False
# frac_Mbc_bkg1_0.0742              -0.140406  -  0.041   +  0.044       False
# frac_deltaE_bkg1_0.0742            0.216656  -   0.15   +   0.15       False
# True
# Iteration 84 - Signal Yield: 18.801311236921883 ± 6.088396360374217
# Running iteration 85/300...
# 25
# 410
# name                     value  (rounded)               errors    at limit
# ---------------------  ------------------  -------------------  ----------
# ...
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5842                 20.3601  -      6   +    6.7       False
# background_yield_0.5842             414.702  -     21   +     21       False
# frac_Mbc_bkg1_0.5842              -0.142495  -  0.042   +  0.045       False
# frac_deltaE_bkg1_0.5842            0.190821  -   0.15   +   0.15       False
# True
# Iteration 273 - Signal Yield: 20.36009030284665 ± 6.366929533412106
# Running iteration 274/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3537                 16.6489  -    5.8   +    6.7       False
# background_yield_0.3537             418.359  -     21   +     21       False
# frac_Mbc_bkg1_0.3537              -0.123056  -  0.043   +  0.045       False
# frac_deltaE_bkg1_0.3537            0.215327  -   0.15   +   0.15       False
# True
# Iteration 274 - Signal Yield: 16.648951857217664 ± 6.249477486159854
# Running iteration 275/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1424                 25.8774  -    6.3   +      7       False
# background_yield_0.1424             409.392  -     21   +     21       False
# frac_Mbc_bkg1_0.1424               -0.16626  -   0.04   +  0.043       False
# frac_deltaE_bkg1_0.1424            0.175476  -   0.15   +   0.15       False
# True
# Iteration 275 - Signal Yield: 25.877407533649 ± 6.625241459768416
# Running iteration 276/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8882                 29.9542  -    6.4   +    7.4       False
# background_yield_0.8882             405.045  -     20   +     21       False
# frac_Mbc_bkg1_0.8882              -0.184299  -   0.04   +  0.043       False
# frac_deltaE_bkg1_0.8882            0.189749  -   0.15   +   0.15       False
# True
# Iteration 276 - Signal Yield: 29.954174569406007 ± 6.926488189631708
# Running iteration 277/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5813                 23.6359  -    6.4   +      7       False
# background_yield_0.5813              412.09  -     21   +     21       False
# frac_Mbc_bkg1_0.5813              -0.155664  -  0.042   +  0.045       False
# frac_deltaE_bkg1_0.5813            0.201859  -   0.15   +   0.15       False
# True
# Iteration 277 - Signal Yield: 23.635880043553442 ± 6.711452477483354
# Running iteration 278/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9879                 22.2189  -    6.2   +    6.8       False
# background_yield_0.9879             412.876  -     20   +     21       False
# frac_Mbc_bkg1_0.9879              -0.149645  -  0.041   +  0.046       False
# frac_deltaE_bkg1_0.9879            0.206911  -   0.15   +   0.15       False
# True
# Iteration 278 - Signal Yield: 22.21890495148148 ± 6.487452056310971
# Running iteration 279/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7831                 18.7678  -    6.3   +      7       False
# background_yield_0.7831             416.241  -     21   +     21       False
# frac_Mbc_bkg1_0.7831              -0.133442  -  0.043   +  0.046       False
# frac_deltaE_bkg1_0.7831             0.21292  -   0.15   +   0.15       False
# True
# Iteration 279 - Signal Yield: 18.767784904705756 ± 6.640493503102491
# Running iteration 280/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5608                 19.9352  -      6   +    6.7       False
# background_yield_0.5608             415.059  -     20   +     21       False
# frac_Mbc_bkg1_0.5608              -0.139134  -  0.042   +  0.045       False
# frac_deltaE_bkg1_0.5608             0.19168  -   0.15   +   0.15       False
# True
# Iteration 280 - Signal Yield: 19.935212299012687 ± 6.335794796515973
# Running iteration 281/300...
# 25
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.388                 21.7422  -    6.4   +    7.2       False
# background_yield_0.388             413.207  -     21   +     21       False
# frac_Mbc_bkg1_0.388              -0.149707  -  0.043   +  0.046       False
# frac_deltaE_bkg1_0.388            0.195083  -   0.15   +   0.15       False
# True
# Iteration 281 - Signal Yield: 21.7422478741694 ± 6.8235091709664095
# Running iteration 282/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3167                 15.5774  -    5.6   +    6.5       False
# background_yield_0.3167             419.315  -     21   +     21       False
# frac_Mbc_bkg1_0.3167              -0.117343  -  0.043   +  0.046       False
# frac_deltaE_bkg1_0.3167            0.203854  -   0.15   +   0.15       False
# True
# Iteration 282 - Signal Yield: 15.577431127222715 ± 6.052399416015194
# Running iteration 283/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2183                 22.1199  -    6.3   +    7.1       False
# background_yield_0.2183             412.708  -     20   +     21       False
# frac_Mbc_bkg1_0.2183              -0.146515  -  0.042   +  0.045       False
# frac_deltaE_bkg1_0.2183            0.193668  -   0.15   +   0.15       False
# True
# Iteration 283 - Signal Yield: 22.11986891240458 ± 6.667735817825312
# Running iteration 284/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1677                 19.3834  -    5.8   +    6.5       False
# background_yield_0.1677             415.603  -     20   +     21       False
# frac_Mbc_bkg1_0.1677              -0.134929  -  0.041   +  0.045       False
# frac_deltaE_bkg1_0.1677            0.200988  -   0.15   +   0.15       False
# True
# Iteration 284 - Signal Yield: 19.383443105750025 ± 6.181842401624968
# Running iteration 285/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7101                 15.5387  -    5.8   +    6.6       False
# background_yield_0.7101             419.653  -     21   +     21       False
# frac_Mbc_bkg1_0.7101              -0.124661  -  0.043   +  0.046       False
# frac_deltaE_bkg1_0.7101            0.205927  -   0.15   +   0.15       False
# True
# Iteration 285 - Signal Yield: 15.538673579173341 ± 6.211483427840811
# Running iteration 286/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5282                 20.8939  -    5.9   +    6.8       False
# background_yield_0.5282             413.534  -     20   +     22       False
# frac_Mbc_bkg1_0.5282              -0.149095  -  0.042   +  0.045       False
# frac_deltaE_bkg1_0.5282            0.210771  -   0.15   +   0.15       False
# True
# Iteration 286 - Signal Yield: 20.893878541464577 ± 6.357405997491859
# Running iteration 287/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3853                 24.9852  -    6.4   +    7.1       False
# background_yield_0.3853             410.477  -     21   +     21       False
# frac_Mbc_bkg1_0.3853              -0.169427  -  0.041   +  0.045       False
# frac_deltaE_bkg1_0.3853            0.181086  -   0.15   +   0.15       False
# True
# Iteration 287 - Signal Yield: 24.98517325946452 ± 6.723307011112431
# Running iteration 288/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0132                 23.2406  -    6.3   +    7.1       False
# background_yield_0.0132              411.71  -     20   +     21       False
# frac_Mbc_bkg1_0.0132              -0.150373  -  0.042   +  0.045       False
# frac_deltaE_bkg1_0.0132            0.178325  -   0.15   +   0.15       False
# True
# Iteration 288 - Signal Yield: 23.24059427173122 ± 6.66934272528204
# Running iteration 289/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3516                  21.655  -      6   +    6.7       False
# background_yield_0.3516             413.362  -     20   +     21       False
# frac_Mbc_bkg1_0.3516              -0.146855  -  0.041   +  0.044       False
# frac_deltaE_bkg1_0.3516            0.179611  -   0.15   +   0.15       False
# True
# Iteration 289 - Signal Yield: 21.655051180687643 ± 6.351090285712083
# Running iteration 290/300...
# 25
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.636                 19.2138  -      6   +    6.8       False
# background_yield_0.636             415.801  -     21   +     21       False
# frac_Mbc_bkg1_0.636              -0.142322  -  0.042   +  0.045       False
# frac_deltaE_bkg1_0.636            0.203235  -   0.15   +   0.15       False
# True
# Iteration 290 - Signal Yield: 19.213783150929693 ± 6.38836981695227
# Running iteration 291/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2706                 23.0016  -    6.5   +    7.3       False
# background_yield_0.2706              412.43  -     21   +     21       False
# frac_Mbc_bkg1_0.2706              -0.151063  -  0.043   +  0.045       False
# frac_deltaE_bkg1_0.2706            0.211549  -   0.15   +   0.15       False
# True
# Iteration 291 - Signal Yield: 23.001589806730784 ± 6.8958958888928885
# Running iteration 292/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1075                 22.5606  -    6.3   +    7.1       False
# background_yield_0.1075             412.247  -     20   +     21       False
# frac_Mbc_bkg1_0.1075              -0.149674  -  0.042   +  0.045       False
# frac_deltaE_bkg1_0.1075            0.218244  -   0.15   +   0.15       False
# True
# Iteration 292 - Signal Yield: 22.560630396772094 ± 6.715387184403399
# Running iteration 293/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3165                 16.7366  -    5.8   +    6.6       False
# background_yield_0.3165             418.333  -     21   +     21       False
# frac_Mbc_bkg1_0.3165              -0.124387  -  0.043   +  0.045       False
# frac_deltaE_bkg1_0.3165            0.190746  -   0.15   +   0.15       False
# True
# Iteration 293 - Signal Yield: 16.736588915590286 ± 6.1757227713225715
# Running iteration 294/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9218                  21.223  -    6.1   +    7.1       False
# background_yield_0.9218             413.619  -     21   +     21       False
# frac_Mbc_bkg1_0.9218              -0.152168  -  0.042   +  0.045       False
# frac_deltaE_bkg1_0.9218            0.198001  -   0.15   +   0.15       False
# True
# Iteration 294 - Signal Yield: 21.22304148238822 ± 6.6161144218364285
# Running iteration 295/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1262                 21.3717  -    6.2   +    7.1       False
# background_yield_0.1262             413.397  -     20   +     21       False
# frac_Mbc_bkg1_0.1262              -0.147139  -  0.043   +  0.045       False
# frac_deltaE_bkg1_0.1262            0.213668  -   0.15   +   0.15       False
# True
# Iteration 295 - Signal Yield: 21.371659831391963 ± 6.6488589098476
# Running iteration 296/300...
# 25
# 410
# name                     value  (rounded)               errors    at limit
# ---------------------  ------------------  -------------------  ----------
# signal_yield_0.58                 25.8657  -    6.4   +    7.2       False
# background_yield_0.58             409.117  -     20   +     21       False
# frac_Mbc_bkg1_0.58              -0.171708  -  0.041   +  0.044       False
# frac_deltaE_bkg1_0.58            0.210578  -   0.15   +   0.15       False
# True
# Iteration 296 - Signal Yield: 25.86568556876577 ± 6.806842879310288
# Running iteration 297/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5652                 22.4781  -    6.2   +    7.2       False
# background_yield_0.5652             412.392  -     21   +     21       False
# frac_Mbc_bkg1_0.5652               -0.15562  -  0.042   +  0.045       False
# frac_deltaE_bkg1_0.5652            0.176661  -   0.15   +   0.15       False
# True
# Iteration 297 - Signal Yield: 22.478059570941504 ± 6.658782347211815
# Running iteration 298/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7657                 17.2871  -      6   +    6.6       False
# background_yield_0.7657             417.723  -     21   +     21       False
# frac_Mbc_bkg1_0.7657              -0.126561  -  0.043   +  0.046       False
# frac_deltaE_bkg1_0.7657            0.208937  -   0.15   +   0.15       False
# True
# Iteration 298 - Signal Yield: 17.287135633553053 ± 6.332556067544946
# Running iteration 299/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3183                  20.203  -    5.9   +    6.8       False
# background_yield_0.3183             414.833  -     21   +     21       False
# frac_Mbc_bkg1_0.3183              -0.144082  -  0.042   +  0.044       False
# frac_deltaE_bkg1_0.3183            0.177865  -   0.15   +   0.15       False
# True
# Iteration 299 - Signal Yield: 20.202963652125913 ± 6.325965143605524
# Running iteration 300/300...
# 25
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4939                 12.4624  -    5.5   +    6.5       False
# background_yield_0.4939             422.464  -     21   +     22       False
# frac_Mbc_bkg1_0.4939              -0.104662  -  0.044   +  0.046       False
# frac_deltaE_bkg1_0.4939            0.230277  -   0.15   +   0.15       False
# True
# Iteration 300 - Signal Yield: 12.462418542263494 ± 6.022241364664318
# Signal yields and errors saved to 'Bppi0_q2reg1_decay_mumu_signal_yields_and_errors_25.csv'

# %% [markdown]
# ## 10

# %%
# Number of iterations
num_iterations = 300

# List to store the signal yields and their errors from each iteration
signal_yields_and_errors = []

for i in range(num_iterations):
    print(f"Running iteration {i + 1}/{num_iterations}...")

    # Process the Monte Carlo data
    mc_mu_signal, mc_mu_only_signal, mc_mu_scf, mc_mu_bkg, mc_mu_signal_weight, mc_mu_only_signal_weight, mc_mu_scf_weight, mc_mu_bkg_weight = process_MC_data_combined(
        file_signal_mu_Bppi0,file_bkg_mu_Bppi0, 'mu', '521', 'pi0', 'mumu', 1, 'rec521', 'weights', 10
    )

    # Fit models for signal, SCF, and background
    Mbc_only_signal_cb_fixed = fit_fixed_without_weight('Mbc', 'mu', 'signal', mc_mu_only_signal["Mbc"], 'cb', 0)
    deltaE_only_signal_cb_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'signal', mc_mu_only_signal["deltaE"],  'cb_gauss', 0)

    Mbc_scf_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'scf', mc_mu_scf["Mbc"], 'argus_gauss', 0)
    deltaE_scf_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'scf', mc_mu_scf["deltaE"], 'poly_gauss', 0)

    Mbc_bkg_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'bkg', mc_mu_bkg["Mbc"], 'argus_gauss', 0)
    deltaE_bkg_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'bkg', mc_mu_bkg["deltaE"], 'poly', 0)

    # Combine signal and background data
    Signal_Mbc = mc_mu_only_signal["Mbc"]
    Signal_deltaE = mc_mu_only_signal["deltaE"]
    Background_Mbc = pd.concat([mc_mu_scf["Mbc"], mc_mu_bkg["Mbc"]])
    Background_deltaE = pd.concat([mc_mu_scf["deltaE"], mc_mu_bkg["deltaE"]])

    Signal_total = pd.concat([Signal_Mbc, Signal_deltaE], axis=1)
    Background_total = pd.concat([Background_Mbc, Background_deltaE], axis=1)

    MC_signal=len(Signal_total)
    MC_bkg=len(Background_total)

    print(MC_signal)
    print(MC_bkg)
    # Fit the extended model and get the result
    Mbc_signal_pdf, deltaE_signal_pdf, Mbc_background_pdf, deltaE_background_pdf, signal_extended, background_extended, total_model, result = fit_extended_model_scf_without_weight(
        Mbc_only_signal_cb_fixed, Mbc_scf_argus_gauss_fixed, deltaE_only_signal_cb_gauss_fixed, deltaE_scf_poly_gauss_fixed,
        Mbc_bkg_argus_gauss_fixed, deltaE_bkg_poly_gauss_fixed,
        pd.concat([Signal_total, Background_total]), 0.5, 0.5, 100, 100
    )
    result.errors(name='errors')
    print(result.params)
    print(result.valid)

    # Retrieve and store the signal yield and its error
    signal_yield = result.params[signal_extended.get_yield()]['value']
    signal_yield_errors = result.params[signal_extended.get_yield()]['errors']
    signal_yield_error = (signal_yield_errors['upper'] - signal_yield_errors['lower']) / 2

    # Store the signal yield and error as a tuple in the list
    signal_yields_and_errors.append((MC_signal,MC_bkg,signal_yield, signal_yield_error))

    print(f"Iteration {i + 1} - Signal Yield: {signal_yield} ± {signal_yield_error}")

# Convert the list to a DataFrame with two columns: 'Signal_Yield' and 'Signal_Yield_Error'
signal_yields_df = pd.DataFrame(signal_yields_and_errors, columns=['MC_signal','MC_bkg','Signal_Yield', 'Signal_Yield_Error'])


# Save the DataFrame to a CSV file
signal_yields_df.to_csv('Bppi0_q2reg1_decay_mumu_signal_yields_and_errors_10.csv', index=False)

print("Signal yields and errors saved to 'Bppi0_q2reg1_decay_mumu_signal_yields_and_errors_10.csv'")
# Out:
# Running iteration 1/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2574                 13.8501  -      5   +    5.7       False
# background_yield_0.2574             406.134  -     20   +     21       False
# frac_Mbc_bkg1_0.2574                 -0.181  -  0.038   +  0.042       False
# frac_deltaE_bkg1_0.2574            0.195365  -   0.15   +   0.15       False
# True
# Iteration 1 - Signal Yield: 13.85012343770873 ± 5.36998779101083
# Running iteration 2/300...
# 10
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.764                 11.4051  -    4.5   +    5.2       False
# background_yield_0.764              408.55  -     20   +     21       False
# frac_Mbc_bkg1_0.764              -0.174128  -  0.038   +  0.041       False
# frac_deltaE_bkg1_0.764            0.166231  -   0.15   +   0.15       False
# True
# Iteration 2 - Signal Yield: 11.405097918731041 ± 4.855227581094985
# Running iteration 3/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7157                 10.7207  -    4.6   +    5.5       False
# background_yield_0.7157             409.298  -     20   +     21       False
# frac_Mbc_bkg1_0.7157              -0.165312  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.7157            0.186722  -   0.15   +   0.15       False
# True
# Iteration 3 - Signal Yield: 10.7207438104805 ± 5.0555658752025945
# Running iteration 4/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9931                 10.0281  -    4.5   +    5.4       False
# background_yield_0.9931             409.712  -     20   +     21       False
# frac_Mbc_bkg1_0.9931              -0.166518  -   0.04   +  0.041       False
# frac_deltaE_bkg1_0.9931            0.193676  -   0.15   +   0.15       False
# True
# Iteration 4 - Signal Yield: 10.028074627342454 ± 4.916675802601112
# Running iteration 5/300...
# 10
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.731                 10.6635  -    4.5   +    5.3       False
# background_yield_0.731             409.185  -     20   +     21       False
# frac_Mbc_bkg1_0.731              -0.164922  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.731            0.185699  -   0.15   +   0.15       False
# True
# Iteration 5 - Signal Yield: 10.663540386702476 ± 4.920083033230156
# Running iteration 6/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0194                 13.4318  -    4.9   +    5.6       False
# background_yield_0.0194             406.747  -     20   +     21       False
# frac_Mbc_bkg1_0.0194              -0.181628  -  0.038   +  0.041       False
# frac_deltaE_bkg1_0.0194            0.192143  -   0.15   +   0.15       False
# True
# Iteration 6 - Signal Yield: 13.431766800822256 ± 5.2132616326136905
# Running iteration 7/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3574                 11.8987  -    4.5   +    5.3       False
# background_yield_0.3574             408.082  -     20   +     21       False
# frac_Mbc_bkg1_0.3574              -0.169121  -  0.038   +  0.041       False
# frac_deltaE_bkg1_0.3574            0.172847  -   0.15   +   0.15       False
# True
# Iteration 7 - Signal Yield: 11.898752933500246 ± 4.9282735427331765
# Running iteration 8/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3422                 12.9432  -    4.9   +    5.6       False
# background_yield_0.3422             407.253  -     20   +     21       False
# frac_Mbc_bkg1_0.3422              -0.177458  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.3422            0.199843  -   0.15   +   0.15       False
# True
# Iteration 8 - Signal Yield: 12.943241043086152 ± 5.282192500668009
# Running iteration 9/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6825                 13.3681  -    4.8   +    5.5       False
# background_yield_0.6825             406.664  -     20   +     21       False
# frac_Mbc_bkg1_0.6825              -0.185524  -  0.038   +  0.041       False
# frac_deltaE_bkg1_0.6825            0.185386  -   0.15   +   0.15       False
# True
# Iteration 9 - Signal Yield: 13.368122242740826 ± 5.155098592682088
# Running iteration 10/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9934                 10.3784  -    4.3   +    5.1       False
# background_yield_0.9934             409.589  -     20   +     21       False
# frac_Mbc_bkg1_0.9934               -0.17157  -  0.038   +  0.042       False
# frac_deltaE_bkg1_0.9934            0.188466  -   0.15   +   0.15       False
# True
# Iteration 10 - Signal Yield: 10.378393300087197 ± 4.740653260248933
# Running iteration 11/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5324                  9.0302  -    4.6   +    5.3       False
# background_yield_0.5324             410.914  -     20   +     21       False
# frac_Mbc_bkg1_0.5324              -0.160815  -   0.04   +  0.043       False
# frac_deltaE_bkg1_0.5324            0.182202  -   0.15   +   0.15       False
# True
# Iteration 11 - Signal Yield: 9.03019814524977 ± 4.9479698728538235
# Running iteration 12/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6048                  11.668  -    4.9   +    5.5       False
# background_yield_0.6048             407.611  -     19   +     22       False
# frac_Mbc_bkg1_0.6048              -0.171664  -  0.039   +  0.043       False
# frac_deltaE_bkg1_0.6048            0.201898  -   0.15   +   0.15       False
# True
# Iteration 12 - Signal Yield: 11.66802025900291 ± 5.1973671785257975
# Running iteration 13/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1209                 11.0544  -    4.8   +    5.5       False
# background_yield_0.1209             409.087  -     20   +     21       False
# frac_Mbc_bkg1_0.1209              -0.168919  -  0.039   +  0.043       False
# frac_deltaE_bkg1_0.1209            0.180688  -   0.15   +   0.15       False
# True
# Iteration 13 - Signal Yield: 11.054370479822987 ± 5.155320061447918
# Running iteration 14/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4831                  10.511  -    4.7   +    5.5       False
# background_yield_0.4831             409.485  -     20   +     21       False
# frac_Mbc_bkg1_0.4831              -0.167505  -  0.039   +  0.043       False
# frac_deltaE_bkg1_0.4831            0.175437  -   0.15   +   0.15       False
# True
# Iteration 14 - Signal Yield: 10.510982364861214 ± 5.069285084118603
# Running iteration 15/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3703                 12.8573  -    4.8   +    5.5       False
# background_yield_0.3703             407.437  -     20   +     21       False
# frac_Mbc_bkg1_0.3703              -0.180241  -  0.039   +  0.041       False
# frac_deltaE_bkg1_0.3703            0.192532  -   0.15   +   0.15       False
# True
# Iteration 15 - Signal Yield: 12.857312992521912 ± 5.166719226201353
# Running iteration 16/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2509                 13.2704  -    4.7   +    5.3       False
# background_yield_0.2509             406.634  -     20   +     21       False
# frac_Mbc_bkg1_0.2509              -0.184887  -  0.036   +  0.042       False
# frac_deltaE_bkg1_0.2509              0.1548  -   0.15   +   0.15       False
# True
# Iteration 16 - Signal Yield: 13.270348386748003 ± 4.973649965520632
# Running iteration 17/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9504                  11.774  -    4.9   +    5.8       False
# background_yield_0.9504             408.014  -     20   +     21       False
# frac_Mbc_bkg1_0.9504              -0.171038  -   0.04   +  0.043       False
# frac_deltaE_bkg1_0.9504            0.199717  -   0.15   +   0.15       False
# True
# Iteration 17 - Signal Yield: 11.774039093165316 ± 5.355929116425507
# Running iteration 18/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0237                 5.56991  -      4   +    4.7       False
# background_yield_0.0237              414.41  -     20   +     21       False
# frac_Mbc_bkg1_0.0237              -0.146647  -  0.039   +  0.043       False
# frac_deltaE_bkg1_0.0237            0.205467  -   0.15   +   0.15       False
# True
# Iteration 18 - Signal Yield: 5.569910237367328 ± 4.321362759329429
# Running iteration 19/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6314                  8.1217  -    4.5   +    5.2       False
# background_yield_0.6314             412.046  -     20   +     21       False
# frac_Mbc_bkg1_0.6314              -0.162101  -  0.039   +  0.043       False
# frac_deltaE_bkg1_0.6314             0.22489  -   0.15   +   0.15       False
# True
# Iteration 19 - Signal Yield: 8.12170090077051 ± 4.858926255413451
# Running iteration 20/300...
# 10
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.168                 11.8902  -    4.8   +    5.4       False
# background_yield_0.168              407.76  -     20   +     21       False
# frac_Mbc_bkg1_0.168              -0.172448  -  0.038   +  0.043       False
# frac_deltaE_bkg1_0.168            0.187575  -   0.15   +   0.15       False
# True
# Iteration 20 - Signal Yield: 11.890164047566765 ± 5.12752996574762
# Running iteration 21/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4567                 12.4398  -    4.9   +    5.7       False
# background_yield_0.4567             407.378  -     20   +     21       False
# frac_Mbc_bkg1_0.4567               -0.17232  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.4567            0.183946  -   0.15   +   0.15       False
# True
# Iteration 21 - Signal Yield: 12.439753668815026 ± 5.294945251977161
# Running iteration 22/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9974                 9.51311  -    4.4   +    5.2       False
# background_yield_0.9974             410.525  -     20   +     21       False
# frac_Mbc_bkg1_0.9974              -0.162051  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.9974             0.18913  -   0.15   +   0.15       False
# True
# Iteration 22 - Signal Yield: 9.513112224914757 ± 4.7895938261931885
# Running iteration 23/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0109                 10.0278  -    4.4   +    5.1       False
# background_yield_0.0109             409.943  -     20   +     21       False
# frac_Mbc_bkg1_0.0109              -0.167575  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.0109            0.184108  -   0.15   +   0.15       False
# True
# Iteration 23 - Signal Yield: 10.027831061909643 ± 4.745679381700021
# Running iteration 24/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0364                 8.97498  -    4.4   +    5.3       False
# background_yield_0.0364             410.933  -     20   +     21       False
# frac_Mbc_bkg1_0.0364               -0.15719  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.0364            0.209873  -   0.15   +   0.15       False
# True
# Iteration 24 - Signal Yield: 8.974983830983813 ± 4.861233350579683
# Running iteration 25/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3545                 9.12992  -    4.5   +    5.3       False
# background_yield_0.3545             410.642  -     20   +     21       False
# frac_Mbc_bkg1_0.3545              -0.157212  -  0.039   +  0.043       False
# frac_deltaE_bkg1_0.3545            0.187361  -   0.15   +   0.15       False
# True
# Iteration 25 - Signal Yield: 9.129923329625814 ± 4.877385624672526
# Running iteration 26/300...
# 10
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.512                  10.872  -    4.5   +    5.3       False
# background_yield_0.512             409.126  -     20   +     21       False
# frac_Mbc_bkg1_0.512              -0.169966  -  0.039   +  0.041       False
# frac_deltaE_bkg1_0.512             0.21335  -   0.15   +   0.15       False
# True
# Iteration 26 - Signal Yield: 10.87198749495947 ± 4.902058102397907
# Running iteration 27/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4777                 11.7539  -    4.6   +    5.4       False
# background_yield_0.4777             408.266  -     20   +     21       False
# frac_Mbc_bkg1_0.4777              -0.172481  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.4777            0.191671  -   0.15   +   0.15       False
# True
# Iteration 27 - Signal Yield: 11.753867236758438 ± 5.009557699038531
# Running iteration 28/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9298                  10.852  -    4.6   +    5.4       False
# background_yield_0.9298             409.268  -     20   +     21       False
# frac_Mbc_bkg1_0.9298              -0.165163  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.9298            0.177971  -   0.15   +   0.15       False
# True
# Iteration 28 - Signal Yield: 10.85195613204876 ± 4.997685612604974
# Running iteration 29/300...
# 10
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.781                 7.86265  -    4.4   +    5.2       False
# background_yield_0.781             412.044  -     20   +     21       False
# frac_Mbc_bkg1_0.781              -0.152059  -  0.039   +  0.043       False
# frac_deltaE_bkg1_0.781            0.215413  -   0.15   +   0.15       False
# True
# Iteration 29 - Signal Yield: 7.862648820752382 ± 4.812321511876989
# Running iteration 30/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7165                 13.1557  -      5   +    5.8       False
# background_yield_0.7165             406.831  -     20   +     21       False
# frac_Mbc_bkg1_0.7165               -0.18168  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.7165            0.199743  -   0.15   +   0.15       False
# True
# Iteration 30 - Signal Yield: 13.155671171462354 ± 5.379448955712753
# Running iteration 31/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3687                 12.4066  -    4.9   +    5.6       False
# background_yield_0.3687             407.706  -     20   +     21       False
# frac_Mbc_bkg1_0.3687              -0.177365  -  0.039   +  0.041       False
# frac_deltaE_bkg1_0.3687             0.19734  -   0.15   +   0.15       False
# True
# Iteration 31 - Signal Yield: 12.406632208413189 ± 5.240349480535031
# Running iteration 32/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7871                 8.96397  -    4.4   +    5.2       False
# background_yield_0.7871             410.861  -     20   +     21       False
# frac_Mbc_bkg1_0.7871              -0.158868  -  0.039   +  0.043       False
# frac_deltaE_bkg1_0.7871            0.208161  -   0.15   +   0.15       False
# True
# Iteration 32 - Signal Yield: 8.963973323197816 ± 4.820009687296258
# Running iteration 33/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5566                 8.75497  -    4.5   +    5.4       False
# background_yield_0.5566              411.05  -     20   +     21       False
# frac_Mbc_bkg1_0.5566              -0.158211  -   0.04   +  0.043       False
# frac_deltaE_bkg1_0.5566            0.197331  -   0.15   +   0.15       False
# True
# Iteration 33 - Signal Yield: 8.75497401838995 ± 4.92271009773421
# Running iteration 34/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8495                 8.99684  -    4.6   +    5.5       False
# background_yield_0.8495             410.941  -     20   +     21       False
# frac_Mbc_bkg1_0.8495              -0.158155  -   0.04   +  0.043       False
# frac_deltaE_bkg1_0.8495            0.200602  -   0.15   +   0.15       False
# True
# Iteration 34 - Signal Yield: 8.996840440182723 ± 5.031537047360812
# Running iteration 35/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7337                 9.53441  -    4.6   +    5.4       False
# background_yield_0.7337             410.306  -     20   +     21       False
# frac_Mbc_bkg1_0.7337              -0.162619  -   0.04   +  0.042       False
# frac_deltaE_bkg1_0.7337            0.216139  -   0.15   +   0.15       False
# True
# Iteration 35 - Signal Yield: 9.534408312712669 ± 4.9975253297822935
# Running iteration 36/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7699                 11.0333  -    4.7   +    5.4       False
# background_yield_0.7699             409.338  -     21   +     21       False
# frac_Mbc_bkg1_0.7699              -0.169469  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.7699             0.19454  -   0.15   +   0.15       False
# True
# Iteration 36 - Signal Yield: 11.03333803538689 ± 5.048596967672188
# Running iteration 37/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1651                 9.98607  -    4.5   +    5.5       False
# background_yield_0.1651             410.372  -     21   +     21       False
# frac_Mbc_bkg1_0.1651              -0.163352  -  0.039   +  0.043       False
# frac_deltaE_bkg1_0.1651            0.190412  -   0.15   +   0.15       False
# True
# Iteration 37 - Signal Yield: 9.986068224120201 ± 5.011121952560902
# Running iteration 38/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3928                 13.3895  -    4.9   +    5.7       False
# background_yield_0.3928             406.621  -     20   +     21       False
# frac_Mbc_bkg1_0.3928              -0.180541  -  0.038   +  0.042       False
# frac_deltaE_bkg1_0.3928            0.180458  -   0.15   +   0.15       False
# True
# Iteration 38 - Signal Yield: 13.389493153977687 ± 5.307864843622951
# Running iteration 39/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4416                 11.0694  -    4.6   +    5.4       False
# background_yield_0.4416             408.843  -     20   +     21       False
# frac_Mbc_bkg1_0.4416              -0.168541  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.4416            0.184074  -   0.15   +   0.15       False
# True
# Iteration 39 - Signal Yield: 11.069447302814384 ± 5.018915802578613
# Running iteration 40/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6429                 7.16857  -    4.2   +    5.1       False
# background_yield_0.6429             412.656  -     20   +     21       False
# frac_Mbc_bkg1_0.6429              -0.152863  -   0.04   +  0.042       False
# frac_deltaE_bkg1_0.6429            0.199626  -   0.15   +   0.15       False
# True
# Iteration 40 - Signal Yield: 7.168570012590627 ± 4.66514342847025
# Running iteration 41/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5933                  14.081  -    4.8   +    5.6       False
# background_yield_0.5933             405.898  -     20   +     21       False
# frac_Mbc_bkg1_0.5933              -0.184016  -  0.038   +  0.041       False
# frac_deltaE_bkg1_0.5933            0.184595  -   0.15   +   0.15       False
# True
# Iteration 41 - Signal Yield: 14.080997462858491 ± 5.196258038896817
# Running iteration 42/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6532                 13.3681  -    4.8   +    5.6       False
# background_yield_0.6532             406.587  -     20   +     21       False
# frac_Mbc_bkg1_0.6532              -0.183346  -  0.038   +  0.041       False
# frac_deltaE_bkg1_0.6532            0.186953  -   0.15   +   0.15       False
# True
# Iteration 42 - Signal Yield: 13.368084534447064 ± 5.195825815838415
# Running iteration 43/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2766                 9.47699  -    4.5   +    5.2       False
# background_yield_0.2766             410.271  -     20   +     21       False
# frac_Mbc_bkg1_0.2766              -0.166862  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.2766            0.189199  -   0.15   +   0.15       False
# True
# Iteration 43 - Signal Yield: 9.476990728213243 ± 4.824645586736686
# Running iteration 44/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8622                 10.5197  -    4.3   +    5.1       False
# background_yield_0.8622             409.471  -     20   +     21       False
# frac_Mbc_bkg1_0.8622              -0.170827  -  0.038   +  0.041       False
# frac_deltaE_bkg1_0.8622            0.180145  -   0.15   +   0.15       False
# True
# Iteration 44 - Signal Yield: 10.519702301308685 ± 4.691412580907356
# Running iteration 45/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1866                 10.8253  -    4.4   +    5.2       False
# background_yield_0.1866             409.129  -     20   +     21       False
# frac_Mbc_bkg1_0.1866               -0.17168  -  0.038   +  0.042       False
# frac_deltaE_bkg1_0.1866            0.177901  -   0.15   +   0.15       False
# True
# Iteration 45 - Signal Yield: 10.82532795292262 ± 4.841345735186071
# Running iteration 46/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2715                 12.5429  -    4.7   +    5.5       False
# background_yield_0.2715             407.204  -     20   +     21       False
# frac_Mbc_bkg1_0.2715              -0.180259  -  0.038   +  0.042       False
# frac_deltaE_bkg1_0.2715            0.199784  -   0.15   +   0.15       False
# True
# Iteration 46 - Signal Yield: 12.542943487474853 ± 5.091856237765928
# Running iteration 47/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4791                  12.852  -    4.9   +    5.5       False
# background_yield_0.4791              407.31  -     20   +     21       False
# frac_Mbc_bkg1_0.4791              -0.173855  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.4791            0.189238  -   0.15   +   0.15       False
# True
# Iteration 47 - Signal Yield: 12.852040745904333 ± 5.207434004805458
# Running iteration 48/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3537                 9.41469  -    4.6   +    5.2       False
# background_yield_0.3537             410.404  -     20   +     21       False
# frac_Mbc_bkg1_0.3537              -0.159145  -   0.04   +  0.042       False
# frac_deltaE_bkg1_0.3537            0.202832  -   0.15   +   0.15       False
# True
# Iteration 48 - Signal Yield: 9.41468929886416 ± 4.906761639695501
# Running iteration 49/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8551                 9.93794  -    4.8   +    5.6       False
# background_yield_0.8551             410.159  -     20   +     21       False
# frac_Mbc_bkg1_0.8551              -0.160347  -   0.04   +  0.043       False
# frac_deltaE_bkg1_0.8551            0.202506  -   0.15   +   0.15       False
# True
# Iteration 49 - Signal Yield: 9.93794418697466 ± 5.1882326471006515
# Running iteration 50/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8685                 13.0456  -    4.9   +    5.6       False
# background_yield_0.8685             406.977  -     20   +     21       False
# frac_Mbc_bkg1_0.8685               -0.17526  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.8685            0.174509  -   0.15   +   0.15       False
# True
# Iteration 50 - Signal Yield: 13.045638039778115 ± 5.256884094449301
# Running iteration 51/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9757                 13.1576  -    4.8   +    5.7       False
# background_yield_0.9757             406.659  -     20   +     21       False
# frac_Mbc_bkg1_0.9757              -0.177654  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.9757            0.189011  -   0.15   +   0.15       False
# True
# Iteration 51 - Signal Yield: 13.157549371278426 ± 5.265239214327572
# Running iteration 52/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9834                 8.50692  -    4.4   +    5.3       False
# background_yield_0.9834             411.514  -     20   +     21       False
# frac_Mbc_bkg1_0.9834              -0.164579  -  0.039   +  0.043       False
# frac_deltaE_bkg1_0.9834            0.217496  -   0.15   +   0.15       False
# True
# Iteration 52 - Signal Yield: 8.506917540999353 ± 4.850712007229489
# Running iteration 53/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3491                 11.6095  -    4.5   +    5.4       False
# background_yield_0.3491             408.434  -     20   +     21       False
# frac_Mbc_bkg1_0.3491              -0.176578  -  0.039   +  0.041       False
# frac_deltaE_bkg1_0.3491            0.168175  -   0.15   +   0.15       False
# True
# Iteration 53 - Signal Yield: 11.609458323097586 ± 4.957384416912335
# Running iteration 54/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5418                 12.8397  -    4.8   +    5.5       False
# background_yield_0.5418             406.802  -     20   +     21       False
# frac_Mbc_bkg1_0.5418              -0.180957  -  0.038   +  0.042       False
# frac_deltaE_bkg1_0.5418            0.182301  -   0.15   +   0.15       False
# True
# Iteration 54 - Signal Yield: 12.839720561817003 ± 5.140807108123193
# Running iteration 55/300...
# 10
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.462                 9.40045  -    4.5   +    5.1       False
# background_yield_0.462             410.804  -     20   +     21       False
# frac_Mbc_bkg1_0.462              -0.160232  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.462            0.212104  -   0.15   +   0.15       False
# True
# Iteration 55 - Signal Yield: 9.400454316356386 ± 4.805431645269694
# Running iteration 56/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3852                 10.8309  -    4.4   +    5.3       False
# background_yield_0.3852             409.377  -     20   +     21       False
# frac_Mbc_bkg1_0.3852              -0.170691  -  0.038   +  0.042       False
# frac_deltaE_bkg1_0.3852             0.18552  -   0.15   +   0.15       False
# True
# Iteration 56 - Signal Yield: 10.830872227346289 ± 4.8418953422514175
# Running iteration 57/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8097                 11.8707  -    4.8   +    5.7       False
# background_yield_0.8097             408.286  -     20   +     21       False
# frac_Mbc_bkg1_0.8097              -0.169594  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.8097            0.187399  -   0.15   +   0.15       False
# True
# Iteration 57 - Signal Yield: 11.870723145962982 ± 5.229713001869854
# Running iteration 58/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6932                 9.84224  -    4.5   +    5.2       False
# background_yield_0.6932             410.211  -     20   +     21       False
# frac_Mbc_bkg1_0.6932                -0.1651  -  0.038   +  0.043       False
# frac_deltaE_bkg1_0.6932            0.181135  -   0.15   +   0.15       False
# True
# Iteration 58 - Signal Yield: 9.842239098355916 ± 4.873065873820971
# Running iteration 59/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2848                 10.8616  -    4.6   +    5.3       False
# background_yield_0.2848             409.072  -     20   +     21       False
# frac_Mbc_bkg1_0.2848              -0.168418  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.2848            0.211237  -   0.15   +   0.15       False
# True
# Iteration 59 - Signal Yield: 10.861645215469196 ± 4.961265596723014
# Running iteration 60/300...
# 10
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.708                 5.79973  -    4.1   +      5       False
# background_yield_0.708              414.63  -     21   +     21       False
# frac_Mbc_bkg1_0.708               -0.14462  -   0.04   +  0.043       False
# frac_deltaE_bkg1_0.708            0.208695  -   0.15   +   0.15       False
# True
# Iteration 60 - Signal Yield: 5.799732143637344 ± 4.529818358925096
# Running iteration 61/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4172                  9.7913  -    4.5   +    5.2       False
# background_yield_0.4172             410.299  -     20   +     21       False
# frac_Mbc_bkg1_0.4172               -0.16943  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.4172            0.200453  -   0.15   +   0.15       False
# True
# Iteration 61 - Signal Yield: 9.79129813056035 ± 4.829903933095343
# Running iteration 62/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1198                 10.4536  -    4.6   +    5.3       False
# background_yield_0.1198             409.625  -     20   +     21       False
# frac_Mbc_bkg1_0.1198              -0.165007  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.1198            0.184193  -   0.15   +   0.15       False
# True
# Iteration 62 - Signal Yield: 10.45359634492023 ± 4.938887120139405
# Running iteration 63/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5858                 12.0492  -    4.9   +    5.7       False
# background_yield_0.5858              407.96  -     20   +     21       False
# frac_Mbc_bkg1_0.5858              -0.171874  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.5858            0.205645  -   0.15   +   0.15       False
# True
# Iteration 63 - Signal Yield: 12.049219763910449 ± 5.301032616553684
# Running iteration 64/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2343                 12.0028  -    4.8   +    5.4       False
# background_yield_0.2343             407.531  -     20   +     21       False
# frac_Mbc_bkg1_0.2343              -0.172657  -  0.038   +  0.043       False
# frac_deltaE_bkg1_0.2343            0.191606  -   0.15   +   0.15       False
# True
# Iteration 64 - Signal Yield: 12.002789943994825 ± 5.141298482821701
# Running iteration 65/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2651                 11.6041  -    4.6   +    5.4       False
# background_yield_0.2651             408.271  -     20   +     21       False
# frac_Mbc_bkg1_0.2651              -0.173157  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.2651            0.186185  -   0.15   +   0.15       False
# True
# Iteration 65 - Signal Yield: 11.604119063127552 ± 5.031093929156
# Running iteration 66/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2861                 10.2339  -    4.6   +    5.5       False
# background_yield_0.2861             409.797  -     20   +     21       False
# frac_Mbc_bkg1_0.2861              -0.167754  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.2861            0.220637  -   0.15   +   0.15       False
# True
# Iteration 66 - Signal Yield: 10.233851363291935 ± 5.043144440474144
# Running iteration 67/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0088                   9.818  -    4.7   +    5.5       False
# background_yield_0.0088              410.33  -     20   +     21       False
# frac_Mbc_bkg1_0.0088              -0.161385  -   0.04   +  0.043       False
# frac_deltaE_bkg1_0.0088            0.187031  -   0.15   +   0.15       False
# True
# Iteration 67 - Signal Yield: 9.818003467595936 ± 5.077544939359072
# Running iteration 68/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4257                 8.79685  -    4.5   +    5.3       False
# background_yield_0.4257             410.861  -     20   +     21       False
# frac_Mbc_bkg1_0.4257              -0.159636  -  0.039   +  0.043       False
# frac_deltaE_bkg1_0.4257            0.199467  -   0.15   +   0.15       False
# True
# Iteration 68 - Signal Yield: 8.796849586299505 ± 4.922972726051688
# Running iteration 69/300...
# 10
# 410
# name                     value  (rounded)               errors    at limit
# ---------------------  ------------------  -------------------  ----------
# signal_yield_0.55                 11.1683  -    4.7   +    5.5       False
# background_yield_0.55             408.794  -     20   +     21       False
# frac_Mbc_bkg1_0.55              -0.174345  -  0.039   +  0.043       False
# frac_deltaE_bkg1_0.55            0.180951  -   0.15   +   0.15       False
# True
# Iteration 69 - Signal Yield: 11.168324887599162 ± 5.128178448514843
# Running iteration 70/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0164                 11.7863  -    4.6   +    5.4       False
# background_yield_0.0164             408.251  -     20   +     21       False
# frac_Mbc_bkg1_0.0164               -0.17916  -  0.038   +  0.041       False
# frac_deltaE_bkg1_0.0164             0.18965  -   0.15   +   0.15       False
# True
# Iteration 70 - Signal Yield: 11.786256566120842 ± 5.004007311985442
# Running iteration 71/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6857                 9.26104  -    4.7   +    5.5       False
# background_yield_0.6857             410.719  -     20   +     21       False
# frac_Mbc_bkg1_0.6857              -0.160672  -   0.04   +  0.043       False
# frac_deltaE_bkg1_0.6857            0.218321  -   0.15   +   0.15       False
# True
# Iteration 71 - Signal Yield: 9.261044203900116 ± 5.136206473525124
# Running iteration 72/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6854                  7.6062  -    4.4   +      5       False
# background_yield_0.6854             412.694  -     21   +     21       False
# frac_Mbc_bkg1_0.6854              -0.153881  -  0.039   +  0.043       False
# frac_deltaE_bkg1_0.6854            0.215994  -   0.15   +   0.15       False
# True
# Iteration 72 - Signal Yield: 7.606198422659679 ± 4.67140348555849
# Running iteration 73/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8195                  9.0353  -    4.5   +    5.3       False
# background_yield_0.8195             410.787  -     20   +     21       False
# frac_Mbc_bkg1_0.8195              -0.159225  -  0.039   +  0.043       False
# frac_deltaE_bkg1_0.8195            0.199956  -   0.15   +   0.15       False
# True
# Iteration 73 - Signal Yield: 9.035301893102133 ± 4.932050752909337
# Running iteration 74/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6278                 10.4534  -    4.8   +    5.6       False
# background_yield_0.6278             409.774  -     21   +     21       False
# frac_Mbc_bkg1_0.6278               -0.16184  -  0.041   +  0.042       False
# frac_deltaE_bkg1_0.6278            0.201023  -   0.15   +   0.15       False
# True
# Iteration 74 - Signal Yield: 10.453402081947658 ± 5.225067762516209
# Running iteration 75/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9749                  10.798  -    4.7   +    5.4       False
# background_yield_0.9749             409.125  -     20   +     21       False
# frac_Mbc_bkg1_0.9749               -0.17481  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.9749            0.203115  -   0.15   +   0.15       False
# True
# Iteration 75 - Signal Yield: 10.797949778079499 ± 5.068446300752454
# Running iteration 76/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6986                  12.062  -    4.8   +    5.5       False
# background_yield_0.6986             407.427  -     20   +     21       False
# frac_Mbc_bkg1_0.6986              -0.170378  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.6986            0.201763  -   0.15   +   0.15       False
# True
# Iteration 76 - Signal Yield: 12.061979798315761 ± 5.184983061487929
# Running iteration 77/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0293                 11.4086  -    4.7   +    5.6       False
# background_yield_0.0293             408.823  -     20   +     21       False
# frac_Mbc_bkg1_0.0293              -0.169029  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.0293            0.202024  -   0.15   +   0.15       False
# True
# Iteration 77 - Signal Yield: 11.408641706825387 ± 5.133746262035739
# Running iteration 78/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7059                 6.99788  -    4.1   +    4.9       False
# background_yield_0.7059             413.122  -     20   +     21       False
# frac_Mbc_bkg1_0.7059              -0.154987  -  0.038   +  0.044       False
# frac_deltaE_bkg1_0.7059            0.213607  -   0.15   +   0.15       False
# True
# Iteration 78 - Signal Yield: 6.9978794914979465 ± 4.5462507773657554
# Running iteration 79/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5061                 11.3088  -    4.5   +    5.2       False
# background_yield_0.5061             408.691  -     20   +     21       False
# frac_Mbc_bkg1_0.5061              -0.175929  -  0.038   +  0.041       False
# frac_deltaE_bkg1_0.5061            0.165285  -   0.15   +   0.15       False
# True
# Iteration 79 - Signal Yield: 11.308806329660952 ± 4.843295519700289
# Running iteration 80/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0764                 12.0469  -    4.6   +    5.4       False
# background_yield_0.0764              408.02  -     20   +     21       False
# frac_Mbc_bkg1_0.0764              -0.175653  -  0.039   +  0.041       False
# frac_deltaE_bkg1_0.0764            0.176242  -   0.15   +   0.15       False
# True
# Iteration 80 - Signal Yield: 12.0468989680914 ± 5.016957831873027
# Running iteration 81/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4721                 10.3367  -    4.6   +    5.3       False
# background_yield_0.4721             409.733  -     20   +     21       False
# frac_Mbc_bkg1_0.4721              -0.164585  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.4721             0.17445  -   0.15   +   0.15       False
# True
# Iteration 81 - Signal Yield: 10.336708540490573 ± 4.976243741635686
# Running iteration 82/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1834                 10.4651  -    4.8   +    5.5       False
# background_yield_0.1834             408.794  -     20   +     22       False
# frac_Mbc_bkg1_0.1834              -0.168026  -  0.039   +  0.043       False
# frac_deltaE_bkg1_0.1834            0.213902  -   0.15   +   0.15       False
# True
# Iteration 82 - Signal Yield: 10.465119053497709 ± 5.183843637542037
# Running iteration 83/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5693                 13.4591  -      5   +    5.7       False
# background_yield_0.5693             406.593  -     20   +     21       False
# frac_Mbc_bkg1_0.5693              -0.178815  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.5693            0.189213  -   0.15   +   0.15       False
# True
# Iteration 83 - Signal Yield: 13.459100054774899 ± 5.341306717987452
# Running iteration 84/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9821                 11.3736  -    4.6   +    5.5       False
# background_yield_0.9821             408.661  -     20   +     21       False
# frac_Mbc_bkg1_0.9821              -0.171963  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.9821            0.198002  -   0.15   +   0.15       False
# True
# Iteration 84 - Signal Yield: 11.373637001220937 ± 5.044706403214796
# Running iteration 85/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# ...
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8652                 9.08385  -    4.2   +    5.4       False
# background_yield_0.8652             410.663  -     20   +     21       False
# frac_Mbc_bkg1_0.8652              -0.160317  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.8652            0.178858  -   0.15   +   0.15       False
# True
# Iteration 273 - Signal Yield: 9.083852503848147 ± 4.803055673210904
# Running iteration 274/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4864                 7.94662  -    4.2   +    5.1       False
# background_yield_0.4864             411.849  -     20   +     21       False
# frac_Mbc_bkg1_0.4864              -0.157799  -  0.038   +  0.043       False
# frac_deltaE_bkg1_0.4864             0.19751  -   0.15   +   0.15       False
# True
# Iteration 274 - Signal Yield: 7.946614670413551 ± 4.679904500901806
# Running iteration 275/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7058                  13.993  -    4.8   +    5.6       False
# background_yield_0.7058             406.096  -     20   +     21       False
# frac_Mbc_bkg1_0.7058              -0.180249  -  0.038   +  0.041       False
# frac_deltaE_bkg1_0.7058            0.168454  -   0.15   +   0.15       False
# True
# Iteration 275 - Signal Yield: 13.992974991475656 ± 5.188864617917512
# Running iteration 276/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7872                 16.2836  -    5.2   +    5.7       False
# background_yield_0.7872             403.784  -     20   +     21       False
# frac_Mbc_bkg1_0.7872              -0.193071  -  0.037   +  0.042       False
# frac_deltaE_bkg1_0.7872            0.183866  -   0.15   +   0.15       False
# True
# Iteration 276 - Signal Yield: 16.283568609326416 ± 5.462082343767387
# Running iteration 277/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7502                 12.7235  -    4.9   +    5.6       False
# background_yield_0.7502             407.302  -     20   +     21       False
# frac_Mbc_bkg1_0.7502              -0.175774  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.7502            0.201153  -   0.15   +   0.15       False
# True
# Iteration 277 - Signal Yield: 12.723546153045493 ± 5.248401335781166
# Running iteration 278/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0372                 13.2619  -    4.9   +    5.5       False
# background_yield_0.0372             406.861  -     20   +     21       False
# frac_Mbc_bkg1_0.0372              -0.176832  -  0.039   +  0.041       False
# frac_deltaE_bkg1_0.0372            0.196093  -   0.15   +   0.15       False
# True
# Iteration 278 - Signal Yield: 13.261922207932262 ± 5.18569087469385
# Running iteration 279/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0218                  8.5732  -    4.5   +    5.4       False
# background_yield_0.0218             410.983  -     20   +     21       False
# frac_Mbc_bkg1_0.0218              -0.151648  -   0.04   +  0.043       False
# frac_deltaE_bkg1_0.0218            0.195886  -   0.15   +   0.15       False
# True
# Iteration 279 - Signal Yield: 8.573205464225655 ± 4.961892811493436
# Running iteration 280/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0694                 14.9187  -    4.9   +    5.5       False
# background_yield_0.0694             405.354  -     20   +     21       False
# frac_Mbc_bkg1_0.0694              -0.188449  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.0694            0.190646  -   0.15   +   0.15       False
# True
# Iteration 280 - Signal Yield: 14.918658522051055 ± 5.2349413036597205
# Running iteration 281/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5073                 10.4624  -    4.7   +    5.5       False
# background_yield_0.5073             409.553  -     20   +     21       False
# frac_Mbc_bkg1_0.5073              -0.168558  -  0.039   +  0.043       False
# frac_deltaE_bkg1_0.5073            0.176345  -   0.15   +   0.15       False
# True
# Iteration 281 - Signal Yield: 10.462437682499184 ± 5.092021643356425
# Running iteration 282/300...
# 10
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.709                 8.35223  -    4.3   +      5       False
# background_yield_0.709             410.943  -     20   +     22       False
# frac_Mbc_bkg1_0.709              -0.153567  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.709            0.181008  -   0.15   +   0.15       False
# True
# Iteration 282 - Signal Yield: 8.3522302229144 ± 4.633555971743739
# Running iteration 283/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6986                 12.1523  -    4.8   +    5.6       False
# background_yield_0.6986             408.113  -     20   +     21       False
# frac_Mbc_bkg1_0.6986              -0.172363  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.6986            0.181843  -   0.15   +   0.15       False
# True
# Iteration 283 - Signal Yield: 12.152286950045044 ± 5.1742734050092345
# Running iteration 284/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4083                 9.73241  -    4.5   +    5.3       False
# background_yield_0.4083             410.211  -     20   +     21       False
# frac_Mbc_bkg1_0.4083               -0.16416  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.4083            0.181971  -   0.15   +   0.15       False
# True
# Iteration 284 - Signal Yield: 9.732414058491681 ± 4.871384489601589
# Running iteration 285/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3079                 9.04274  -    4.4   +    5.3       False
# background_yield_0.3079             410.671  -     20   +     21       False
# frac_Mbc_bkg1_0.3079              -0.158961  -   0.04   +  0.042       False
# frac_deltaE_bkg1_0.3079            0.199705  -   0.15   +   0.15       False
# True
# Iteration 285 - Signal Yield: 9.042738004056641 ± 4.868375173404381
# Running iteration 286/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3001                 13.7813  -    4.8   +    5.6       False
# background_yield_0.3001             405.827  -     20   +     21       False
# frac_Mbc_bkg1_0.3001              -0.181524  -  0.039   +  0.041       False
# frac_deltaE_bkg1_0.3001            0.186681  -   0.15   +   0.15       False
# True
# Iteration 286 - Signal Yield: 13.781349333098785 ± 5.224846694706983
# Running iteration 287/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5746                 9.36756  -    4.6   +    5.3       False
# background_yield_0.5746             410.482  -     20   +     21       False
# frac_Mbc_bkg1_0.5746              -0.159426  -   0.04   +  0.043       False
# frac_deltaE_bkg1_0.5746            0.182518  -   0.15   +   0.15       False
# True
# Iteration 287 - Signal Yield: 9.367558073255738 ± 4.948606193478444
# Running iteration 288/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5033                 15.4078  -    5.1   +    5.7       False
# background_yield_0.5033             405.081  -     21   +     20       False
# frac_Mbc_bkg1_0.5033               -0.18864  -  0.037   +  0.042       False
# frac_deltaE_bkg1_0.5033            0.177603  -   0.15   +   0.15       False
# True
# Iteration 288 - Signal Yield: 15.407780868040613 ± 5.3752008084761105
# Running iteration 289/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9061                 7.84856  -      4   +    4.9       False
# background_yield_0.9061             411.993  -     20   +     21       False
# frac_Mbc_bkg1_0.9061              -0.151222  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.9061            0.179596  -   0.15   +   0.15       False
# True
# Iteration 289 - Signal Yield: 7.848556328478043 ± 4.473729413927101
# Running iteration 290/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2877                 11.3428  -    4.8   +    5.6       False
# background_yield_0.2877             408.385  -     20   +     21       False
# frac_Mbc_bkg1_0.2877              -0.173376  -  0.039   +  0.043       False
# frac_deltaE_bkg1_0.2877            0.211466  -   0.15   +   0.15       False
# True
# Iteration 290 - Signal Yield: 11.342752214907248 ± 5.193198406202469
# Running iteration 291/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2614                 12.8689  -      5   +    5.5       False
# background_yield_0.2614             407.517  -     20   +     21       False
# frac_Mbc_bkg1_0.2614              -0.175491  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.2614            0.203473  -   0.15   +   0.15       False
# True
# Iteration 291 - Signal Yield: 12.868911406566252 ± 5.262778170795095
# Running iteration 292/300...
# 10
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.562                 9.54864  -    4.6   +    5.4       False
# background_yield_0.562             410.213  -     20   +     21       False
# frac_Mbc_bkg1_0.562              -0.161138  -  0.039   +  0.043       False
# frac_deltaE_bkg1_0.562            0.198613  -   0.15   +   0.15       False
# True
# Iteration 292 - Signal Yield: 9.54863486081397 ± 4.977720346885521
# Running iteration 293/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8928                 8.79009  -    4.3   +      5       False
# background_yield_0.8928             411.125  -     20   +     21       False
# frac_Mbc_bkg1_0.8928              -0.161847  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.8928            0.187437  -   0.15   +   0.15       False
# True
# Iteration 293 - Signal Yield: 8.790092948974625 ± 4.653026349212077
# Running iteration 294/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4274                 12.4419  -    4.8   +    5.6       False
# background_yield_0.4274             407.473  -     20   +     21       False
# frac_Mbc_bkg1_0.4274              -0.177478  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.4274            0.191664  -   0.15   +   0.15       False
# True
# Iteration 294 - Signal Yield: 12.441852987886207 ± 5.2145197771245595
# Running iteration 295/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4268                 9.45612  -    4.4   +    5.2       False
# background_yield_0.4268             410.603  -     20   +     21       False
# frac_Mbc_bkg1_0.4268               -0.16169  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.4268            0.202188  -   0.15   +   0.15       False
# True
# Iteration 295 - Signal Yield: 9.456115342172538 ± 4.80983036769447
# Running iteration 296/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0861                 11.2041  -    4.6   +    5.4       False
# background_yield_0.0861             408.794  -     20   +     21       False
# frac_Mbc_bkg1_0.0861              -0.170784  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.0861            0.190806  -   0.15   +   0.15       False
# True
# Iteration 296 - Signal Yield: 11.204070745045719 ± 4.993771972107844
# Running iteration 297/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5539                 11.0136  -    4.8   +    5.5       False
# background_yield_0.5539             409.135  -     20   +     21       False
# frac_Mbc_bkg1_0.5539              -0.165919  -  0.039   +  0.043       False
# frac_deltaE_bkg1_0.5539            0.180877  -   0.15   +   0.15       False
# True
# Iteration 297 - Signal Yield: 11.013621938041402 ± 5.155229058281994
# Running iteration 298/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0978                 10.6174  -    4.6   +    5.5       False
# background_yield_0.0978             409.373  -     20   +     21       False
# frac_Mbc_bkg1_0.0978              -0.166354  -  0.039   +  0.043       False
# frac_deltaE_bkg1_0.0978            0.187648  -   0.15   +   0.15       False
# True
# Iteration 298 - Signal Yield: 10.617412690142345 ± 5.045535062553228
# Running iteration 299/300...
# 10
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7761                 12.9139  -    4.7   +    5.6       False
# background_yield_0.7761             407.114  -     20   +     21       False
# frac_Mbc_bkg1_0.7761              -0.178517  -  0.038   +  0.042       False
# frac_deltaE_bkg1_0.7761            0.192017  -   0.15   +   0.15       False
# True
# Iteration 299 - Signal Yield: 12.91386122747822 ± 5.1778625596992285
# Running iteration 300/300...
# 10
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.281                 10.0958  -    4.7   +    5.5       False
# background_yield_0.281             409.951  -     20   +     21       False
# frac_Mbc_bkg1_0.281              -0.166341  -   0.04   +  0.043       False
# frac_deltaE_bkg1_0.281            0.208509  -   0.15   +   0.15       False
# True
# Iteration 300 - Signal Yield: 10.095806882609631 ± 5.11907313435883
# Signal yields and errors saved to 'Bppi0_q2reg1_decay_mumu_signal_yields_and_errors_10.csv'

# %% [markdown]
# ## 5

# %%
# Number of iterations
num_iterations = 300

# List to store the signal yields and their errors from each iteration
signal_yields_and_errors = []

for i in range(num_iterations):
    print(f"Running iteration {i + 1}/{num_iterations}...")

    # Process the Monte Carlo data
    mc_mu_signal, mc_mu_only_signal, mc_mu_scf, mc_mu_bkg, mc_mu_signal_weight, mc_mu_only_signal_weight, mc_mu_scf_weight, mc_mu_bkg_weight = process_MC_data_combined(
        file_signal_mu_Bppi0,file_bkg_mu_Bppi0, 'mu', '521', 'pi0', 'mumu', 1, 'rec521', 'weights', 5
    )

    # Fit models for signal, SCF, and background
    Mbc_only_signal_cb_fixed = fit_fixed_without_weight('Mbc', 'mu', 'signal', mc_mu_only_signal["Mbc"], 'cb', 0)
    deltaE_only_signal_cb_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'signal', mc_mu_only_signal["deltaE"],  'cb_gauss', 0)

    Mbc_scf_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'scf', mc_mu_scf["Mbc"], 'argus_gauss', 0)
    deltaE_scf_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'scf', mc_mu_scf["deltaE"], 'poly_gauss', 0)

    Mbc_bkg_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'bkg', mc_mu_bkg["Mbc"], 'argus_gauss', 0)
    deltaE_bkg_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'bkg', mc_mu_bkg["deltaE"], 'poly', 0)

    # Combine signal and background data
    Signal_Mbc = mc_mu_only_signal["Mbc"]
    Signal_deltaE = mc_mu_only_signal["deltaE"]
    Background_Mbc = pd.concat([mc_mu_scf["Mbc"], mc_mu_bkg["Mbc"]])
    Background_deltaE = pd.concat([mc_mu_scf["deltaE"], mc_mu_bkg["deltaE"]])

    Signal_total = pd.concat([Signal_Mbc, Signal_deltaE], axis=1)
    Background_total = pd.concat([Background_Mbc, Background_deltaE], axis=1)

    MC_signal=len(Signal_total)
    MC_bkg=len(Background_total)

    print(MC_signal)
    print(MC_bkg)
    # Fit the extended model and get the result
    Mbc_signal_pdf, deltaE_signal_pdf, Mbc_background_pdf, deltaE_background_pdf, signal_extended, background_extended, total_model, result = fit_extended_model_scf_without_weight(
        Mbc_only_signal_cb_fixed, Mbc_scf_argus_gauss_fixed, deltaE_only_signal_cb_gauss_fixed, deltaE_scf_poly_gauss_fixed,
        Mbc_bkg_argus_gauss_fixed, deltaE_bkg_poly_gauss_fixed,
        pd.concat([Signal_total, Background_total]), 0.5, 0.5, 100, 100
    )
    result.errors(name='errors')
    print(result.params)
    print(result.valid)

    # Retrieve and store the signal yield and its error
    signal_yield = result.params[signal_extended.get_yield()]['value']
    signal_yield_errors = result.params[signal_extended.get_yield()]['errors']
    signal_yield_error = (signal_yield_errors['upper'] - signal_yield_errors['lower']) / 2

    # Store the signal yield and error as a tuple in the list
    signal_yields_and_errors.append((MC_signal,MC_bkg,signal_yield, signal_yield_error))

    print(f"Iteration {i + 1} - Signal Yield: {signal_yield} ± {signal_yield_error}")

# Convert the list to a DataFrame with two columns: 'Signal_Yield' and 'Signal_Yield_Error'
signal_yields_df = pd.DataFrame(signal_yields_and_errors, columns=['MC_signal','MC_bkg','Signal_Yield', 'Signal_Yield_Error'])


# Save the DataFrame to a CSV file
signal_yields_df.to_csv('Bppi0_q2reg1_decay_mumu_signal_yields_and_errors_5.csv', index=False)

print("Signal yields and errors saved to 'Bppi0_q2reg1_decay_mumu_signal_yields_and_errors_5.csv'")
# Out:
# Running iteration 1/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5532                 9.99562  -    4.3   +    5.1       False
# background_yield_0.5532             405.035  -     20   +     21       False
# frac_Mbc_bkg1_0.5532              -0.188999  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.5532            0.189827  -   0.15   +   0.15       False
# True
# Iteration 1 - Signal Yield: 9.995618253135072 ± 4.721362731267917
# Running iteration 2/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2864                 7.25716  -    3.9   +    4.7       False
# background_yield_0.2864             407.738  -     20   +     21       False
# frac_Mbc_bkg1_0.2864              -0.176365  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.2864            0.166061  -   0.15   +   0.15       False
# True
# Iteration 2 - Signal Yield: 7.257163636387639 ± 4.278811629554957
# Running iteration 3/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6834                 7.61169  -      4   +    4.9       False
# background_yield_0.6834             407.388  -     20   +     21       False
# frac_Mbc_bkg1_0.6834              -0.174297  -  0.038   +  0.041       False
# frac_deltaE_bkg1_0.6834            0.188967  -   0.15   +   0.15       False
# True
# Iteration 3 - Signal Yield: 7.611688536322581 ± 4.442722848396656
# Running iteration 4/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1257                 8.00365  -    4.1   +    4.9       False
# background_yield_0.1257             407.041  -     20   +     21       False
# frac_Mbc_bkg1_0.1257              -0.178107  -  0.037   +  0.042       False
# frac_deltaE_bkg1_0.1257            0.175858  -   0.15   +   0.15       False
# True
# Iteration 4 - Signal Yield: 8.003651191623426 ± 4.486786424361103
# Running iteration 5/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5176                 7.67753  -      4   +    4.8       False
# background_yield_0.5176             407.397  -     20   +     21       False
# frac_Mbc_bkg1_0.5176              -0.176986  -  0.037   +  0.042       False
# frac_deltaE_bkg1_0.5176            0.186597  -   0.15   +   0.15       False
# True
# Iteration 5 - Signal Yield: 7.677531964124457 ± 4.384648453736945
# Running iteration 6/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3884                 10.2232  -    4.3   +    5.1       False
# background_yield_0.3884             404.772  -     20   +     21       False
# frac_Mbc_bkg1_0.3884               -0.18935  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.3884            0.181664  -   0.15   +   0.15       False
# True
# Iteration 6 - Signal Yield: 10.223241156007964 ± 4.6844170598348125
# Running iteration 7/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8258                 6.38265  -    3.8   +    4.6       False
# background_yield_0.8258             408.433  -     20   +     21       False
# frac_Mbc_bkg1_0.8258              -0.167385  -  0.038   +  0.041       False
# frac_deltaE_bkg1_0.8258            0.177483  -   0.15   +   0.15       False
# True
# Iteration 7 - Signal Yield: 6.382649752168463 ± 4.211760666993466
# Running iteration 8/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6222                 7.07288  -    4.1   +    4.9       False
# background_yield_0.6222             408.008  -     20   +     21       False
# frac_Mbc_bkg1_0.6222               -0.17551  -  0.037   +  0.043       False
# frac_deltaE_bkg1_0.6222            0.205468  -   0.15   +   0.15       False
# True
# Iteration 8 - Signal Yield: 7.072883849040127 ± 4.477374746262784
# Running iteration 9/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2738                 7.17363  -    3.9   +    4.7       False
# background_yield_0.2738             407.847  -     20   +     21       False
# frac_Mbc_bkg1_0.2738              -0.179904  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.2738            0.190171  -   0.15   +   0.15       False
# True
# Iteration 9 - Signal Yield: 7.173635403143375 ± 4.340736907964309
# Running iteration 10/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4875                 6.68523  -    3.7   +    4.6       False
# background_yield_0.4875             408.268  -     20   +     21       False
# frac_Mbc_bkg1_0.4875              -0.176253  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.4875            0.181542  -   0.15   +   0.15       False
# True
# Iteration 10 - Signal Yield: 6.685235400144979 ± 4.14039859601462
# Running iteration 11/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4202                 6.86629  -    3.9   +    4.7       False
# background_yield_0.4202             408.133  -     20   +     21       False
# frac_Mbc_bkg1_0.4202              -0.175347  -  0.038   +  0.041       False
# frac_deltaE_bkg1_0.4202            0.180953  -   0.15   +   0.15       False
# True
# Iteration 11 - Signal Yield: 6.866288008027056 ± 4.314348061079878
# Running iteration 12/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3165                 7.90404  -    4.2   +      5       False
# background_yield_0.3165             407.164  -     20   +     21       False
# frac_Mbc_bkg1_0.3165              -0.175574  -  0.037   +  0.042       False
# frac_deltaE_bkg1_0.3165            0.199943  -   0.15   +   0.15       False
# True
# Iteration 12 - Signal Yield: 7.904044007650411 ± 4.594742377337836
# Running iteration 13/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0538                 5.96742  -    3.8   +    4.8       False
# background_yield_0.0538              408.91  -     20   +     21       False
# frac_Mbc_bkg1_0.0538              -0.168679  -  0.038   +  0.042       False
# frac_deltaE_bkg1_0.0538            0.175592  -   0.15   +   0.15       False
# True
# Iteration 13 - Signal Yield: 5.967419847598511 ± 4.288142036765526
# Running iteration 14/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3822                 7.53223  -    4.1   +      5       False
# background_yield_0.3822              407.31  -     20   +     21       False
# frac_Mbc_bkg1_0.3822              -0.175971  -  0.038   +  0.042       False
# frac_deltaE_bkg1_0.3822            0.184005  -   0.15   +   0.15       False
# True
# Iteration 14 - Signal Yield: 7.532228520244253 ± 4.571889248955519
# Running iteration 15/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4667                 8.31829  -    4.1   +    4.9       False
# background_yield_0.4667             406.728  -     20   +     21       False
# frac_Mbc_bkg1_0.4667              -0.181711  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.4667            0.190527  -   0.15   +   0.15       False
# True
# Iteration 15 - Signal Yield: 8.318289758381374 ± 4.521010704992936
# Running iteration 16/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3723                 8.50957  -      4   +    4.8       False
# background_yield_0.3723              406.49  -     20   +     21       False
# frac_Mbc_bkg1_0.3723              -0.184979  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.3723            0.171293  -   0.15   +   0.15       False
# True
# Iteration 16 - Signal Yield: 8.509565002558066 ± 4.404641632825247
# Running iteration 17/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1919                 8.24676  -    4.1   +    5.1       False
# background_yield_0.1919             406.724  -     20   +     21       False
# frac_Mbc_bkg1_0.1919              -0.179593  -  0.038   +  0.042       False
# frac_deltaE_bkg1_0.1919            0.193336  -   0.15   +   0.15       False
# True
# Iteration 17 - Signal Yield: 8.2467572004281 ± 4.636417003651472
# Running iteration 18/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6034                 4.82151  -    3.6   +    4.3       False
# background_yield_0.6034                 410  -     20   +     21       False
# frac_Mbc_bkg1_0.6034              -0.162722  -  0.038   +  0.042       False
# frac_deltaE_bkg1_0.6034            0.182945  -   0.15   +   0.15       False
# True
# Iteration 18 - Signal Yield: 4.821508882604281 ± 3.957411407210082
# Running iteration 19/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2931                 5.69147  -    3.8   +    4.7       False
# background_yield_0.2931             409.248  -     20   +     21       False
# frac_Mbc_bkg1_0.2931              -0.169011  -  0.038   +  0.042       False
# frac_deltaE_bkg1_0.2931            0.201372  -   0.15   +   0.15       False
# True
# Iteration 19 - Signal Yield: 5.6914732312044265 ± 4.2339708737283015
# Running iteration 20/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3879                 8.14281  -      4   +    4.9       False
# background_yield_0.3879             406.569  -     20   +     21       False
# frac_Mbc_bkg1_0.3879              -0.179389  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.3879            0.194079  -   0.15   +   0.15       False
# True
# Iteration 20 - Signal Yield: 8.142810151048847 ± 4.4810310958587465
# Running iteration 21/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4696                 7.99218  -    4.1   +    4.9       False
# background_yield_0.4696             407.064  -     20   +     21       False
# frac_Mbc_bkg1_0.4696              -0.177328  -  0.037   +  0.042       False
# frac_deltaE_bkg1_0.4696            0.184881  -   0.15   +   0.15       False
# True
# Iteration 21 - Signal Yield: 7.992178136574515 ± 4.523072626466439
# Running iteration 22/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8231                 9.36323  -    4.2   +    4.9       False
# background_yield_0.8231             405.582  -     20   +     21       False
# frac_Mbc_bkg1_0.8231              -0.185899  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.8231            0.181615  -   0.15   +   0.15       False
# True
# Iteration 22 - Signal Yield: 9.363230918800722 ± 4.540632985117176
# Running iteration 23/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9051                 6.30258  -    3.8   +    4.7       False
# background_yield_0.9051             408.459  -     20   +     21       False
# frac_Mbc_bkg1_0.9051               -0.17226  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.9051            0.191435  -   0.15   +   0.15       False
# True
# Iteration 23 - Signal Yield: 6.302584509957846 ± 4.209743876020324
# Running iteration 24/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5171                 6.81095  -    3.9   +    4.8       False
# background_yield_0.5171             408.107  -     20   +     21       False
# frac_Mbc_bkg1_0.5171              -0.170485  -  0.038   +  0.041       False
# frac_deltaE_bkg1_0.5171            0.186547  -   0.15   +   0.15       False
# True
# Iteration 24 - Signal Yield: 6.810950392468322 ± 4.352377765638458
# Running iteration 25/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0604                 7.00103  -      4   +    4.7       False
# background_yield_0.0604             408.037  -     20   +     21       False
# frac_Mbc_bkg1_0.0604              -0.172985  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.0604             0.17821  -   0.15   +   0.15       False
# True
# Iteration 25 - Signal Yield: 7.001026275867596 ± 4.321621839508025
# Running iteration 26/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6813                 6.68595  -    3.9   +    4.5       False
# background_yield_0.6813             408.587  -     20   +     21       False
# frac_Mbc_bkg1_0.6813              -0.173616  -  0.036   +  0.042       False
# frac_deltaE_bkg1_0.6813            0.210287  -   0.15   +   0.15       False
# True
# Iteration 26 - Signal Yield: 6.685954037749035 ± 4.214763423844769
# Running iteration 27/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6942                 9.59745  -    4.2   +      5       False
# background_yield_0.6942             405.313  -     20   +     21       False
# frac_Mbc_bkg1_0.6942              -0.186169  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.6942            0.184138  -   0.15   +   0.15       False
# True
# Iteration 27 - Signal Yield: 9.597453882952577 ± 4.5935852852316685
# Running iteration 28/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7431                 7.52624  -    3.9   +    4.9       False
# background_yield_0.7431             407.416  -     20   +     21       False
# frac_Mbc_bkg1_0.7431               -0.17509  -  0.038   +  0.041       False
# frac_deltaE_bkg1_0.7431            0.181755  -   0.15   +   0.15       False
# True
# Iteration 28 - Signal Yield: 7.526242874138748 ± 4.40749064288553
# Running iteration 29/300...
# 5
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.329                 4.94228  -    3.7   +    4.5       False
# background_yield_0.329             410.108  -     20   +     21       False
# frac_Mbc_bkg1_0.329              -0.160306  -  0.038   +  0.041       False
# frac_deltaE_bkg1_0.329            0.202695  -   0.15   +   0.15       False
# True
# Iteration 29 - Signal Yield: 4.9422785783898435 ± 4.079034564977034
# Running iteration 30/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8253                 8.30069  -    4.2   +    5.2       False
# background_yield_0.8253             406.879  -     20   +     21       False
# frac_Mbc_bkg1_0.8253              -0.180934  -  0.038   +  0.041       False
# frac_deltaE_bkg1_0.8253            0.196888  -   0.15   +   0.15       False
# True
# Iteration 30 - Signal Yield: 8.300695033683565 ± 4.681192522655209
# Running iteration 31/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0451                 8.48012  -    4.1   +      5       False
# background_yield_0.0451             406.415  -     20   +     21       False
# frac_Mbc_bkg1_0.0451              -0.183341  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.0451             0.18507  -   0.15   +   0.15       False
# True
# Iteration 31 - Signal Yield: 8.480118349939954 ± 4.549440972451686
# Running iteration 32/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4772                 6.75924  -    3.9   +    4.8       False
# background_yield_0.4772             408.423  -     20   +     21       False
# frac_Mbc_bkg1_0.4772              -0.172637  -  0.038   +  0.042       False
# frac_deltaE_bkg1_0.4772            0.203005  -   0.15   +   0.15       False
# True
# Iteration 32 - Signal Yield: 6.75924331871767 ± 4.3477744357953005
# Running iteration 33/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1711                 5.43729  -    3.8   +    4.5       False
# background_yield_0.1711             409.671  -     20   +     21       False
# frac_Mbc_bkg1_0.1711              -0.167798  -  0.038   +  0.042       False
# frac_deltaE_bkg1_0.1711            0.193358  -   0.15   +   0.15       False
# True
# Iteration 33 - Signal Yield: 5.437289907851317 ± 4.154252921886894
# Running iteration 34/300...
# 5
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.022                 5.52276  -    3.8   +    4.6       False
# background_yield_0.022             409.658  -     20   +     21       False
# frac_Mbc_bkg1_0.022              -0.163345  -  0.039   +  0.041       False
# frac_deltaE_bkg1_0.022            0.185912  -   0.15   +   0.15       False
# True
# Iteration 34 - Signal Yield: 5.522764208037036 ± 4.230581355920197
# Running iteration 35/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1846                 6.22084  -    3.8   +    4.6       False
# background_yield_0.1846             408.779  -     20   +     21       False
# frac_Mbc_bkg1_0.1846              -0.169607  -  0.038   +  0.041       False
# frac_deltaE_bkg1_0.1846             0.19132  -   0.15   +   0.15       False
# True
# Iteration 35 - Signal Yield: 6.220842884398725 ± 4.218120523511918
# Running iteration 36/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6158                 5.77917  -    3.8   +    4.7       False
# background_yield_0.6158             409.212  -     20   +     21       False
# frac_Mbc_bkg1_0.6158              -0.168295  -  0.038   +  0.042       False
# frac_deltaE_bkg1_0.6158            0.193354  -   0.15   +   0.15       False
# True
# Iteration 36 - Signal Yield: 5.779172229152486 ± 4.275204933439364
# Running iteration 37/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9531                  8.5777  -      4   +      5       False
# background_yield_0.9531             406.341  -     20   +     21       False
# frac_Mbc_bkg1_0.9531              -0.182063  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.9531            0.180063  -   0.15   +   0.15       False
# True
# Iteration 37 - Signal Yield: 8.577700102134376 ± 4.516293155394404
# Running iteration 38/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8096                 9.12035  -    4.3   +    5.2       False
# background_yield_0.8096             405.823  -     20   +     21       False
# frac_Mbc_bkg1_0.8096              -0.184299  -  0.038   +   0.04       False
# frac_deltaE_bkg1_0.8096            0.187198  -   0.15   +   0.15       False
# True
# Iteration 38 - Signal Yield: 9.12035404759914 ± 4.721237520543074
# Running iteration 39/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6937                 8.09622  -      4   +    4.8       False
# background_yield_0.6937             406.902  -     20   +     21       False
# frac_Mbc_bkg1_0.6937              -0.179444  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.6937              0.1782  -   0.15   +   0.15       False
# True
# Iteration 39 - Signal Yield: 8.096215081042553 ± 4.421230083155248
# Running iteration 40/300...
# 5
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.086                 5.54024  -    3.7   +    4.5       False
# background_yield_0.086             409.914  -     21   +     20       False
# frac_Mbc_bkg1_0.086              -0.168625  -  0.038   +  0.041       False
# frac_deltaE_bkg1_0.086            0.184982  -   0.15   +   0.15       False
# True
# Iteration 40 - Signal Yield: 5.540240347829015 ± 4.119541962739159
# Running iteration 41/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3972                 10.1112  -    4.3   +      5       False
# background_yield_0.3972             404.897  -     20   +     21       False
# frac_Mbc_bkg1_0.3972               -0.18874  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.3972            0.190712  -   0.15   +   0.15       False
# True
# Iteration 41 - Signal Yield: 10.111185465102562 ± 4.670331056124172
# Running iteration 42/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6973                 8.93755  -    4.1   +      5       False
# background_yield_0.6973             405.982  -     20   +     21       False
# frac_Mbc_bkg1_0.6973              -0.187488  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.6973            0.176676  -   0.15   +   0.15       False
# True
# Iteration 42 - Signal Yield: 8.93754872827031 ± 4.541100730802377
# Running iteration 43/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1289                 5.91657  -    3.7   +    4.7       False
# background_yield_0.1289             409.495  -     21   +     20       False
# frac_Mbc_bkg1_0.1289              -0.171763  -  0.038   +  0.041       False
# frac_deltaE_bkg1_0.1289             0.18717  -   0.14   +   0.15       False
# True
# Iteration 43 - Signal Yield: 5.916570318752467 ± 4.2064384666869845
# Running iteration 44/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1213                  7.8669  -    3.9   +    4.7       False
# background_yield_0.1213             407.174  -     20   +     21       False
# frac_Mbc_bkg1_0.1213              -0.179267  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.1213            0.184497  -   0.15   +   0.15       False
# True
# Iteration 44 - Signal Yield: 7.866902407983223 ± 4.346382214425033
# Running iteration 45/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6447                 9.56984  -    4.1   +    4.9       False
# background_yield_0.6447              405.46  -     20   +     21       False
# frac_Mbc_bkg1_0.6447               -0.18986  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.6447            0.188568  -   0.15   +   0.15       False
# True
# Iteration 45 - Signal Yield: 9.569838186954572 ± 4.545584283605078
# Running iteration 46/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7398                 10.3611  -    4.3   +      5       False
# background_yield_0.7398             404.635  -     20   +     21       False
# frac_Mbc_bkg1_0.7398              -0.190615  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.7398            0.189849  -   0.15   +   0.15       False
# True
# Iteration 46 - Signal Yield: 10.361100679010319 ± 4.656223528972737
# Running iteration 47/300...
# 5
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.257                 8.97315  -    4.2   +      5       False
# background_yield_0.257             405.878  -     20   +     21       False
# frac_Mbc_bkg1_0.257              -0.182316  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.257            0.187735  -   0.15   +   0.15       False
# True
# Iteration 47 - Signal Yield: 8.97314790051584 ± 4.636420788315096
# Running iteration 48/300...
# 5
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.883                 6.65509  -    3.8   +    4.7       False
# background_yield_0.883             408.433  -     20   +     21       False
# frac_Mbc_bkg1_0.883              -0.172023  -  0.037   +  0.042       False
# frac_deltaE_bkg1_0.883            0.201843  -   0.15   +   0.15       False
# True
# Iteration 48 - Signal Yield: 6.655094188974989 ± 4.282692607382443
# Running iteration 49/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8889                 6.64576  -    4.1   +    4.7       False
# background_yield_0.8889             408.502  -     20   +     21       False
# frac_Mbc_bkg1_0.8889              -0.170727  -  0.038   +  0.042       False
# frac_deltaE_bkg1_0.8889            0.196301  -   0.15   +   0.15       False
# True
# Iteration 49 - Signal Yield: 6.645758643573035 ± 4.408983281866492
# Running iteration 50/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2115                 8.41899  -    4.1   +    4.9       False
# background_yield_0.2115             406.529  -     20   +     21       False
# frac_Mbc_bkg1_0.2115              -0.178124  -  0.038   +  0.041       False
# frac_deltaE_bkg1_0.2115            0.177421  -   0.15   +   0.15       False
# True
# Iteration 50 - Signal Yield: 8.41898596033013 ± 4.5362750034658275
# Running iteration 51/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8471                 9.18881  -    4.2   +      5       False
# background_yield_0.8471             405.732  -     20   +     21       False
# frac_Mbc_bkg1_0.8471              -0.182234  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.8471            0.180567  -   0.15   +   0.15       False
# True
# Iteration 51 - Signal Yield: 9.188812771112572 ± 4.6335690295563765
# Running iteration 52/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4184                 6.99367  -    3.9   +    4.7       False
# background_yield_0.4184             408.019  -     20   +     21       False
# frac_Mbc_bkg1_0.4184               -0.17955  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.4184            0.190433  -   0.15   +   0.15       False
# True
# Iteration 52 - Signal Yield: 6.99366464319681 ± 4.315086988717192
# Running iteration 53/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4919                 9.44404  -    4.2   +    5.1       False
# background_yield_0.4919             405.506  -     20   +     21       False
# frac_Mbc_bkg1_0.4919              -0.185407  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.4919            0.180043  -   0.15   +   0.15       False
# True
# Iteration 53 - Signal Yield: 9.444036682364658 ± 4.636676565854999
# Running iteration 54/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8351                 7.70396  -      4   +    4.8       False
# background_yield_0.8351             407.324  -     20   +     21       False
# frac_Mbc_bkg1_0.8351              -0.180608  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.8351            0.184359  -   0.15   +   0.15       False
# True
# Iteration 54 - Signal Yield: 7.703962020865983 ± 4.377681077889248
# Running iteration 55/300...
# 5
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.419                 7.19629  -      4   +    4.9       False
# background_yield_0.419             407.815  -     20   +     21       False
# frac_Mbc_bkg1_0.419              -0.174931  -  0.038   +  0.041       False
# frac_deltaE_bkg1_0.419            0.202006  -   0.15   +   0.15       False
# True
# Iteration 55 - Signal Yield: 7.196286192542398 ± 4.443367758277898
# Running iteration 56/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4379                 7.38294  -    3.8   +    4.9       False
# background_yield_0.4379             407.387  -     20   +     21       False
# frac_Mbc_bkg1_0.4379              -0.176257  -  0.039   +   0.04       False
# frac_deltaE_bkg1_0.4379            0.192142  -   0.15   +   0.15       False
# True
# Iteration 56 - Signal Yield: 7.382936765267211 ± 4.374996069815709
# Running iteration 57/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4979                 7.62241  -    4.1   +      5       False
# background_yield_0.4979             407.214  -     20   +     21       False
# frac_Mbc_bkg1_0.4979              -0.175382  -  0.038   +  0.042       False
# frac_deltaE_bkg1_0.4979            0.184521  -   0.15   +   0.15       False
# True
# Iteration 57 - Signal Yield: 7.622413588583601 ± 4.566279124090528
# Running iteration 58/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3621                 5.51088  -    3.7   +    4.5       False
# background_yield_0.3621             409.491  -     20   +     21       False
# frac_Mbc_bkg1_0.3621              -0.168877  -  0.038   +  0.041       False
# frac_deltaE_bkg1_0.3621            0.181194  -   0.15   +   0.15       False
# True
# Iteration 58 - Signal Yield: 5.51087891811911 ± 4.0759222233529115
# Running iteration 59/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7958                  6.6944  -    3.7   +    4.9       False
# background_yield_0.7958             408.029  -     20   +     21       False
# frac_Mbc_bkg1_0.7958              -0.174627  -  0.039   +   0.04       False
# frac_deltaE_bkg1_0.7958            0.199928  -   0.15   +   0.15       False
# True
# Iteration 59 - Signal Yield: 6.694401398745785 ± 4.282587915796369
# Running iteration 60/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7087                 5.69798  -    3.8   +    4.6       False
# background_yield_0.7087             409.503  -     20   +     21       False
# frac_Mbc_bkg1_0.7087              -0.168824  -  0.038   +  0.042       False
# frac_deltaE_bkg1_0.7087            0.203467  -   0.15   +   0.15       False
# True
# Iteration 60 - Signal Yield: 5.697981072460363 ± 4.237577473964136
# Running iteration 61/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9329                 7.95311  -      4   +    4.8       False
# background_yield_0.9329             407.049  -     20   +     21       False
# frac_Mbc_bkg1_0.9329              -0.179313  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.9329             0.18674  -   0.15   +   0.15       False
# True
# Iteration 61 - Signal Yield: 7.953109681157028 ± 4.410783181862495
# Running iteration 62/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4593                 7.98978  -    4.1   +    4.8       False
# background_yield_0.4593             407.045  -     20   +     21       False
# frac_Mbc_bkg1_0.4593              -0.178948  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.4593            0.181528  -   0.15   +   0.15       False
# True
# Iteration 62 - Signal Yield: 7.989781749414643 ± 4.444505178984231
# Running iteration 63/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7712                 9.94249  -    4.3   +      5       False
# background_yield_0.7712               405.1  -     20   +     21       False
# frac_Mbc_bkg1_0.7712              -0.187698  -  0.038   +   0.04       False
# frac_deltaE_bkg1_0.7712            0.189151  -   0.15   +   0.15       False
# True
# Iteration 63 - Signal Yield: 9.94248997083511 ± 4.666880447998714
# Running iteration 64/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8397                  8.9526  -    4.2   +      5       False
# background_yield_0.8397             406.073  -     20   +     21       False
# frac_Mbc_bkg1_0.8397              -0.182431  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.8397            0.183217  -   0.15   +   0.15       False
# True
# Iteration 64 - Signal Yield: 8.952603045284318 ± 4.583198321354773
# Running iteration 65/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4975                 6.39783  -    3.9   +    4.6       False
# background_yield_0.4975             409.007  -     21   +     21       False
# frac_Mbc_bkg1_0.4975              -0.173134  -  0.037   +  0.042       False
# frac_deltaE_bkg1_0.4975            0.188223  -   0.15   +   0.15       False
# True
# Iteration 65 - Signal Yield: 6.397834311474727 ± 4.255306607754326
# Running iteration 66/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5179                 7.46969  -      4   +    4.8       False
# background_yield_0.5179             407.526  -     20   +     21       False
# frac_Mbc_bkg1_0.5179               -0.18001  -  0.038   +  0.041       False
# frac_deltaE_bkg1_0.5179            0.209521  -   0.15   +   0.15       False
# True
# Iteration 66 - Signal Yield: 7.46969303173191 ± 4.379635401986449
# Running iteration 67/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3117                 7.33956  -    4.1   +      5       False
# background_yield_0.3117             407.668  -     20   +     21       False
# frac_Mbc_bkg1_0.3117              -0.172849  -  0.038   +  0.042       False
# frac_deltaE_bkg1_0.3117            0.190927  -   0.15   +   0.15       False
# True
# Iteration 67 - Signal Yield: 7.339561606818619 ± 4.557882399161889
# Running iteration 68/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9407                 8.29311  -    4.2   +    4.9       False
# background_yield_0.9407             406.748  -     20   +     21       False
# frac_Mbc_bkg1_0.9407              -0.178384  -  0.037   +  0.042       False
# frac_deltaE_bkg1_0.9407             0.18013  -   0.15   +   0.15       False
# True
# Iteration 68 - Signal Yield: 8.293108713402637 ± 4.56359915862878
# Running iteration 69/300...
# 5
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.799                 7.02166  -    3.8   +    4.8       False
# background_yield_0.799             408.107  -     20   +     21       False
# frac_Mbc_bkg1_0.799              -0.179008  -  0.038   +  0.041       False
# frac_deltaE_bkg1_0.799            0.173796  -   0.15   +   0.15       False
# True
# Iteration 69 - Signal Yield: 7.021664146119462 ± 4.320456894881339
# Running iteration 70/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3286                 7.70942  -      4   +    4.8       False
# background_yield_0.3286             407.303  -     20   +     21       False
# frac_Mbc_bkg1_0.3286              -0.182306  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.3286            0.190525  -   0.15   +   0.15       False
# True
# Iteration 70 - Signal Yield: 7.709421684315375 ± 4.369137054396713
# Running iteration 71/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6292                 6.38947  -      4   +    4.9       False
# background_yield_0.6292             408.641  -     20   +     21       False
# frac_Mbc_bkg1_0.6292              -0.170533  -  0.038   +  0.042       False
# frac_deltaE_bkg1_0.6292            0.208424  -   0.15   +   0.15       False
# True
# Iteration 71 - Signal Yield: 6.389464692520253 ± 4.419282917420823
# Running iteration 72/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2827                 5.58083  -    3.7   +    4.6       False
# background_yield_0.2827             409.419  -     20   +     21       False
# frac_Mbc_bkg1_0.2827              -0.169006  -  0.038   +  0.041       False
# frac_deltaE_bkg1_0.2827            0.190845  -   0.15   +   0.15       False
# True
# Iteration 72 - Signal Yield: 5.580826608263891 ± 4.15963092479827
# Running iteration 73/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0349                   7.338  -      4   +      5       False
# background_yield_0.0349             407.601  -     20   +     21       False
# frac_Mbc_bkg1_0.0349               -0.17585  -  0.038   +  0.042       False
# frac_deltaE_bkg1_0.0349            0.186449  -   0.15   +   0.15       False
# True
# Iteration 73 - Signal Yield: 7.338002756074655 ± 4.494859092093921
# Running iteration 74/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0006                 7.36581  -    4.2   +      5       False
# background_yield_0.0006             407.623  -     20   +     21       False
# frac_Mbc_bkg1_0.0006              -0.173356  -  0.039   +  0.042       False
# frac_deltaE_bkg1_0.0006            0.193052  -   0.15   +   0.15       False
# True
# Iteration 74 - Signal Yield: 7.365808336673907 ± 4.602469894429057
# Running iteration 75/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7822                 7.19885  -      4   +    4.8       False
# background_yield_0.7822             407.799  -     20   +     21       False
# frac_Mbc_bkg1_0.7822              -0.179181  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.7822            0.194098  -   0.15   +   0.15       False
# True
# Iteration 75 - Signal Yield: 7.1988480651306 ± 4.398334623421366
# Running iteration 76/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7422                  8.0787  -    4.2   +      5       False
# background_yield_0.7422             406.964  -     20   +     21       False
# frac_Mbc_bkg1_0.7422              -0.177603  -  0.037   +  0.042       False
# frac_deltaE_bkg1_0.7422            0.195923  -   0.15   +   0.15       False
# True
# Iteration 76 - Signal Yield: 8.07870285447543 ± 4.60360979549411
# Running iteration 77/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5266                 7.37628  -    4.1   +    4.9       False
# background_yield_0.5266             407.707  -     20   +     21       False
# frac_Mbc_bkg1_0.5266              -0.173796  -  0.037   +  0.042       False
# frac_deltaE_bkg1_0.5266             0.20268  -   0.15   +   0.15       False
# True
# Iteration 77 - Signal Yield: 7.376276566264779 ± 4.4836641839277975
# Running iteration 78/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3849                 6.12098  -    3.8   +    4.6       False
# background_yield_0.3849              408.59  -     20   +     21       False
# frac_Mbc_bkg1_0.3849              -0.172073  -  0.037   +  0.042       False
# frac_deltaE_bkg1_0.3849             0.20263  -   0.15   +   0.15       False
# True
# Iteration 78 - Signal Yield: 6.120978197267713 ± 4.193492784361151
# Running iteration 79/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6425                 8.72226  -    4.1   +    4.9       False
# background_yield_0.6425              406.15  -     20   +     21       False
# frac_Mbc_bkg1_0.6425              -0.183292  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.6425            0.176978  -   0.15   +   0.15       False
# True
# Iteration 79 - Signal Yield: 8.72226209972977 ± 4.513697467798589
# Running iteration 80/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1857                 7.26069  -      4   +    4.8       False
# background_yield_0.1857             407.771  -     20   +     21       False
# frac_Mbc_bkg1_0.1857              -0.177001  -  0.037   +  0.042       False
# frac_deltaE_bkg1_0.1857            0.189064  -   0.15   +   0.15       False
# True
# Iteration 80 - Signal Yield: 7.260685778773591 ± 4.389799481400226
# Running iteration 81/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8269                 7.21088  -    3.8   +    4.8       False
# background_yield_0.8269             407.718  -     20   +     21       False
# frac_Mbc_bkg1_0.8269              -0.175541  -  0.038   +   0.04       False
# frac_deltaE_bkg1_0.8269            0.174336  -   0.15   +   0.15       False
# True
# Iteration 81 - Signal Yield: 7.21087922521143 ± 4.313776998770423
# Running iteration 82/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2729                 7.91728  -    4.1   +    4.9       False
# background_yield_0.2729             407.152  -     20   +     21       False
# frac_Mbc_bkg1_0.2729              -0.178692  -  0.037   +  0.042       False
# frac_deltaE_bkg1_0.2729            0.196365  -   0.15   +   0.15       False
# True
# Iteration 82 - Signal Yield: 7.917278970110574 ± 4.530149280347647
# Running iteration 83/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7682                 10.1005  -    4.4   +    5.2       False
# background_yield_0.7682             404.893  -     20   +     21       False
# frac_Mbc_bkg1_0.7682              -0.186789  -  0.038   +  0.041       False
# frac_deltaE_bkg1_0.7682            0.182736  -   0.15   +   0.15       False
# True
# Iteration 83 - Signal Yield: 10.100538637283856 ± 4.765396748307642
# Running iteration 84/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7354                 8.45066  -    4.1   +    4.9       False
# background_yield_0.7354              406.32  -     20   +     21       False
# frac_Mbc_bkg1_0.7354              -0.183472  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.7354              0.1895  -   0.15   +   0.15       False
# True
# Iteration 84 - Signal Yield: 8.45065609681573 ± 4.460693292844274
# Running iteration 85/300...
# 5
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.729                 6.21096  -    3.6   +    4.5       False
# background_yield_0.729             408.756  -     20   +     21       False
# ...
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8585                 9.02519  -    4.1   +    5.1       False
# background_yield_0.8585             406.089  -     20   +     21       False
# frac_Mbc_bkg1_0.8585              -0.185154  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.8585            0.189021  -   0.15   +   0.15       False
# True
# Iteration 273 - Signal Yield: 9.025193153659831 ± 4.59814405381019
# Running iteration 274/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9249                 5.71108  -    3.9   +    4.5       False
# background_yield_0.9249             409.396  -     20   +     21       False
# frac_Mbc_bkg1_0.9249              -0.169145  -  0.038   +  0.042       False
# frac_deltaE_bkg1_0.9249            0.211554  -   0.15   +   0.15       False
# True
# Iteration 274 - Signal Yield: 5.711078849878021 ± 4.203696399420803
# Running iteration 275/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2245                 9.36749  -    4.2   +    4.9       False
# background_yield_0.2245             405.673  -     20   +     21       False
# frac_Mbc_bkg1_0.2245              -0.183829  -  0.036   +  0.041       False
# frac_deltaE_bkg1_0.2245            0.173537  -   0.15   +   0.15       False
# True
# Iteration 275 - Signal Yield: 9.367485512829502 ± 4.549872229096539
# Running iteration 276/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7441                 11.0442  -    4.5   +    5.1       False
# background_yield_0.7441             403.601  -     20   +     21       False
# frac_Mbc_bkg1_0.7441              -0.192825  -  0.036   +  0.041       False
# frac_deltaE_bkg1_0.7441             0.18829  -   0.15   +   0.15       False
# True
# Iteration 276 - Signal Yield: 11.044225086953722 ± 4.768668547786044
# Running iteration 277/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0165                 8.70729  -    4.1   +    4.9       False
# background_yield_0.0165             406.318  -     20   +     21       False
# frac_Mbc_bkg1_0.0165              -0.180642  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.0165            0.190582  -   0.15   +   0.15       False
# True
# Iteration 277 - Signal Yield: 8.70728918716976 ± 4.5267727481006395
# Running iteration 278/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0385                 7.78693  -      4   +      5       False
# background_yield_0.0385             406.759  -     20   +     21       False
# frac_Mbc_bkg1_0.0385              -0.174238  -  0.039   +   0.04       False
# frac_deltaE_bkg1_0.0385            0.189956  -   0.15   +   0.15       False
# True
# Iteration 278 - Signal Yield: 7.7869343954375045 ± 4.5192447131575255
# Running iteration 279/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4747                 5.22892  -    3.7   +    4.6       False
# background_yield_0.4747             409.745  -     20   +     21       False
# frac_Mbc_bkg1_0.4747              -0.160889  -  0.039   +  0.041       False
# frac_deltaE_bkg1_0.4747            0.187026  -   0.15   +   0.15       False
# True
# Iteration 279 - Signal Yield: 5.2289155853125315 ± 4.131570152163537
# Running iteration 280/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5402                 9.44352  -    4.2   +      5       False
# background_yield_0.5402             405.545  -     20   +     21       False
# frac_Mbc_bkg1_0.5402              -0.185814  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.5402             0.19182  -   0.15   +   0.15       False
# True
# Iteration 280 - Signal Yield: 9.44351932432746 ± 4.584567871198389
# Running iteration 281/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1588                 7.25542  -    3.8   +    4.9       False
# background_yield_0.1588             407.448  -     20   +     21       False
# frac_Mbc_bkg1_0.1588              -0.176917  -  0.039   +   0.04       False
# frac_deltaE_bkg1_0.1588            0.171565  -   0.15   +   0.15       False
# True
# Iteration 281 - Signal Yield: 7.255418795597503 ± 4.354609866655348
# Running iteration 282/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2346                   6.214  -    3.8   +    4.7       False
# background_yield_0.2346             408.786  -     20   +     21       False
# frac_Mbc_bkg1_0.2346              -0.169076  -  0.038   +  0.041       False
# frac_deltaE_bkg1_0.2346            0.189324  -   0.15   +   0.15       False
# True
# Iteration 282 - Signal Yield: 6.214000905124141 ± 4.2584937363264155
# Running iteration 283/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2352                 7.27221  -      4   +    4.8       False
# background_yield_0.2352             407.723  -     20   +     21       False
# frac_Mbc_bkg1_0.2352              -0.172408  -  0.038   +  0.041       False
# frac_deltaE_bkg1_0.2352            0.180216  -   0.15   +   0.15       False
# True
# Iteration 283 - Signal Yield: 7.272211929846714 ± 4.4230477767528535
# Running iteration 284/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7983                 7.27426  -      4   +    4.6       False
# background_yield_0.7983             407.768  -     20   +     21       False
# frac_Mbc_bkg1_0.7983              -0.172846  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.7983            0.171227  -   0.15   +   0.15       False
# True
# Iteration 284 - Signal Yield: 7.274264462186612 ± 4.277490662945213
# Running iteration 285/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1257                 6.96196  -    3.9   +    4.7       False
# background_yield_0.1257             407.828  -     20   +     21       False
# frac_Mbc_bkg1_0.1257              -0.171605  -  0.037   +  0.042       False
# frac_deltaE_bkg1_0.1257            0.187228  -   0.15   +   0.15       False
# True
# Iteration 285 - Signal Yield: 6.961958220655242 ± 4.30665012306752
# Running iteration 286/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2639                 8.86027  -    4.2   +      5       False
# background_yield_0.2639              406.03  -     20   +     21       False
# frac_Mbc_bkg1_0.2639              -0.182383  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.2639            0.189707  -   0.15   +   0.15       False
# True
# Iteration 286 - Signal Yield: 8.860265679918593 ± 4.586154000115924
# Running iteration 287/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9352                 6.20099  -      4   +    4.8       False
# background_yield_0.9352             409.246  -     21   +     20       False
# frac_Mbc_bkg1_0.9352              -0.168029  -  0.038   +  0.042       False
# frac_deltaE_bkg1_0.9352            0.193614  -   0.15   +   0.15       False
# True
# Iteration 287 - Signal Yield: 6.200989350179812 ± 4.377193336691683
# Running iteration 288/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2729                 10.8761  -    4.3   +    5.1       False
# background_yield_0.2729              404.15  -     20   +     21       False
# frac_Mbc_bkg1_0.2729              -0.191239  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.2729            0.176811  -   0.15   +   0.15       False
# True
# Iteration 288 - Signal Yield: 10.876109678583603 ± 4.694505607390548
# Running iteration 289/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6838                  6.1691  -    3.6   +    4.5       False
# background_yield_0.6838             409.211  -     21   +     20       False
# frac_Mbc_bkg1_0.6838              -0.169447  -  0.038   +  0.041       False
# frac_deltaE_bkg1_0.6838            0.164068  -   0.15   +   0.15       False
# True
# Iteration 289 - Signal Yield: 6.169104371613917 ± 4.0523528945488625
# Running iteration 290/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5845                 7.59719  -    4.1   +    4.9       False
# background_yield_0.5845             407.416  -     20   +     21       False
# frac_Mbc_bkg1_0.5845              -0.177385  -  0.038   +  0.041       False
# frac_deltaE_bkg1_0.5845            0.195535  -   0.15   +   0.15       False
# True
# Iteration 290 - Signal Yield: 7.597190676482151 ± 4.478983080402472
# Running iteration 291/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6924                 8.74108  -    4.2   +    5.1       False
# background_yield_0.6924             406.082  -     20   +     21       False
# frac_Mbc_bkg1_0.6924              -0.179768  -  0.038   +  0.041       False
# frac_deltaE_bkg1_0.6924            0.199086  -   0.15   +   0.15       False
# True
# Iteration 291 - Signal Yield: 8.741079435530093 ± 4.643156295010418
# Running iteration 292/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3449                 7.49158  -      4   +    4.8       False
# background_yield_0.3449             407.555  -     20   +     21       False
# frac_Mbc_bkg1_0.3449              -0.177159  -  0.037   +  0.042       False
# frac_deltaE_bkg1_0.3449            0.186153  -   0.15   +   0.15       False
# True
# Iteration 292 - Signal Yield: 7.491575786237453 ± 4.411568747043674
# Running iteration 293/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6741                 6.85816  -      4   +    4.5       False
# background_yield_0.6741             408.115  -     20   +     21       False
# frac_Mbc_bkg1_0.6741              -0.172106  -  0.037   +  0.042       False
# frac_deltaE_bkg1_0.6741            0.194147  -   0.15   +   0.15       False
# True
# Iteration 293 - Signal Yield: 6.858160665421321 ± 4.249871895130343
# Running iteration 294/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1787                 8.08385  -    4.2   +      5       False
# background_yield_0.1787             406.912  -     20   +     21       False
# frac_Mbc_bkg1_0.1787              -0.180397  -  0.038   +  0.041       False
# frac_deltaE_bkg1_0.1787            0.195904  -   0.15   +   0.15       False
# True
# Iteration 294 - Signal Yield: 8.08384504145212 ± 4.6233105912984245
# Running iteration 295/300...
# 5
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.399                 7.97418  -    3.9   +    4.9       False
# background_yield_0.399             406.887  -     20   +     21       False
# frac_Mbc_bkg1_0.399              -0.177579  -  0.038   +   0.04       False
# frac_deltaE_bkg1_0.399            0.178323  -   0.15   +   0.15       False
# True
# Iteration 295 - Signal Yield: 7.974184307627369 ± 4.3678993430479816
# Running iteration 296/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5648                 8.64946  -    4.1   +    4.9       False
# background_yield_0.5648             406.379  -     20   +     21       False
# frac_Mbc_bkg1_0.5648              -0.180338  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.5648            0.188914  -   0.15   +   0.15       False
# True
# Iteration 296 - Signal Yield: 8.649462251662646 ± 4.497199752360298
# Running iteration 297/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2265                 7.44076  -      4   +      5       False
# background_yield_0.2265              407.49  -     20   +     21       False
# frac_Mbc_bkg1_0.2265               -0.17298  -  0.038   +  0.041       False
# frac_deltaE_bkg1_0.2265            0.178018  -   0.15   +   0.15       False
# True
# Iteration 297 - Signal Yield: 7.440764757374959 ± 4.484646896301194
# Running iteration 298/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4551                 6.27719  -    3.6   +    4.8       False
# background_yield_0.4551             408.445  -     20   +     21       False
# frac_Mbc_bkg1_0.4551              -0.168747  -  0.039   +   0.04       False
# frac_deltaE_bkg1_0.4551            0.189501  -   0.15   +   0.15       False
# True
# Iteration 298 - Signal Yield: 6.277190820560016 ± 4.191774143846869
# Running iteration 299/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3442                 10.0087  -    4.4   +      5       False
# background_yield_0.3442             405.212  -     20   +     21       False
# frac_Mbc_bkg1_0.3442              -0.186071  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.3442            0.179798  -   0.15   +   0.15       False
# True
# Iteration 299 - Signal Yield: 10.008743269057375 ± 4.676609821598919
# Running iteration 300/300...
# 5
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1829                  7.8029  -    4.1   +    4.9       False
# background_yield_0.1829             407.286  -     20   +     21       False
# frac_Mbc_bkg1_0.1829              -0.176353  -  0.037   +  0.042       False
# frac_deltaE_bkg1_0.1829            0.187779  -   0.15   +   0.15       False
# True
# Iteration 300 - Signal Yield: 7.80290279729236 ± 4.534188674938161
# Signal yields and errors saved to 'Bppi0_q2reg1_decay_mumu_signal_yields_and_errors_5.csv'

# %% [markdown]
# ## 2

# %%
# Number of iterations
num_iterations = 300

# List to store the signal yields and their errors from each iteration
signal_yields_and_errors = []

for i in range(num_iterations):
    print(f"Running iteration {i + 1}/{num_iterations}...")

    # Process the Monte Carlo data
    mc_mu_signal, mc_mu_only_signal, mc_mu_scf, mc_mu_bkg, mc_mu_signal_weight, mc_mu_only_signal_weight, mc_mu_scf_weight, mc_mu_bkg_weight = process_MC_data_combined(
        file_signal_mu_Bppi0,file_bkg_mu_Bppi0, 'mu', '521', 'pi0', 'mumu', 1, 'rec521', 'weights', 2
    )

    # Fit models for signal, SCF, and background
    Mbc_only_signal_cb_fixed = fit_fixed_without_weight('Mbc', 'mu', 'signal', mc_mu_only_signal["Mbc"], 'cb', 0)
    deltaE_only_signal_cb_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'signal', mc_mu_only_signal["deltaE"],  'cb_gauss', 0)

    Mbc_scf_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'scf', mc_mu_scf["Mbc"], 'argus_gauss', 0)
    deltaE_scf_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'scf', mc_mu_scf["deltaE"], 'poly_gauss', 0)

    Mbc_bkg_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'bkg', mc_mu_bkg["Mbc"], 'argus_gauss', 0)
    deltaE_bkg_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'bkg', mc_mu_bkg["deltaE"], 'poly', 0)

    # Combine signal and background data
    Signal_Mbc = mc_mu_only_signal["Mbc"]
    Signal_deltaE = mc_mu_only_signal["deltaE"]
    Background_Mbc = pd.concat([mc_mu_scf["Mbc"], mc_mu_bkg["Mbc"]])
    Background_deltaE = pd.concat([mc_mu_scf["deltaE"], mc_mu_bkg["deltaE"]])

    Signal_total = pd.concat([Signal_Mbc, Signal_deltaE], axis=1)
    Background_total = pd.concat([Background_Mbc, Background_deltaE], axis=1)

    MC_signal=len(Signal_total)
    MC_bkg=len(Background_total)

    print(MC_signal)
    print(MC_bkg)
    # Fit the extended model and get the result
    Mbc_signal_pdf, deltaE_signal_pdf, Mbc_background_pdf, deltaE_background_pdf, signal_extended, background_extended, total_model, result = fit_extended_model_scf_without_weight(
        Mbc_only_signal_cb_fixed, Mbc_scf_argus_gauss_fixed, deltaE_only_signal_cb_gauss_fixed, deltaE_scf_poly_gauss_fixed,
        Mbc_bkg_argus_gauss_fixed, deltaE_bkg_poly_gauss_fixed,
        pd.concat([Signal_total, Background_total]), 0.5, 0.5, 100, 100
    )
    result.errors(name='errors')
    print(result.params)
    print(result.valid)

    # Retrieve and store the signal yield and its error
    signal_yield = result.params[signal_extended.get_yield()]['value']
    signal_yield_errors = result.params[signal_extended.get_yield()]['errors']
    signal_yield_error = (signal_yield_errors['upper'] - signal_yield_errors['lower']) / 2

    # Store the signal yield and error as a tuple in the list
    signal_yields_and_errors.append((MC_signal,MC_bkg,signal_yield, signal_yield_error))

    print(f"Iteration {i + 1} - Signal Yield: {signal_yield} ± {signal_yield_error}")

# Convert the list to a DataFrame with two columns: 'Signal_Yield' and 'Signal_Yield_Error'
signal_yields_df = pd.DataFrame(signal_yields_and_errors, columns=['MC_signal','MC_bkg','Signal_Yield', 'Signal_Yield_Error'])


# Save the DataFrame to a CSV file
signal_yields_df.to_csv('Bppi0_q2reg1_decay_mumu_signal_yields_and_errors_2.csv', index=False)

print("Signal yields and errors saved to 'Bppi0_q2reg1_decay_mumu_signal_yields_and_errors_2.csv'")
# Out:
# Running iteration 1/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1134                  6.4251  -    3.8   +    4.6       False
# background_yield_0.1134             405.694  -     20   +     21       False
# frac_Mbc_bkg1_0.1134              -0.184666  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.1134            0.189095  -   0.15   +   0.15       False
# True
# Iteration 1 - Signal Yield: 6.425095508475788 ± 4.217166750310863
# Running iteration 2/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0446                 4.75065  -    3.4   +    4.2       False
# background_yield_0.0446             407.123  -     20   +     21       False
# frac_Mbc_bkg1_0.0446               -0.17953  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.0446            0.170063  -   0.15   +   0.15       False
# True
# Iteration 2 - Signal Yield: 4.750648629173042 ± 3.792949175352786
# Running iteration 3/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3177                 7.45666  -    3.8   +    4.6       False
# background_yield_0.3177              404.53  -     20   +     21       False
# frac_Mbc_bkg1_0.3177              -0.190601  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.3177            0.183665  -   0.15   +   0.15       False
# True
# Iteration 3 - Signal Yield: 7.456663800973913 ± 4.2314681674002195
# Running iteration 4/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1067                 7.04025  -    3.8   +    4.6       False
# background_yield_0.1067             404.931  -     20   +     21       False
# frac_Mbc_bkg1_0.1067              -0.187639  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.1067            0.182136  -   0.15   +   0.15       False
# True
# Iteration 4 - Signal Yield: 7.040253117563584 ± 4.177027797459562
# Running iteration 5/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5224                 5.17159  -    3.6   +    4.3       False
# background_yield_0.5224             406.802  -     20   +     21       False
# frac_Mbc_bkg1_0.5224              -0.178223  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.5224            0.188889  -   0.15   +   0.15       False
# True
# Iteration 5 - Signal Yield: 5.171585037558925 ± 3.9586567789680096
# Running iteration 6/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9878                 6.77009  -    3.8   +    4.5       False
# background_yield_0.9878             405.402  -     20   +     21       False
# frac_Mbc_bkg1_0.9878               -0.18692  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.9878            0.184221  -   0.15   +   0.15       False
# True
# Iteration 6 - Signal Yield: 6.7700904325716245 ± 4.144501485531902
# Running iteration 7/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5235                 5.34642  -    3.6   +    4.4       False
# background_yield_0.5235             406.513  -     20   +     21       False
# frac_Mbc_bkg1_0.5235              -0.177832  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.5235            0.188997  -   0.15   +   0.15       False
# True
# Iteration 7 - Signal Yield: 5.346422087375887 ± 3.9967026931332446
# Running iteration 8/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2345                 5.82009  -    3.7   +    4.5       False
# background_yield_0.2345             406.132  -     20   +     21       False
# frac_Mbc_bkg1_0.2345              -0.183074  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.2345            0.188734  -   0.15   +   0.15       False
# True
# Iteration 8 - Signal Yield: 5.820087028521153 ± 4.109761373971509
# Running iteration 9/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1401                 7.18024  -    3.8   +    4.6       False
# background_yield_0.1401             404.806  -     20   +     21       False
# frac_Mbc_bkg1_0.1401              -0.189072  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.1401            0.184585  -   0.15   +   0.15       False
# True
# Iteration 9 - Signal Yield: 7.180236970072484 ± 4.236905497561482
# Running iteration 10/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4054                 4.74014  -    3.4   +    4.2       False
# background_yield_0.4054             407.278  -     20   +     21       False
# frac_Mbc_bkg1_0.4054              -0.179523  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.4054            0.189665  -   0.15   +   0.15       False
# True
# Iteration 10 - Signal Yield: 4.74014187976864 ± 3.805577897240901
# Running iteration 11/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3276                 7.05402  -    3.8   +    4.6       False
# background_yield_0.3276             404.932  -     20   +     21       False
# frac_Mbc_bkg1_0.3276              -0.188443  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.3276            0.184775  -   0.15   +   0.15       False
# True
# Iteration 11 - Signal Yield: 7.0540163050845806 ± 4.2385903573221775
# Running iteration 12/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0887                 5.61128  -    3.6   +    4.5       False
# background_yield_0.0887             406.409  -     20   +     21       False
# frac_Mbc_bkg1_0.0887              -0.179557  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.0887            0.186843  -   0.15   +   0.15       False
# True
# Iteration 12 - Signal Yield: 5.61127672299304 ± 4.060026885390033
# Running iteration 13/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9341                 5.37361  -    3.6   +    4.4       False
# background_yield_0.9341             406.629  -     20   +     21       False
# frac_Mbc_bkg1_0.9341              -0.178981  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.9341            0.176553  -   0.15   +   0.15       False
# True
# Iteration 13 - Signal Yield: 5.373612327024338 ± 3.9872861844354026
# Running iteration 14/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4035                 5.17311  -    3.5   +    4.4       False
# background_yield_0.4035             406.619  -     20   +     21       False
# frac_Mbc_bkg1_0.4035              -0.177535  -  0.038   +   0.04       False
# frac_deltaE_bkg1_0.4035            0.182544  -   0.15   +   0.15       False
# True
# Iteration 14 - Signal Yield: 5.173112773141047 ± 3.973500890155866
# Running iteration 15/300...
# 2
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.474                 5.86853  -    3.7   +    4.5       False
# background_yield_0.474             406.144  -     20   +     21       False
# frac_Mbc_bkg1_0.474               -0.18185  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.474            0.183122  -   0.15   +   0.15       False
# True
# Iteration 15 - Signal Yield: 5.868526284388703 ± 4.105099012516575
# Running iteration 16/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6668                 7.72029  -    3.8   +    4.7       False
# background_yield_0.6668             404.152  -     20   +     21       False
# frac_Mbc_bkg1_0.6668              -0.192026  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.6668            0.182125  -   0.15   +   0.15       False
# True
# Iteration 16 - Signal Yield: 7.720290051725334 ± 4.233594447792173
# Running iteration 17/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4506                 5.71503  -    3.7   +    4.5       False
# background_yield_0.4506             406.337  -     20   +     21       False
# frac_Mbc_bkg1_0.4506                -0.1797  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.4506            0.181926  -   0.15   +   0.15       False
# True
# Iteration 17 - Signal Yield: 5.715031583874961 ± 4.119207815440111
# Running iteration 18/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1397                 5.43186  -    3.6   +    4.4       False
# background_yield_0.1397             406.411  -     20   +     21       False
# frac_Mbc_bkg1_0.1397              -0.178021  -  0.038   +   0.04       False
# frac_deltaE_bkg1_0.1397            0.181337  -   0.15   +   0.15       False
# True
# Iteration 18 - Signal Yield: 5.431863957594055 ± 4.003961299760684
# Running iteration 19/300...
# 2
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.181                 5.12284  -    3.5   +    4.3       False
# background_yield_0.181             406.775  -     20   +     21       False
# frac_Mbc_bkg1_0.181              -0.181856  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.181            0.194621  -   0.15   +   0.15       False
# True
# Iteration 19 - Signal Yield: 5.1228362406073895 ± 3.918613737337868
# Running iteration 20/300...
# 2
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.835                 6.51742  -    3.6   +    4.4       False
# background_yield_0.835             405.713  -     20   +     21       False
# frac_Mbc_bkg1_0.835              -0.185455  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.835             0.18004  -   0.15   +   0.15       False
# True
# Iteration 20 - Signal Yield: 6.517419930300436 ± 4.027841330776511
# Running iteration 21/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7985                 5.82559  -    3.7   +    4.5       False
# background_yield_0.7985              406.53  -     20   +     20       False
# frac_Mbc_bkg1_0.7985              -0.180856  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.7985             0.18563  -   0.15   +   0.15       False
# True
# Iteration 21 - Signal Yield: 5.825589746932944 ± 4.09725044182465
# Running iteration 22/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4542                 8.10311  -    3.9   +    4.6       False
# background_yield_0.4542             404.079  -     20   +     21       False
# frac_Mbc_bkg1_0.4542              -0.192913  -  0.036   +  0.039       False
# frac_deltaE_bkg1_0.4542             0.17811  -   0.15   +   0.15       False
# True
# Iteration 22 - Signal Yield: 8.103111327821429 ± 4.211901136671678
# Running iteration 23/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2078                 5.05607  -    3.5   +    4.4       False
# background_yield_0.2078             406.736  -     20   +     21       False
# frac_Mbc_bkg1_0.2078              -0.178674  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.2078            0.190379  -   0.15   +   0.15       False
# True
# Iteration 23 - Signal Yield: 5.056067360863808 ± 3.9468660106291695
# Running iteration 24/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9438                 4.86625  -    3.5   +    4.3       False
# background_yield_0.9438             407.072  -     20   +     21       False
# frac_Mbc_bkg1_0.9438              -0.176377  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.9438            0.189677  -   0.15   +   0.15       False
# True
# Iteration 24 - Signal Yield: 4.866248506251024 ± 3.881839496902897
# Running iteration 25/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2594                 4.93449  -    3.4   +    4.3       False
# background_yield_0.2594             407.314  -     20   +     20       False
# frac_Mbc_bkg1_0.2594               -0.17862  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.2594              0.1772  -   0.15   +   0.15       False
# True
# Iteration 25 - Signal Yield: 4.934490422350646 ± 3.8890361467773293
# Running iteration 26/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6188                 4.80893  -    3.5   +    4.2       False
# background_yield_0.6188             407.111  -     20   +     21       False
# frac_Mbc_bkg1_0.6188              -0.178345  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.6188            0.198403  -   0.15   +   0.15       False
# True
# Iteration 26 - Signal Yield: 4.808924743946174 ± 3.8450087443983776
# Running iteration 27/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0133                 6.62777  -    3.8   +    4.6       False
# background_yield_0.0133             405.364  -     20   +     21       False
# frac_Mbc_bkg1_0.0133              -0.186549  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.0133            0.189973  -   0.15   +   0.15       False
# True
# Iteration 27 - Signal Yield: 6.627769545630838 ± 4.172759626257724
# Running iteration 28/300...
# 2
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.432                 6.44476  -    3.6   +    4.4       False
# background_yield_0.432              405.49  -     20   +     21       False
# frac_Mbc_bkg1_0.432               -0.18508  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.432            0.175945  -   0.15   +   0.15       False
# True
# Iteration 28 - Signal Yield: 6.444758318030636 ± 4.009942683926816
# Running iteration 29/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4428                 4.80764  -    3.5   +    4.3       False
# background_yield_0.4428             407.105  -     20   +     21       False
# frac_Mbc_bkg1_0.4428              -0.175473  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.4428            0.191547  -   0.15   +   0.15       False
# True
# Iteration 29 - Signal Yield: 4.8076444068374755 ± 3.8770597835895186
# Running iteration 30/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3323                 6.12356  -    3.8   +    4.6       False
# background_yield_0.3323             405.863  -     20   +     21       False
# frac_Mbc_bkg1_0.3323              -0.182943  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.3323            0.189732  -   0.15   +   0.15       False
# True
# Iteration 30 - Signal Yield: 6.1235562855698245 ± 4.176040489990232
# Running iteration 31/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6951                 6.04834  -    3.7   +    4.6       False
# background_yield_0.6951             405.806  -     20   +     21       False
# frac_Mbc_bkg1_0.6951              -0.183052  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.6951            0.187582  -   0.15   +   0.15       False
# True
# Iteration 31 - Signal Yield: 6.048342005451045 ± 4.144023877932947
# Running iteration 32/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8714                 6.18657  -    3.7   +    4.5       False
# background_yield_0.8714             405.803  -     20   +     21       False
# frac_Mbc_bkg1_0.8714              -0.185841  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.8714            0.187651  -   0.15   +   0.15       False
# True
# Iteration 32 - Signal Yield: 6.186570638440295 ± 4.059746303952836
# Running iteration 33/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6107                  5.0809  -    3.5   +    4.3       False
# background_yield_0.6107             406.732  -     20   +     21       False
# frac_Mbc_bkg1_0.6107              -0.178045  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.6107            0.180998  -   0.15   +   0.15       False
# True
# Iteration 33 - Signal Yield: 5.080904397587067 ± 3.929159711911617
# Running iteration 34/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4266                 5.19712  -    3.6   +    4.4       False
# background_yield_0.4266             407.156  -     20   +     20       False
# frac_Mbc_bkg1_0.4266              -0.176379  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.4266            0.182543  -   0.15   +   0.15       False
# True
# Iteration 34 - Signal Yield: 5.1971176544787845 ± 3.9887157430851685
# Running iteration 35/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4282                 6.08175  -    3.6   +    4.5       False
# background_yield_0.4282             405.745  -     20   +     21       False
# frac_Mbc_bkg1_0.4282              -0.181944  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.4282            0.188384  -   0.15   +   0.15       False
# True
# Iteration 35 - Signal Yield: 6.081749291511667 ± 4.046145739983265
# Running iteration 36/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1197                 5.46488  -    3.6   +    4.5       False
# background_yield_0.1197              407.19  -     21   +     20       False
# frac_Mbc_bkg1_0.1197              -0.180686  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.1197            0.192096  -   0.15   +   0.15       False
# True
# Iteration 36 - Signal Yield: 5.4648754247001925 ± 4.053449024661157
# Running iteration 37/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5499                 6.47199  -    3.7   +    4.5       False
# background_yield_0.5499             405.494  -     20   +     21       False
# frac_Mbc_bkg1_0.5499              -0.185871  -  0.036   +  0.041       False
# frac_deltaE_bkg1_0.5499            0.184219  -   0.15   +   0.15       False
# True
# Iteration 37 - Signal Yield: 6.471986898481196 ± 4.101129181807546
# Running iteration 38/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7758                 6.34271  -    3.8   +    4.6       False
# background_yield_0.7758             405.654  -     20   +     21       False
# frac_Mbc_bkg1_0.7758              -0.184185  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.7758            0.183564  -   0.15   +   0.15       False
# True
# Iteration 38 - Signal Yield: 6.3427109456796655 ± 4.182459708805878
# Running iteration 39/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4455                 7.54347  -    3.9   +    4.6       False
# background_yield_0.4455              404.48  -     20   +     21       False
# frac_Mbc_bkg1_0.4455              -0.190134  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.4455            0.179673  -   0.15   +   0.15       False
# True
# Iteration 39 - Signal Yield: 7.5434699853629565 ± 4.23024341758218
# Running iteration 40/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6687                 5.82838  -    3.7   +    4.5       False
# background_yield_0.6687             406.116  -     20   +     21       False
# frac_Mbc_bkg1_0.6687              -0.184852  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.6687            0.194188  -   0.15   +   0.15       False
# True
# Iteration 40 - Signal Yield: 5.82837770245597 ± 4.0652199750601286
# Running iteration 41/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7919                 7.47071  -    3.8   +    4.6       False
# background_yield_0.7919             404.514  -     20   +     21       False
# frac_Mbc_bkg1_0.7919              -0.190361  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.7919            0.184213  -   0.15   +   0.15       False
# True
# Iteration 41 - Signal Yield: 7.4707084961643675 ± 4.2102701728065455
# Running iteration 42/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3285                 7.11752  -    3.8   +    4.5       False
# background_yield_0.3285             405.009  -     20   +     21       False
# frac_Mbc_bkg1_0.3285              -0.189247  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.3285            0.184731  -   0.15   +   0.15       False
# True
# Iteration 42 - Signal Yield: 7.117522032832622 ± 4.179816145859753
# Running iteration 43/300...
# 2
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.411                 6.24221  -    3.7   +    4.7       False
# background_yield_0.411             406.173  -     21   +     20       False
# frac_Mbc_bkg1_0.411              -0.182355  -  0.038   +   0.04       False
# frac_deltaE_bkg1_0.411              0.1964  -   0.15   +   0.15       False
# True
# Iteration 43 - Signal Yield: 6.24221362888221 ± 4.204709282396279
# Running iteration 44/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0971                 6.61105  -    3.7   +    4.5       False
# background_yield_0.0971              405.83  -     20   +     20       False
# frac_Mbc_bkg1_0.0971              -0.184363  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.0971            0.181286  -   0.15   +   0.15       False
# True
# Iteration 44 - Signal Yield: 6.611054026970221 ± 4.092411950172719
# Running iteration 45/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8893                 7.21579  -    3.8   +    4.6       False
# background_yield_0.8893             404.841  -     20   +     21       False
# frac_Mbc_bkg1_0.8893              -0.190021  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.8893            0.183716  -   0.15   +   0.15       False
# True
# Iteration 45 - Signal Yield: 7.215789831257656 ± 4.177167065223571
# Running iteration 46/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6585                 7.44795  -    3.9   +    4.6       False
# background_yield_0.6585             404.539  -     20   +     21       False
# frac_Mbc_bkg1_0.6585              -0.189521  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.6585            0.183017  -   0.15   +   0.15       False
# True
# Iteration 46 - Signal Yield: 7.4479455633278935 ± 4.251103429688113
# Running iteration 47/300...
# 2
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.944                 7.09213  -    3.9   +    4.6       False
# background_yield_0.944             404.961  -     20   +     21       False
# frac_Mbc_bkg1_0.944              -0.187279  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.944            0.188755  -   0.15   +   0.15       False
# True
# Iteration 47 - Signal Yield: 7.092126993472502 ± 4.2503634947810145
# Running iteration 48/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5125                 5.02205  -    3.5   +    4.3       False
# background_yield_0.5125             407.023  -     20   +     21       False
# frac_Mbc_bkg1_0.5125              -0.177481  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.5125            0.183122  -   0.15   +   0.15       False
# True
# Iteration 48 - Signal Yield: 5.022048348285254 ± 3.9146435501358914
# Running iteration 49/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1165                 6.16595  -    3.8   +    4.6       False
# background_yield_0.1165             405.828  -     20   +     21       False
# frac_Mbc_bkg1_0.1165              -0.183538  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.1165            0.184718  -   0.15   +   0.15       False
# True
# Iteration 49 - Signal Yield: 6.165946266805824 ± 4.171994958213867
# Running iteration 50/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6012                 7.37955  -    3.8   +    4.6       False
# background_yield_0.6012             404.607  -     20   +     21       False
# frac_Mbc_bkg1_0.6012              -0.189039  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.6012            0.181559  -   0.15   +   0.15       False
# True
# Iteration 50 - Signal Yield: 7.379552235622836 ± 4.242811375693469
# Running iteration 51/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2436                 5.96175  -    3.7   +    4.5       False
# background_yield_0.2436              406.49  -     21   +     20       False
# frac_Mbc_bkg1_0.2436              -0.181273  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.2436            0.179597  -   0.15   +   0.15       False
# True
# Iteration 51 - Signal Yield: 5.961751993734957 ± 4.108700143183824
# Running iteration 52/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0775                  6.3035  -    3.7   +    4.5       False
# background_yield_0.0775             405.881  -     20   +     21       False
# frac_Mbc_bkg1_0.0775              -0.187117  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.0775            0.196161  -   0.15   +   0.15       False
# True
# Iteration 52 - Signal Yield: 6.3035017935968165 ± 4.083213902562574
# Running iteration 53/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8944                   8.122  -    3.9   +    4.6       False
# background_yield_0.8944             404.033  -     20   +     21       False
# frac_Mbc_bkg1_0.8944               -0.19315  -  0.036   +  0.039       False
# frac_deltaE_bkg1_0.8944            0.178849  -   0.15   +   0.15       False
# True
# Iteration 53 - Signal Yield: 8.122001904088108 ± 4.209266905714356
# Running iteration 54/300...
# 2
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.961                  5.8816  -    3.6   +    4.4       False
# background_yield_0.961             406.118  -     20   +     21       False
# frac_Mbc_bkg1_0.961              -0.184644  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.961              0.1855  -   0.15   +   0.15       False
# True
# Iteration 54 - Signal Yield: 5.881598052921764 ± 4.038525193143153
# Running iteration 55/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7378                  4.9762  -    3.5   +    4.4       False
# background_yield_0.7378             407.046  -     20   +     21       False
# frac_Mbc_bkg1_0.7378               -0.17855  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.7378             0.19112  -   0.15   +   0.15       False
# True
# Iteration 55 - Signal Yield: 4.976201886102004 ± 3.921154455847363
# Running iteration 56/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1523                 6.56406  -    3.7   +    4.5       False
# background_yield_0.1523             405.181  -     20   +     21       False
# frac_Mbc_bkg1_0.1523              -0.185256  -  0.037   +  0.039       False
# frac_deltaE_bkg1_0.1523             0.18235  -   0.15   +   0.15       False
# True
# Iteration 56 - Signal Yield: 6.5640630366692525 ± 4.061055801296729
# Running iteration 57/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7808                 5.45597  -    3.6   +    4.5       False
# background_yield_0.7808             406.508  -     20   +     21       False
# frac_Mbc_bkg1_0.7808              -0.179268  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.7808            0.184502  -   0.15   +   0.15       False
# True
# Iteration 57 - Signal Yield: 5.455969045066357 ± 4.04275635945718
# Running iteration 58/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1385                 4.83433  -    3.5   +    4.3       False
# background_yield_0.1385             407.177  -     20   +     21       False
# frac_Mbc_bkg1_0.1385              -0.175961  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.1385             0.17974  -   0.15   +   0.15       False
# True
# Iteration 58 - Signal Yield: 4.834330665794008 ± 3.860154311968263
# Running iteration 59/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7895                   5.768  -    3.6   +    4.5       False
# background_yield_0.7895             406.058  -     20   +     21       False
# frac_Mbc_bkg1_0.7895              -0.183591  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.7895            0.194024  -   0.15   +   0.15       False
# True
# Iteration 59 - Signal Yield: 5.768002063296493 ± 4.064932418737455
# Running iteration 60/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9065                 5.23345  -    3.6   +    4.4       False
# background_yield_0.9065             406.788  -     20   +     21       False
# frac_Mbc_bkg1_0.9065              -0.179337  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.9065            0.194453  -   0.15   +   0.15       False
# True
# Iteration 60 - Signal Yield: 5.233446608807019 ± 3.9783697309022985
# Running iteration 61/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1939                 5.49342  -    3.6   +    4.4       False
# background_yield_0.1939             406.762  -     20   +     21       False
# frac_Mbc_bkg1_0.1939               -0.18232  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.1939            0.189519  -   0.15   +   0.15       False
# True
# Iteration 61 - Signal Yield: 5.493422886238873 ± 3.999887571806097
# Running iteration 62/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9566                 6.34973  -    3.6   +    4.4       False
# background_yield_0.9566             405.667  -     20   +     21       False
# frac_Mbc_bkg1_0.9566              -0.184556  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.9566            0.181313  -   0.15   +   0.15       False
# True
# Iteration 62 - Signal Yield: 6.349734531960525 ± 4.044068339262327
# Running iteration 63/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5482                 6.74213  -    3.7   +    4.6       False
# background_yield_0.5482             405.255  -     20   +     21       False
# frac_Mbc_bkg1_0.5482              -0.186567  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.5482            0.189874  -   0.15   +   0.15       False
# True
# Iteration 63 - Signal Yield: 6.742133955489435 ± 4.140896848141755
# Running iteration 64/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1785                 6.83579  -    3.8   +    4.6       False
# background_yield_0.1785             405.099  -     20   +     21       False
# frac_Mbc_bkg1_0.1785              -0.187253  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.1785            0.184608  -   0.15   +   0.15       False
# True
# Iteration 64 - Signal Yield: 6.835785508221945 ± 4.187907009228969
# Running iteration 65/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5651                 4.80885  -    3.4   +    4.2       False
# background_yield_0.5651             407.838  -     21   +     20       False
# frac_Mbc_bkg1_0.5651              -0.178066  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.5651            0.181851  -   0.15   +   0.15       False
# True
# Iteration 65 - Signal Yield: 4.808849224757022 ± 3.828168647264919
# Running iteration 66/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1172                 5.72311  -    3.6   +    4.5       False
# background_yield_0.1172             406.117  -     20   +     21       False
# frac_Mbc_bkg1_0.1172              -0.183621  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.1172            0.194482  -   0.15   +   0.15       False
# True
# Iteration 66 - Signal Yield: 5.723107848621137 ± 4.058404414354483
# Running iteration 67/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8963                 5.25687  -    3.6   +    4.4       False
# background_yield_0.8963             406.754  -     20   +     21       False
# frac_Mbc_bkg1_0.8963              -0.179283  -  0.036   +  0.041       False
# frac_deltaE_bkg1_0.8963            0.187574  -   0.15   +   0.15       False
# True
# Iteration 67 - Signal Yield: 5.256868753309024 ± 3.989989729464952
# Running iteration 68/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3122                 7.37357  -    3.9   +    4.6       False
# background_yield_0.3122             404.613  -     20   +     21       False
# frac_Mbc_bkg1_0.3122              -0.189111  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.3122            0.183153  -   0.15   +   0.15       False
# True
# Iteration 68 - Signal Yield: 7.373572506017781 ± 4.25497584906371
# Running iteration 69/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4526                 7.23687  -    3.9   +    4.7       False
# background_yield_0.4526             404.749  -     20   +     21       False
# frac_Mbc_bkg1_0.4526              -0.188259  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.4526            0.183046  -   0.15   +   0.15       False
# True
# Iteration 69 - Signal Yield: 7.236871874685151 ± 4.254625376132604
# Running iteration 70/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2825                 5.05607  -    3.5   +    4.4       False
# background_yield_0.2825             406.736  -     20   +     21       False
# frac_Mbc_bkg1_0.2825              -0.178674  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.2825            0.190379  -   0.15   +   0.15       False
# True
# Iteration 70 - Signal Yield: 5.056067360590182 ± 3.9468660106253495
# Running iteration 71/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9929                  5.5713  -    3.7   +    4.5       False
# background_yield_0.9929             406.954  -     21   +     20       False
# frac_Mbc_bkg1_0.9929                -0.1793  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.9929            0.202309  -   0.15   +   0.15       False
# True
# Iteration 71 - Signal Yield: 5.571303143378667 ± 4.092267116096865
# Running iteration 72/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9446                 5.60823  -    3.7   +    4.3       False
# background_yield_0.9446             406.369  -     20   +     21       False
# frac_Mbc_bkg1_0.9446              -0.183193  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.9446            0.194069  -   0.15   +   0.15       False
# True
# Iteration 72 - Signal Yield: 5.6082335589785295 ± 4.007328692650972
# Running iteration 73/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6303                 6.31049  -    3.8   +    4.5       False
# background_yield_0.6303             405.782  -     20   +     21       False
# frac_Mbc_bkg1_0.6303              -0.186219  -  0.035   +  0.042       False
# frac_deltaE_bkg1_0.6303            0.185018  -   0.15   +   0.15       False
# True
# Iteration 73 - Signal Yield: 6.310491463235291 ± 4.137675545066788
# Running iteration 74/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3339                 6.38412  -    3.8   +    4.7       False
# background_yield_0.3339             405.847  -     20   +     20       False
# frac_Mbc_bkg1_0.3339              -0.184215  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.3339            0.184509  -   0.15   +   0.15       False
# True
# Iteration 74 - Signal Yield: 6.384119654721586 ± 4.202148186849104
# Running iteration 75/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4194                 6.99262  -    3.8   +    4.6       False
# background_yield_0.4194             404.993  -     20   +     21       False
# frac_Mbc_bkg1_0.4194              -0.188205  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.4194            0.187634  -   0.15   +   0.15       False
# True
# Iteration 75 - Signal Yield: 6.992623618234594 ± 4.243835359235815
# Running iteration 76/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8366                  6.3339  -    3.8   +    4.6       False
# background_yield_0.8366             405.786  -     20   +     21       False
# frac_Mbc_bkg1_0.8366              -0.183999  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.8366            0.183821  -   0.15   +   0.15       False
# True
# Iteration 76 - Signal Yield: 6.333902354432375 ± 4.204756010232681
# Running iteration 77/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4927                  5.2259  -    3.6   +    4.5       False
# background_yield_0.4927             406.767  -     20   +     21       False
# frac_Mbc_bkg1_0.4927              -0.177218  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.4927            0.192865  -   0.15   +   0.15       False
# True
# Iteration 77 - Signal Yield: 5.225903514529966 ± 4.014205004426056
# Running iteration 78/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1738                 6.02669  -    3.6   +    4.4       False
# background_yield_0.1738                 406  -     20   +     21       False
# frac_Mbc_bkg1_0.1738              -0.186268  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.1738            0.193095  -   0.15   +   0.15       False
# True
# Iteration 78 - Signal Yield: 6.026689899472096 ± 4.034159142865178
# Running iteration 79/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8326                 5.85828  -    3.6   +    4.4       False
# background_yield_0.8326             406.144  -     20   +     21       False
# frac_Mbc_bkg1_0.8326              -0.183567  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.8326            0.179778  -   0.15   +   0.15       False
# True
# Iteration 79 - Signal Yield: 5.858278458094289 ± 4.036601361111291
# Running iteration 80/300...
# 2
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.233                 5.89178  -    3.7   +    4.5       False
# background_yield_0.233             406.008  -     20   +     21       False
# frac_Mbc_bkg1_0.233              -0.181786  -  0.038   +   0.04       False
# frac_deltaE_bkg1_0.233             0.18994  -   0.15   +   0.15       False
# True
# Iteration 80 - Signal Yield: 5.891784409875689 ± 4.0912430619919515
# Running iteration 81/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6847                 6.87875  -    3.6   +    4.7       False
# background_yield_0.6847             405.202  -     20   +     21       False
# frac_Mbc_bkg1_0.6847              -0.187684  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.6847            0.180274  -   0.15   +   0.15       False
# True
# Iteration 81 - Signal Yield: 6.878749435834087 ± 4.158543459031387
# Running iteration 82/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9087                 5.00335  -    3.5   +    4.3       False
# background_yield_0.9087             407.038  -     20   +     21       False
# frac_Mbc_bkg1_0.9087              -0.176948  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.9087            0.193195  -   0.15   +   0.15       False
# True
# Iteration 82 - Signal Yield: 5.003345029634881 ± 3.931812568712971
# Running iteration 83/300...
# 2
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.321                 6.95639  -    3.9   +    4.6       False
# background_yield_0.321             405.207  -     20   +     21       False
# frac_Mbc_bkg1_0.321              -0.186844  -  0.036   +  0.041       False
# frac_deltaE_bkg1_0.321            0.180619  -   0.15   +   0.15       False
# True
# Iteration 83 - Signal Yield: 6.956392513579502 ± 4.224222992767242
# Running iteration 84/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4355                  7.0743  -    3.9   +    4.7       False
# background_yield_0.4355             404.909  -     20   +     21       False
# frac_Mbc_bkg1_0.4355               -0.18738  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.4355            0.185309  -   0.15   +   0.15       False
# True
# Iteration 84 - Signal Yield: 7.074300951132078 ± 4.2592624160742965
# Running iteration 85/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3994                 6.51047  -    3.6   +    4.4       False
# ...
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9217                 6.38658  -    3.7   +    4.5       False
# background_yield_0.9217             406.182  -     21   +     20       False
# frac_Mbc_bkg1_0.9217              -0.185222  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.9217            0.189593  -   0.15   +   0.15       False
# True
# Iteration 273 - Signal Yield: 6.386578271036692 ± 4.107306562644627
# Running iteration 274/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4884                 4.81623  -    3.4   +    4.3       False
# background_yield_0.4884             407.428  -     20   +     20       False
# frac_Mbc_bkg1_0.4884              -0.178969  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.4884             0.18822  -   0.15   +   0.15       False
# True
# Iteration 274 - Signal Yield: 4.816234245653186 ± 3.8536933851888318
# Running iteration 275/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6208                 6.76686  -    3.8   +    4.6       False
# background_yield_0.6208             405.225  -     20   +     21       False
# frac_Mbc_bkg1_0.6208              -0.185521  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.6208            0.188349  -   0.15   +   0.15       False
# True
# Iteration 275 - Signal Yield: 6.766862371511839 ± 4.209163586927716
# Running iteration 276/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6332                 8.01061  -    3.9   +    4.6       False
# background_yield_0.6332             404.166  -     20   +     21       False
# frac_Mbc_bkg1_0.6332              -0.192581  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.6332            0.179365  -   0.15   +   0.15       False
# True
# Iteration 276 - Signal Yield: 8.01060678672943 ± 4.218735141836613
# Running iteration 277/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7581                 7.55768  -    3.9   +    4.6       False
# background_yield_0.7581              404.43  -     20   +     21       False
# frac_Mbc_bkg1_0.7581              -0.190075  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.7581            0.181423  -   0.15   +   0.15       False
# True
# Iteration 277 - Signal Yield: 7.557678667191045 ± 4.247364738260281
# Running iteration 278/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4174                    5.89  -    3.6   +    4.4       False
# background_yield_0.4174             406.134  -     20   +     21       False
# frac_Mbc_bkg1_0.4174              -0.180865  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.4174            0.188144  -   0.15   +   0.15       False
# True
# Iteration 278 - Signal Yield: 5.889998185522144 ± 4.039348549027354
# Running iteration 279/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3176                 4.93592  -    3.5   +    4.3       False
# background_yield_0.3176             407.082  -     20   +     21       False
# frac_Mbc_bkg1_0.3176              -0.176922  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.3176            0.180278  -   0.15   +   0.15       False
# True
# Iteration 279 - Signal Yield: 4.9359159836179 ± 3.895220555258587
# Running iteration 280/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2545                 6.76592  -    3.8   +    4.7       False
# background_yield_0.2545             405.215  -     20   +     21       False
# frac_Mbc_bkg1_0.2545              -0.186152  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.2545            0.187036  -   0.15   +   0.15       False
# True
# Iteration 280 - Signal Yield: 6.765920976671467 ± 4.245310104111425
# Running iteration 281/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6609                 5.98346  -    3.7   +    4.5       False
# background_yield_0.6609             406.012  -     20   +     21       False
# frac_Mbc_bkg1_0.6609              -0.182093  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.6609            0.183127  -   0.15   +   0.15       False
# True
# Iteration 281 - Signal Yield: 5.983461323629585 ± 4.120510425788343
# Running iteration 282/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6698                 6.01165  -    3.6   +    4.4       False
# background_yield_0.6698             405.373  -     19   +     21       False
# frac_Mbc_bkg1_0.6698              -0.185404  -  0.036   +  0.041       False
# frac_deltaE_bkg1_0.6698            0.180328  -   0.15   +   0.15       False
# True
# Iteration 282 - Signal Yield: 6.011645768655588 ± 4.038141975819544
# Running iteration 283/300...
# 2
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.613                 5.73525  -    3.7   +    4.5       False
# background_yield_0.613             406.131  -     20   +     21       False
# frac_Mbc_bkg1_0.613              -0.179944  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.613            0.180874  -   0.15   +   0.15       False
# True
# Iteration 283 - Signal Yield: 5.735246119032379 ± 4.067992190003851
# Running iteration 284/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8817                 5.91188  -    3.6   +    4.4       False
# background_yield_0.8817             406.013  -     20   +     21       False
# frac_Mbc_bkg1_0.8817              -0.181658  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.8817            0.172268  -   0.15   +   0.15       False
# True
# Iteration 284 - Signal Yield: 5.911884537713176 ± 4.033911234473722
# Running iteration 285/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4997                 5.10107  -    3.5   +    4.4       False
# background_yield_0.4997             406.676  -     20   +     21       False
# frac_Mbc_bkg1_0.4997              -0.178262  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.4997            0.183172  -   0.15   +   0.15       False
# True
# Iteration 285 - Signal Yield: 5.1010660701605 ± 3.9534752498133843
# Running iteration 286/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3411                 7.34998  -    3.8   +    4.6       False
# background_yield_0.3411             404.636  -     20   +     21       False
# frac_Mbc_bkg1_0.3411              -0.188915  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.3411            0.181872  -   0.15   +   0.15       False
# True
# Iteration 286 - Signal Yield: 7.349980809206846 ± 4.246426563492221
# Running iteration 287/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4525                 5.03712  -    3.5   +    4.4       False
# background_yield_0.4525             407.047  -     20   +     21       False
# frac_Mbc_bkg1_0.4525              -0.178321  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.4525            0.193029  -   0.15   +   0.15       False
# True
# Iteration 287 - Signal Yield: 5.037124810578844 ± 3.9341405099244637
# Running iteration 288/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8329                 7.06701  -    3.8   +    4.6       False
# background_yield_0.8329               404.9  -     20   +     21       False
# frac_Mbc_bkg1_0.8329              -0.187256  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.8329            0.181084  -   0.15   +   0.15       False
# True
# Iteration 288 - Signal Yield: 7.067009889460518 ± 4.184806361097261
# Running iteration 289/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1271                 6.60411  -    3.7   +    4.3       False
# background_yield_0.1271             405.593  -     20   +     21       False
# frac_Mbc_bkg1_0.1271              -0.183573  -  0.037   +  0.039       False
# frac_deltaE_bkg1_0.1271            0.175454  -   0.15   +   0.15       False
# True
# Iteration 289 - Signal Yield: 6.604110996566181 ± 4.021173654635899
# Running iteration 290/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4086                 6.60881  -    3.8   +    4.4       False
# background_yield_0.4086              405.35  -     20   +     21       False
# frac_Mbc_bkg1_0.4086              -0.187158  -  0.036   +  0.041       False
# frac_deltaE_bkg1_0.4086            0.195228  -   0.15   +   0.15       False
# True
# Iteration 290 - Signal Yield: 6.608809543086383 ± 4.099845662779894
# Running iteration 291/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1291                  6.5358  -    3.9   +    4.6       False
# background_yield_0.1291              405.54  -     20   +     21       False
# frac_Mbc_bkg1_0.1291              -0.184036  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.1291            0.186791  -   0.15   +   0.15       False
# True
# Iteration 291 - Signal Yield: 6.53580099753672 ± 4.232471515905375
# Running iteration 292/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5809                 5.62588  -    3.6   +    4.5       False
# background_yield_0.5809             406.132  -     20   +     21       False
# frac_Mbc_bkg1_0.5809              -0.182047  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.5809            0.187432  -   0.15   +   0.15       False
# True
# Iteration 292 - Signal Yield: 5.625880696225669 ± 4.033833783643938
# Running iteration 293/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0687                 6.68452  -    3.7   +    4.5       False
# background_yield_0.0687             405.245  -     20   +     21       False
# frac_Mbc_bkg1_0.0687              -0.187422  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.0687            0.190429  -   0.15   +   0.15       False
# True
# Iteration 293 - Signal Yield: 6.68451932389028 ± 4.087225646318413
# Running iteration 294/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0452                 5.69796  -    3.6   +    4.5       False
# background_yield_0.0452             406.116  -     20   +     21       False
# frac_Mbc_bkg1_0.0452              -0.183053  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.0452            0.194559  -   0.15   +   0.15       False
# True
# Iteration 294 - Signal Yield: 5.697959860256215 ± 4.058335399983325
# Running iteration 295/300...
# 2
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.386                 6.85625  -    3.7   +    4.6       False
# background_yield_0.386             404.532  -     20   +     21       False
# frac_Mbc_bkg1_0.386              -0.187046  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.386            0.180817  -   0.15   +   0.15       False
# True
# Iteration 295 - Signal Yield: 6.8562534716912005 ± 4.13581701903229
# Running iteration 296/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7783                 6.31267  -    3.7   +    4.5       False
# background_yield_0.7783             405.441  -     20   +     21       False
# frac_Mbc_bkg1_0.7783              -0.183766  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.7783            0.180465  -   0.15   +   0.15       False
# True
# Iteration 296 - Signal Yield: 6.312668674432442 ± 4.07124980064944
# Running iteration 297/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1282                 5.75486  -    3.6   +    4.5       False
# background_yield_0.1282             406.051  -     20   +     21       False
# frac_Mbc_bkg1_0.1282              -0.180554  -  0.037   +   0.04       False
# frac_deltaE_bkg1_0.1282            0.178425  -   0.15   +   0.15       False
# True
# Iteration 297 - Signal Yield: 5.754859472186224 ± 4.0415993698916015
# Running iteration 298/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5201                 4.79692  -    3.4   +    4.3       False
# background_yield_0.5201             407.389  -     20   +     21       False
# frac_Mbc_bkg1_0.5201              -0.176102  -  0.038   +   0.04       False
# frac_deltaE_bkg1_0.5201            0.189417  -   0.15   +   0.15       False
# True
# Iteration 298 - Signal Yield: 4.796914569206651 ± 3.863853713489265
# Running iteration 299/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1963                 7.49709  -    3.8   +    4.7       False
# background_yield_0.1963             404.551  -     20   +     21       False
# frac_Mbc_bkg1_0.1963              -0.189998  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.1963            0.180914  -   0.15   +   0.15       False
# True
# Iteration 299 - Signal Yield: 7.49709019442022 ± 4.229089676596457
# Running iteration 300/300...
# 2
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3787                 5.43948  -    3.6   +    4.4       False
# background_yield_0.3787             406.682  -     20   +     21       False
# frac_Mbc_bkg1_0.3787              -0.179717  -  0.037   +  0.041       False
# frac_deltaE_bkg1_0.3787            0.178639  -   0.15   +   0.15       False
# True
# Iteration 300 - Signal Yield: 5.439475730696565 ± 4.014744448912213
# Signal yields and errors saved to 'Bppi0_q2reg1_decay_mumu_signal_yields_and_errors_2.csv'

# %% [markdown]
# ## 0

# %%
# Number of iterations
num_iterations = 300

# List to store the signal yields and their errors from each iteration
signal_yields_and_errors = []

for i in range(num_iterations):
    print(f"Running iteration {i + 1}/{num_iterations}...")

    # Process the Monte Carlo data
    mc_mu_signal, mc_mu_only_signal, mc_mu_scf, mc_mu_bkg, mc_mu_signal_weight, mc_mu_only_signal_weight, mc_mu_scf_weight, mc_mu_bkg_weight = process_MC_data_combined(
        file_signal_mu_Bppi0,file_bkg_mu_Bppi0, 'mu', '521', 'pi0', 'mumu', 1, 'rec521', 'weights', 0
    )

    # Fit models for signal, SCF, and background
    Mbc_only_signal_cb_fixed = fit_fixed_without_weight('Mbc', 'mu', 'signal', mc_mu_only_signal["Mbc"], 'cb', 0)
    deltaE_only_signal_cb_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'signal', mc_mu_only_signal["deltaE"],  'cb_gauss', 0)

    Mbc_scf_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'scf', mc_mu_scf["Mbc"], 'argus_gauss', 0)
    deltaE_scf_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'scf', mc_mu_scf["deltaE"], 'poly_gauss', 0)

    Mbc_bkg_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'bkg', mc_mu_bkg["Mbc"], 'argus_gauss', 0)
    deltaE_bkg_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'bkg', mc_mu_bkg["deltaE"], 'poly', 0)

    # Combine signal and background data
    Signal_Mbc = mc_mu_only_signal["Mbc"]
    Signal_deltaE = mc_mu_only_signal["deltaE"]
    Background_Mbc = pd.concat([mc_mu_scf["Mbc"], mc_mu_bkg["Mbc"]])
    Background_deltaE = pd.concat([mc_mu_scf["deltaE"], mc_mu_bkg["deltaE"]])

    Signal_total = pd.concat([Signal_Mbc, Signal_deltaE], axis=1)
    Background_total = pd.concat([Background_Mbc, Background_deltaE], axis=1)

    MC_signal=len(Signal_total)
    MC_bkg=len(Background_total)

    print(MC_signal)
    print(MC_bkg)
    # Fit the extended model and get the result
    Mbc_signal_pdf, deltaE_signal_pdf, Mbc_background_pdf, deltaE_background_pdf, signal_extended, background_extended, total_model, result = fit_extended_model_scf_without_weight(
        Mbc_only_signal_cb_fixed, Mbc_scf_argus_gauss_fixed, deltaE_only_signal_cb_gauss_fixed, deltaE_scf_poly_gauss_fixed,
        Mbc_bkg_argus_gauss_fixed, deltaE_bkg_poly_gauss_fixed,
        pd.concat([Signal_total, Background_total]), 0.5, 0.5, 100, 100
    )
    result.errors(name='errors')
    print(result.params)
    print(result.valid)

    # Retrieve and store the signal yield and its error
    signal_yield = result.params[signal_extended.get_yield()]['value']
    signal_yield_errors = result.params[signal_extended.get_yield()]['errors']
    signal_yield_error = (signal_yield_errors['upper'] - signal_yield_errors['lower']) / 2

    # Store the signal yield and error as a tuple in the list
    signal_yields_and_errors.append((MC_signal,MC_bkg,signal_yield, signal_yield_error))

    print(f"Iteration {i + 1} - Signal Yield: {signal_yield} ± {signal_yield_error}")

# Convert the list to a DataFrame with two columns: 'Signal_Yield' and 'Signal_Yield_Error'
signal_yields_df = pd.DataFrame(signal_yields_and_errors, columns=['MC_signal','MC_bkg','Signal_Yield', 'Signal_Yield_Error'])


# Save the DataFrame to a CSV file
signal_yields_df.to_csv('Bppi0_q2reg1_decay_mumu_signal_yields_and_errors_0.csv', index=False)

print("Signal yields and errors saved to 'Bppi0_q2reg1_decay_mumu_signal_yields_and_errors_0.csv'")
# Out:
# Running iteration 1/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7348                 5.00204  -    3.4   +    4.3       False
# background_yield_0.7348             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.7348              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.7348            0.184101  -   0.15   +   0.15       False
# True
# Iteration 1 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 2/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0792                 5.00204  -    3.4   +    4.3       False
# background_yield_0.0792             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.0792              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.0792            0.184101  -   0.15   +   0.15       False
# True
# Iteration 2 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 3/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3576                 5.00204  -    3.4   +    4.3       False
# background_yield_0.3576             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.3576              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.3576            0.184101  -   0.15   +   0.15       False
# True
# Iteration 3 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 4/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5972                 5.00204  -    3.4   +    4.3       False
# background_yield_0.5972             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.5972              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.5972            0.184101  -   0.15   +   0.15       False
# True
# Iteration 4 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 5/300...
# 0
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.388                 5.00204  -    3.4   +    4.3       False
# background_yield_0.388             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.388              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.388            0.184101  -   0.15   +   0.15       False
# True
# Iteration 5 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 6/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3971                 5.00204  -    3.4   +    4.3       False
# background_yield_0.3971             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.3971              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.3971            0.184101  -   0.15   +   0.15       False
# True
# Iteration 6 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 7/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3337                 5.00204  -    3.4   +    4.3       False
# background_yield_0.3337             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.3337              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.3337            0.184101  -   0.15   +   0.15       False
# True
# Iteration 7 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 8/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2237                 5.00204  -    3.4   +    4.3       False
# background_yield_0.2237             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.2237              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.2237            0.184101  -   0.15   +   0.15       False
# True
# Iteration 8 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 9/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4167                 5.00204  -    3.4   +    4.3       False
# background_yield_0.4167             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.4167              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.4167            0.184101  -   0.15   +   0.15       False
# True
# Iteration 9 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 10/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2489                 5.00204  -    3.4   +    4.3       False
# background_yield_0.2489             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.2489              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.2489            0.184101  -   0.15   +   0.15       False
# True
# Iteration 10 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 11/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4111                 5.00204  -    3.4   +    4.3       False
# background_yield_0.4111             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.4111              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.4111            0.184101  -   0.15   +   0.15       False
# True
# Iteration 11 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 12/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0614                 5.00204  -    3.4   +    4.3       False
# background_yield_0.0614             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.0614              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.0614            0.184101  -   0.15   +   0.15       False
# True
# Iteration 12 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 13/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6716                 5.00204  -    3.4   +    4.3       False
# background_yield_0.6716             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.6716              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.6716            0.184101  -   0.15   +   0.15       False
# True
# Iteration 13 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 14/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5094                 5.00204  -    3.4   +    4.3       False
# background_yield_0.5094             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.5094              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.5094            0.184101  -   0.15   +   0.15       False
# True
# Iteration 14 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 15/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7986                 5.00204  -    3.4   +    4.3       False
# background_yield_0.7986             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.7986              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.7986            0.184101  -   0.15   +   0.15       False
# True
# Iteration 15 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 16/300...
# 0
# 410
# name                     value  (rounded)               errors    at limit
# ---------------------  ------------------  -------------------  ----------
# signal_yield_0.13                 5.00204  -    3.4   +    4.3       False
# background_yield_0.13             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.13              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.13            0.184101  -   0.15   +   0.15       False
# True
# Iteration 16 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 17/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4437                 5.00204  -    3.4   +    4.3       False
# background_yield_0.4437             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.4437              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.4437            0.184101  -   0.15   +   0.15       False
# True
# Iteration 17 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 18/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6267                 5.00204  -    3.4   +    4.3       False
# background_yield_0.6267             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.6267              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.6267            0.184101  -   0.15   +   0.15       False
# True
# Iteration 18 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 19/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4782                 5.00204  -    3.4   +    4.3       False
# background_yield_0.4782             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.4782              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.4782            0.184101  -   0.15   +   0.15       False
# True
# Iteration 19 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 20/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3226                 5.00204  -    3.4   +    4.3       False
# background_yield_0.3226             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.3226              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.3226            0.184101  -   0.15   +   0.15       False
# True
# Iteration 20 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 21/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3876                 5.00204  -    3.4   +    4.3       False
# background_yield_0.3876             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.3876              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.3876            0.184101  -   0.15   +   0.15       False
# True
# Iteration 21 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 22/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4694                 5.00204  -    3.4   +    4.3       False
# background_yield_0.4694             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.4694              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.4694            0.184101  -   0.15   +   0.15       False
# True
# Iteration 22 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 23/300...
# 0
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.803                 5.00204  -    3.4   +    4.3       False
# background_yield_0.803             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.803              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.803            0.184101  -   0.15   +   0.15       False
# True
# Iteration 23 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 24/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7844                 5.00204  -    3.4   +    4.3       False
# background_yield_0.7844             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.7844              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.7844            0.184101  -   0.15   +   0.15       False
# True
# Iteration 24 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 25/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7635                 5.00204  -    3.4   +    4.3       False
# background_yield_0.7635             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.7635              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.7635            0.184101  -   0.15   +   0.15       False
# True
# Iteration 25 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 26/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7861                 5.00204  -    3.4   +    4.3       False
# background_yield_0.7861             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.7861              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.7861            0.184101  -   0.15   +   0.15       False
# True
# Iteration 26 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 27/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6401                 5.00204  -    3.4   +    4.3       False
# background_yield_0.6401             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.6401              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.6401            0.184101  -   0.15   +   0.15       False
# True
# Iteration 27 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 28/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8043                 5.00204  -    3.4   +    4.3       False
# background_yield_0.8043             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.8043              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.8043            0.184101  -   0.15   +   0.15       False
# True
# Iteration 28 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 29/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0319                 5.00204  -    3.4   +    4.3       False
# background_yield_0.0319             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.0319              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.0319            0.184101  -   0.15   +   0.15       False
# True
# Iteration 29 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 30/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9252                 5.00204  -    3.4   +    4.3       False
# background_yield_0.9252             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.9252              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.9252            0.184101  -   0.15   +   0.15       False
# True
# Iteration 30 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 31/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6419                 5.00204  -    3.4   +    4.3       False
# background_yield_0.6419             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.6419              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.6419            0.184101  -   0.15   +   0.15       False
# True
# Iteration 31 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 32/300...
# 0
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.648                 5.00204  -    3.4   +    4.3       False
# background_yield_0.648             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.648              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.648            0.184101  -   0.15   +   0.15       False
# True
# Iteration 32 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 33/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5221                 5.00204  -    3.4   +    4.3       False
# background_yield_0.5221             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.5221              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.5221            0.184101  -   0.15   +   0.15       False
# True
# Iteration 33 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 34/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1329                 5.00204  -    3.4   +    4.3       False
# background_yield_0.1329             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.1329              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.1329            0.184101  -   0.15   +   0.15       False
# True
# Iteration 34 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 35/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3401                 5.00204  -    3.4   +    4.3       False
# background_yield_0.3401             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.3401              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.3401            0.184101  -   0.15   +   0.15       False
# True
# Iteration 35 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 36/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6449                 5.00204  -    3.4   +    4.3       False
# background_yield_0.6449             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.6449              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.6449            0.184101  -   0.15   +   0.15       False
# True
# Iteration 36 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 37/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3207                 5.00204  -    3.4   +    4.3       False
# background_yield_0.3207             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.3207              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.3207            0.184101  -   0.15   +   0.15       False
# True
# Iteration 37 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 38/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9939                 5.00204  -    3.4   +    4.3       False
# background_yield_0.9939             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.9939              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.9939            0.184101  -   0.15   +   0.15       False
# True
# Iteration 38 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 39/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0678                 5.00204  -    3.4   +    4.3       False
# background_yield_0.0678             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.0678              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.0678            0.184101  -   0.15   +   0.15       False
# True
# Iteration 39 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 40/300...
# 0
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.567                 5.00204  -    3.4   +    4.3       False
# background_yield_0.567             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.567              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.567            0.184101  -   0.15   +   0.15       False
# True
# Iteration 40 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 41/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3896                 5.00204  -    3.4   +    4.3       False
# background_yield_0.3896             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.3896              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.3896            0.184101  -   0.15   +   0.15       False
# True
# Iteration 41 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 42/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3601                 5.00204  -    3.4   +    4.3       False
# background_yield_0.3601             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.3601              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.3601            0.184101  -   0.15   +   0.15       False
# True
# Iteration 42 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 43/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7265                 5.00204  -    3.4   +    4.3       False
# background_yield_0.7265             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.7265              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.7265            0.184101  -   0.15   +   0.15       False
# True
# Iteration 43 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 44/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9181                 5.00204  -    3.4   +    4.3       False
# background_yield_0.9181             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.9181              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.9181            0.184101  -   0.15   +   0.15       False
# True
# Iteration 44 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 45/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1446                 5.00204  -    3.4   +    4.3       False
# background_yield_0.1446             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.1446              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.1446            0.184101  -   0.15   +   0.15       False
# True
# Iteration 45 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 46/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8074                 5.00204  -    3.4   +    4.3       False
# background_yield_0.8074             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.8074              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.8074            0.184101  -   0.15   +   0.15       False
# True
# Iteration 46 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 47/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8273                 5.00204  -    3.4   +    4.3       False
# background_yield_0.8273             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.8273              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.8273            0.184101  -   0.15   +   0.15       False
# True
# Iteration 47 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 48/300...
# 0
# 410
# name                    value  (rounded)               errors    at limit
# --------------------  ------------------  -------------------  ----------
# signal_yield_1.0                 5.00204  -    3.4   +    4.3       False
# background_yield_1.0             405.064  -     20   +     21       False
# frac_Mbc_bkg1_1.0              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_1.0            0.184101  -   0.15   +   0.15       False
# True
# Iteration 48 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 49/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1412                 5.00204  -    3.4   +    4.3       False
# background_yield_0.1412             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.1412              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.1412            0.184101  -   0.15   +   0.15       False
# True
# Iteration 49 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 50/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3962                 5.00204  -    3.4   +    4.3       False
# background_yield_0.3962             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.3962              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.3962            0.184101  -   0.15   +   0.15       False
# True
# Iteration 50 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 51/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6703                 5.00204  -    3.4   +    4.3       False
# background_yield_0.6703             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.6703              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.6703            0.184101  -   0.15   +   0.15       False
# True
# Iteration 51 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 52/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6827                 5.00204  -    3.4   +    4.3       False
# background_yield_0.6827             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.6827              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.6827            0.184101  -   0.15   +   0.15       False
# True
# Iteration 52 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 53/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1715                 5.00204  -    3.4   +    4.3       False
# background_yield_0.1715             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.1715              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.1715            0.184101  -   0.15   +   0.15       False
# True
# Iteration 53 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 54/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0407                 5.00204  -    3.4   +    4.3       False
# background_yield_0.0407             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.0407              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.0407            0.184101  -   0.15   +   0.15       False
# True
# Iteration 54 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 55/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1739                 5.00204  -    3.4   +    4.3       False
# background_yield_0.1739             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.1739              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.1739            0.184101  -   0.15   +   0.15       False
# True
# Iteration 55 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 56/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5349                 5.00204  -    3.4   +    4.3       False
# background_yield_0.5349             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.5349              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.5349            0.184101  -   0.15   +   0.15       False
# True
# Iteration 56 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 57/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3791                 5.00204  -    3.4   +    4.3       False
# background_yield_0.3791             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.3791              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.3791            0.184101  -   0.15   +   0.15       False
# True
# Iteration 57 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 58/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1346                 5.00204  -    3.4   +    4.3       False
# background_yield_0.1346             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.1346              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.1346            0.184101  -   0.15   +   0.15       False
# True
# Iteration 58 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 59/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0609                 5.00204  -    3.4   +    4.3       False
# background_yield_0.0609             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.0609              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.0609            0.184101  -   0.15   +   0.15       False
# True
# Iteration 59 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 60/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1759                 5.00204  -    3.4   +    4.3       False
# background_yield_0.1759             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.1759              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.1759            0.184101  -   0.15   +   0.15       False
# True
# Iteration 60 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 61/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5322                 5.00204  -    3.4   +    4.3       False
# background_yield_0.5322             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.5322              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.5322            0.184101  -   0.15   +   0.15       False
# True
# Iteration 61 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 62/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3358                 5.00204  -    3.4   +    4.3       False
# background_yield_0.3358             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.3358              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.3358            0.184101  -   0.15   +   0.15       False
# True
# Iteration 62 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 63/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7115                 5.00204  -    3.4   +    4.3       False
# background_yield_0.7115             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.7115              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.7115            0.184101  -   0.15   +   0.15       False
# True
# Iteration 63 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 64/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9349                 5.00204  -    3.4   +    4.3       False
# background_yield_0.9349             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.9349              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.9349            0.184101  -   0.15   +   0.15       False
# True
# Iteration 64 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 65/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1538                 5.00204  -    3.4   +    4.3       False
# background_yield_0.1538             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.1538              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.1538            0.184101  -   0.15   +   0.15       False
# True
# Iteration 65 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 66/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2408                 5.00204  -    3.4   +    4.3       False
# background_yield_0.2408             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.2408              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.2408            0.184101  -   0.15   +   0.15       False
# True
# Iteration 66 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 67/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8798                 5.00204  -    3.4   +    4.3       False
# background_yield_0.8798             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.8798              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.8798            0.184101  -   0.15   +   0.15       False
# True
# Iteration 67 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 68/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2253                 5.00204  -    3.4   +    4.3       False
# background_yield_0.2253             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.2253              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.2253            0.184101  -   0.15   +   0.15       False
# True
# Iteration 68 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 69/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1604                 5.00204  -    3.4   +    4.3       False
# background_yield_0.1604             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.1604              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.1604            0.184101  -   0.15   +   0.15       False
# True
# Iteration 69 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 70/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3439                 5.00204  -    3.4   +    4.3       False
# background_yield_0.3439             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.3439              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.3439            0.184101  -   0.15   +   0.15       False
# True
# Iteration 70 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 71/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4179                 5.00204  -    3.4   +    4.3       False
# background_yield_0.4179             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.4179              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.4179            0.184101  -   0.15   +   0.15       False
# True
# Iteration 71 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 72/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1528                 5.00204  -    3.4   +    4.3       False
# background_yield_0.1528             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.1528              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.1528            0.184101  -   0.15   +   0.15       False
# True
# Iteration 72 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 73/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8187                 5.00204  -    3.4   +    4.3       False
# background_yield_0.8187             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.8187              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.8187            0.184101  -   0.15   +   0.15       False
# True
# Iteration 73 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 74/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6876                 5.00204  -    3.4   +    4.3       False
# background_yield_0.6876             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.6876              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.6876            0.184101  -   0.15   +   0.15       False
# True
# Iteration 74 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 75/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3588                 5.00204  -    3.4   +    4.3       False
# background_yield_0.3588             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.3588              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.3588            0.184101  -   0.15   +   0.15       False
# True
# Iteration 75 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 76/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0839                 5.00204  -    3.4   +    4.3       False
# background_yield_0.0839             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.0839              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.0839            0.184101  -   0.15   +   0.15       False
# True
# Iteration 76 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 77/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7158                 5.00204  -    3.4   +    4.3       False
# background_yield_0.7158             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.7158              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.7158            0.184101  -   0.15   +   0.15       False
# True
# Iteration 77 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 78/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2075                 5.00204  -    3.4   +    4.3       False
# background_yield_0.2075             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.2075              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.2075            0.184101  -   0.15   +   0.15       False
# True
# Iteration 78 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 79/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3193                 5.00204  -    3.4   +    4.3       False
# background_yield_0.3193             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.3193              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.3193            0.184101  -   0.15   +   0.15       False
# True
# Iteration 79 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 80/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0587                 5.00204  -    3.4   +    4.3       False
# background_yield_0.0587             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.0587              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.0587            0.184101  -   0.15   +   0.15       False
# True
# Iteration 80 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 81/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5305                 5.00204  -    3.4   +    4.3       False
# background_yield_0.5305             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.5305              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.5305            0.184101  -   0.15   +   0.15       False
# True
# Iteration 81 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 82/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6022                 5.00204  -    3.4   +    4.3       False
# background_yield_0.6022             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.6022              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.6022            0.184101  -   0.15   +   0.15       False
# True
# Iteration 82 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 83/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5883                 5.00204  -    3.4   +    4.3       False
# background_yield_0.5883             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.5883              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.5883            0.184101  -   0.15   +   0.15       False
# True
# Iteration 83 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 84/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9102                 5.00204  -    3.4   +    4.3       False
# background_yield_0.9102             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.9102              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.9102            0.184101  -   0.15   +   0.15       False
# True
# Iteration 84 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 85/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5439                 5.00204  -    3.4   +    4.3       False
# ...
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.368                 5.00204  -    3.4   +    4.3       False
# background_yield_0.368             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.368              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.368            0.184101  -   0.15   +   0.15       False
# True
# Iteration 273 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 274/300...
# 0
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.906                 5.00204  -    3.4   +    4.3       False
# background_yield_0.906             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.906              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.906            0.184101  -   0.15   +   0.15       False
# True
# Iteration 274 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 275/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8626                 5.00204  -    3.4   +    4.3       False
# background_yield_0.8626             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.8626              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.8626            0.184101  -   0.15   +   0.15       False
# True
# Iteration 275 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 276/300...
# 0
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.706                 5.00204  -    3.4   +    4.3       False
# background_yield_0.706             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.706              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.706            0.184101  -   0.15   +   0.15       False
# True
# Iteration 276 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 277/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0306                 5.00204  -    3.4   +    4.3       False
# background_yield_0.0306             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.0306              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.0306            0.184101  -   0.15   +   0.15       False
# True
# Iteration 277 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 278/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2438                 5.00204  -    3.4   +    4.3       False
# background_yield_0.2438             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.2438              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.2438            0.184101  -   0.15   +   0.15       False
# True
# Iteration 278 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 279/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9054                 5.00204  -    3.4   +    4.3       False
# background_yield_0.9054             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.9054              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.9054            0.184101  -   0.15   +   0.15       False
# True
# Iteration 279 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 280/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6157                 5.00204  -    3.4   +    4.3       False
# background_yield_0.6157             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.6157              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.6157            0.184101  -   0.15   +   0.15       False
# True
# Iteration 280 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 281/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2276                 5.00204  -    3.4   +    4.3       False
# background_yield_0.2276             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.2276              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.2276            0.184101  -   0.15   +   0.15       False
# True
# Iteration 281 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 282/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6406                 5.00204  -    3.4   +    4.3       False
# background_yield_0.6406             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.6406              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.6406            0.184101  -   0.15   +   0.15       False
# True
# Iteration 282 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 283/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2561                 5.00204  -    3.4   +    4.3       False
# background_yield_0.2561             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.2561              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.2561            0.184101  -   0.15   +   0.15       False
# True
# Iteration 283 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 284/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1322                 5.00204  -    3.4   +    4.3       False
# background_yield_0.1322             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.1322              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.1322            0.184101  -   0.15   +   0.15       False
# True
# Iteration 284 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 285/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5034                 5.00204  -    3.4   +    4.3       False
# background_yield_0.5034             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.5034              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.5034            0.184101  -   0.15   +   0.15       False
# True
# Iteration 285 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 286/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2391                 5.00204  -    3.4   +    4.3       False
# background_yield_0.2391             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.2391              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.2391            0.184101  -   0.15   +   0.15       False
# True
# Iteration 286 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 287/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9994                 5.00204  -    3.4   +    4.3       False
# background_yield_0.9994             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.9994              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.9994            0.184101  -   0.15   +   0.15       False
# True
# Iteration 287 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 288/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8487                 5.00204  -    3.4   +    4.3       False
# background_yield_0.8487             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.8487              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.8487            0.184101  -   0.15   +   0.15       False
# True
# Iteration 288 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 289/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4266                 5.00204  -    3.4   +    4.3       False
# background_yield_0.4266             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.4266              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.4266            0.184101  -   0.15   +   0.15       False
# True
# Iteration 289 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 290/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2598                 5.00204  -    3.4   +    4.3       False
# background_yield_0.2598             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.2598              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.2598            0.184101  -   0.15   +   0.15       False
# True
# Iteration 290 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 291/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1966                 5.00204  -    3.4   +    4.3       False
# background_yield_0.1966             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.1966              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.1966            0.184101  -   0.15   +   0.15       False
# True
# Iteration 291 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 292/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5546                 5.00204  -    3.4   +    4.3       False
# background_yield_0.5546             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.5546              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.5546            0.184101  -   0.15   +   0.15       False
# True
# Iteration 292 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 293/300...
# 0
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.371                 5.00204  -    3.4   +    4.3       False
# background_yield_0.371             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.371              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.371            0.184101  -   0.15   +   0.15       False
# True
# Iteration 293 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 294/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5143                 5.00204  -    3.4   +    4.3       False
# background_yield_0.5143             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.5143              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.5143            0.184101  -   0.15   +   0.15       False
# True
# Iteration 294 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 295/300...
# 0
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.401                 5.00204  -    3.4   +    4.3       False
# background_yield_0.401             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.401              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.401            0.184101  -   0.15   +   0.15       False
# True
# Iteration 295 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 296/300...
# 0
# 410
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.844                 5.00204  -    3.4   +    4.3       False
# background_yield_0.844             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.844              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.844            0.184101  -   0.15   +   0.15       False
# True
# Iteration 296 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 297/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5453                 5.00204  -    3.4   +    4.3       False
# background_yield_0.5453             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.5453              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.5453            0.184101  -   0.15   +   0.15       False
# True
# Iteration 297 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 298/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8872                 5.00204  -    3.4   +    4.3       False
# background_yield_0.8872             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.8872              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.8872            0.184101  -   0.15   +   0.15       False
# True
# Iteration 298 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 299/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1236                 5.00204  -    3.4   +    4.3       False
# background_yield_0.1236             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.1236              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.1236            0.184101  -   0.15   +   0.15       False
# True
# Iteration 299 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Running iteration 300/300...
# 0
# 410
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0751                 5.00204  -    3.4   +    4.3       False
# background_yield_0.0751             405.064  -     20   +     21       False
# frac_Mbc_bkg1_0.0751              -0.187711  -  0.036   +   0.04       False
# frac_deltaE_bkg1_0.0751            0.184101  -   0.15   +   0.15       False
# True
# Iteration 300 - Signal Yield: 5.002041625859438 ± 3.8200170225045245
# Signal yields and errors saved to 'Bppi0_q2reg1_decay_mumu_signal_yields_and_errors_0.csv'
