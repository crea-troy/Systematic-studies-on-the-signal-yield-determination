# %%
import pandas as pd
import uproot
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import crystalball
from scipy.optimize import curve_fit,Bounds
from scipy.integrate import simps
import zfit_physics as zphysics
import zfit
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.pyplot as plt
import mplhep
import uncertainties 
from uncertainties import ufloat
import tensorflow as tf

plt.style.use('belle2')
#%jsroot on


# %run /afs/desy.de/user/j/jipatel/MT/MC_fit/Files_After_Acceptance/Signal_Background_thesis_final/Function.ipynb
# Out:
# 2024-09-11 20:21:13.835336: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-11 20:21:13.882245: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-11 20:21:13.883160: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-11 20:21:15.534765: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /afs/desy.de/user/j/jipatel/.local/lib/python3.8/site-packages/zfit/__init__.py:63: UserWarning: TensorFlow warnings are by default suppressed by zfit. In order to show them, set the environment variable ZFIT_DISABLE_TF_WARNINGS=0. In order to suppress the TensorFlow warnings AND this warning, set ZFIT_DISABLE_TF_WARNINGS=1.
#   warnings.warn(

# %% [markdown]
# ## 200

# %%
# Number of iterations
num_iterations = 300

# List to store the signal yields and their errors from each iteration
signal_yields_and_errors = []

for i in range(num_iterations):
    print(f"Running iteration {i + 1}/{num_iterations}...")

    # Process the Monte Carlo data
    mc_mu_signal, mc_mu_only_signal, mc_mu_scf, mc_mu_bkg, mc_mu_signal_weight, mc_mu_only_signal_weight, mc_mu_scf_weight, mc_mu_bkg_weight = process_MC_data_combined(
        file_signal_mu_Bppi0,file_bkg_mu_Bppi0, 'mu', '521', 'pi0', 'mumu', 4, 'rec521', 'weights', 200
    )

    # Fit models for signal, SCF, and background
    Mbc_only_signal_cb_fixed = fit_fixed_without_weight('Mbc', 'mu', 'signal', mc_mu_only_signal["Mbc"],  'cb', 0)
    deltaE_only_signal_cb_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'signal', mc_mu_only_signal["deltaE"], 'cb_gauss', 0)

    Mbc_scf_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'scf', mc_mu_scf["Mbc"],  'argus_gauss', 0)
    deltaE_scf_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'scf', mc_mu_scf["deltaE"], 'poly_gauss', 0)

    Mbc_bkg_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'bkg', mc_mu_bkg["Mbc"],  'argus_gauss', 0)
    deltaE_bkg_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'bkg', mc_mu_bkg["deltaE"],  'poly', 0)

    # Combine signal and background data
    Signal_Mbc = mc_mu_only_signal["Mbc"]
    Signal_deltaE = mc_mu_only_signal["deltaE"]
    Background_Mbc = pd.concat([mc_mu_scf["Mbc"], mc_mu_bkg["Mbc"]])
    Background_deltaE = pd.concat([mc_mu_scf["deltaE"], mc_mu_bkg["deltaE"]])

    Signal_total = pd.concat([Signal_Mbc, Signal_deltaE], axis=1)
    Background_total = pd.concat([Background_Mbc, Background_deltaE], axis=1)

    MC_signal=len(Signal_total)
    MC_bkg=len(Background_total)

    print(MC_signal)
    print(MC_bkg)


    # Fit the extended model and get the result
    Mbc_signal_pdf, deltaE_signal_pdf, Mbc_background_pdf, deltaE_background_pdf, signal_extended, background_extended, total_model, result = fit_extended_model_scf_without_weight(
        Mbc_only_signal_cb_fixed, Mbc_scf_argus_gauss_fixed, deltaE_only_signal_cb_gauss_fixed, deltaE_scf_poly_gauss_fixed,
        Mbc_bkg_argus_gauss_fixed, deltaE_bkg_poly_gauss_fixed,
        pd.concat([Signal_total, Background_total]), 0.5, 0.5, 100, 100
    )
    result.errors(name='errors')
    print(result.params)
    print(result.valid)

    # Retrieve and store the signal yield and its error
    signal_yield = result.params[signal_extended.get_yield()]['value']
    signal_yield_errors = result.params[signal_extended.get_yield()]['errors']
    signal_yield_error = (signal_yield_errors['upper'] - signal_yield_errors['lower']) / 2

    # Store the signal yield and error as a tuple in the list
    signal_yields_and_errors.append((MC_signal,MC_bkg,signal_yield, signal_yield_error))

    print(f"Iteration {i + 1} - Signal Yield: {signal_yield} ± {signal_yield_error}")

# Convert the list to a DataFrame with two columns: 'Signal_Yield' and 'Signal_Yield_Error'
signal_yields_df = pd.DataFrame(signal_yields_and_errors, columns=['MC_signal','MC_bkg','Signal_Yield', 'Signal_Yield_Error'])

# Save the DataFrame to a CSV file
signal_yields_df.to_csv('Bppi0_q2reg4_decay_mumu_signal_yields_and_errors_200.csv', index=False)

print("Signal yields and errors saved to 'Bppi0_q2reg4_decay_mumu_signal_yields_and_errors_200.csv'")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_1379551/2984280029.py in <module>
#      45         pd.concat([Signal_total, Background_total]), 0.5, 0.5, 100, 100
#      46     )
# ---> 47     result.errors(name='errors')
#      48     print(result.params)
#      49     print(result.valid)
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     574                 'in a future version' if date is None else ('after %s' % date),
#     575                 instructions)
# --> 576       return func(*args, **kwargs)
#     577
#     578     doc = _add_deprecated_arg_notice_to_docstring(
#
# ~/.local/lib/python3.8/site-packages/zfit/minimizers/fitresult.py in errors(self, params, method, name, cl, sigma, error_name)
#    1382
#    1383             if uncached_params:
# -> 1384                 error_dict, new_result = self._error(
#    1385                     params=uncached_params, method=method, cl=cl
#    1386                 )
#
# ~/.local/lib/python3.8/site-packages/zfit/minimizers/fitresult.py in _error(self, params, method, cl)
#    1409                     f"The following method is not a valid, implemented method: {method}"
#    1410                 )
# -> 1411         return method(result=self, params=params, cl=cl)
#    1412
#    1413     def covariance(
#
# ~/.local/lib/python3.8/site-packages/zfit/minimizers/fitresult.py in _minos_minuit(result, params, cl)
#     157
#     158     try:
# --> 159         minuit_minimizer.minos(*(p.name for p in params), cl=cl)
#     160         # Minuit seems very ustable on this and the call can fail after a few trials
#     161     except RuntimeError as error:
#
# ~/.local/lib/python3.8/site-packages/iminuit/minuit.py in minos(self, cl, ncall, *parameters)
#    1475
#    1476         if not self.valid:
# -> 1477             raise RuntimeError(f"Function minimum is not valid: {repr(self._fmin)}")
#    1478
#    1479         if len(parameters) == 0:
#
# RuntimeError: Function minimum is not valid: <FMin algorithm='Migrad' edm=0.0004035606241402507 edm_goal=0.001 errordef=0.5 fval=-5201.762980773633 has_accurate_covar=False has_covariance=True has_made_posdef_covar=False has_parameters_at_limit=False has_posdef_covar=False has_reached_call_limit=True has_valid_parameters=False hesse_failed=True is_above_max_edm=False is_valid=False nfcn=699 ngrad=0 reduced_chi2=nan time=3.7307504564523697>

# %% [markdown]
# ## 150

# %%
# Number of iterations
num_iterations = 300

# List to store the signal yields and their errors from each iteration
signal_yields_and_errors = []

for i in range(num_iterations):
    print(f"Running iteration {i + 1}/{num_iterations}...")

    # Process the Monte Carlo data
    mc_mu_signal, mc_mu_only_signal, mc_mu_scf, mc_mu_bkg, mc_mu_signal_weight, mc_mu_only_signal_weight, mc_mu_scf_weight, mc_mu_bkg_weight = process_MC_data_combined(
        file_signal_mu_Bppi0,file_bkg_mu_Bppi0, 'mu', '521', 'pi0', 'mumu', 4, 'rec521', 'weights', 150
    )

    # Fit models for signal, SCF, and background
    Mbc_only_signal_cb_fixed = fit_fixed_without_weight('Mbc', 'mu', 'signal', mc_mu_only_signal["Mbc"], 'cb', 0)
    deltaE_only_signal_cb_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'signal', mc_mu_only_signal["deltaE"],  'cb_gauss', 0)

    Mbc_scf_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'scf', mc_mu_scf["Mbc"], 'argus_gauss', 0)
    deltaE_scf_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'scf', mc_mu_scf["deltaE"], 'poly_gauss', 0)

    Mbc_bkg_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'bkg', mc_mu_bkg["Mbc"], 'argus_gauss', 0)
    deltaE_bkg_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'bkg',  mc_mu_bkg["deltaE"],  'poly', 0)

    # Combine signal and background data
    Signal_Mbc = mc_mu_only_signal["Mbc"]
    Signal_deltaE = mc_mu_only_signal["deltaE"]
    Background_Mbc = pd.concat([mc_mu_scf["Mbc"], mc_mu_bkg["Mbc"]])
    Background_deltaE = pd.concat([mc_mu_scf["deltaE"], mc_mu_bkg["deltaE"]])

    Signal_total = pd.concat([Signal_Mbc, Signal_deltaE], axis=1)
    Background_total = pd.concat([Background_Mbc, Background_deltaE], axis=1)

    MC_signal=len(Signal_total)
    MC_bkg=len(Background_total)

    print(MC_signal)
    print(MC_bkg)
    
    # Fit the extended model and get the result
    Mbc_signal_pdf, deltaE_signal_pdf, Mbc_background_pdf, deltaE_background_pdf, signal_extended, background_extended, total_model, result = fit_extended_model_scf_without_weight(
        Mbc_only_signal_cb_fixed, Mbc_scf_argus_gauss_fixed, deltaE_only_signal_cb_gauss_fixed, deltaE_scf_poly_gauss_fixed,
        Mbc_bkg_argus_gauss_fixed, deltaE_bkg_poly_gauss_fixed,
        pd.concat([Signal_total, Background_total]), 0.5, 0.5, 100, 100
    )
    result.errors(name='errors')
    print(result.params)
    print(result.valid)

    # Retrieve and store the signal yield and its error
    signal_yield = result.params[signal_extended.get_yield()]['value']
    signal_yield_errors = result.params[signal_extended.get_yield()]['errors']
    signal_yield_error = (signal_yield_errors['upper'] - signal_yield_errors['lower']) / 2

    # Store the signal yield and error as a tuple in the list
    signal_yields_and_errors.append((MC_signal,MC_bkg,signal_yield, signal_yield_error))

    print(f"Iteration {i + 1} - Signal Yield: {signal_yield} ± {signal_yield_error}")

# Convert the list to a DataFrame with two columns: 'Signal_Yield' and 'Signal_Yield_Error'
signal_yields_df = pd.DataFrame(signal_yields_and_errors, columns=['MC_signal','MC_bkg','Signal_Yield', 'Signal_Yield_Error'])

# Save the DataFrame to a CSV file
signal_yields_df.to_csv('Bppi0_q2reg4_decay_mumu_signal_yields_and_errors_150.csv', index=False)

print("Signal yields and errors saved to 'Bppi0_q2reg4_decay_mumu_signal_yields_and_errors_150.csv'")
# Out:
# Running iteration 1/300...
# 150
# 5454
# /afs/desy.de/user/j/jipatel/.local/lib/python3.8/site-packages/zfit/core/basepdf.py:585: UserWarning: As `copy` is not yet properly implemented, this may fails (for ProductPDF for example?). Thiswill be fixed in the future.
#   warnings.warn(
# /afs/desy.de/user/j/jipatel/.local/lib/python3.8/site-packages/zfit/minimizers/fitresult.py:1340: FutureWarning: 'minuit_minos' will be changed as the default errors method to a custom implementationwith the same functionality. If you want to make sure that 'minuit_minos' will be used in the future, add it explicitly as in `errors(method='minuit_minos')`
#   warnings.warn(
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.629                 305.409  -     32   +     33       False
# background_yield_0.629             5298.25  -     77   +     78       False
# frac_Mbc_bkg1_0.629               0.408618  -  0.017   +  0.016       False
# frac_deltaE_bkg1_0.629            0.445883  -  0.044   +  0.043       False
# True
# Iteration 1 - Signal Yield: 305.4084950485474 ± 32.213223570916945
# Running iteration 2/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3483                  308.18  -     32   +     33       False
# background_yield_0.3483              5296.1  -     78   +     78       False
# frac_Mbc_bkg1_0.3483               0.407669  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.3483            0.447524  -  0.044   +  0.044       False
# True
# Iteration 2 - Signal Yield: 308.18035333467327 ± 32.303159506594405
# Running iteration 3/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9039                 307.018  -     32   +     33       False
# background_yield_0.9039             5296.57  -     77   +     78       False
# frac_Mbc_bkg1_0.9039               0.408255  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.9039            0.445553  -  0.044   +  0.043       False
# True
# Iteration 3 - Signal Yield: 307.0179358944611 ± 32.221634438977944
# Running iteration 4/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4908                 309.255  -     32   +     33       False
# background_yield_0.4908             5292.92  -     75   +     80       False
# frac_Mbc_bkg1_0.4908               0.407068  -  0.016   +  0.017       False
# frac_deltaE_bkg1_0.4908            0.445028  -  0.043   +  0.044       False
# True
# Iteration 4 - Signal Yield: 309.2552266446282 ± 32.204304579218984
# Running iteration 5/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2062                 312.106  -     32   +     32       False
# background_yield_0.2062             5292.21  -     77   +     78       False
# frac_Mbc_bkg1_0.2062                0.40665  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.2062              0.4398  -  0.044   +  0.044       False
# True
# Iteration 5 - Signal Yield: 312.1061259589979 ± 32.20913518289558
# Running iteration 6/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2687                  301.67  -     32   +     33       False
# background_yield_0.2687             5302.16  -     77   +     78       False
# frac_Mbc_bkg1_0.2687               0.409434  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.2687            0.445997  -  0.044   +  0.044       False
# True
# Iteration 6 - Signal Yield: 301.67025432669345 ± 32.29898086225815
# Running iteration 7/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8888                 303.516  -     32   +     32       False
# background_yield_0.8888             5300.87  -     78   +     78       False
# frac_Mbc_bkg1_0.8888               0.408658  -  0.016   +  0.017       False
# frac_deltaE_bkg1_0.8888            0.444835  -  0.044   +  0.044       False
# True
# Iteration 7 - Signal Yield: 303.5159541368022 ± 32.20024400783894
# Running iteration 8/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3088                 310.732  -     32   +     33       False
# background_yield_0.3088             5293.02  -     77   +     78       False
# frac_Mbc_bkg1_0.3088               0.407119  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.3088            0.442116  -  0.044   +  0.044       False
# True
# Iteration 8 - Signal Yield: 310.7318166126557 ± 32.3562198822721
# Running iteration 9/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8618                  283.34  -     32   +     33       False
# background_yield_0.8618             5320.62  -     78   +     78       False
# frac_Mbc_bkg1_0.8618               0.414174  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.8618            0.453817  -  0.044   +  0.043       False
# True
# Iteration 9 - Signal Yield: 283.3399445339929 ± 32.100303686541665
# Running iteration 10/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7044                 301.073  -     31   +     33       False
# background_yield_0.7044             5302.82  -     78   +     78       False
# frac_Mbc_bkg1_0.7044               0.409113  -  0.016   +  0.017       False
# frac_deltaE_bkg1_0.7044             0.44648  -  0.044   +  0.044       False
# True
# Iteration 10 - Signal Yield: 301.0730513725085 ± 32.25621503115343
# Running iteration 11/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9494                 301.366  -     32   +     33       False
# background_yield_0.9494             5302.46  -     77   +     78       False
# frac_Mbc_bkg1_0.9494               0.409517  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.9494            0.442846  -  0.044   +  0.043       False
# True
# Iteration 11 - Signal Yield: 301.3662767709131 ± 32.017165294240456
# Running iteration 12/300...
# 150
# 5454
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.473                 301.552  -     32   +     33       False
# background_yield_0.473             5302.82  -     78   +     78       False
# frac_Mbc_bkg1_0.473               0.408954  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.473            0.442669  -  0.044   +  0.043       False
# True
# Iteration 12 - Signal Yield: 301.55225533691436 ± 32.215968654509894
# Running iteration 13/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1382                  315.51  -     32   +     33       False
# background_yield_0.1382             5288.26  -     77   +     78       False
# frac_Mbc_bkg1_0.1382                0.40595  -  0.017   +  0.016       False
# frac_deltaE_bkg1_0.1382            0.438063  -  0.044   +  0.044       False
# True
# Iteration 13 - Signal Yield: 315.5099774618623 ± 32.26073601321552
# Running iteration 14/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4345                 298.219  -     31   +     33       False
# background_yield_0.4345             5305.41  -     78   +     78       False
# frac_Mbc_bkg1_0.4345               0.410406  -  0.017   +  0.016       False
# frac_deltaE_bkg1_0.4345            0.445711  -  0.044   +  0.043       False
# True
# Iteration 14 - Signal Yield: 298.21939130081137 ± 32.315787683867384
# Running iteration 15/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7424                 294.526  -     32   +     33       False
# background_yield_0.7424             5308.57  -     77   +     79       False
# frac_Mbc_bkg1_0.7424               0.411339  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.7424            0.448362  -  0.044   +  0.043       False
# True
# Iteration 15 - Signal Yield: 294.52590792373303 ± 32.18634105783563
# Running iteration 16/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5525                 307.607  -     32   +     33       False
# background_yield_0.5525             5296.45  -     77   +     78       False
# frac_Mbc_bkg1_0.5525               0.407905  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.5525            0.441475  -  0.044   +  0.044       False
# True
# Iteration 16 - Signal Yield: 307.60706413798505 ± 32.15923429788445
# Running iteration 17/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0716                 288.541  -     32   +     33       False
# background_yield_0.0716             5315.12  -     77   +     78       False
# frac_Mbc_bkg1_0.0716               0.412876  -  0.017   +  0.016       False
# frac_deltaE_bkg1_0.0716            0.449462  -  0.044   +  0.043       False
# True
# Iteration 17 - Signal Yield: 288.54050163662765 ± 32.13745266594741
# Running iteration 18/300...
# 150
# 5454
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.197                 311.131  -     32   +     33       False
# background_yield_0.197             5292.81  -     77   +     78       False
# frac_Mbc_bkg1_0.197               0.406976  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.197            0.441307  -  0.044   +  0.043       False
# True
# Iteration 18 - Signal Yield: 311.1308787020402 ± 32.34754307784997
# Running iteration 19/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0401                 307.885  -     32   +     33       False
# background_yield_0.0401             5296.09  -     77   +     78       False
# frac_Mbc_bkg1_0.0401               0.408147  -  0.017   +  0.016       False
# frac_deltaE_bkg1_0.0401            0.443067  -  0.044   +  0.044       False
# True
# Iteration 19 - Signal Yield: 307.8847281040341 ± 32.24330774040016
# Running iteration 20/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9727                 302.675  -     32   +     33       False
# background_yield_0.9727             5301.42  -     77   +     78       False
# frac_Mbc_bkg1_0.9727               0.409215  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.9727            0.446284  -  0.044   +  0.044       False
# True
# Iteration 20 - Signal Yield: 302.6748755654413 ± 32.24726139933156
# Running iteration 21/300...
# 150
# 5454
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.087                 313.398  -     32   +     32       False
# background_yield_0.087             5289.86  -     76   +     79       False
# frac_Mbc_bkg1_0.087               0.406187  -  0.016   +  0.017       False
# frac_deltaE_bkg1_0.087            0.436755  -  0.044   +  0.044       False
# True
# Iteration 21 - Signal Yield: 313.39793241450195 ± 32.179402697349744
# Running iteration 22/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3261                 305.841  -     32   +     33       False
# background_yield_0.3261             5297.88  -     77   +     78       False
# frac_Mbc_bkg1_0.3261               0.408202  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.3261            0.444111  -  0.043   +  0.044       False
# True
# Iteration 22 - Signal Yield: 305.84102873926514 ± 32.17679518493574
# Running iteration 23/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8099                 292.782  -     32   +     33       False
# background_yield_0.8099             5311.28  -     77   +     78       False
# frac_Mbc_bkg1_0.8099               0.411168  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.8099             0.44971  -  0.044   +  0.044       False
# True
# Iteration 23 - Signal Yield: 292.78182895404694 ± 32.269725841496005
# Running iteration 24/300...
# 150
# 5454
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.173                 316.651  -     32   +     33       False
# background_yield_0.173             5287.24  -     77   +     78       False
# frac_Mbc_bkg1_0.173               0.405213  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.173            0.440171  -  0.044   +  0.044       False
# True
# Iteration 24 - Signal Yield: 316.65143765399466 ± 32.292211073977306
# Running iteration 25/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9658                 298.068  -     32   +     32       False
# background_yield_0.9658             5305.53  -     77   +     79       False
# frac_Mbc_bkg1_0.9658               0.410961  -  0.017   +  0.016       False
# frac_deltaE_bkg1_0.9658            0.451373  -  0.044   +  0.043       False
# True
# Iteration 25 - Signal Yield: 298.0684814928182 ± 32.25118576897262
# Running iteration 26/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6774                 304.783  -     32   +     33       False
# background_yield_0.6774             5299.41  -     78   +     78       False
# frac_Mbc_bkg1_0.6774               0.408758  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.6774            0.444854  -  0.044   +  0.044       False
# True
# Iteration 26 - Signal Yield: 304.7830617358674 ± 32.1904643765043
# Running iteration 27/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2346                 301.009  -     32   +     33       False
# background_yield_0.2346             5300.07  -     75   +     81       False
# frac_Mbc_bkg1_0.2346               0.409974  -  0.017   +  0.016       False
# frac_deltaE_bkg1_0.2346            0.439402  -  0.044   +  0.044       False
# True
# Iteration 27 - Signal Yield: 301.008578573186 ± 32.128204936889944
# Running iteration 28/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3225                 306.061  -     32   +     33       False
# background_yield_0.3225             5297.96  -     77   +     78       False
# frac_Mbc_bkg1_0.3225               0.407999  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.3225            0.447023  -  0.044   +  0.043       False
# True
# Iteration 28 - Signal Yield: 306.0613721502756 ± 32.18786499662612
# Running iteration 29/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3936                  300.77  -     32   +     33       False
# background_yield_0.3936             5302.56  -     77   +     79       False
# frac_Mbc_bkg1_0.3936               0.409717  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.3936             0.44761  -  0.044   +  0.044       False
# True
# Iteration 29 - Signal Yield: 300.76989373947066 ± 32.29774914448381
# Running iteration 30/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5145                 303.765  -     32   +     33       False
# background_yield_0.5145             5299.93  -     77   +     78       False
# frac_Mbc_bkg1_0.5145               0.409027  -  0.017   +  0.016       False
# frac_deltaE_bkg1_0.5145            0.446278  -  0.044   +  0.044       False
# True
# Iteration 30 - Signal Yield: 303.76521068950933 ± 32.252651642556785
# Running iteration 31/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8597                 310.774  -     32   +     33       False
# background_yield_0.8597             5293.74  -     78   +     78       False
# frac_Mbc_bkg1_0.8597               0.407199  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.8597            0.442699  -  0.043   +  0.044       False
# True
# Iteration 31 - Signal Yield: 310.77415320646327 ± 32.28682510328563
# Running iteration 32/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7752                 293.384  -     32   +     32       False
# background_yield_0.7752             5311.23  -     78   +     78       False
# frac_Mbc_bkg1_0.7752               0.411166  -  0.016   +  0.017       False
# frac_deltaE_bkg1_0.7752            0.453367  -  0.044   +  0.043       False
# True
# Iteration 32 - Signal Yield: 293.38351487811104 ± 32.30482380456233
# Running iteration 33/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2873                 293.446  -     32   +     32       False
# background_yield_0.2873             5309.52  -     76   +     79       False
# frac_Mbc_bkg1_0.2873               0.411346  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.2873            0.451194  -  0.044   +  0.043       False
# True
# Iteration 33 - Signal Yield: 293.4458857593829 ± 32.148289929353425
# Running iteration 34/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3074                 314.716  -     32   +     33       False
# background_yield_0.3074             5288.96  -     77   +     78       False
# frac_Mbc_bkg1_0.3074               0.406092  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.3074             0.44158  -  0.044   +  0.044       False
# True
# Iteration 34 - Signal Yield: 314.71633898297813 ± 32.37477080388456
# Running iteration 35/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1019                 305.886  -     32   +     33       False
# background_yield_0.1019             5297.95  -     77   +     78       False
# frac_Mbc_bkg1_0.1019               0.407484  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.1019            0.444186  -  0.044   +  0.044       False
# True
# Iteration 35 - Signal Yield: 305.8860042527815 ± 32.189999641651376
# Running iteration 36/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2716                 300.829  -     31   +     33       False
# background_yield_0.2716             5303.19  -     78   +     78       False
# frac_Mbc_bkg1_0.2716               0.409837  -  0.017   +  0.016       False
# frac_deltaE_bkg1_0.2716            0.444609  -  0.044   +  0.043       False
# True
# Iteration 36 - Signal Yield: 300.8292622552071 ± 32.175155421079324
# Running iteration 37/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9343                 304.122  -     32   +     32       False
# background_yield_0.9343             5299.96  -     77   +     79       False
# frac_Mbc_bkg1_0.9343               0.408456  -  0.016   +  0.017       False
# frac_deltaE_bkg1_0.9343            0.443723  -  0.043   +  0.045       False
# True
# Iteration 37 - Signal Yield: 304.12182429583225 ± 32.306303600313896
# Running iteration 38/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9231                 300.229  -     32   +     33       False
# background_yield_0.9231             5303.84  -     77   +     78       False
# frac_Mbc_bkg1_0.9231               0.409764  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.9231             0.44468  -  0.044   +  0.044       False
# True
# Iteration 38 - Signal Yield: 300.22911941837657 ± 32.2225300677943
# Running iteration 39/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6514                 291.966  -     32   +     33       False
# background_yield_0.6514             5309.81  -     75   +     80       False
# frac_Mbc_bkg1_0.6514               0.412055  -  0.017   +  0.016       False
# frac_deltaE_bkg1_0.6514            0.450636  -  0.044   +  0.043       False
# True
# Iteration 39 - Signal Yield: 291.9661169281603 ± 32.178064959114145
# Running iteration 40/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2283                 312.164  -     32   +     33       False
# background_yield_0.2283             5292.06  -     77   +     78       False
# frac_Mbc_bkg1_0.2283               0.406445  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.2283            0.439329  -  0.044   +  0.044       False
# True
# Iteration 40 - Signal Yield: 312.1636370951458 ± 32.26661634305878
# Running iteration 41/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3211                 306.464  -     32   +     33       False
# background_yield_0.3211             5297.34  -     77   +     78       False
# frac_Mbc_bkg1_0.3211               0.407782  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.3211            0.443332  -  0.044   +  0.044       False
# True
# Iteration 41 - Signal Yield: 306.46412690390787 ± 32.24721090485818
# Running iteration 42/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8063                 296.492  -     33   +     32       False
# background_yield_0.8063             5308.17  -     77   +     78       False
# frac_Mbc_bkg1_0.8063               0.410813  -  0.016   +  0.017       False
# frac_deltaE_bkg1_0.8063            0.447004  -  0.044   +  0.044       False
# True
# Iteration 42 - Signal Yield: 296.4922454997923 ± 32.18386103502135
# Running iteration 43/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0273                 319.866  -     32   +     33       False
# background_yield_0.0273             5284.25  -     77   +     78       False
# frac_Mbc_bkg1_0.0273               0.404571  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.0273            0.438985  -  0.044   +  0.044       False
# True
# Iteration 43 - Signal Yield: 319.86626272237385 ± 32.39606314743125
# Running iteration 44/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9732                 305.011  -     32   +     33       False
# background_yield_0.9732             5299.53  -     78   +     78       False
# frac_Mbc_bkg1_0.9732               0.408564  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.9732            0.443011  -  0.043   +  0.044       False
# True
# Iteration 44 - Signal Yield: 305.0106982937979 ± 32.26203804771216
# Running iteration 45/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6277                  314.17  -     32   +     33       False
# background_yield_0.6277             5290.37  -     78   +     78       False
# frac_Mbc_bkg1_0.6277               0.406256  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.6277            0.441322  -  0.044   +  0.043       False
# True
# Iteration 45 - Signal Yield: 314.170158499935 ± 32.369990212610446
# Running iteration 46/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7607                 311.642  -     32   +     33       False
# background_yield_0.7607             5292.32  -     77   +     78       False
# frac_Mbc_bkg1_0.7607               0.406589  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.7607            0.443969  -  0.044   +  0.044       False
# True
# Iteration 46 - Signal Yield: 311.6420469357489 ± 32.23590943323964
# Running iteration 47/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4304                  300.81  -     32   +     33       False
# background_yield_0.4304             5303.33  -     78   +     78       False
# frac_Mbc_bkg1_0.4304               0.409453  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.4304            0.447641  -  0.044   +  0.044       False
# True
# Iteration 47 - Signal Yield: 300.81009480273644 ± 32.283071051036664
# Running iteration 48/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6809                 308.387  -     32   +     33       False
# background_yield_0.6809             5294.71  -     76   +     79       False
# frac_Mbc_bkg1_0.6809                0.40787  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.6809            0.440604  -  0.044   +  0.043       False
# True
# Iteration 48 - Signal Yield: 308.3867679516127 ± 32.24142024432217
# Running iteration 49/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0473                 307.253  -     32   +     33       False
# background_yield_0.0473             5296.88  -     77   +     78       False
# frac_Mbc_bkg1_0.0473               0.408189  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.0473            0.442991  -  0.044   +  0.044       False
# True
# Iteration 49 - Signal Yield: 307.25326759190546 ± 32.3120353336936
# Running iteration 50/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9657                 310.637  -     32   +     33       False
# background_yield_0.9657             5293.07  -     77   +     78       False
# frac_Mbc_bkg1_0.9657               0.407043  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.9657            0.439797  -  0.044   +  0.044       False
# True
# Iteration 50 - Signal Yield: 310.63715727983373 ± 32.29980143567492
# Running iteration 51/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2072                 310.557  -     32   +     33       False
# background_yield_0.2072             5293.59  -     77   +     78       False
# frac_Mbc_bkg1_0.2072                0.40701  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.2072            0.437399  -  0.044   +  0.044       False
# True
# Iteration 51 - Signal Yield: 310.55726137134275 ± 32.153836292227886
# Running iteration 52/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9589                 310.669  -     32   +     32       False
# background_yield_0.9589             5292.47  -     76   +     79       False
# frac_Mbc_bkg1_0.9589               0.406972  -  0.016   +  0.017       False
# frac_deltaE_bkg1_0.9589            0.438694  -  0.043   +  0.045       False
# True
# Iteration 52 - Signal Yield: 310.66935191317486 ± 32.25675522191426
# Running iteration 53/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9279                 291.966  -     32   +     33       False
# background_yield_0.9279             5310.93  -     76   +     79       False
# frac_Mbc_bkg1_0.9279               0.411826  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.9279            0.451286  -  0.044   +  0.043       False
# True
# Iteration 53 - Signal Yield: 291.9656559134645 ± 32.11575163282406
# Running iteration 54/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0991                 299.834  -     32   +     32       False
# background_yield_0.0991             5304.23  -     77   +     78       False
# frac_Mbc_bkg1_0.0991               0.409529  -  0.016   +  0.017       False
# frac_deltaE_bkg1_0.0991            0.446156  -  0.044   +  0.044       False
# True
# Iteration 54 - Signal Yield: 299.833862558168 ± 32.17679914872469
# Running iteration 55/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8169                 304.786  -     32   +     33       False
# background_yield_0.8169              5299.2  -     77   +     78       False
# frac_Mbc_bkg1_0.8169               0.408598  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.8169            0.442745  -  0.044   +  0.044       False
# True
# Iteration 55 - Signal Yield: 304.78597531086746 ± 32.12440883013795
# Running iteration 56/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3209                 302.311  -     32   +     32       False
# background_yield_0.3209             5301.48  -     77   +     78       False
# frac_Mbc_bkg1_0.3209               0.409414  -  0.017   +  0.016       False
# frac_deltaE_bkg1_0.3209            0.446064  -  0.044   +  0.044       False
# True
# Iteration 56 - Signal Yield: 302.3109515722703 ± 32.240677904073486
# Running iteration 57/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7147                 306.782  -     32   +     33       False
# background_yield_0.7147              5297.2  -     77   +     78       False
# frac_Mbc_bkg1_0.7147               0.408079  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.7147            0.445715  -  0.044   +  0.044       False
# True
# Iteration 57 - Signal Yield: 306.7817491684378 ± 32.24858112178819
# Running iteration 58/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4293                 302.687  -     32   +     32       False
# background_yield_0.4293             5299.98  -     76   +     80       False
# frac_Mbc_bkg1_0.4293               0.408993  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.4293            0.442671  -  0.043   +  0.044       False
# True
# Iteration 58 - Signal Yield: 302.687020635429 ± 32.181406322581125
# Running iteration 59/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0191                 309.237  -     32   +     33       False
# background_yield_0.0191             5294.74  -     77   +     78       False
# frac_Mbc_bkg1_0.0191                0.40772  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.0191            0.439551  -  0.044   +  0.044       False
# True
# Iteration 59 - Signal Yield: 309.2369225414964 ± 32.31145544574742
# Running iteration 60/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8716                  299.96  -     32   +     33       False
# background_yield_0.8716             5304.17  -     78   +     78       False
# frac_Mbc_bkg1_0.8716                0.40988  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.8716            0.445534  -  0.044   +  0.044       False
# True
# Iteration 60 - Signal Yield: 299.95958739955154 ± 32.2373051720586
# Running iteration 61/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6349                 314.915  -     32   +     33       False
# background_yield_0.6349             5288.43  -     77   +     78       False
# frac_Mbc_bkg1_0.6349               0.405823  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.6349            0.440034  -  0.044   +  0.044       False
# True
# Iteration 61 - Signal Yield: 314.91505794841316 ± 32.3026562704996
# Running iteration 62/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7028                 305.302  -     32   +     33       False
# background_yield_0.7028             5297.67  -     76   +     79       False
# frac_Mbc_bkg1_0.7028               0.408614  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.7028            0.443935  -  0.044   +  0.043       False
# True
# Iteration 62 - Signal Yield: 305.3020591859498 ± 32.28051609163013
# Running iteration 63/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3378                 299.374  -     32   +     32       False
# background_yield_0.3378             5305.06  -     78   +     78       False
# frac_Mbc_bkg1_0.3378               0.409949  -  0.016   +  0.017       False
# frac_deltaE_bkg1_0.3378            0.444343  -  0.044   +  0.043       False
# True
# Iteration 63 - Signal Yield: 299.37403293443407 ± 32.02752875815624
# Running iteration 64/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3216                     310  -     32   +     32       False
# background_yield_0.3216             5294.94  -     78   +     77       False
# frac_Mbc_bkg1_0.3216               0.406701  -  0.016   +  0.017       False
# frac_deltaE_bkg1_0.3216            0.443471  -  0.044   +  0.043       False
# True
# Iteration 64 - Signal Yield: 310.0002856637803 ± 32.25746573730856
# Running iteration 65/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7531                 301.394  -     32   +     33       False
# background_yield_0.7531              5302.6  -     77   +     78       False
# frac_Mbc_bkg1_0.7531               0.409445  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.7531            0.445202  -  0.044   +  0.044       False
# True
# Iteration 65 - Signal Yield: 301.3944218307261 ± 32.19404374012501
# Running iteration 66/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9514                 313.258  -     32   +     33       False
# background_yield_0.9514             5290.81  -     77   +     78       False
# frac_Mbc_bkg1_0.9514               0.406562  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.9514            0.440715  -  0.044   +  0.043       False
# True
# Iteration 66 - Signal Yield: 313.2583618184634 ± 32.22040272965111
# Running iteration 67/300...
# 150
# 5454
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.652                 303.406  -     32   +     33       False
# background_yield_0.652              5300.7  -     77   +     78       False
# frac_Mbc_bkg1_0.652               0.408692  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.652            0.446047  -  0.044   +  0.044       False
# True
# Iteration 67 - Signal Yield: 303.40625290034154 ± 32.16923299291102
# Running iteration 68/300...
# 150
# 5454
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.345                 291.917  -     32   +     33       False
# background_yield_0.345             5311.97  -     77   +     78       False
# frac_Mbc_bkg1_0.345               0.411676  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.345            0.446004  -  0.044   +  0.044       False
# True
# Iteration 68 - Signal Yield: 291.9174142053712 ± 32.10948409651524
# Running iteration 69/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8748                 285.668  -     32   +     33       False
# background_yield_0.8748             5318.02  -     77   +     78       False
# frac_Mbc_bkg1_0.8748               0.413302  -  0.017   +  0.016       False
# frac_deltaE_bkg1_0.8748            0.451154  -  0.044   +  0.043       False
# True
# Iteration 69 - Signal Yield: 285.6675606258617 ± 32.11326959538448
# Running iteration 70/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6833                 307.664  -     32   +     33       False
# background_yield_0.6833             5295.76  -     77   +     78       False
# frac_Mbc_bkg1_0.6833                0.40772  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.6833            0.441324  -  0.044   +  0.044       False
# True
# Iteration 70 - Signal Yield: 307.66367621921205 ± 32.14997114992053
# Running iteration 71/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2483                 293.345  -     32   +     32       False
# background_yield_0.2483             5310.69  -     77   +     79       False
# frac_Mbc_bkg1_0.2483               0.411973  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.2483            0.447905  -  0.044   +  0.044       False
# True
# Iteration 71 - Signal Yield: 293.34544411781997 ± 32.187339075722704
# Running iteration 72/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5302                 306.033  -     32   +     33       False
# background_yield_0.5302             5298.01  -     77   +     78       False
# frac_Mbc_bkg1_0.5302               0.408118  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.5302            0.445815  -  0.044   +  0.044       False
# True
# Iteration 72 - Signal Yield: 306.0326027255138 ± 32.25154643661988
# Running iteration 73/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4325                 299.567  -     32   +     33       False
# background_yield_0.4325             5305.54  -     78   +     77       False
# frac_Mbc_bkg1_0.4325               0.410129  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.4325            0.445136  -  0.044   +  0.043       False
# True
# Iteration 73 - Signal Yield: 299.56680678833646 ± 32.38681256537373
# Running iteration 74/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0275                 309.705  -     32   +     33       False
# background_yield_0.0275              5294.2  -     77   +     78       False
# frac_Mbc_bkg1_0.0275               0.407161  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.0275            0.442685  -  0.044   +  0.044       False
# True
# Iteration 74 - Signal Yield: 309.7045825285525 ± 32.357815788491536
# Running iteration 75/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8255                  306.25  -     32   +     33       False
# background_yield_0.8255             5297.63  -     77   +     78       False
# frac_Mbc_bkg1_0.8255               0.408274  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.8255            0.447392  -  0.044   +  0.044       False
# True
# Iteration 75 - Signal Yield: 306.2495967765976 ± 32.30760299306172
# Running iteration 76/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6118                 307.468  -     32   +     33       False
# background_yield_0.6118             5296.59  -     77   +     78       False
# frac_Mbc_bkg1_0.6118               0.407958  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.6118            0.444164  -  0.044   +  0.044       False
# True
# Iteration 76 - Signal Yield: 307.468348236173 ± 32.40909216236554
# Running iteration 77/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2818                 305.964  -     32   +     33       False
# background_yield_0.2818             5298.14  -     78   +     78       False
# frac_Mbc_bkg1_0.2818               0.407993  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.2818            0.440148  -  0.044   +  0.044       False
# True
# Iteration 77 - Signal Yield: 305.9638146914052 ± 32.23269901833287
# Running iteration 78/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1514                 310.839  -     32   +     33       False
# background_yield_0.1514             5293.14  -     77   +     78       False
# frac_Mbc_bkg1_0.1514               0.407147  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.1514            0.436761  -  0.044   +  0.044       False
# True
# Iteration 78 - Signal Yield: 310.83858557665764 ± 32.217369653783464
# Running iteration 79/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8916                 317.296  -     33   +     32       False
# background_yield_0.8916             5286.55  -     76   +     79       False
# frac_Mbc_bkg1_0.8916               0.404962  -  0.016   +  0.017       False
# frac_deltaE_bkg1_0.8916            0.439255  -  0.043   +  0.045       False
# True
# Iteration 79 - Signal Yield: 317.29572937723026 ± 32.439508309743694
# Running iteration 80/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7591                 295.719  -     32   +     32       False
# background_yield_0.7591              5308.1  -     77   +     78       False
# frac_Mbc_bkg1_0.7591               0.410966  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.7591            0.449302  -  0.044   +  0.044       False
# True
# Iteration 80 - Signal Yield: 295.71854358823134 ± 32.1804609364114
# Running iteration 81/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3319                 296.863  -     32   +     33       False
# background_yield_0.3319             5307.57  -     78   +     78       False
# frac_Mbc_bkg1_0.3319               0.410001  -  0.016   +  0.017       False
# frac_deltaE_bkg1_0.3319            0.446551  -  0.043   +  0.044       False
# True
# Iteration 81 - Signal Yield: 296.8631436229197 ± 32.224293474925126
# Running iteration 82/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5067                 305.434  -     32   +     33       False
# background_yield_0.5067             5299.44  -     79   +     77       False
# frac_Mbc_bkg1_0.5067                0.40851  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.5067             0.44705  -  0.044   +  0.043       False
# True
# Iteration 82 - Signal Yield: 305.43376095689064 ± 32.34775560498559
# Running iteration 83/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9143                  303.69  -     32   +     33       False
# background_yield_0.9143             5300.65  -     78   +     78       False
# frac_Mbc_bkg1_0.9143               0.408277  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.9143            0.444958  -  0.044   +  0.043       False
# True
# ...
# signal_yield_0.8245                 311.269  -     32   +     33       False
# background_yield_0.8245             5292.51  -     77   +     78       False
# frac_Mbc_bkg1_0.8245               0.407065  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.8245            0.440882  -  0.044   +  0.044       False
# True
# Iteration 273 - Signal Yield: 311.26896172327224 ± 32.29620675239053
# Running iteration 274/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5816                 303.115  -     32   +     33       False
# background_yield_0.5816              5300.7  -     77   +     78       False
# frac_Mbc_bkg1_0.5816               0.409093  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.5816            0.446165  -  0.044   +  0.044       False
# True
# Iteration 274 - Signal Yield: 303.1151017339124 ± 32.258407623934396
# Running iteration 275/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1578                 304.215  -     32   +     32       False
# background_yield_0.1578             5299.89  -     77   +     78       False
# frac_Mbc_bkg1_0.1578               0.409098  -  0.017   +  0.016       False
# frac_deltaE_bkg1_0.1578             0.44511  -  0.044   +  0.044       False
# True
# Iteration 275 - Signal Yield: 304.21461328770033 ± 32.306421059225066
# Running iteration 276/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1391                 308.404  -     32   +     33       False
# background_yield_0.1391             5295.13  -     77   +     78       False
# frac_Mbc_bkg1_0.1391               0.407426  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.1391            0.442606  -  0.044   +  0.043       False
# True
# Iteration 276 - Signal Yield: 308.40390331901443 ± 32.26844157354246
# Running iteration 277/300...
# 150
# 5454
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.808                 304.876  -     32   +     32       False
# background_yield_0.808             5301.22  -     79   +     76       False
# frac_Mbc_bkg1_0.808               0.408632  -  0.017   +  0.016       False
# frac_deltaE_bkg1_0.808            0.443668  -  0.044   +  0.043       False
# True
# Iteration 277 - Signal Yield: 304.87599071767266 ± 32.18911894121231
# Running iteration 278/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8314                 304.303  -     32   +     33       False
# background_yield_0.8314             5299.93  -     78   +     78       False
# frac_Mbc_bkg1_0.8314               0.408444  -  0.016   +  0.017       False
# frac_deltaE_bkg1_0.8314            0.443767  -  0.044   +  0.043       False
# True
# Iteration 278 - Signal Yield: 304.3034067965118 ± 32.27614353475576
# Running iteration 279/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7498                 307.943  -     32   +     33       False
# background_yield_0.7498             5295.76  -     77   +     78       False
# frac_Mbc_bkg1_0.7498               0.407686  -  0.017   +  0.016       False
# frac_deltaE_bkg1_0.7498            0.442704  -  0.044   +  0.043       False
# True
# Iteration 279 - Signal Yield: 307.9426238267364 ± 32.1921538808776
# Running iteration 280/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8525                 300.522  -     32   +     33       False
# background_yield_0.8525             5303.18  -     77   +     79       False
# frac_Mbc_bkg1_0.8525               0.409831  -  0.017   +  0.016       False
# frac_deltaE_bkg1_0.8525            0.450815  -  0.044   +  0.044       False
# True
# Iteration 280 - Signal Yield: 300.5217951882281 ± 32.33585556701516
# Running iteration 281/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7122                 311.886  -     32   +     33       False
# background_yield_0.7122              5292.3  -     77   +     78       False
# frac_Mbc_bkg1_0.7122               0.406646  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.7122            0.442799  -  0.044   +  0.044       False
# True
# Iteration 281 - Signal Yield: 311.8857405955798 ± 32.34399104565154
# Running iteration 282/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6591                 308.711  -     32   +     33       False
# background_yield_0.6591             5295.06  -     77   +     78       False
# frac_Mbc_bkg1_0.6591               0.407501  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.6591             0.44143  -  0.044   +  0.044       False
# True
# Iteration 282 - Signal Yield: 308.71072360140556 ± 32.22300139132748
# Running iteration 283/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4048                 297.767  -     32   +     33       False
# background_yield_0.4048             5306.26  -     77   +     78       False
# frac_Mbc_bkg1_0.4048               0.410193  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.4048            0.450298  -  0.044   +  0.044       False
# True
# Iteration 283 - Signal Yield: 297.7666000880147 ± 32.191720025982704
# Running iteration 284/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0006                 312.297  -     32   +     33       False
# background_yield_0.0006             5291.56  -     77   +     78       False
# frac_Mbc_bkg1_0.0006               0.406559  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.0006            0.439807  -  0.044   +  0.044       False
# True
# Iteration 284 - Signal Yield: 312.29738616824267 ± 32.153358581262665
# Running iteration 285/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9279                  303.13  -     32   +     33       False
# background_yield_0.9279             5301.75  -     78   +     77       False
# frac_Mbc_bkg1_0.9279               0.409281  -  0.017   +  0.016       False
# frac_deltaE_bkg1_0.9279            0.450555  -  0.044   +  0.043       False
# True
# Iteration 285 - Signal Yield: 303.1300277757671 ± 32.28496059272884
# Running iteration 286/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1492                 296.217  -     32   +     33       False
# background_yield_0.1492              5309.2  -     79   +     77       False
# frac_Mbc_bkg1_0.1492               0.410107  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.1492             0.45385  -  0.044   +  0.044       False
# True
# Iteration 286 - Signal Yield: 296.2168633855081 ± 32.33149942754005
# Running iteration 287/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4763                 304.066  -     32   +     33       False
# background_yield_0.4763             5299.75  -     77   +     78       False
# frac_Mbc_bkg1_0.4763               0.408874  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.4763            0.441313  -  0.044   +  0.044       False
# True
# Iteration 287 - Signal Yield: 304.0658877601146 ± 32.27375746729166
# Running iteration 288/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1306                 297.051  -     32   +     32       False
# background_yield_0.1306             5306.93  -     77   +     78       False
# frac_Mbc_bkg1_0.1306                0.41053  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.1306            0.446474  -  0.044   +  0.043       False
# True
# Iteration 288 - Signal Yield: 297.0515121110026 ± 32.23918068081338
# Running iteration 289/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2417                 304.485  -     32   +     32       False
# background_yield_0.2417             5299.65  -     77   +     78       False
# frac_Mbc_bkg1_0.2417               0.408848  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.2417            0.444379  -  0.044   +  0.044       False
# True
# Iteration 289 - Signal Yield: 304.48523816382897 ± 32.20691819504712
# Running iteration 290/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5901                 295.434  -     32   +     33       False
# background_yield_0.5901             5308.56  -     77   +     78       False
# frac_Mbc_bkg1_0.5901               0.410511  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.5901            0.445659  -  0.044   +  0.044       False
# True
# Iteration 290 - Signal Yield: 295.43443658310196 ± 32.17097100984679
# Running iteration 291/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8736                  310.75  -     32   +     33       False
# background_yield_0.8736             5293.31  -     77   +     78       False
# frac_Mbc_bkg1_0.8736                0.40698  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.8736            0.442901  -  0.044   +  0.044       False
# True
# Iteration 291 - Signal Yield: 310.7499594177286 ± 32.353187448106176
# Running iteration 292/300...
# 150
# 5454
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.674                  296.93  -     32   +     33       False
# background_yield_0.674             5306.99  -     77   +     78       False
# frac_Mbc_bkg1_0.674               0.410422  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.674            0.444958  -  0.044   +  0.043       False
# True
# Iteration 292 - Signal Yield: 296.92979966720014 ± 32.263075668134036
# Running iteration 293/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9086                 316.707  -     32   +     33       False
# background_yield_0.9086             5287.35  -     77   +     78       False
# frac_Mbc_bkg1_0.9086               0.405448  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.9086            0.439846  -  0.044   +  0.044       False
# True
# Iteration 293 - Signal Yield: 316.7068003066254 ± 32.281092114488324
# Running iteration 294/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7383                 288.676  -     32   +     32       False
# background_yield_0.7383             5314.97  -     77   +     79       False
# frac_Mbc_bkg1_0.7383               0.412672  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.7383            0.451686  -  0.044   +  0.043       False
# True
# Iteration 294 - Signal Yield: 288.6759732551336 ± 32.22868278683944
# Running iteration 295/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2989                 307.952  -     32   +     32       False
# background_yield_0.2989             5296.41  -     77   +     78       False
# frac_Mbc_bkg1_0.2989               0.407512  -  0.016   +  0.017       False
# frac_deltaE_bkg1_0.2989            0.440584  -  0.043   +  0.044       False
# True
# Iteration 295 - Signal Yield: 307.9514677201255 ± 32.1787390996477
# Running iteration 296/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0471                  309.05  -     32   +     33       False
# background_yield_0.0471             5294.95  -     77   +     78       False
# frac_Mbc_bkg1_0.0471               0.407192  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.0471            0.442643  -  0.044   +  0.044       False
# True
# Iteration 296 - Signal Yield: 309.0503865412954 ± 32.22705729654723
# Running iteration 297/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4065                 306.102  -     32   +     33       False
# background_yield_0.4065             5296.93  -     76   +     79       False
# frac_Mbc_bkg1_0.4065               0.407965  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.4065            0.443235  -  0.044   +  0.043       False
# True
# Iteration 297 - Signal Yield: 306.10176631180803 ± 32.19808721135217
# Running iteration 298/300...
# 150
# 5454
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.299                 303.498  -     32   +     33       False
# background_yield_0.299             5300.13  -     77   +     78       False
# frac_Mbc_bkg1_0.299               0.408914  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.299            0.448833  -  0.044   +  0.043       False
# True
# Iteration 298 - Signal Yield: 303.49776277370285 ± 32.25157730270833
# Running iteration 299/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9636                 292.267  -     32   +     32       False
# background_yield_0.9636             5311.32  -     76   +     79       False
# frac_Mbc_bkg1_0.9636               0.411711  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.9636            0.449605  -  0.043   +  0.044       False
# True
# Iteration 299 - Signal Yield: 292.267417367692 ± 32.14002470701689
# Running iteration 300/300...
# 150
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1773                 305.974  -     32   +     33       False
# background_yield_0.1773             5298.15  -     77   +     78       False
# frac_Mbc_bkg1_0.1773                0.40825  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.1773            0.443439  -  0.044   +  0.044       False
# True
# Iteration 300 - Signal Yield: 305.97388712415903 ± 32.252220453932985
# Signal yields and errors saved to 'Bppi0_q2reg4_decay_mumu_signal_yields_and_errors_150.csv'

# %% [markdown]
# ## 100

# %%
# Number of iterations
num_iterations = 300

# List to store the signal yields and their errors from each iteration
signal_yields_and_errors = []

for i in range(num_iterations):
    print(f"Running iteration {i + 1}/{num_iterations}...")

    # Process the Monte Carlo data
    mc_mu_signal, mc_mu_only_signal, mc_mu_scf, mc_mu_bkg, mc_mu_signal_weight, mc_mu_only_signal_weight, mc_mu_scf_weight, mc_mu_bkg_weight = process_MC_data_combined(
        file_signal_mu_Bppi0,file_bkg_mu_Bppi0, 'mu', '521', 'pi0', 'mumu', 4, 'rec521', 'weights', 100
    )

    # Fit models for signal, SCF, and background
    Mbc_only_signal_cb_fixed = fit_fixed_without_weight('Mbc', 'mu', 'signal', mc_mu_only_signal["Mbc"], 'cb', 0)
    deltaE_only_signal_cb_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'signal', mc_mu_only_signal["deltaE"],  'cb_gauss', 0)

    Mbc_scf_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'scf', mc_mu_scf["Mbc"], 'argus_gauss', 0)
    deltaE_scf_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'scf', mc_mu_scf["deltaE"], 'poly_gauss', 0)

    Mbc_bkg_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'bkg', mc_mu_bkg["Mbc"], 'argus_gauss', 0)
    deltaE_bkg_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'bkg',  mc_mu_bkg["deltaE"],  'poly', 0)

    # Combine signal and background data
    Signal_Mbc = mc_mu_only_signal["Mbc"]
    Signal_deltaE = mc_mu_only_signal["deltaE"]
    Background_Mbc = pd.concat([mc_mu_scf["Mbc"], mc_mu_bkg["Mbc"]])
    Background_deltaE = pd.concat([mc_mu_scf["deltaE"], mc_mu_bkg["deltaE"]])

    Signal_total = pd.concat([Signal_Mbc, Signal_deltaE], axis=1)
    Background_total = pd.concat([Background_Mbc, Background_deltaE], axis=1)

    MC_signal=len(Signal_total)
    MC_bkg=len(Background_total)

    print(MC_signal)
    print(MC_bkg)
    
    # Fit the extended model and get the result
    Mbc_signal_pdf, deltaE_signal_pdf, Mbc_background_pdf, deltaE_background_pdf, signal_extended, background_extended, total_model, result = fit_extended_model_scf_without_weight(
        Mbc_only_signal_cb_fixed, Mbc_scf_argus_gauss_fixed, deltaE_only_signal_cb_gauss_fixed, deltaE_scf_poly_gauss_fixed,
        Mbc_bkg_argus_gauss_fixed, deltaE_bkg_poly_gauss_fixed,
        pd.concat([Signal_total, Background_total]), 0.5, 0.5, 100, 100
    )
    result.errors(name='errors')
    print(result.params)
    print(result.valid)

    # Retrieve and store the signal yield and its error
    signal_yield = result.params[signal_extended.get_yield()]['value']
    signal_yield_errors = result.params[signal_extended.get_yield()]['errors']
    signal_yield_error = (signal_yield_errors['upper'] - signal_yield_errors['lower']) / 2

    # Store the signal yield and error as a tuple in the list
    signal_yields_and_errors.append((MC_signal,MC_bkg,signal_yield, signal_yield_error))

    print(f"Iteration {i + 1} - Signal Yield: {signal_yield} ± {signal_yield_error}")

# Convert the list to a DataFrame with two columns: 'Signal_Yield' and 'Signal_Yield_Error'
signal_yields_df = pd.DataFrame(signal_yields_and_errors, columns=['MC_signal','MC_bkg','Signal_Yield', 'Signal_Yield_Error'])


# Save the DataFrame to a CSV file
signal_yields_df.to_csv('Bppi0_q2reg4_decay_mumu_signal_yields_and_errors_100.csv', index=False)

print("Signal yields and errors saved to 'Bppi0_q2reg4_decay_mumu_signal_yields_and_errors_100.csv'")
# Out:
# Running iteration 1/300...
# 100
# 5454
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.693                 248.909  -     30   +     31       False
# background_yield_0.693             5305.08  -     77   +     78       False
# frac_Mbc_bkg1_0.693               0.410077  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.693            0.446114  -  0.044   +  0.043       False
# True
# Iteration 1 - Signal Yield: 248.9087760724542 ± 30.886474271029687
# Running iteration 2/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9712                 246.944  -     31   +     31       False
# background_yield_0.9712             5307.05  -     77   +     78       False
# frac_Mbc_bkg1_0.9712               0.410591  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.9712            0.450168  -  0.044   +  0.043       False
# True
# Iteration 2 - Signal Yield: 246.94354752148584 ± 31.014847798704956
# Running iteration 3/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6407                 242.957  -     30   +     32       False
# background_yield_0.6407             5310.28  -     77   +     78       False
# frac_Mbc_bkg1_0.6407               0.411769  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.6407            0.450391  -  0.044   +  0.043       False
# True
# Iteration 3 - Signal Yield: 242.95691149785964 ± 30.90990438303757
# Running iteration 4/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3955                 247.056  -     30   +     31       False
# background_yield_0.3955             5307.49  -     78   +     77       False
# frac_Mbc_bkg1_0.3955               0.410525  -  0.017   +  0.016       False
# frac_deltaE_bkg1_0.3955            0.449394  -  0.044   +  0.043       False
# True
# Iteration 4 - Signal Yield: 247.05647661811395 ± 30.911417721159488
# Running iteration 5/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3887                  253.54  -     31   +     32       False
# background_yield_0.3887             5300.45  -     77   +     78       False
# frac_Mbc_bkg1_0.3887               0.408696  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.3887            0.445074  -  0.044   +  0.043       False
# True
# Iteration 5 - Signal Yield: 253.54004908277213 ± 31.074371746693267
# Running iteration 6/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9468                 246.184  -     31   +     31       False
# background_yield_0.9468             5307.83  -     77   +     78       False
# frac_Mbc_bkg1_0.9468               0.410929  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.9468            0.447968  -  0.044   +  0.043       False
# True
# Iteration 6 - Signal Yield: 246.1836216979178 ± 31.059944482284564
# Running iteration 7/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0465                 241.534  -     31   +     31       False
# background_yield_0.0465             5313.51  -     78   +     77       False
# frac_Mbc_bkg1_0.0465               0.411791  -  0.016   +  0.017       False
# frac_deltaE_bkg1_0.0465            0.449114  -  0.043   +  0.044       False
# True
# Iteration 7 - Signal Yield: 241.53410373401752 ± 30.940475090012757
# Running iteration 8/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8225                 250.413  -     31   +     32       False
# background_yield_0.8225             5303.79  -     77   +     78       False
# frac_Mbc_bkg1_0.8225               0.409862  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.8225            0.444748  -  0.044   +  0.044       False
# True
# Iteration 8 - Signal Yield: 250.41267575249674 ± 31.113371546507118
# Running iteration 9/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9699                 229.805  -     31   +     31       False
# background_yield_0.9699             5325.42  -     78   +     77       False
# frac_Mbc_bkg1_0.9699               0.415019  -  0.016   +  0.017       False
# frac_deltaE_bkg1_0.9699            0.455012  -  0.043   +  0.044       False
# True
# Iteration 9 - Signal Yield: 229.80501482850022 ± 30.86213355308542
# Running iteration 10/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7668                 252.758  -     31   +     31       False
# background_yield_0.7668             5301.77  -     77   +     78       False
# frac_Mbc_bkg1_0.7668               0.408888  -  0.016   +  0.017       False
# frac_deltaE_bkg1_0.7668            0.443456  -  0.044   +  0.044       False
# True
# Iteration 10 - Signal Yield: 252.75794205973565 ± 31.003861956259307
# Running iteration 11/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8158                 248.925  -     30   +     31       False
# background_yield_0.8158             5304.86  -     77   +     78       False
# frac_Mbc_bkg1_0.8158               0.410206  -  0.017   +  0.016       False
# frac_deltaE_bkg1_0.8158            0.443444  -  0.044   +  0.043       False
# True
# Iteration 11 - Signal Yield: 248.92460885895082 ± 30.82875219008888
# Running iteration 12/300...
# 100
# 5454
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.179                 240.612  -     31   +     31       False
# background_yield_0.179             5313.04  -     77   +     78       False
# frac_Mbc_bkg1_0.179               0.412109  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.179            0.448623  -  0.044   +  0.044       False
# True
# Iteration 12 - Signal Yield: 240.61150192102374 ± 31.03510269275727
# Running iteration 13/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2059                 256.277  -     31   +     31       False
# background_yield_0.2059             5297.71  -     77   +     78       False
# frac_Mbc_bkg1_0.2059               0.408278  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.2059            0.442295  -  0.044   +  0.044       False
# True
# Iteration 13 - Signal Yield: 256.2774554332013 ± 31.033250368932958
# Running iteration 14/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3783                 241.557  -     30   +     32       False
# background_yield_0.3783             5312.58  -     78   +     78       False
# frac_Mbc_bkg1_0.3783               0.412097  -  0.017   +  0.016       False
# frac_deltaE_bkg1_0.3783             0.44949  -  0.044   +  0.043       False
# True
# Iteration 14 - Signal Yield: 241.55720099124144 ± 31.086032365224604
# Running iteration 15/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6793                 237.254  -     31   +     31       False
# background_yield_0.6793             5317.96  -     78   +     77       False
# frac_Mbc_bkg1_0.6793               0.413033  -  0.016   +  0.017       False
# frac_deltaE_bkg1_0.6793            0.450922  -  0.044   +  0.043       False
# True
# Iteration 15 - Signal Yield: 237.25385411121647 ± 30.937347969498695
# Running iteration 16/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5283                 246.164  -     30   +     31       False
# background_yield_0.5283             5307.71  -     77   +     78       False
# frac_Mbc_bkg1_0.5283                 0.4108  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.5283            0.445595  -  0.044   +  0.043       False
# True
# Iteration 16 - Signal Yield: 246.1640688158465 ± 30.91431820225891
# Running iteration 17/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1429                 235.704  -     30   +     31       False
# background_yield_0.1429             5318.73  -     78   +     78       False
# frac_Mbc_bkg1_0.1429               0.413283  -  0.016   +  0.017       False
# frac_deltaE_bkg1_0.1429            0.451836  -  0.044   +  0.043       False
# True
# Iteration 17 - Signal Yield: 235.7041942718861 ± 30.896161978156854
# Running iteration 18/300...
# 100
# 5454
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.168                 247.429  -     30   +     32       False
# background_yield_0.168             5306.68  -     78   +     78       False
# frac_Mbc_bkg1_0.168               0.410587  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.168            0.445923  -  0.044   +  0.043       False
# True
# Iteration 18 - Signal Yield: 247.42943411800886 ± 31.13436738755403
# Running iteration 19/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5923                 245.706  -     31   +     31       False
# background_yield_0.5923             5308.39  -     77   +     78       False
# frac_Mbc_bkg1_0.5923               0.411245  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.5923            0.446121  -  0.044   +  0.043       False
# True
# Iteration 19 - Signal Yield: 245.70626939944475 ± 31.0197310402298
# Running iteration 20/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0963                 238.432  -     31   +     31       False
# background_yield_0.0963             5314.37  -     76   +     79       False
# frac_Mbc_bkg1_0.0963               0.412906  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.0963            0.453297  -  0.044   +  0.043       False
# True
# Iteration 20 - Signal Yield: 238.4320784316832 ± 31.01716375017427
# Running iteration 21/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2599                 247.119  -     31   +     31       False
# background_yield_0.2599             5308.03  -     78   +     77       False
# frac_Mbc_bkg1_0.2599               0.410562  -  0.016   +  0.017       False
# frac_deltaE_bkg1_0.2599            0.442756  -  0.043   +  0.045       False
# True
# Iteration 21 - Signal Yield: 247.11951876130263 ± 30.940495163294205
# Running iteration 22/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0459                  244.15  -     31   +     31       False
# background_yield_0.0459             5308.89  -     76   +     79       False
# frac_Mbc_bkg1_0.0459               0.411253  -  0.016   +  0.017       False
# frac_deltaE_bkg1_0.0459            0.447705  -  0.043   +  0.044       False
# True
# Iteration 22 - Signal Yield: 244.15036343434926 ± 30.906327123149733
# Running iteration 23/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9053                 231.449  -     31   +     31       False
# background_yield_0.9053             5324.28  -     79   +     77       False
# frac_Mbc_bkg1_0.9053               0.414181  -  0.016   +  0.017       False
# frac_deltaE_bkg1_0.9053            0.453047  -  0.044   +  0.043       False
# True
# Iteration 23 - Signal Yield: 231.4487314451897 ± 30.97843693463249
# Running iteration 24/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0463                 257.812  -     30   +     32       False
# background_yield_0.0463             5296.39  -     78   +     77       False
# frac_Mbc_bkg1_0.0463               0.407679  -  0.017   +  0.016       False
# frac_deltaE_bkg1_0.0463            0.443211  -  0.043   +  0.044       False
# True
# Iteration 24 - Signal Yield: 257.81182060933816 ± 31.07347068744361
# Running iteration 25/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0704                 242.834  -     31   +     31       False
# background_yield_0.0704             5311.43  -     78   +     78       False
# frac_Mbc_bkg1_0.0704                0.41186  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.0704             0.45175  -  0.044   +  0.043       False
# True
# Iteration 25 - Signal Yield: 242.8339861654506 ± 31.017704215759956
# Running iteration 26/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8721                 241.719  -     31   +     31       False
# background_yield_0.8721             5312.27  -     77   +     78       False
# frac_Mbc_bkg1_0.8721                0.41205  -  0.016   +  0.017       False
# frac_deltaE_bkg1_0.8721            0.448883  -  0.044   +  0.043       False
# True
# Iteration 26 - Signal Yield: 241.71864411236484 ± 30.919255048241034
# Running iteration 27/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3705                  238.55  -     30   +     32       False
# background_yield_0.3705             5316.49  -     79   +     77       False
# frac_Mbc_bkg1_0.3705               0.413124  -  0.017   +  0.016       False
# frac_deltaE_bkg1_0.3705            0.446715  -  0.044   +  0.043       False
# True
# Iteration 27 - Signal Yield: 238.5496680956785 ± 30.88381062765859
# Running iteration 28/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1941                  242.93  -     31   +     31       False
# background_yield_0.1941             5311.02  -     77   +     78       False
# frac_Mbc_bkg1_0.1941               0.411636  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.1941            0.450165  -  0.044   +  0.043       False
# True
# Iteration 28 - Signal Yield: 242.93032732952315 ± 30.968783660910894
# Running iteration 29/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3711                 241.972  -     31   +     32       False
# background_yield_0.3711             5312.31  -     78   +     78       False
# frac_Mbc_bkg1_0.3711               0.411902  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.3711            0.450831  -  0.044   +  0.043       False
# True
# Iteration 29 - Signal Yield: 241.97254241546707 ± 31.063807694755173
# Running iteration 30/300...
# 100
# 5454
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.509                 248.857  -     31   +     31       False
# background_yield_0.509              5305.3  -     77   +     78       False
# frac_Mbc_bkg1_0.509               0.410209  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.509            0.447184  -  0.044   +  0.043       False
# True
# Iteration 30 - Signal Yield: 248.8569660794416 ± 30.972657823281427
# Running iteration 31/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0592                 246.626  -     31   +     31       False
# background_yield_0.0592             5307.32  -     77   +     78       False
# frac_Mbc_bkg1_0.0592               0.410554  -  0.016   +  0.017       False
# frac_deltaE_bkg1_0.0592            0.447904  -  0.044   +  0.043       False
# True
# Iteration 31 - Signal Yield: 246.6264830291451 ± 30.997116717057438
# Running iteration 32/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2382                  231.95  -     31   +     31       False
# background_yield_0.2382             5323.36  -     79   +     77       False
# frac_Mbc_bkg1_0.2382               0.414543  -  0.016   +  0.017       False
# frac_deltaE_bkg1_0.2382            0.456773  -  0.044   +  0.043       False
# True
# Iteration 32 - Signal Yield: 231.94977839821138 ± 31.086708958700587
# Running iteration 33/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0556                 241.971  -     31   +     31       False
# background_yield_0.0556             5311.71  -     77   +     78       False
# frac_Mbc_bkg1_0.0556               0.411792  -  0.017   +  0.016       False
# frac_deltaE_bkg1_0.0556            0.448668  -  0.044   +  0.043       False
# True
# Iteration 33 - Signal Yield: 241.9715280113419 ± 30.917969278822127
# Running iteration 34/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7455                 253.567  -     30   +     32       False
# background_yield_0.7455             5300.61  -     78   +     77       False
# frac_Mbc_bkg1_0.7455               0.408912  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.7455            0.444631  -  0.043   +  0.044       False
# True
# Iteration 34 - Signal Yield: 253.56664884385816 ± 31.09807213062986
# Running iteration 35/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2201                 246.413  -     30   +     32       False
# background_yield_0.2201             5307.23  -     77   +     78       False
# frac_Mbc_bkg1_0.2201               0.409942  -  0.016   +  0.017       False
# frac_deltaE_bkg1_0.2201            0.447599  -  0.044   +  0.043       False
# True
# Iteration 35 - Signal Yield: 246.41267262034089 ± 30.967824704515365
# Running iteration 36/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3502                 237.288  -     30   +     32       False
# background_yield_0.3502             5316.51  -     77   +     78       False
# frac_Mbc_bkg1_0.3502               0.413487  -  0.017   +  0.016       False
# frac_deltaE_bkg1_0.3502            0.450466  -  0.044   +  0.043       False
# True
# Iteration 36 - Signal Yield: 237.288507079988 ± 30.932497704481392
# Running iteration 37/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1943                 240.819  -     31   +     31       False
# background_yield_0.1943             5313.04  -     77   +     78       False
# frac_Mbc_bkg1_0.1943               0.412255  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.1943            0.448177  -  0.043   +  0.044       False
# True
# Iteration 37 - Signal Yield: 240.81944655009627 ± 31.014755696612276
# Running iteration 38/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0218                  233.25  -     30   +     32       False
# background_yield_0.0218             5319.63  -     77   +     79       False
# frac_Mbc_bkg1_0.0218               0.414098  -  0.017   +  0.016       False
# frac_deltaE_bkg1_0.0218            0.452329  -  0.045   +  0.042       False
# True
# Iteration 38 - Signal Yield: 233.24952439649422 ± 30.95220217109496
# Running iteration 39/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2791                 235.424  -     31   +     31       False
# background_yield_0.2791             5319.72  -     78   +     77       False
# frac_Mbc_bkg1_0.2791                0.41339  -  0.016   +  0.017       False
# frac_deltaE_bkg1_0.2791            0.451345  -  0.044   +  0.043       False
# True
# Iteration 39 - Signal Yield: 235.42366980560615 ± 30.92043170126781
# Running iteration 40/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6503                 247.782  -     31   +     31       False
# background_yield_0.6503              5306.4  -     77   +     78       False
# frac_Mbc_bkg1_0.6503               0.410294  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.6503            0.444681  -  0.044   +  0.043       False
# True
# Iteration 40 - Signal Yield: 247.7822210387461 ± 30.967680633798448
# Running iteration 41/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4211                 248.307  -     31   +     31       False
# background_yield_0.4211             5305.87  -     77   +     78       False
# frac_Mbc_bkg1_0.4211               0.409926  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.4211            0.448082  -  0.044   +  0.043       False
# True
# Iteration 41 - Signal Yield: 248.30697154968036 ± 30.984445121778375
# Running iteration 42/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0357                  237.43  -     31   +     31       False
# background_yield_0.0357             5317.75  -     78   +     77       False
# frac_Mbc_bkg1_0.0357               0.413138  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.0357            0.450018  -  0.043   +  0.044       False
# True
# Iteration 42 - Signal Yield: 237.43052516731092 ± 30.971978588735936
# Running iteration 43/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2991                 250.188  -     30   +     32       False
# background_yield_0.2991             5303.94  -     78   +     77       False
# frac_Mbc_bkg1_0.2991               0.409893  -  0.017   +  0.016       False
# frac_deltaE_bkg1_0.2991            0.446167  -  0.045   +  0.043       False
# True
# Iteration 43 - Signal Yield: 250.1880725763805 ± 31.06757808197682
# Running iteration 44/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0382                 245.144  -     31   +     31       False
# background_yield_0.0382              5308.9  -     77   +     78       False
# frac_Mbc_bkg1_0.0382               0.411227  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.0382              0.4463  -  0.044   +  0.043       False
# True
# Iteration 44 - Signal Yield: 245.14439617679517 ± 31.08555539962432
# Running iteration 45/300...
# 100
# 5454
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.507                 259.625  -     31   +     32       False
# background_yield_0.507             5292.16  -     75   +     80       False
# frac_Mbc_bkg1_0.507               0.407662  -  0.017   +  0.016       False
# frac_deltaE_bkg1_0.507            0.440904  -  0.044   +  0.043       False
# True
# Iteration 45 - Signal Yield: 259.6248357970473 ± 31.07668353589623
# Running iteration 46/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1592                 251.429  -     30   +     32       False
# background_yield_0.1592             5303.23  -     78   +     77       False
# frac_Mbc_bkg1_0.1592               0.408834  -  0.016   +  0.017       False
# frac_deltaE_bkg1_0.1592            0.446219  -  0.044   +  0.043       False
# True
# Iteration 46 - Signal Yield: 251.42899439894174 ± 30.960677888939685
# Running iteration 47/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8943                  246.72  -     30   +     31       False
# background_yield_0.8943             5307.41  -     77   +     78       False
# frac_Mbc_bkg1_0.8943               0.410709  -  0.017   +  0.016       False
# frac_deltaE_bkg1_0.8943            0.447397  -  0.044   +  0.043       False
# True
# Iteration 47 - Signal Yield: 246.7198159081807 ± 30.93396207991866
# Running iteration 48/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4345                 245.758  -     30   +     31       False
# background_yield_0.4345             5308.23  -     77   +     78       False
# frac_Mbc_bkg1_0.4345               0.411144  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.4345             0.44514  -  0.044   +  0.044       False
# True
# Iteration 48 - Signal Yield: 245.75808065265147 ± 30.962360877702768
# Running iteration 49/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7956                 250.175  -     31   +     31       False
# background_yield_0.7956             5303.76  -     77   +     78       False
# frac_Mbc_bkg1_0.7956               0.409817  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.7956            0.445728  -  0.044   +  0.044       False
# True
# Iteration 49 - Signal Yield: 250.17467831908536 ± 31.07788585199714
# Running iteration 50/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0251                 245.494  -     31   +     31       False
# background_yield_0.0251             5308.73  -     77   +     78       False
# frac_Mbc_bkg1_0.0251               0.410985  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.0251            0.445852  -  0.043   +  0.044       False
# True
# Iteration 50 - Signal Yield: 245.4944541769643 ± 31.02889075554334
# Running iteration 51/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1021                 247.079  -     30   +     31       False
# background_yield_0.1021             5306.77  -     77   +     78       False
# frac_Mbc_bkg1_0.1021               0.410503  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.1021            0.444034  -  0.044   +  0.043       False
# True
# Iteration 51 - Signal Yield: 247.07873490236426 ± 30.849170088995013
# Running iteration 52/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5804                 258.907  -     30   +     32       False
# background_yield_0.5804             5294.57  -     77   +     78       False
# frac_Mbc_bkg1_0.5804               0.407696  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.5804             0.44182  -  0.044   +  0.043       False
# True
# Iteration 52 - Signal Yield: 258.90742788637505 ± 31.130683374504898
# Running iteration 53/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2389                 242.226  -     31   +     31       False
# background_yield_0.2389             5311.78  -     77   +     78       False
# frac_Mbc_bkg1_0.2389               0.411727  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.2389            0.450321  -  0.044   +  0.043       False
# True
# Iteration 53 - Signal Yield: 242.22575678383654 ± 30.957666765929886
# Running iteration 54/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6381                 247.089  -     31   +     31       False
# background_yield_0.6381             5307.11  -     77   +     78       False
# frac_Mbc_bkg1_0.6381               0.410433  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.6381            0.445319  -  0.043   +  0.044       False
# True
# Iteration 54 - Signal Yield: 247.088647550729 ± 30.97538083263934
# Running iteration 55/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0916                 243.871  -     31   +     31       False
# background_yield_0.0916             5309.63  -     76   +     79       False
# frac_Mbc_bkg1_0.0916                0.41158  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.0916            0.446682  -  0.043   +  0.044       False
# True
# Iteration 55 - Signal Yield: 243.8709795526038 ± 30.940411518057907
# Running iteration 56/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2752                 247.744  -     31   +     31       False
# background_yield_0.2752             5306.32  -     77   +     78       False
# frac_Mbc_bkg1_0.2752               0.410417  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.2752            0.447632  -  0.044   +  0.043       False
# True
# Iteration 56 - Signal Yield: 247.7441673552137 ± 31.048736942444805
# Running iteration 57/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6529                 253.709  -     30   +     32       False
# background_yield_0.6529             5299.92  -     77   +     78       False
# frac_Mbc_bkg1_0.6529               0.408702  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.6529            0.443766  -  0.044   +  0.043       False
# True
# Iteration 57 - Signal Yield: 253.70948768993392 ± 31.073018535031018
# Running iteration 58/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3293                  241.06  -     31   +     31       False
# background_yield_0.3293             5312.98  -     77   +     78       False
# frac_Mbc_bkg1_0.3293               0.411969  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.3293             0.44737  -  0.044   +  0.043       False
# True
# Iteration 58 - Signal Yield: 241.06046937462506 ± 30.860464311496536
# Running iteration 59/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7949                 247.133  -     31   +     31       False
# background_yield_0.7949              5307.2  -     78   +     78       False
# frac_Mbc_bkg1_0.7949               0.410719  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.7949             0.44502  -  0.044   +  0.043       False
# True
# Iteration 59 - Signal Yield: 247.1334402559595 ± 30.957035435893797
# Running iteration 60/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4781                 239.781  -     31   +     31       False
# background_yield_0.4781             5314.13  -     77   +     78       False
# frac_Mbc_bkg1_0.4781               0.412443  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.4781            0.448369  -  0.044   +  0.043       False
# True
# Iteration 60 - Signal Yield: 239.78058626830293 ± 30.932978720980213
# Running iteration 61/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6888                 253.063  -     31   +     31       False
# background_yield_0.6888             5301.11  -     77   +     78       False
# frac_Mbc_bkg1_0.6888                0.40894  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.6888            0.445166  -  0.044   +  0.043       False
# True
# Iteration 61 - Signal Yield: 253.06286890327655 ± 31.033520372036193
# Running iteration 62/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3211                 248.908  -     31   +     31       False
# background_yield_0.3211             5305.24  -     77   +     78       False
# frac_Mbc_bkg1_0.3211               0.410381  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.3211            0.443684  -  0.044   +  0.043       False
# True
# Iteration 62 - Signal Yield: 248.90807026310682 ± 31.00483805598467
# Running iteration 63/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7931                 237.244  -     30   +     31       False
# background_yield_0.7931              5317.1  -     78   +     78       False
# frac_Mbc_bkg1_0.7931               0.413384  -  0.017   +  0.016       False
# frac_deltaE_bkg1_0.7931            0.447751  -  0.043   +  0.044       False
# True
# Iteration 63 - Signal Yield: 237.2436292538396 ± 30.747763113530016
# Running iteration 64/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2739                 256.073  -     30   +     32       False
# background_yield_0.2739             5296.83  -     77   +     78       False
# frac_Mbc_bkg1_0.2739               0.407962  -  0.017   +  0.016       False
# frac_deltaE_bkg1_0.2739            0.442433  -  0.044   +  0.043       False
# True
# Iteration 64 - Signal Yield: 256.07263943040857 ± 30.971018494042248
# Running iteration 65/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7127                 244.923  -     30   +     31       False
# background_yield_0.7127              5309.3  -     78   +     78       False
# frac_Mbc_bkg1_0.7127               0.411114  -  0.017   +  0.016       False
# frac_deltaE_bkg1_0.7127            0.448576  -  0.044   +  0.043       False
# True
# Iteration 65 - Signal Yield: 244.92278898438548 ± 30.945222844950813
# Running iteration 66/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5715                 245.755  -     31   +     31       False
# background_yield_0.5715             5308.24  -     77   +     78       False
# frac_Mbc_bkg1_0.5715                0.41105  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.5715            0.447069  -  0.044   +  0.043       False
# True
# Iteration 66 - Signal Yield: 245.75496404767634 ± 30.93578048269263
# Running iteration 67/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4754                 250.525  -     30   +     31       False
# background_yield_0.4754             5303.42  -     77   +     78       False
# frac_Mbc_bkg1_0.4754               0.409754  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.4754            0.443141  -  0.044   +  0.044       False
# True
# Iteration 67 - Signal Yield: 250.52458968232543 ± 30.85440190102478
# Running iteration 68/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8678                  234.18  -     31   +     31       False
# background_yield_0.8678             5321.64  -     79   +     77       False
# frac_Mbc_bkg1_0.8678               0.413568  -  0.016   +  0.017       False
# frac_deltaE_bkg1_0.8678            0.449976  -  0.044   +  0.043       False
# True
# Iteration 68 - Signal Yield: 234.17983793664013 ± 30.886757112233475
# Running iteration 69/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8724                 228.336  -     30   +     31       False
# background_yield_0.8724             5325.41  -     77   +     78       False
# frac_Mbc_bkg1_0.8724               0.415301  -  0.017   +  0.016       False
# frac_deltaE_bkg1_0.8724            0.452945  -  0.044   +  0.043       False
# True
# Iteration 69 - Signal Yield: 228.33592660082752 ± 30.856687613382398
# Running iteration 70/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3222                 253.961  -     31   +     31       False
# background_yield_0.3222             5300.12  -     77   +     78       False
# frac_Mbc_bkg1_0.3222               0.408776  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.3222            0.445017  -  0.044   +  0.043       False
# True
# Iteration 70 - Signal Yield: 253.96135681461487 ± 30.935224272881555
# Running iteration 71/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1066                  237.09  -     30   +     31       False
# background_yield_0.1066             5316.88  -     77   +     78       False
# frac_Mbc_bkg1_0.1066               0.413329  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.1066             0.44898  -  0.044   +  0.043       False
# True
# Iteration 71 - Signal Yield: 237.08972648024007 ± 30.895755106319072
# Running iteration 72/300...
# 100
# 5454
# name                     value  (rounded)               errors    at limit
# ---------------------  ------------------  -------------------  ----------
# signal_yield_0.84                 251.514  -     30   +     32       False
# background_yield_0.84             5302.18  -     78   +     77       False
# frac_Mbc_bkg1_0.84               0.408938  -  0.016   +  0.017       False
# frac_deltaE_bkg1_0.84            0.447338  -  0.045   +  0.042       False
# True
# Iteration 72 - Signal Yield: 251.51365014549415 ± 31.004735277296838
# Running iteration 73/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3778                 245.713  -     32   +     31       False
# background_yield_0.3778             5308.08  -     76   +     79       False
# frac_Mbc_bkg1_0.3778               0.411008  -  0.016   +  0.017       False
# frac_deltaE_bkg1_0.3778            0.447236  -  0.043   +  0.044       False
# True
# Iteration 73 - Signal Yield: 245.7131867420462 ± 31.181704979312244
# Running iteration 74/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1502                  255.54  -     31   +     32       False
# background_yield_0.1502             5298.31  -     77   +     78       False
# frac_Mbc_bkg1_0.1502               0.408328  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.1502             0.44613  -  0.044   +  0.043       False
# True
# Iteration 74 - Signal Yield: 255.5396393929122 ± 31.14451658548544
# Running iteration 75/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0052                 249.978  -     31   +     31       False
# background_yield_0.0052             5304.02  -     77   +     78       False
# frac_Mbc_bkg1_0.0052               0.409988  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.0052            0.447336  -  0.044   +  0.043       False
# True
# Iteration 75 - Signal Yield: 249.97779036605476 ± 30.998542799157118
# Running iteration 76/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3536                 255.284  -     31   +     31       False
# background_yield_0.3536             5298.74  -     77   +     78       False
# frac_Mbc_bkg1_0.3536               0.408388  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.3536            0.443112  -  0.044   +  0.044       False
# True
# Iteration 76 - Signal Yield: 255.28367192042572 ± 31.083943589761887
# Running iteration 77/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1606                 246.376  -     31   +     31       False
# background_yield_0.1606             5307.56  -     77   +     78       False
# frac_Mbc_bkg1_0.1606               0.410936  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.1606             0.44433  -  0.044   +  0.043       False
# True
# Iteration 77 - Signal Yield: 246.37632031833016 ± 30.975712133905343
# Running iteration 78/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4484                 247.008  -     31   +     31       False
# background_yield_0.4484             5306.87  -     77   +     78       False
# frac_Mbc_bkg1_0.4484               0.410782  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.4484            0.443519  -  0.044   +  0.043       False
# True
# Iteration 78 - Signal Yield: 247.00832614932338 ± 31.000645027839056
# Running iteration 79/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2301                 252.746  -     31   +     32       False
# background_yield_0.2301             5301.27  -     77   +     78       False
# frac_Mbc_bkg1_0.2301                0.40869  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.2301             0.44571  -  0.044   +  0.043       False
# True
# Iteration 79 - Signal Yield: 252.74567723078562 ± 31.0774517535017
# Running iteration 80/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7104                 246.549  -     31   +     31       False
# background_yield_0.7104             5307.38  -     77   +     78       False
# frac_Mbc_bkg1_0.7104               0.410808  -  0.017   +  0.017       False
# frac_deltaE_bkg1_0.7104            0.448174  -  0.044   +  0.043       False
# True
# Iteration 80 - Signal Yield: 246.54943072583225 ± 30.995482536555066
# Running iteration 81/300...
# 100
# 5454
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6023                 236.773  -     31   +     31       False
# background_yield_0.6023              5316.8  -     77   +     79       False
# frac_Mbc_bkg1_0.6023               0.413476  -  0.017   +  0.016       False
# frac_deltaE_bkg1_0.6023            0.449879  -  0.044   +  0.043       False
# True
# Iteration 81 - Signal Yield: 236.77310930670606 ± 30.896122699128806
# Running iteration 82/300...
# 100
# 5454
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_666993/3232498049.py in <module>
#      44         pd.concat([Signal_total, Background_total]), 0.5, 0.5, 100, 100
#      45     )
# ---> 46     result.errors(name='errors')
#      47     print(result.params)
#      48     print(result.valid)
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     574                 'in a future version' if date is None else ('after %s' % date),
#     575                 instructions)
# --> 576       return func(*args, **kwargs)
#     577
#     578     doc = _add_deprecated_arg_notice_to_docstring(
#
# ~/.local/lib/python3.8/site-packages/zfit/minimizers/fitresult.py in errors(self, params, method, name, cl, sigma, error_name)
#    1382
#    1383             if uncached_params:
# -> 1384                 error_dict, new_result = self._error(
#    1385                     params=uncached_params, method=method, cl=cl
#    1386                 )
#
# ~/.local/lib/python3.8/site-packages/zfit/minimizers/fitresult.py in _error(self, params, method, cl)
#    1409                     f"The following method is not a valid, implemented method: {method}"
#    1410                 )
# -> 1411         return method(result=self, params=params, cl=cl)
#    1412
#    1413     def covariance(
#
# ~/.local/lib/python3.8/site-packages/zfit/minimizers/fitresult.py in _minos_minuit(result, params, cl)
#     157
#     158     try:
# --> 159         minuit_minimizer.minos(*(p.name for p in params), cl=cl)
#     160         # Minuit seems very ustable on this and the call can fail after a few trials
#     161     except RuntimeError as error:
#
# ~/.local/lib/python3.8/site-packages/iminuit/minuit.py in minos(self, cl, ncall, *parameters)
#    1475
#    1476         if not self.valid:
# -> 1477             raise RuntimeError(f"Function minimum is not valid: {repr(self._fmin)}")
#    1478
#    1479         if len(parameters) == 0:
#
# RuntimeError: Function minimum is not valid: <FMin algorithm='Migrad' edm=0.00046339169646177883 edm_goal=0.001 errordef=0.5 fval=-5004.223156067427 has_accurate_covar=False has_covariance=True has_made_posdef_covar=False has_parameters_at_limit=False has_posdef_covar=False has_reached_call_limit=True has_valid_parameters=False hesse_failed=True is_above_max_edm=False is_valid=False nfcn=824 ngrad=0 reduced_chi2=nan time=3.9754356150515378>

# %% [markdown]
# ## 75

# %%
# Number of iterations
num_iterations = 300

# List to store the signal yields and their errors from each iteration
signal_yields_and_errors = []

for i in range(num_iterations):
    print(f"Running iteration {i + 1}/{num_iterations}...")

    # Process the Monte Carlo data
    mc_mu_signal, mc_mu_only_signal, mc_mu_scf, mc_mu_bkg, mc_mu_signal_weight, mc_mu_only_signal_weight, mc_mu_scf_weight, mc_mu_bkg_weight = process_MC_data_combined(
        file_signal_mu_Bppi0,file_bkg_mu_Bppi0, 'mu', '521', 'pi0', 'mumu', 4, 'rec521', 'weights', 75
    )

    # Fit models for signal, SCF, and background
    Mbc_only_signal_cb_fixed = fit_fixed_without_weight('Mbc', 'mu', 'signal', mc_mu_only_signal["Mbc"], 'cb', 0)
    deltaE_only_signal_cb_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'signal', mc_mu_only_signal["deltaE"],  'cb_gauss', 0)

    Mbc_scf_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'scf', mc_mu_scf["Mbc"], 'argus_gauss', 0)
    deltaE_scf_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'scf', mc_mu_scf["deltaE"], 'poly_gauss', 0)

    Mbc_bkg_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'bkg', mc_mu_bkg["Mbc"], 'argus_gauss', 0)
    deltaE_bkg_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'bkg',  mc_mu_bkg["deltaE"],  'poly', 0)

    # Combine signal and background data
    Signal_Mbc = mc_mu_only_signal["Mbc"]
    Signal_deltaE = mc_mu_only_signal["deltaE"]
    Background_Mbc = pd.concat([mc_mu_scf["Mbc"], mc_mu_bkg["Mbc"]])
    Background_deltaE = pd.concat([mc_mu_scf["deltaE"], mc_mu_bkg["deltaE"]])

    Signal_total = pd.concat([Signal_Mbc, Signal_deltaE], axis=1)
    Background_total = pd.concat([Background_Mbc, Background_deltaE], axis=1)

    MC_signal=len(Signal_total)
    MC_bkg=len(Background_total)

    print(MC_signal)
    print(MC_bkg)
    # Fit the extended model and get the result
    Mbc_signal_pdf, deltaE_signal_pdf, Mbc_background_pdf, deltaE_background_pdf, signal_extended, background_extended, total_model, result = fit_extended_model_scf_without_weight(
        Mbc_only_signal_cb_fixed, Mbc_scf_argus_gauss_fixed, deltaE_only_signal_cb_gauss_fixed, deltaE_scf_poly_gauss_fixed,
        Mbc_bkg_argus_gauss_fixed, deltaE_bkg_poly_gauss_fixed,
        pd.concat([Signal_total, Background_total]), 0.5, 0.5, 100, 100
    )
    result.errors(name='errors')
    print(result.params)
    print(result.valid)

    # Retrieve and store the signal yield and its error
    signal_yield = result.params[signal_extended.get_yield()]['value']
    signal_yield_errors = result.params[signal_extended.get_yield()]['errors']
    signal_yield_error = (signal_yield_errors['upper'] - signal_yield_errors['lower']) / 2

    # Store the signal yield and error as a tuple in the list
    signal_yields_and_errors.append((MC_signal,MC_bkg,signal_yield, signal_yield_error))

    print(f"Iteration {i + 1} - Signal Yield: {signal_yield} ± {signal_yield_error}")

# Convert the list to a DataFrame with two columns: 'Signal_Yield' and 'Signal_Yield_Error'
signal_yields_df = pd.DataFrame(signal_yields_and_errors, columns=['MC_signal','MC_bkg','Signal_Yield', 'Signal_Yield_Error'])


# Save the DataFrame to a CSV file
signal_yields_df.to_csv('Bppi0_q2reg4_decay_mumu_signal_yields_and_errors_75.csv', index=False)

print("Signal yields and errors saved to 'Bppi0_q2reg4_decay_mumu_signal_yields_and_errors_75.csv'")

# %% [markdown]
# ## 50

# %%
# Number of iterations
num_iterations = 300

# List to store the signal yields and their errors from each iteration
signal_yields_and_errors = []

for i in range(num_iterations):
    print(f"Running iteration {i + 1}/{num_iterations}...")

    # Process the Monte Carlo data
    mc_mu_signal, mc_mu_only_signal, mc_mu_scf, mc_mu_bkg, mc_mu_signal_weight, mc_mu_only_signal_weight, mc_mu_scf_weight, mc_mu_bkg_weight = process_MC_data_combined(
        file_signal_mu_Bppi0,file_bkg_mu_Bppi0, 'mu', '521', 'pi0', 'mumu', 4, 'rec521', 'weights', 50
    )

    # Fit models for signal, SCF, and background
    Mbc_only_signal_cb_fixed = fit_fixed_without_weight('Mbc', 'mu', 'signal', mc_mu_only_signal["Mbc"], 'cb', 0)
    deltaE_only_signal_cb_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'signal', mc_mu_only_signal["deltaE"],  'cb_gauss', 0)

    Mbc_scf_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'scf', mc_mu_scf["Mbc"], 'argus_gauss', 0)
    deltaE_scf_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'scf', mc_mu_scf["deltaE"], 'poly_gauss', 0)

    Mbc_bkg_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'bkg', mc_mu_bkg["Mbc"], 'argus_gauss', 0)
    deltaE_bkg_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'bkg',  mc_mu_bkg["deltaE"],  'poly', 0)

    # Combine signal and background data
    Signal_Mbc = mc_mu_only_signal["Mbc"]
    Signal_deltaE = mc_mu_only_signal["deltaE"]
    Background_Mbc = pd.concat([mc_mu_scf["Mbc"], mc_mu_bkg["Mbc"]])
    Background_deltaE = pd.concat([mc_mu_scf["deltaE"], mc_mu_bkg["deltaE"]])

    Signal_total = pd.concat([Signal_Mbc, Signal_deltaE], axis=1)
    Background_total = pd.concat([Background_Mbc, Background_deltaE], axis=1)

    MC_signal=len(Signal_total)
    MC_bkg=len(Background_total)

    print(MC_signal)
    print(MC_bkg)
    # Fit the extended model and get the result
    Mbc_signal_pdf, deltaE_signal_pdf, Mbc_background_pdf, deltaE_background_pdf, signal_extended, background_extended, total_model, result = fit_extended_model_scf_without_weight(
        Mbc_only_signal_cb_fixed, Mbc_scf_argus_gauss_fixed, deltaE_only_signal_cb_gauss_fixed, deltaE_scf_poly_gauss_fixed,
        Mbc_bkg_argus_gauss_fixed, deltaE_bkg_poly_gauss_fixed,
        pd.concat([Signal_total, Background_total]), 0.5, 0.5, 100, 100
    )
    result.errors(name='errors')
    print(result.params)
    print(result.valid)

    # Retrieve and store the signal yield and its error
    signal_yield = result.params[signal_extended.get_yield()]['value']
    signal_yield_errors = result.params[signal_extended.get_yield()]['errors']
    signal_yield_error = (signal_yield_errors['upper'] - signal_yield_errors['lower']) / 2

    # Store the signal yield and error as a tuple in the list
    signal_yields_and_errors.append((MC_signal,MC_bkg,signal_yield, signal_yield_error))

    print(f"Iteration {i + 1} - Signal Yield: {signal_yield} ± {signal_yield_error}")

# Convert the list to a DataFrame with two columns: 'Signal_Yield' and 'Signal_Yield_Error'
signal_yields_df = pd.DataFrame(signal_yields_and_errors, columns=['MC_signal','MC_bkg','Signal_Yield', 'Signal_Yield_Error'])

# Save the DataFrame to a CSV file
signal_yields_df.to_csv('Bppi0_q2reg4_decay_mumu_signal_yields_and_errors_50.csv', index=False)

print("Signal yields and errors saved to 'Bppi0_q2reg4_decay_mumu_signal_yields_and_errors_50.csv'")

# %% [markdown]
# ## 25

# %%
# Number of iterations
num_iterations = 300

# List to store the signal yields and their errors from each iteration
signal_yields_and_errors = []

for i in range(num_iterations):
    print(f"Running iteration {i + 1}/{num_iterations}...")

    # Process the Monte Carlo data
    mc_mu_signal, mc_mu_only_signal, mc_mu_scf, mc_mu_bkg, mc_mu_signal_weight, mc_mu_only_signal_weight, mc_mu_scf_weight, mc_mu_bkg_weight = process_MC_data_combined(
        file_signal_mu_Bppi0,file_bkg_mu_Bppi0, 'mu', '521', 'pi0', 'mumu', 4, 'rec521', 'weights', 25
    )

    # Fit models for signal, SCF, and background
    Mbc_only_signal_cb_fixed = fit_fixed_without_weight('Mbc', 'mu', 'signal', mc_mu_only_signal["Mbc"], 'cb', 0)
    deltaE_only_signal_cb_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'signal', mc_mu_only_signal["deltaE"],  'cb_gauss', 0)

    Mbc_scf_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'scf', mc_mu_scf["Mbc"], 'argus_gauss', 0)
    deltaE_scf_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'scf', mc_mu_scf["deltaE"], 'poly_gauss', 0)

    Mbc_bkg_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'bkg', mc_mu_bkg["Mbc"], 'argus_gauss', 0)
    deltaE_bkg_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'bkg',  mc_mu_bkg["deltaE"],  'poly', 0)

    # Combine signal and background data
    Signal_Mbc = mc_mu_only_signal["Mbc"]
    Signal_deltaE = mc_mu_only_signal["deltaE"]
    Background_Mbc = pd.concat([mc_mu_scf["Mbc"], mc_mu_bkg["Mbc"]])
    Background_deltaE = pd.concat([mc_mu_scf["deltaE"], mc_mu_bkg["deltaE"]])

    Signal_total = pd.concat([Signal_Mbc, Signal_deltaE], axis=1)
    Background_total = pd.concat([Background_Mbc, Background_deltaE], axis=1)

    MC_signal=len(Signal_total)
    MC_bkg=len(Background_total)

    print(MC_signal)
    print(MC_bkg)
    # Fit the extended model and get the result
    Mbc_signal_pdf, deltaE_signal_pdf, Mbc_background_pdf, deltaE_background_pdf, signal_extended, background_extended, total_model, result = fit_extended_model_scf_without_weight(
        Mbc_only_signal_cb_fixed, Mbc_scf_argus_gauss_fixed, deltaE_only_signal_cb_gauss_fixed, deltaE_scf_poly_gauss_fixed,
        Mbc_bkg_argus_gauss_fixed, deltaE_bkg_poly_gauss_fixed,
        pd.concat([Signal_total, Background_total]), 0.5, 0.5, 100, 100
    )
    result.errors(name='errors')
    print(result.params)
    print(result.valid)

    # Retrieve and store the signal yield and its error
    signal_yield = result.params[signal_extended.get_yield()]['value']
    signal_yield_errors = result.params[signal_extended.get_yield()]['errors']
    signal_yield_error = (signal_yield_errors['upper'] - signal_yield_errors['lower']) / 2

    # Store the signal yield and error as a tuple in the list
    signal_yields_and_errors.append((MC_signal,MC_bkg,signal_yield, signal_yield_error))

    print(f"Iteration {i + 1} - Signal Yield: {signal_yield} ± {signal_yield_error}")

# Convert the list to a DataFrame with two columns: 'Signal_Yield' and 'Signal_Yield_Error'
signal_yields_df = pd.DataFrame(signal_yields_and_errors, columns=['MC_signal','MC_bkg','Signal_Yield', 'Signal_Yield_Error'])


# Save the DataFrame to a CSV file
signal_yields_df.to_csv('Bppi0_q2reg4_decay_mumu_signal_yields_and_errors_25.csv', index=False)

print("Signal yields and errors saved to 'Bppi0_q2reg4_decay_mumu_signal_yields_and_errors_25.csv'")

# %% [markdown]
# ## 10

# %%
# Number of iterations
num_iterations = 300

# List to store the signal yields and their errors from each iteration
signal_yields_and_errors = []

for i in range(num_iterations):
    print(f"Running iteration {i + 1}/{num_iterations}...")

    # Process the Monte Carlo data
    mc_mu_signal, mc_mu_only_signal, mc_mu_scf, mc_mu_bkg, mc_mu_signal_weight, mc_mu_only_signal_weight, mc_mu_scf_weight, mc_mu_bkg_weight = process_MC_data_combined(
        file_signal_mu_Bppi0,file_bkg_mu_Bppi0, 'mu', '521', 'pi0', 'mumu', 4, 'rec521', 'weights', 10
    )

    # Fit models for signal, SCF, and background
    Mbc_only_signal_cb_fixed = fit_fixed_without_weight('Mbc', 'mu', 'signal', mc_mu_only_signal["Mbc"], 'cb', 0)
    deltaE_only_signal_cb_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'signal', mc_mu_only_signal["deltaE"],  'cb_gauss', 0)

    Mbc_scf_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'scf', mc_mu_scf["Mbc"], 'argus_gauss', 0)
    deltaE_scf_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'scf', mc_mu_scf["deltaE"], 'poly_gauss', 0)

    Mbc_bkg_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'bkg', mc_mu_bkg["Mbc"], 'argus_gauss', 0)
    deltaE_bkg_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'bkg',  mc_mu_bkg["deltaE"],  'poly', 0)

    # Combine signal and background data
    Signal_Mbc = mc_mu_only_signal["Mbc"]
    Signal_deltaE = mc_mu_only_signal["deltaE"]
    Background_Mbc = pd.concat([mc_mu_scf["Mbc"], mc_mu_bkg["Mbc"]])
    Background_deltaE = pd.concat([mc_mu_scf["deltaE"], mc_mu_bkg["deltaE"]])

    Signal_total = pd.concat([Signal_Mbc, Signal_deltaE], axis=1)
    Background_total = pd.concat([Background_Mbc, Background_deltaE], axis=1)

    MC_signal=len(Signal_total)
    MC_bkg=len(Background_total)

    print(MC_signal)
    print(MC_bkg)
    # Fit the extended model and get the result
    Mbc_signal_pdf, deltaE_signal_pdf, Mbc_background_pdf, deltaE_background_pdf, signal_extended, background_extended, total_model, result = fit_extended_model_scf_without_weight(
        Mbc_only_signal_cb_fixed, Mbc_scf_argus_gauss_fixed, deltaE_only_signal_cb_gauss_fixed, deltaE_scf_poly_gauss_fixed,
        Mbc_bkg_argus_gauss_fixed, deltaE_bkg_poly_gauss_fixed,
        pd.concat([Signal_total, Background_total]), 0.5, 0.5, 100, 100
    )
    result.errors(name='errors')
    print(result.params)
    print(result.valid)

    # Retrieve and store the signal yield and its error
    signal_yield = result.params[signal_extended.get_yield()]['value']
    signal_yield_errors = result.params[signal_extended.get_yield()]['errors']
    signal_yield_error = (signal_yield_errors['upper'] - signal_yield_errors['lower']) / 2

    # Store the signal yield and error as a tuple in the list
    signal_yields_and_errors.append((MC_signal,MC_bkg,signal_yield, signal_yield_error))

    print(f"Iteration {i + 1} - Signal Yield: {signal_yield} ± {signal_yield_error}")

# Convert the list to a DataFrame with two columns: 'Signal_Yield' and 'Signal_Yield_Error'
signal_yields_df = pd.DataFrame(signal_yields_and_errors, columns=['MC_signal','MC_bkg','Signal_Yield', 'Signal_Yield_Error'])


# Save the DataFrame to a CSV file
signal_yields_df.to_csv('Bppi0_q2reg4_decay_mumu_signal_yields_and_errors_10.csv', index=False)

print("Signal yields and errors saved to 'Bppi0_q2reg4_decay_mumu_signal_yields_and_errors_10.csv'")

# %% [markdown]
# ## 5

# %%
# Number of iterations
num_iterations = 300

# List to store the signal yields and their errors from each iteration
signal_yields_and_errors = []

for i in range(num_iterations):
    print(f"Running iteration {i + 1}/{num_iterations}...")

    # Process the Monte Carlo data
    mc_mu_signal, mc_mu_only_signal, mc_mu_scf, mc_mu_bkg, mc_mu_signal_weight, mc_mu_only_signal_weight, mc_mu_scf_weight, mc_mu_bkg_weight = process_MC_data_combined(
        file_signal_mu_Bppi0,file_bkg_mu_Bppi0, 'mu', '521', 'pi0', 'mumu', 4, 'rec521', 'weights', 5
    )

    # Fit models for signal, SCF, and background
    Mbc_only_signal_cb_fixed = fit_fixed_without_weight('Mbc', 'mu', 'signal', mc_mu_only_signal["Mbc"], 'cb', 0)
    deltaE_only_signal_cb_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'signal', mc_mu_only_signal["deltaE"],  'cb_gauss', 0)

    Mbc_scf_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'scf', mc_mu_scf["Mbc"], 'argus_gauss', 0)
    deltaE_scf_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'scf', mc_mu_scf["deltaE"], 'poly_gauss', 0)

    Mbc_bkg_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'bkg', mc_mu_bkg["Mbc"], 'argus_gauss', 0)
    deltaE_bkg_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'bkg',  mc_mu_bkg["deltaE"],  'poly', 0)

    # Combine signal and background data
    Signal_Mbc = mc_mu_only_signal["Mbc"]
    Signal_deltaE = mc_mu_only_signal["deltaE"]
    Background_Mbc = pd.concat([mc_mu_scf["Mbc"], mc_mu_bkg["Mbc"]])
    Background_deltaE = pd.concat([mc_mu_scf["deltaE"], mc_mu_bkg["deltaE"]])

    Signal_total = pd.concat([Signal_Mbc, Signal_deltaE], axis=1)
    Background_total = pd.concat([Background_Mbc, Background_deltaE], axis=1)

    MC_signal=len(Signal_total)
    MC_bkg=len(Background_total)

    print(MC_signal)
    print(MC_bkg)
    # Fit the extended model and get the result
    Mbc_signal_pdf, deltaE_signal_pdf, Mbc_background_pdf, deltaE_background_pdf, signal_extended, background_extended, total_model, result = fit_extended_model_scf_without_weight(
        Mbc_only_signal_cb_fixed, Mbc_scf_argus_gauss_fixed, deltaE_only_signal_cb_gauss_fixed, deltaE_scf_poly_gauss_fixed,
        Mbc_bkg_argus_gauss_fixed, deltaE_bkg_poly_gauss_fixed,
        pd.concat([Signal_total, Background_total]), 0.5, 0.5, 100, 100
    )
    result.errors(name='errors')
    print(result.params)
    print(result.valid)

    # Retrieve and store the signal yield and its error
    signal_yield = result.params[signal_extended.get_yield()]['value']
    signal_yield_errors = result.params[signal_extended.get_yield()]['errors']
    signal_yield_error = (signal_yield_errors['upper'] - signal_yield_errors['lower']) / 2

    # Store the signal yield and error as a tuple in the list
    signal_yields_and_errors.append((MC_signal,MC_bkg,signal_yield, signal_yield_error))

    print(f"Iteration {i + 1} - Signal Yield: {signal_yield} ± {signal_yield_error}")

# Convert the list to a DataFrame with two columns: 'Signal_Yield' and 'Signal_Yield_Error'
signal_yields_df = pd.DataFrame(signal_yields_and_errors, columns=['MC_signal','MC_bkg','Signal_Yield', 'Signal_Yield_Error'])


# Save the DataFrame to a CSV file
signal_yields_df.to_csv('Bppi0_q2reg4_decay_mumu_signal_yields_and_errors_5.csv', index=False)

print("Signal yields and errors saved to 'Bppi0_q2reg4_decay_mumu_signal_yields_and_errors_5.csv'")

# %% [markdown]
# ## 2

# %%
# Number of iterations
num_iterations = 300

# List to store the signal yields and their errors from each iteration
signal_yields_and_errors = []

for i in range(num_iterations):
    print(f"Running iteration {i + 1}/{num_iterations}...")

    # Process the Monte Carlo data
    mc_mu_signal, mc_mu_only_signal, mc_mu_scf, mc_mu_bkg, mc_mu_signal_weight, mc_mu_only_signal_weight, mc_mu_scf_weight, mc_mu_bkg_weight = process_MC_data_combined(
        file_signal_mu_Bppi0,file_bkg_mu_Bppi0, 'mu', '521', 'pi0', 'mumu', 4, 'rec521', 'weights', 2
    )

    # Fit models for signal, SCF, and background
    Mbc_only_signal_cb_fixed = fit_fixed_without_weight('Mbc', 'mu', 'signal', mc_mu_only_signal["Mbc"], 'cb', 0)
    deltaE_only_signal_cb_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'signal', mc_mu_only_signal["deltaE"],  'cb_gauss', 0)

    Mbc_scf_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'scf', mc_mu_scf["Mbc"], 'argus_gauss', 0)
    deltaE_scf_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'scf', mc_mu_scf["deltaE"], 'poly_gauss', 0)

    Mbc_bkg_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'bkg', mc_mu_bkg["Mbc"], 'argus_gauss', 0)
    deltaE_bkg_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'bkg',  mc_mu_bkg["deltaE"],  'poly', 0)

    # Combine signal and background data
    Signal_Mbc = mc_mu_only_signal["Mbc"]
    Signal_deltaE = mc_mu_only_signal["deltaE"]
    Background_Mbc = pd.concat([mc_mu_scf["Mbc"], mc_mu_bkg["Mbc"]])
    Background_deltaE = pd.concat([mc_mu_scf["deltaE"], mc_mu_bkg["deltaE"]])

    Signal_total = pd.concat([Signal_Mbc, Signal_deltaE], axis=1)
    Background_total = pd.concat([Background_Mbc, Background_deltaE], axis=1)

    MC_signal=len(Signal_total)
    MC_bkg=len(Background_total)

    print(MC_signal)
    print(MC_bkg)
    # Fit the extended model and get the result
    Mbc_signal_pdf, deltaE_signal_pdf, Mbc_background_pdf, deltaE_background_pdf, signal_extended, background_extended, total_model, result = fit_extended_model_scf_without_weight(
        Mbc_only_signal_cb_fixed, Mbc_scf_argus_gauss_fixed, deltaE_only_signal_cb_gauss_fixed, deltaE_scf_poly_gauss_fixed,
        Mbc_bkg_argus_gauss_fixed, deltaE_bkg_poly_gauss_fixed,
        pd.concat([Signal_total, Background_total]), 0.5, 0.5, 100, 100
    )
    result.errors(name='errors')
    print(result.params)
    print(result.valid)

    # Retrieve and store the signal yield and its error
    signal_yield = result.params[signal_extended.get_yield()]['value']
    signal_yield_errors = result.params[signal_extended.get_yield()]['errors']
    signal_yield_error = (signal_yield_errors['upper'] - signal_yield_errors['lower']) / 2

    # Store the signal yield and error as a tuple in the list
    signal_yields_and_errors.append((MC_signal,MC_bkg,signal_yield, signal_yield_error))

    print(f"Iteration {i + 1} - Signal Yield: {signal_yield} ± {signal_yield_error}")

# Convert the list to a DataFrame with two columns: 'Signal_Yield' and 'Signal_Yield_Error'
signal_yields_df = pd.DataFrame(signal_yields_and_errors, columns=['MC_signal','MC_bkg','Signal_Yield', 'Signal_Yield_Error'])


# Save the DataFrame to a CSV file
signal_yields_df.to_csv('Bppi0_q2reg4_decay_mumu_signal_yields_and_errors_2.csv', index=False)

print("Signal yields and errors saved to 'Bppi0_q2reg4_decay_mumu_signal_yields_and_errors_2.csv'")

# %% [markdown]
# ## 0

# %%
# Number of iterations
num_iterations = 300

# List to store the signal yields and their errors from each iteration
signal_yields_and_errors = []

for i in range(num_iterations):
    print(f"Running iteration {i + 1}/{num_iterations}...")

    # Process the Monte Carlo data
    mc_mu_signal, mc_mu_only_signal, mc_mu_scf, mc_mu_bkg, mc_mu_signal_weight, mc_mu_only_signal_weight, mc_mu_scf_weight, mc_mu_bkg_weight = process_MC_data_combined(
        file_signal_mu_Bppi0,file_bkg_mu_Bppi0, 'mu', '521', 'pi0', 'mumu', 4, 'rec521', 'weights', 0
    )

    # Fit models for signal, SCF, and background
    Mbc_only_signal_cb_fixed = fit_fixed_without_weight('Mbc', 'mu', 'signal', mc_mu_only_signal["Mbc"], 'cb', 0)
    deltaE_only_signal_cb_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'signal', mc_mu_only_signal["deltaE"],  'cb_gauss', 0)

    Mbc_scf_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'scf', mc_mu_scf["Mbc"], 'argus_gauss', 0)
    deltaE_scf_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'scf', mc_mu_scf["deltaE"], 'poly_gauss', 0)

    Mbc_bkg_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'mu', 'bkg', mc_mu_bkg["Mbc"], 'argus_gauss', 0)
    deltaE_bkg_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'mu', 'bkg',  mc_mu_bkg["deltaE"],  'poly', 0)

    # Combine signal and background data
    Signal_Mbc = mc_mu_only_signal["Mbc"]
    Signal_deltaE = mc_mu_only_signal["deltaE"]
    Background_Mbc = pd.concat([mc_mu_scf["Mbc"], mc_mu_bkg["Mbc"]])
    Background_deltaE = pd.concat([mc_mu_scf["deltaE"], mc_mu_bkg["deltaE"]])

    Signal_total = pd.concat([Signal_Mbc, Signal_deltaE], axis=1)
    Background_total = pd.concat([Background_Mbc, Background_deltaE], axis=1)

    MC_signal=len(Signal_total)
    MC_bkg=len(Background_total)

    print(MC_signal)
    print(MC_bkg)
    # Fit the extended model and get the result
    Mbc_signal_pdf, deltaE_signal_pdf, Mbc_background_pdf, deltaE_background_pdf, signal_extended, background_extended, total_model, result = fit_extended_model_scf_without_weight(
        Mbc_only_signal_cb_fixed, Mbc_scf_argus_gauss_fixed, deltaE_only_signal_cb_gauss_fixed, deltaE_scf_poly_gauss_fixed,
        Mbc_bkg_argus_gauss_fixed, deltaE_bkg_poly_gauss_fixed,
        pd.concat([Signal_total, Background_total]), 0.5, 0.5, 100, 100
    )
    result.errors(name='errors')
    print(result.params)
    print(result.valid)

    # Retrieve and store the signal yield and its error
    signal_yield = result.params[signal_extended.get_yield()]['value']
    signal_yield_errors = result.params[signal_extended.get_yield()]['errors']
    signal_yield_error = (signal_yield_errors['upper'] - signal_yield_errors['lower']) / 2

    # Store the signal yield and error as a tuple in the list
    signal_yields_and_errors.append((MC_signal,MC_bkg,signal_yield, signal_yield_error))

    print(f"Iteration {i + 1} - Signal Yield: {signal_yield} ± {signal_yield_error}")

# Convert the list to a DataFrame with two columns: 'Signal_Yield' and 'Signal_Yield_Error'
signal_yields_df = pd.DataFrame(signal_yields_and_errors, columns=['MC_signal','MC_bkg','Signal_Yield', 'Signal_Yield_Error'])


# Save the DataFrame to a CSV file
signal_yields_df.to_csv('Bppi0_q2reg4_decay_mumu_signal_yields_and_errors_0.csv', index=False)

print("Signal yields and errors saved to 'Bppi0_q2reg4_decay_mumu_signal_yields_and_errors_0.csv'")
