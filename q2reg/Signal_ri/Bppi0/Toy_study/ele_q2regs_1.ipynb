# %%
import pandas as pd
import uproot
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import crystalball
from scipy.optimize import curve_fit,Bounds
from scipy.integrate import simps
import zfit_physics as zphysics
import zfit
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.pyplot as plt
import mplhep
import uncertainties 
from uncertainties import ufloat
import tensorflow as tf

plt.style.use('belle2')
#%jsroot on


# %run /afs/desy.de/user/j/jipatel/MT/MC_fit/Files_After_Acceptance/Signal_Background_thesis_final/Function.ipynb
# Out:
# 2024-09-04 09:58:41.878533: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-04 09:58:41.910709: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-04 09:58:41.911477: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-04 09:58:42.726172: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /afs/desy.de/user/j/jipatel/.local/lib/python3.8/site-packages/zfit/__init__.py:63: UserWarning: TensorFlow warnings are by default suppressed by zfit. In order to show them, set the environment variable ZFIT_DISABLE_TF_WARNINGS=0. In order to suppress the TensorFlow warnings AND this warning, set ZFIT_DISABLE_TF_WARNINGS=1.
#   warnings.warn(

# %% [markdown]
# ## 200

# %%
# Number of iterations
num_iterations = 300

# List to store the signal yields and their errors from each iteration
signal_yields_and_errors = []

for i in range(num_iterations):
    print(f"Running iteration {i + 1}/{num_iterations}...")

    # Process the Monte Carlo data
    mc_ele_signal, mc_ele_only_signal, mc_ele_scf, mc_ele_bkg, mc_ele_signal_weight, mc_ele_only_signal_weight, mc_ele_scf_weight, mc_ele_bkg_weight = process_MC_data_combined(
        file_signal_ele_Bppi0,file_bkg_ele_Bppi0, 'ele', '521', 'pi0', 'ee', 1, 'rec521', 'weights', 200
    )

    # Fit models for signal, SCF, and background
    Mbc_only_signal_cb_fixed = fit_fixed_without_weight('Mbc', 'ele', 'signal', mc_ele_only_signal["Mbc"],  'cb', 0)
    deltaE_only_signal_cb_gauss_fixed = fit_fixed_without_weight('deltaE', 'ele', 'signal', mc_ele_only_signal["deltaE"], 'cb_gauss', 0)

    Mbc_scf_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'ele', 'scf', mc_ele_scf["Mbc"],  'argus_gauss', 0)
    deltaE_scf_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'ele', 'scf', mc_ele_scf["deltaE"], 'poly_gauss', 0)

    Mbc_bkg_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'ele', 'bkg', mc_ele_bkg["Mbc"],  'argus_gauss', 0)
    deltaE_bkg_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'ele', 'bkg', mc_ele_bkg["deltaE"], 'poly', 0)

    # Combine signal and background data
    Signal_Mbc = mc_ele_only_signal["Mbc"]
    Signal_deltaE = mc_ele_only_signal["deltaE"]
    Background_Mbc = pd.concat([mc_ele_scf["Mbc"], mc_ele_bkg["Mbc"]])
    Background_deltaE = pd.concat([mc_ele_scf["deltaE"], mc_ele_bkg["deltaE"]])

    Signal_total = pd.concat([Signal_Mbc, Signal_deltaE], axis=1)
    Background_total = pd.concat([Background_Mbc, Background_deltaE], axis=1)

    MC_signal=len(Signal_total)
    MC_bkg=len(Background_total)

    print(MC_signal)
    print(MC_bkg)


    # Fit the extended model and get the result
    Mbc_signal_pdf, deltaE_signal_pdf, Mbc_background_pdf, deltaE_background_pdf, signal_extended, background_extended, total_model, result = fit_extended_model_scf_without_weight(
        Mbc_only_signal_cb_fixed, Mbc_scf_argus_gauss_fixed, deltaE_only_signal_cb_gauss_fixed, deltaE_scf_poly_gauss_fixed,
        Mbc_bkg_argus_gauss_fixed, deltaE_bkg_poly_gauss_fixed,
        pd.concat([Signal_total, Background_total]), 0.5, 0.5, 100, 100
    )
    result.errors(name='errors')
    print(result.params)
    print(result.valid)

    # Retrieve and store the signal yield and its error
    signal_yield = result.params[signal_extended.get_yield()]['value']
    signal_yield_errors = result.params[signal_extended.get_yield()]['errors']
    signal_yield_error = (signal_yield_errors['upper'] - signal_yield_errors['lower']) / 2

    # Store the signal yield and error as a tuple in the list
    signal_yields_and_errors.append((MC_signal,MC_bkg,signal_yield, signal_yield_error))

    print(f"Iteration {i + 1} - Signal Yield: {signal_yield} ± {signal_yield_error}")

# Convert the list to a DataFrame with two columns: 'Signal_Yield' and 'Signal_Yield_Error'
signal_yields_df = pd.DataFrame(signal_yields_and_errors, columns=['MC_signal','MC_bkg','Signal_Yield', 'Signal_Yield_Error'])

# Save the DataFrame to a CSV file
signal_yields_df.to_csv('Bppi0_q2reg1_decay_ee_signal_yields_and_errors_200.csv', index=False)

print("Signal yields and errors saved to 'Bppi0_q2reg1_decay_ee_signal_yields_and_errors_200.csv'")
# Out:
# Running iteration 1/300...

# %% [markdown]
# ## 150

# %%
# Number of iterations
num_iterations = 300

# List to store the signal yields and their errors from each iteration
signal_yields_and_errors = []

for i in range(num_iterations):
    print(f"Running iteration {i + 1}/{num_iterations}...")

    # Process the Monte Carlo data
    mc_ele_signal, mc_ele_only_signal, mc_ele_scf, mc_ele_bkg, mc_ele_signal_weight, mc_ele_only_signal_weight, mc_ele_scf_weight, mc_ele_bkg_weight = process_MC_data_combined(
        file_signal_ele_Bppi0,file_bkg_ele_Bppi0, 'ele', '521', 'pi0', 'ee', 1, 'rec521', 'weights', 150
    )

    # Fit models for signal, SCF, and background
    Mbc_only_signal_cb_fixed = fit_fixed_without_weight('Mbc', 'ele', 'signal', mc_ele_only_signal["Mbc"], 'cb', 0)
    deltaE_only_signal_cb_gauss_fixed = fit_fixed_without_weight('deltaE', 'ele', 'signal', mc_ele_only_signal["deltaE"],  'cb_gauss', 0)

    Mbc_scf_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'ele', 'scf', mc_ele_scf["Mbc"], 'argus_gauss', 0)
    deltaE_scf_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'ele', 'scf', mc_ele_scf["deltaE"], 'poly_gauss', 0)

    Mbc_bkg_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'ele', 'bkg', mc_ele_bkg["Mbc"], 'argus_gauss', 0)
    deltaE_bkg_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'ele', 'bkg', mc_ele_bkg["deltaE"],  'poly', 0)

    # Combine signal and background data
    Signal_Mbc = mc_ele_only_signal["Mbc"]
    Signal_deltaE = mc_ele_only_signal["deltaE"]
    Background_Mbc = pd.concat([mc_ele_scf["Mbc"], mc_ele_bkg["Mbc"]])
    Background_deltaE = pd.concat([mc_ele_scf["deltaE"], mc_ele_bkg["deltaE"]])

    Signal_total = pd.concat([Signal_Mbc, Signal_deltaE], axis=1)
    Background_total = pd.concat([Background_Mbc, Background_deltaE], axis=1)

    MC_signal=len(Signal_total)
    MC_bkg=len(Background_total)

    print(MC_signal)
    print(MC_bkg)
    
    # Fit the extended model and get the result
    Mbc_signal_pdf, deltaE_signal_pdf, Mbc_background_pdf, deltaE_background_pdf, signal_extended, background_extended, total_model, result = fit_extended_model_scf_without_weight(
        Mbc_only_signal_cb_fixed, Mbc_scf_argus_gauss_fixed, deltaE_only_signal_cb_gauss_fixed, deltaE_scf_poly_gauss_fixed,
        Mbc_bkg_argus_gauss_fixed, deltaE_bkg_poly_gauss_fixed,
        pd.concat([Signal_total, Background_total]), 0.5, 0.5, 100, 100
    )
    result.errors(name='errors')
    print(result.params)
    print(result.valid)

    # Retrieve and store the signal yield and its error
    signal_yield = result.params[signal_extended.get_yield()]['value']
    signal_yield_errors = result.params[signal_extended.get_yield()]['errors']
    signal_yield_error = (signal_yield_errors['upper'] - signal_yield_errors['lower']) / 2

    # Store the signal yield and error as a tuple in the list
    signal_yields_and_errors.append((MC_signal,MC_bkg,signal_yield, signal_yield_error))

    print(f"Iteration {i + 1} - Signal Yield: {signal_yield} ± {signal_yield_error}")

# Convert the list to a DataFrame with two columns: 'Signal_Yield' and 'Signal_Yield_Error'
signal_yields_df = pd.DataFrame(signal_yields_and_errors, columns=['MC_signal','MC_bkg','Signal_Yield', 'Signal_Yield_Error'])

# Save the DataFrame to a CSV file
signal_yields_df.to_csv('Bppi0_q2reg1_decay_ee_signal_yields_and_errors_150.csv', index=False)

print("Signal yields and errors saved to 'Bppi0_q2reg1_decay_ee_signal_yields_and_errors_150.csv'")

# %% [markdown]
# ## 100

# %%
# Number of iterations
num_iterations = 300

# List to store the signal yields and their errors from each iteration
signal_yields_and_errors = []

for i in range(num_iterations):
    print(f"Running iteration {i + 1}/{num_iterations}...")

    # Process the Monte Carlo data
    mc_ele_signal, mc_ele_only_signal, mc_ele_scf, mc_ele_bkg, mc_ele_signal_weight, mc_ele_only_signal_weight, mc_ele_scf_weight, mc_ele_bkg_weight = process_MC_data_combined(
        file_signal_ele_Bppi0,file_bkg_ele_Bppi0, 'ele', '521', 'pi0', 'ee', 1, 'rec521', 'weights', 100
    )

    # Fit models for signal, SCF, and background
    Mbc_only_signal_cb_fixed = fit_fixed_without_weight('Mbc', 'ele', 'signal', mc_ele_only_signal["Mbc"], 'cb', 0)
    deltaE_only_signal_cb_gauss_fixed = fit_fixed_without_weight('deltaE', 'ele', 'signal', mc_ele_only_signal["deltaE"],  'cb_gauss', 0)

    Mbc_scf_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'ele', 'scf', mc_ele_scf["Mbc"], 'argus_gauss', 0)
    deltaE_scf_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'ele', 'scf', mc_ele_scf["deltaE"], 'poly_gauss', 0)

    Mbc_bkg_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'ele', 'bkg', mc_ele_bkg["Mbc"], 'argus_gauss', 0)
    deltaE_bkg_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'ele', 'bkg', mc_ele_bkg["deltaE"],  'poly', 0)

    # Combine signal and background data
    Signal_Mbc = mc_ele_only_signal["Mbc"]
    Signal_deltaE = mc_ele_only_signal["deltaE"]
    Background_Mbc = pd.concat([mc_ele_scf["Mbc"], mc_ele_bkg["Mbc"]])
    Background_deltaE = pd.concat([mc_ele_scf["deltaE"], mc_ele_bkg["deltaE"]])

    Signal_total = pd.concat([Signal_Mbc, Signal_deltaE], axis=1)
    Background_total = pd.concat([Background_Mbc, Background_deltaE], axis=1)

    MC_signal=len(Signal_total)
    MC_bkg=len(Background_total)

    print(MC_signal)
    print(MC_bkg)
    
    # Fit the extended model and get the result
    Mbc_signal_pdf, deltaE_signal_pdf, Mbc_background_pdf, deltaE_background_pdf, signal_extended, background_extended, total_model, result = fit_extended_model_scf_without_weight(
        Mbc_only_signal_cb_fixed, Mbc_scf_argus_gauss_fixed, deltaE_only_signal_cb_gauss_fixed, deltaE_scf_poly_gauss_fixed,
        Mbc_bkg_argus_gauss_fixed, deltaE_bkg_poly_gauss_fixed,
        pd.concat([Signal_total, Background_total]), 0.5, 0.5, 100, 100
    )
    result.errors(name='errors')
    print(result.params)
    print(result.valid)

    # Retrieve and store the signal yield and its error
    signal_yield = result.params[signal_extended.get_yield()]['value']
    signal_yield_errors = result.params[signal_extended.get_yield()]['errors']
    signal_yield_error = (signal_yield_errors['upper'] - signal_yield_errors['lower']) / 2

    # Store the signal yield and error as a tuple in the list
    signal_yields_and_errors.append((MC_signal,MC_bkg,signal_yield, signal_yield_error))

    print(f"Iteration {i + 1} - Signal Yield: {signal_yield} ± {signal_yield_error}")

# Convert the list to a DataFrame with two columns: 'Signal_Yield' and 'Signal_Yield_Error'
signal_yields_df = pd.DataFrame(signal_yields_and_errors, columns=['MC_signal','MC_bkg','Signal_Yield', 'Signal_Yield_Error'])


# Save the DataFrame to a CSV file
signal_yields_df.to_csv('Bppi0_q2reg1_decay_ee_signal_yields_and_errors_100.csv', index=False)

print("Signal yields and errors saved to 'Bppi0_q2reg1_decay_ee_signal_yields_and_errors_100.csv'")

# %% [markdown]
# ## 75

# %%
# Number of iterations
num_iterations = 300

# List to store the signal yields and their errors from each iteration
signal_yields_and_errors = []

for i in range(num_iterations):
    print(f"Running iteration {i + 1}/{num_iterations}...")

    # Process the Monte Carlo data
    mc_ele_signal, mc_ele_only_signal, mc_ele_scf, mc_ele_bkg, mc_ele_signal_weight, mc_ele_only_signal_weight, mc_ele_scf_weight, mc_ele_bkg_weight = process_MC_data_combined(
        file_signal_ele_Bppi0,file_bkg_ele_Bppi0, 'ele', '521', 'pi0', 'ee', 1, 'rec521', 'weights', 75
    )

    # Fit models for signal, SCF, and background
    Mbc_only_signal_cb_fixed = fit_fixed_without_weight('Mbc', 'ele', 'signal', mc_ele_only_signal["Mbc"], 'cb', 0)
    deltaE_only_signal_cb_gauss_fixed = fit_fixed_without_weight('deltaE', 'ele', 'signal', mc_ele_only_signal["deltaE"],  'cb_gauss', 0)

    Mbc_scf_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'ele', 'scf', mc_ele_scf["Mbc"], 'argus_gauss', 0)
    deltaE_scf_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'ele', 'scf', mc_ele_scf["deltaE"], 'poly_gauss', 0)

    Mbc_bkg_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'ele', 'bkg', mc_ele_bkg["Mbc"], 'argus_gauss', 0)
    deltaE_bkg_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'ele', 'bkg', mc_ele_bkg["deltaE"],  'poly', 0)

    # Combine signal and background data
    Signal_Mbc = mc_ele_only_signal["Mbc"]
    Signal_deltaE = mc_ele_only_signal["deltaE"]
    Background_Mbc = pd.concat([mc_ele_scf["Mbc"], mc_ele_bkg["Mbc"]])
    Background_deltaE = pd.concat([mc_ele_scf["deltaE"], mc_ele_bkg["deltaE"]])

    Signal_total = pd.concat([Signal_Mbc, Signal_deltaE], axis=1)
    Background_total = pd.concat([Background_Mbc, Background_deltaE], axis=1)

    MC_signal=len(Signal_total)
    MC_bkg=len(Background_total)

    print(MC_signal)
    print(MC_bkg)
    # Fit the extended model and get the result
    Mbc_signal_pdf, deltaE_signal_pdf, Mbc_background_pdf, deltaE_background_pdf, signal_extended, background_extended, total_model, result = fit_extended_model_scf_without_weight(
        Mbc_only_signal_cb_fixed, Mbc_scf_argus_gauss_fixed, deltaE_only_signal_cb_gauss_fixed, deltaE_scf_poly_gauss_fixed,
        Mbc_bkg_argus_gauss_fixed, deltaE_bkg_poly_gauss_fixed,
        pd.concat([Signal_total, Background_total]), 0.5, 0.5, 100, 100
    )
    result.errors(name='errors')
    print(result.params)
    print(result.valid)

    # Retrieve and store the signal yield and its error
    signal_yield = result.params[signal_extended.get_yield()]['value']
    signal_yield_errors = result.params[signal_extended.get_yield()]['errors']
    signal_yield_error = (signal_yield_errors['upper'] - signal_yield_errors['lower']) / 2

    # Store the signal yield and error as a tuple in the list
    signal_yields_and_errors.append((MC_signal,MC_bkg,signal_yield, signal_yield_error))

    print(f"Iteration {i + 1} - Signal Yield: {signal_yield} ± {signal_yield_error}")

# Convert the list to a DataFrame with two columns: 'Signal_Yield' and 'Signal_Yield_Error'
signal_yields_df = pd.DataFrame(signal_yields_and_errors, columns=['MC_signal','MC_bkg','Signal_Yield', 'Signal_Yield_Error'])


# Save the DataFrame to a CSV file
signal_yields_df.to_csv('Bppi0_q2reg1_decay_ee_signal_yields_and_errors_75.csv', index=False)

print("Signal yields and errors saved to 'Bppi0_q2reg1_decay_ee_signal_yields_and_errors_75.csv'")

# %% [markdown]
# ## 50

# %%
# Number of iterations
num_iterations = 300

# List to store the signal yields and their errors from each iteration
signal_yields_and_errors = []

for i in range(num_iterations):
    print(f"Running iteration {i + 1}/{num_iterations}...")

    # Process the Monte Carlo data
    mc_ele_signal, mc_ele_only_signal, mc_ele_scf, mc_ele_bkg, mc_ele_signal_weight, mc_ele_only_signal_weight, mc_ele_scf_weight, mc_ele_bkg_weight = process_MC_data_combined(
        file_signal_ele_Bppi0,file_bkg_ele_Bppi0, 'ele', '521', 'pi0', 'ee', 1, 'rec521', 'weights', 50
    )

    # Fit models for signal, SCF, and background
    Mbc_only_signal_cb_fixed = fit_fixed_without_weight('Mbc', 'ele', 'signal', mc_ele_only_signal["Mbc"], 'cb', 0)
    deltaE_only_signal_cb_gauss_fixed = fit_fixed_without_weight('deltaE', 'ele', 'signal', mc_ele_only_signal["deltaE"],  'cb_gauss', 0)

    Mbc_scf_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'ele', 'scf', mc_ele_scf["Mbc"], 'argus_gauss', 0)
    deltaE_scf_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'ele', 'scf', mc_ele_scf["deltaE"], 'poly_gauss', 0)

    Mbc_bkg_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'ele', 'bkg', mc_ele_bkg["Mbc"], 'argus_gauss', 0)
    deltaE_bkg_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'ele', 'bkg', mc_ele_bkg["deltaE"],  'poly', 0)

    # Combine signal and background data
    Signal_Mbc = mc_ele_only_signal["Mbc"]
    Signal_deltaE = mc_ele_only_signal["deltaE"]
    Background_Mbc = pd.concat([mc_ele_scf["Mbc"], mc_ele_bkg["Mbc"]])
    Background_deltaE = pd.concat([mc_ele_scf["deltaE"], mc_ele_bkg["deltaE"]])

    Signal_total = pd.concat([Signal_Mbc, Signal_deltaE], axis=1)
    Background_total = pd.concat([Background_Mbc, Background_deltaE], axis=1)

    MC_signal=len(Signal_total)
    MC_bkg=len(Background_total)

    print(MC_signal)
    print(MC_bkg)
    # Fit the extended model and get the result
    Mbc_signal_pdf, deltaE_signal_pdf, Mbc_background_pdf, deltaE_background_pdf, signal_extended, background_extended, total_model, result = fit_extended_model_scf_without_weight(
        Mbc_only_signal_cb_fixed, Mbc_scf_argus_gauss_fixed, deltaE_only_signal_cb_gauss_fixed, deltaE_scf_poly_gauss_fixed,
        Mbc_bkg_argus_gauss_fixed, deltaE_bkg_poly_gauss_fixed,
        pd.concat([Signal_total, Background_total]), 0.5, 0.5, 100, 100
    )
    result.errors(name='errors')
    print(result.params)
    print(result.valid)

    # Retrieve and store the signal yield and its error
    signal_yield = result.params[signal_extended.get_yield()]['value']
    signal_yield_errors = result.params[signal_extended.get_yield()]['errors']
    signal_yield_error = (signal_yield_errors['upper'] - signal_yield_errors['lower']) / 2

    # Store the signal yield and error as a tuple in the list
    signal_yields_and_errors.append((MC_signal,MC_bkg,signal_yield, signal_yield_error))

    print(f"Iteration {i + 1} - Signal Yield: {signal_yield} ± {signal_yield_error}")

# Convert the list to a DataFrame with two columns: 'Signal_Yield' and 'Signal_Yield_Error'
signal_yields_df = pd.DataFrame(signal_yields_and_errors, columns=['MC_signal','MC_bkg','Signal_Yield', 'Signal_Yield_Error'])

# Save the DataFrame to a CSV file
signal_yields_df.to_csv('Bppi0_q2reg1_decay_ee_signal_yields_and_errors_50.csv', index=False)

print("Signal yields and errors saved to 'Bppi0_q2reg1_decay_ee_signal_yields_and_errors_50.csv'")

# %% [markdown]
# ## 25

# %%
# Number of iterations
num_iterations = 300

# List to store the signal yields and their errors from each iteration
signal_yields_and_errors = []

for i in range(num_iterations):
    print(f"Running iteration {i + 1}/{num_iterations}...")

    # Process the Monte Carlo data
    mc_ele_signal, mc_ele_only_signal, mc_ele_scf, mc_ele_bkg, mc_ele_signal_weight, mc_ele_only_signal_weight, mc_ele_scf_weight, mc_ele_bkg_weight = process_MC_data_combined(
        file_signal_ele_Bppi0,file_bkg_ele_Bppi0, 'ele', '521', 'pi0', 'ee', 1, 'rec521', 'weights', 25
    )

    # Fit models for signal, SCF, and background
    Mbc_only_signal_cb_fixed = fit_fixed_without_weight('Mbc', 'ele', 'signal', mc_ele_only_signal["Mbc"], 'cb', 0)
    deltaE_only_signal_cb_gauss_fixed = fit_fixed_without_weight('deltaE', 'ele', 'signal', mc_ele_only_signal["deltaE"],  'cb_gauss', 0)

    Mbc_scf_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'ele', 'scf', mc_ele_scf["Mbc"], 'argus_gauss', 0)
    deltaE_scf_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'ele', 'scf', mc_ele_scf["deltaE"], 'poly_gauss', 0)

    Mbc_bkg_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'ele', 'bkg', mc_ele_bkg["Mbc"], 'argus_gauss', 0)
    deltaE_bkg_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'ele', 'bkg', mc_ele_bkg["deltaE"],  'poly', 0)

    # Combine signal and background data
    Signal_Mbc = mc_ele_only_signal["Mbc"]
    Signal_deltaE = mc_ele_only_signal["deltaE"]
    Background_Mbc = pd.concat([mc_ele_scf["Mbc"], mc_ele_bkg["Mbc"]])
    Background_deltaE = pd.concat([mc_ele_scf["deltaE"], mc_ele_bkg["deltaE"]])

    Signal_total = pd.concat([Signal_Mbc, Signal_deltaE], axis=1)
    Background_total = pd.concat([Background_Mbc, Background_deltaE], axis=1)

    MC_signal=len(Signal_total)
    MC_bkg=len(Background_total)

    print(MC_signal)
    print(MC_bkg)
    # Fit the extended model and get the result
    Mbc_signal_pdf, deltaE_signal_pdf, Mbc_background_pdf, deltaE_background_pdf, signal_extended, background_extended, total_model, result = fit_extended_model_scf_without_weight(
        Mbc_only_signal_cb_fixed, Mbc_scf_argus_gauss_fixed, deltaE_only_signal_cb_gauss_fixed, deltaE_scf_poly_gauss_fixed,
        Mbc_bkg_argus_gauss_fixed, deltaE_bkg_poly_gauss_fixed,
        pd.concat([Signal_total, Background_total]), 0.5, 0.5, 100, 100
    )
    result.errors(name='errors')
    print(result.params)
    print(result.valid)

    # Retrieve and store the signal yield and its error
    signal_yield = result.params[signal_extended.get_yield()]['value']
    signal_yield_errors = result.params[signal_extended.get_yield()]['errors']
    signal_yield_error = (signal_yield_errors['upper'] - signal_yield_errors['lower']) / 2

    # Store the signal yield and error as a tuple in the list
    signal_yields_and_errors.append((MC_signal,MC_bkg,signal_yield, signal_yield_error))

    print(f"Iteration {i + 1} - Signal Yield: {signal_yield} ± {signal_yield_error}")

# Convert the list to a DataFrame with two columns: 'Signal_Yield' and 'Signal_Yield_Error'
signal_yields_df = pd.DataFrame(signal_yields_and_errors, columns=['MC_signal','MC_bkg','Signal_Yield', 'Signal_Yield_Error'])


# Save the DataFrame to a CSV file
signal_yields_df.to_csv('Bppi0_q2reg1_decay_ee_signal_yields_and_errors_25.csv', index=False)

print("Signal yields and errors saved to 'Bppi0_q2reg1_decay_ee_signal_yields_and_errors_25.csv'")

# %% [markdown]
# ## 10

# %%
# Number of iterations
num_iterations = 300

# List to store the signal yields and their errors from each iteration
signal_yields_and_errors = []

for i in range(num_iterations):
    print(f"Running iteration {i + 1}/{num_iterations}...")

    # Process the Monte Carlo data
    mc_ele_signal, mc_ele_only_signal, mc_ele_scf, mc_ele_bkg, mc_ele_signal_weight, mc_ele_only_signal_weight, mc_ele_scf_weight, mc_ele_bkg_weight = process_MC_data_combined(
        file_signal_ele_Bppi0,file_bkg_ele_Bppi0, 'ele', '521', 'pi0', 'ee', 1, 'rec521', 'weights', 10
    )

    # Fit models for signal, SCF, and background
    Mbc_only_signal_cb_fixed = fit_fixed_without_weight('Mbc', 'ele', 'signal', mc_ele_only_signal["Mbc"], 'cb', 0)
    deltaE_only_signal_cb_gauss_fixed = fit_fixed_without_weight('deltaE', 'ele', 'signal', mc_ele_only_signal["deltaE"],  'cb_gauss', 0)

    Mbc_scf_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'ele', 'scf', mc_ele_scf["Mbc"], 'argus_gauss', 0)
    deltaE_scf_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'ele', 'scf', mc_ele_scf["deltaE"], 'poly_gauss', 0)

    Mbc_bkg_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'ele', 'bkg', mc_ele_bkg["Mbc"], 'argus_gauss', 0)
    deltaE_bkg_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'ele', 'bkg', mc_ele_bkg["deltaE"],  'poly', 0)

    # Combine signal and background data
    Signal_Mbc = mc_ele_only_signal["Mbc"]
    Signal_deltaE = mc_ele_only_signal["deltaE"]
    Background_Mbc = pd.concat([mc_ele_scf["Mbc"], mc_ele_bkg["Mbc"]])
    Background_deltaE = pd.concat([mc_ele_scf["deltaE"], mc_ele_bkg["deltaE"]])

    Signal_total = pd.concat([Signal_Mbc, Signal_deltaE], axis=1)
    Background_total = pd.concat([Background_Mbc, Background_deltaE], axis=1)

    MC_signal=len(Signal_total)
    MC_bkg=len(Background_total)

    print(MC_signal)
    print(MC_bkg)
    # Fit the extended model and get the result
    Mbc_signal_pdf, deltaE_signal_pdf, Mbc_background_pdf, deltaE_background_pdf, signal_extended, background_extended, total_model, result = fit_extended_model_scf_without_weight(
        Mbc_only_signal_cb_fixed, Mbc_scf_argus_gauss_fixed, deltaE_only_signal_cb_gauss_fixed, deltaE_scf_poly_gauss_fixed,
        Mbc_bkg_argus_gauss_fixed, deltaE_bkg_poly_gauss_fixed,
        pd.concat([Signal_total, Background_total]), 0.5, 0.5, 100, 100
    )
    result.errors(name='errors')
    print(result.params)
    print(result.valid)

    # Retrieve and store the signal yield and its error
    signal_yield = result.params[signal_extended.get_yield()]['value']
    signal_yield_errors = result.params[signal_extended.get_yield()]['errors']
    signal_yield_error = (signal_yield_errors['upper'] - signal_yield_errors['lower']) / 2

    # Store the signal yield and error as a tuple in the list
    signal_yields_and_errors.append((MC_signal,MC_bkg,signal_yield, signal_yield_error))

    print(f"Iteration {i + 1} - Signal Yield: {signal_yield} ± {signal_yield_error}")

# Convert the list to a DataFrame with two columns: 'Signal_Yield' and 'Signal_Yield_Error'
signal_yields_df = pd.DataFrame(signal_yields_and_errors, columns=['MC_signal','MC_bkg','Signal_Yield', 'Signal_Yield_Error'])


# Save the DataFrame to a CSV file
signal_yields_df.to_csv('Bppi0_q2reg1_decay_ee_signal_yields_and_errors_10.csv', index=False)

print("Signal yields and errors saved to 'Bppi0_q2reg1_decay_ee_signal_yields_and_errors_10.csv'")

# %% [markdown]
# ## 5

# %%
# Number of iterations
num_iterations = 300

# List to store the signal yields and their errors from each iteration
signal_yields_and_errors = []

for i in range(num_iterations):
    print(f"Running iteration {i + 1}/{num_iterations}...")

    # Process the Monte Carlo data
    mc_ele_signal, mc_ele_only_signal, mc_ele_scf, mc_ele_bkg, mc_ele_signal_weight, mc_ele_only_signal_weight, mc_ele_scf_weight, mc_ele_bkg_weight = process_MC_data_combined(
        file_signal_ele_Bppi0,file_bkg_ele_Bppi0, 'ele', '521', 'pi0', 'ee', 1, 'rec521', 'weights', 5
    )

    # Fit models for signal, SCF, and background
    Mbc_only_signal_cb_fixed = fit_fixed_without_weight('Mbc', 'ele', 'signal', mc_ele_only_signal["Mbc"], 'cb', 0)
    deltaE_only_signal_cb_gauss_fixed = fit_fixed_without_weight('deltaE', 'ele', 'signal', mc_ele_only_signal["deltaE"],  'cb_gauss', 0)

    Mbc_scf_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'ele', 'scf', mc_ele_scf["Mbc"], 'argus_gauss', 0)
    deltaE_scf_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'ele', 'scf', mc_ele_scf["deltaE"], 'poly_gauss', 0)

    Mbc_bkg_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'ele', 'bkg', mc_ele_bkg["Mbc"], 'argus_gauss', 0)
    deltaE_bkg_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'ele', 'bkg', mc_ele_bkg["deltaE"],  'poly', 0)

    # Combine signal and background data
    Signal_Mbc = mc_ele_only_signal["Mbc"]
    Signal_deltaE = mc_ele_only_signal["deltaE"]
    Background_Mbc = pd.concat([mc_ele_scf["Mbc"], mc_ele_bkg["Mbc"]])
    Background_deltaE = pd.concat([mc_ele_scf["deltaE"], mc_ele_bkg["deltaE"]])

    Signal_total = pd.concat([Signal_Mbc, Signal_deltaE], axis=1)
    Background_total = pd.concat([Background_Mbc, Background_deltaE], axis=1)

    MC_signal=len(Signal_total)
    MC_bkg=len(Background_total)

    print(MC_signal)
    print(MC_bkg)
    # Fit the extended model and get the result
    Mbc_signal_pdf, deltaE_signal_pdf, Mbc_background_pdf, deltaE_background_pdf, signal_extended, background_extended, total_model, result = fit_extended_model_scf_without_weight(
        Mbc_only_signal_cb_fixed, Mbc_scf_argus_gauss_fixed, deltaE_only_signal_cb_gauss_fixed, deltaE_scf_poly_gauss_fixed,
        Mbc_bkg_argus_gauss_fixed, deltaE_bkg_poly_gauss_fixed,
        pd.concat([Signal_total, Background_total]), 0.5, 0.5, 100, 100
    )
    result.errors(name='errors')
    print(result.params)
    print(result.valid)

    # Retrieve and store the signal yield and its error
    signal_yield = result.params[signal_extended.get_yield()]['value']
    signal_yield_errors = result.params[signal_extended.get_yield()]['errors']
    signal_yield_error = (signal_yield_errors['upper'] - signal_yield_errors['lower']) / 2

    # Store the signal yield and error as a tuple in the list
    signal_yields_and_errors.append((MC_signal,MC_bkg,signal_yield, signal_yield_error))

    print(f"Iteration {i + 1} - Signal Yield: {signal_yield} ± {signal_yield_error}")

# Convert the list to a DataFrame with two columns: 'Signal_Yield' and 'Signal_Yield_Error'
signal_yields_df = pd.DataFrame(signal_yields_and_errors, columns=['MC_signal','MC_bkg','Signal_Yield', 'Signal_Yield_Error'])


# Save the DataFrame to a CSV file
signal_yields_df.to_csv('Bppi0_q2reg1_decay_ee_signal_yields_and_errors_5.csv', index=False)

print("Signal yields and errors saved to 'Bppi0_q2reg1_decay_ee_signal_yields_and_errors_5.csv'")

# %% [markdown]
# ## 2

# %%
# Number of iterations
num_iterations = 300

# List to store the signal yields and their errors from each iteration
signal_yields_and_errors = []

for i in range(num_iterations):
    print(f"Running iteration {i + 1}/{num_iterations}...")

    # Process the Monte Carlo data
    mc_ele_signal, mc_ele_only_signal, mc_ele_scf, mc_ele_bkg, mc_ele_signal_weight, mc_ele_only_signal_weight, mc_ele_scf_weight, mc_ele_bkg_weight = process_MC_data_combined(
        file_signal_ele_Bppi0,file_bkg_ele_Bppi0, 'ele', '521', 'pi0', 'ee', 1, 'rec521', 'weights', 2
    )

    # Fit models for signal, SCF, and background
    Mbc_only_signal_cb_fixed = fit_fixed_without_weight('Mbc', 'ele', 'signal', mc_ele_only_signal["Mbc"], 'cb', 0)
    deltaE_only_signal_cb_gauss_fixed = fit_fixed_without_weight('deltaE', 'ele', 'signal', mc_ele_only_signal["deltaE"],  'cb_gauss', 0)

    Mbc_scf_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'ele', 'scf', mc_ele_scf["Mbc"], 'argus_gauss', 0)
    deltaE_scf_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'ele', 'scf', mc_ele_scf["deltaE"], 'poly_gauss', 0)

    Mbc_bkg_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'ele', 'bkg', mc_ele_bkg["Mbc"], 'argus_gauss', 0)
    deltaE_bkg_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'ele', 'bkg', mc_ele_bkg["deltaE"],  'poly', 0)

    # Combine signal and background data
    Signal_Mbc = mc_ele_only_signal["Mbc"]
    Signal_deltaE = mc_ele_only_signal["deltaE"]
    Background_Mbc = pd.concat([mc_ele_scf["Mbc"], mc_ele_bkg["Mbc"]])
    Background_deltaE = pd.concat([mc_ele_scf["deltaE"], mc_ele_bkg["deltaE"]])

    Signal_total = pd.concat([Signal_Mbc, Signal_deltaE], axis=1)
    Background_total = pd.concat([Background_Mbc, Background_deltaE], axis=1)

    MC_signal=len(Signal_total)
    MC_bkg=len(Background_total)

    print(MC_signal)
    print(MC_bkg)
    # Fit the extended model and get the result
    Mbc_signal_pdf, deltaE_signal_pdf, Mbc_background_pdf, deltaE_background_pdf, signal_extended, background_extended, total_model, result = fit_extended_model_scf_without_weight(
        Mbc_only_signal_cb_fixed, Mbc_scf_argus_gauss_fixed, deltaE_only_signal_cb_gauss_fixed, deltaE_scf_poly_gauss_fixed,
        Mbc_bkg_argus_gauss_fixed, deltaE_bkg_poly_gauss_fixed,
        pd.concat([Signal_total, Background_total]), 0.5, 0.5, 100, 100
    )
    result.errors(name='errors')
    print(result.params)
    print(result.valid)

    # Retrieve and store the signal yield and its error
    signal_yield = result.params[signal_extended.get_yield()]['value']
    signal_yield_errors = result.params[signal_extended.get_yield()]['errors']
    signal_yield_error = (signal_yield_errors['upper'] - signal_yield_errors['lower']) / 2

    # Store the signal yield and error as a tuple in the list
    signal_yields_and_errors.append((MC_signal,MC_bkg,signal_yield, signal_yield_error))

    print(f"Iteration {i + 1} - Signal Yield: {signal_yield} ± {signal_yield_error}")

# Convert the list to a DataFrame with two columns: 'Signal_Yield' and 'Signal_Yield_Error'
signal_yields_df = pd.DataFrame(signal_yields_and_errors, columns=['MC_signal','MC_bkg','Signal_Yield', 'Signal_Yield_Error'])


# Save the DataFrame to a CSV file
signal_yields_df.to_csv('Bppi0_q2reg1_decay_ee_signal_yields_and_errors_2.csv', index=False)

print("Signal yields and errors saved to 'Bppi0_q2reg1_decay_ee_signal_yields_and_errors_2.csv'")

# %% [markdown]
# ## 0

# %%
# Number of iterations
num_iterations = 300

# List to store the signal yields and their errors from each iteration
signal_yields_and_errors = []

for i in range(num_iterations):
    print(f"Running iteration {i + 1}/{num_iterations}...")

    # Process the Monte Carlo data
    mc_ele_signal, mc_ele_only_signal, mc_ele_scf, mc_ele_bkg, mc_ele_signal_weight, mc_ele_only_signal_weight, mc_ele_scf_weight, mc_ele_bkg_weight = process_MC_data_combined(
        file_signal_ele_Bppi0,file_bkg_ele_Bppi0, 'ele', '521', 'pi0', 'ee', 1, 'rec521', 'weights', 0
    )

    # Fit models for signal, SCF, and background
    Mbc_only_signal_cb_fixed = fit_fixed_without_weight('Mbc', 'ele', 'signal', mc_ele_only_signal["Mbc"], 'cb', 0)
    deltaE_only_signal_cb_gauss_fixed = fit_fixed_without_weight('deltaE', 'ele', 'signal', mc_ele_only_signal["deltaE"],  'cb_gauss', 0)

    Mbc_scf_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'ele', 'scf', mc_ele_scf["Mbc"], 'argus_gauss', 0)
    deltaE_scf_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'ele', 'scf', mc_ele_scf["deltaE"], 'poly_gauss', 0)

    Mbc_bkg_argus_gauss_fixed = fit_fixed_without_weight('Mbc', 'ele', 'bkg', mc_ele_bkg["Mbc"], 'argus_gauss', 0)
    deltaE_bkg_poly_gauss_fixed = fit_fixed_without_weight('deltaE', 'ele', 'bkg', mc_ele_bkg["deltaE"],  'poly', 0)

    # Combine signal and background data
    Signal_Mbc = mc_ele_only_signal["Mbc"]
    Signal_deltaE = mc_ele_only_signal["deltaE"]
    Background_Mbc = pd.concat([mc_ele_scf["Mbc"], mc_ele_bkg["Mbc"]])
    Background_deltaE = pd.concat([mc_ele_scf["deltaE"], mc_ele_bkg["deltaE"]])

    Signal_total = pd.concat([Signal_Mbc, Signal_deltaE], axis=1)
    Background_total = pd.concat([Background_Mbc, Background_deltaE], axis=1)

    MC_signal=len(Signal_total)
    MC_bkg=len(Background_total)

    print(MC_signal)
    print(MC_bkg)
    # Fit the extended model and get the result
    Mbc_signal_pdf, deltaE_signal_pdf, Mbc_background_pdf, deltaE_background_pdf, signal_extended, background_extended, total_model, result = fit_extended_model_scf_without_weight(
        Mbc_only_signal_cb_fixed, Mbc_scf_argus_gauss_fixed, deltaE_only_signal_cb_gauss_fixed, deltaE_scf_poly_gauss_fixed,
        Mbc_bkg_argus_gauss_fixed, deltaE_bkg_poly_gauss_fixed,
        pd.concat([Signal_total, Background_total]), 0.5, 0.5, 100, 100
    )
    result.errors(name='errors')
    print(result.params)
    print(result.valid)

    # Retrieve and store the signal yield and its error
    signal_yield = result.params[signal_extended.get_yield()]['value']
    signal_yield_errors = result.params[signal_extended.get_yield()]['errors']
    signal_yield_error = (signal_yield_errors['upper'] - signal_yield_errors['lower']) / 2

    # Store the signal yield and error as a tuple in the list
    signal_yields_and_errors.append((MC_signal,MC_bkg,signal_yield, signal_yield_error))

    print(f"Iteration {i + 1} - Signal Yield: {signal_yield} ± {signal_yield_error}")

# Convert the list to a DataFrame with two columns: 'Signal_Yield' and 'Signal_Yield_Error'
signal_yields_df = pd.DataFrame(signal_yields_and_errors, columns=['MC_signal','MC_bkg','Signal_Yield', 'Signal_Yield_Error'])


# Save the DataFrame to a CSV file
signal_yields_df.to_csv('Bppi0_q2reg1_decay_ee_signal_yields_and_errors_0.csv', index=False)

print("Signal yields and errors saved to 'Bppi0_q2reg1_decay_ee_signal_yields_and_errors_0.csv'")
# Out:
# Running iteration 1/300...
# 0
# 50
# /afs/desy.de/user/j/jipatel/.local/lib/python3.8/site-packages/zfit/core/basepdf.py:585: UserWarning: As `copy` is not yet properly implemented, this may fails (for ProductPDF for example?). Thiswill be fixed in the future.
#   warnings.warn(
# /afs/desy.de/user/j/jipatel/.local/lib/python3.8/site-packages/zfit/minimizers/fitresult.py:1340: FutureWarning: 'minuit_minos' will be changed as the default errors method to a custom implementationwith the same functionality. If you want to make sure that 'minuit_minos' will be used in the future, add it explicitly as in `errors(method='minuit_minos')`
#   warnings.warn(
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0738               -0.738997  -    1.6   +    2.2       False
# background_yield_0.0738             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.0738             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.0738            0.389277  -   0.52   +    0.5       False
# True
# Iteration 1 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 2/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3381               -0.738997  -    1.6   +    2.2       False
# background_yield_0.3381             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.3381             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.3381            0.389277  -   0.52   +    0.5       False
# True
# Iteration 2 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 3/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3453               -0.738997  -    1.6   +    2.2       False
# background_yield_0.3453             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.3453             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.3453            0.389277  -   0.52   +    0.5       False
# True
# Iteration 3 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 4/300...
# 0
# 50
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.389               -0.738997  -    1.6   +    2.2       False
# background_yield_0.389             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.389             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.389            0.389277  -   0.52   +    0.5       False
# True
# Iteration 4 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 5/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4069               -0.738997  -    1.6   +    2.2       False
# background_yield_0.4069             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.4069             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.4069            0.389277  -   0.52   +    0.5       False
# True
# Iteration 5 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 6/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2274               -0.738997  -    1.6   +    2.2       False
# background_yield_0.2274             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.2274             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.2274            0.389277  -   0.52   +    0.5       False
# True
# Iteration 6 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 7/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6414               -0.738997  -    1.6   +    2.2       False
# background_yield_0.6414             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.6414             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.6414            0.389277  -   0.52   +    0.5       False
# True
# Iteration 7 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 8/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8604               -0.738997  -    1.6   +    2.2       False
# background_yield_0.8604             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.8604             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.8604            0.389277  -   0.52   +    0.5       False
# True
# Iteration 8 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 9/300...
# 0
# 50
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.438               -0.738997  -    1.6   +    2.2       False
# background_yield_0.438             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.438             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.438            0.389277  -   0.52   +    0.5       False
# True
# Iteration 9 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 10/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6507               -0.738997  -    1.6   +    2.2       False
# background_yield_0.6507             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.6507             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.6507            0.389277  -   0.52   +    0.5       False
# True
# Iteration 10 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 11/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6357               -0.738997  -    1.6   +    2.2       False
# background_yield_0.6357             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.6357             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.6357            0.389277  -   0.52   +    0.5       False
# True
# Iteration 11 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 12/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5816               -0.738997  -    1.6   +    2.2       False
# background_yield_0.5816             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.5816             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.5816            0.389277  -   0.52   +    0.5       False
# True
# Iteration 12 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 13/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0041               -0.738997  -    1.6   +    2.2       False
# background_yield_0.0041             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.0041             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.0041            0.389277  -   0.52   +    0.5       False
# True
# Iteration 13 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 14/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4577               -0.738997  -    1.6   +    2.2       False
# background_yield_0.4577             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.4577             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.4577            0.389277  -   0.52   +    0.5       False
# True
# Iteration 14 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 15/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2569               -0.738997  -    1.6   +    2.2       False
# background_yield_0.2569             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.2569             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.2569            0.389277  -   0.52   +    0.5       False
# True
# Iteration 15 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 16/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3018               -0.738997  -    1.6   +    2.2       False
# background_yield_0.3018             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.3018             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.3018            0.389277  -   0.52   +    0.5       False
# True
# Iteration 16 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 17/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8357               -0.738997  -    1.6   +    2.2       False
# background_yield_0.8357             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.8357             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.8357            0.389277  -   0.52   +    0.5       False
# True
# Iteration 17 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 18/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7051               -0.738997  -    1.6   +    2.2       False
# background_yield_0.7051             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.7051             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.7051            0.389277  -   0.52   +    0.5       False
# True
# Iteration 18 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 19/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4169               -0.738997  -    1.6   +    2.2       False
# background_yield_0.4169             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.4169             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.4169            0.389277  -   0.52   +    0.5       False
# True
# Iteration 19 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 20/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6958               -0.738997  -    1.6   +    2.2       False
# background_yield_0.6958             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.6958             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.6958            0.389277  -   0.52   +    0.5       False
# True
# Iteration 20 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 21/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3797               -0.738997  -    1.6   +    2.2       False
# background_yield_0.3797             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.3797             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.3797            0.389277  -   0.52   +    0.5       False
# True
# Iteration 21 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 22/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5399               -0.738997  -    1.6   +    2.2       False
# background_yield_0.5399             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.5399             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.5399            0.389277  -   0.52   +    0.5       False
# True
# Iteration 22 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 23/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6926               -0.738997  -    1.6   +    2.2       False
# background_yield_0.6926             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.6926             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.6926            0.389277  -   0.52   +    0.5       False
# True
# Iteration 23 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 24/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2281               -0.738997  -    1.6   +    2.2       False
# background_yield_0.2281             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.2281             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.2281            0.389277  -   0.52   +    0.5       False
# True
# Iteration 24 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 25/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8794               -0.738997  -    1.6   +    2.2       False
# background_yield_0.8794             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.8794             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.8794            0.389277  -   0.52   +    0.5       False
# True
# Iteration 25 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 26/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5473               -0.738997  -    1.6   +    2.2       False
# background_yield_0.5473             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.5473             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.5473            0.389277  -   0.52   +    0.5       False
# True
# Iteration 26 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 27/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2833               -0.738997  -    1.6   +    2.2       False
# background_yield_0.2833             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.2833             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.2833            0.389277  -   0.52   +    0.5       False
# True
# Iteration 27 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 28/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4651               -0.738997  -    1.6   +    2.2       False
# background_yield_0.4651             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.4651             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.4651            0.389277  -   0.52   +    0.5       False
# True
# Iteration 28 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 29/300...
# 0
# 50
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.309               -0.738997  -    1.6   +    2.2       False
# background_yield_0.309             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.309             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.309            0.389277  -   0.52   +    0.5       False
# True
# Iteration 29 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 30/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9759               -0.738997  -    1.6   +    2.2       False
# background_yield_0.9759             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.9759             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.9759            0.389277  -   0.52   +    0.5       False
# True
# Iteration 30 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 31/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2906               -0.738997  -    1.6   +    2.2       False
# background_yield_0.2906             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.2906             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.2906            0.389277  -   0.52   +    0.5       False
# True
# Iteration 31 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 32/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5392               -0.738997  -    1.6   +    2.2       False
# background_yield_0.5392             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.5392             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.5392            0.389277  -   0.52   +    0.5       False
# True
# Iteration 32 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 33/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2909               -0.738997  -    1.6   +    2.2       False
# background_yield_0.2909             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.2909             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.2909            0.389277  -   0.52   +    0.5       False
# True
# Iteration 33 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 34/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0872               -0.738997  -    1.6   +    2.2       False
# background_yield_0.0872             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.0872             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.0872            0.389277  -   0.52   +    0.5       False
# True
# Iteration 34 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 35/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2519               -0.738997  -    1.6   +    2.2       False
# background_yield_0.2519             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.2519             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.2519            0.389277  -   0.52   +    0.5       False
# True
# Iteration 35 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 36/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3434               -0.738997  -    1.6   +    2.2       False
# background_yield_0.3434             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.3434             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.3434            0.389277  -   0.52   +    0.5       False
# True
# Iteration 36 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 37/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1137               -0.738997  -    1.6   +    2.2       False
# background_yield_0.1137             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.1137             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.1137            0.389277  -   0.52   +    0.5       False
# True
# Iteration 37 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 38/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4362               -0.738997  -    1.6   +    2.2       False
# background_yield_0.4362             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.4362             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.4362            0.389277  -   0.52   +    0.5       False
# True
# Iteration 38 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 39/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4179               -0.738997  -    1.6   +    2.2       False
# background_yield_0.4179             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.4179             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.4179            0.389277  -   0.52   +    0.5       False
# True
# Iteration 39 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 40/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0934               -0.738997  -    1.6   +    2.2       False
# background_yield_0.0934             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.0934             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.0934            0.389277  -   0.52   +    0.5       False
# True
# Iteration 40 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 41/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3889               -0.738997  -    1.6   +    2.2       False
# background_yield_0.3889             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.3889             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.3889            0.389277  -   0.52   +    0.5       False
# True
# Iteration 41 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 42/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4387               -0.738997  -    1.6   +    2.2       False
# background_yield_0.4387             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.4387             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.4387            0.389277  -   0.52   +    0.5       False
# True
# Iteration 42 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 43/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8334               -0.738997  -    1.6   +    2.2       False
# background_yield_0.8334             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.8334             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.8334            0.389277  -   0.52   +    0.5       False
# True
# Iteration 43 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 44/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4419               -0.738997  -    1.6   +    2.2       False
# background_yield_0.4419             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.4419             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.4419            0.389277  -   0.52   +    0.5       False
# True
# Iteration 44 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 45/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5506               -0.738997  -    1.6   +    2.2       False
# background_yield_0.5506             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.5506             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.5506            0.389277  -   0.52   +    0.5       False
# True
# Iteration 45 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 46/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1224               -0.738997  -    1.6   +    2.2       False
# background_yield_0.1224             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.1224             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.1224            0.389277  -   0.52   +    0.5       False
# True
# Iteration 46 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 47/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1369               -0.738997  -    1.6   +    2.2       False
# background_yield_0.1369             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.1369             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.1369            0.389277  -   0.52   +    0.5       False
# True
# Iteration 47 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 48/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2959               -0.738997  -    1.6   +    2.2       False
# background_yield_0.2959             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.2959             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.2959            0.389277  -   0.52   +    0.5       False
# True
# Iteration 48 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 49/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2345               -0.738997  -    1.6   +    2.2       False
# background_yield_0.2345             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.2345             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.2345            0.389277  -   0.52   +    0.5       False
# True
# Iteration 49 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 50/300...
# 0
# 50
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.904               -0.738997  -    1.6   +    2.2       False
# background_yield_0.904             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.904             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.904            0.389277  -   0.52   +    0.5       False
# True
# Iteration 50 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 51/300...
# 0
# 50
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.928               -0.738997  -    1.6   +    2.2       False
# background_yield_0.928             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.928             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.928            0.389277  -   0.52   +    0.5       False
# True
# Iteration 51 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 52/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0555               -0.738997  -    1.6   +    2.2       False
# background_yield_0.0555             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.0555             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.0555            0.389277  -   0.52   +    0.5       False
# True
# Iteration 52 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 53/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0197               -0.738997  -    1.6   +    2.2       False
# background_yield_0.0197             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.0197             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.0197            0.389277  -   0.52   +    0.5       False
# True
# Iteration 53 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 54/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2826               -0.738997  -    1.6   +    2.2       False
# background_yield_0.2826             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.2826             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.2826            0.389277  -   0.52   +    0.5       False
# True
# Iteration 54 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 55/300...
# 0
# 50
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.692               -0.738997  -    1.6   +    2.2       False
# background_yield_0.692             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.692             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.692            0.389277  -   0.52   +    0.5       False
# True
# Iteration 55 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 56/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1894               -0.738997  -    1.6   +    2.2       False
# background_yield_0.1894             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.1894             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.1894            0.389277  -   0.52   +    0.5       False
# True
# Iteration 56 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 57/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8026               -0.738997  -    1.6   +    2.2       False
# background_yield_0.8026             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.8026             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.8026            0.389277  -   0.52   +    0.5       False
# True
# Iteration 57 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 58/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9121               -0.738997  -    1.6   +    2.2       False
# background_yield_0.9121             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.9121             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.9121            0.389277  -   0.52   +    0.5       False
# True
# Iteration 58 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 59/300...
# 0
# 50
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.883               -0.738997  -    1.6   +    2.2       False
# background_yield_0.883             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.883             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.883            0.389277  -   0.52   +    0.5       False
# True
# Iteration 59 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 60/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5023               -0.738997  -    1.6   +    2.2       False
# background_yield_0.5023             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.5023             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.5023            0.389277  -   0.52   +    0.5       False
# True
# Iteration 60 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 61/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3638               -0.738997  -    1.6   +    2.2       False
# background_yield_0.3638             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.3638             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.3638            0.389277  -   0.52   +    0.5       False
# True
# Iteration 61 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 62/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3413               -0.738997  -    1.6   +    2.2       False
# background_yield_0.3413             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.3413             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.3413            0.389277  -   0.52   +    0.5       False
# True
# Iteration 62 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 63/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9117               -0.738997  -    1.6   +    2.2       False
# background_yield_0.9117             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.9117             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.9117            0.389277  -   0.52   +    0.5       False
# True
# Iteration 63 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 64/300...
# 0
# 50
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.447               -0.738997  -    1.6   +    2.2       False
# background_yield_0.447             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.447             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.447            0.389277  -   0.52   +    0.5       False
# True
# Iteration 64 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 65/300...
# 0
# 50
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.643               -0.738997  -    1.6   +    2.2       False
# background_yield_0.643             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.643             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.643            0.389277  -   0.52   +    0.5       False
# True
# Iteration 65 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 66/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7441               -0.738997  -    1.6   +    2.2       False
# background_yield_0.7441             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.7441             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.7441            0.389277  -   0.52   +    0.5       False
# True
# Iteration 66 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 67/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9249               -0.738997  -    1.6   +    2.2       False
# background_yield_0.9249             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.9249             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.9249            0.389277  -   0.52   +    0.5       False
# True
# Iteration 67 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 68/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8296               -0.738997  -    1.6   +    2.2       False
# background_yield_0.8296             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.8296             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.8296            0.389277  -   0.52   +    0.5       False
# True
# Iteration 68 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 69/300...
# 0
# 50
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.771               -0.738997  -    1.6   +    2.2       False
# background_yield_0.771             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.771             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.771            0.389277  -   0.52   +    0.5       False
# True
# Iteration 69 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 70/300...
# 0
# 50
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.415               -0.738997  -    1.6   +    2.2       False
# background_yield_0.415             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.415             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.415            0.389277  -   0.52   +    0.5       False
# True
# Iteration 70 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 71/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6996               -0.738997  -    1.6   +    2.2       False
# background_yield_0.6996             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.6996             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.6996            0.389277  -   0.52   +    0.5       False
# True
# Iteration 71 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 72/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5042               -0.738997  -    1.6   +    2.2       False
# background_yield_0.5042             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.5042             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.5042            0.389277  -   0.52   +    0.5       False
# True
# Iteration 72 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 73/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8003               -0.738997  -    1.6   +    2.2       False
# background_yield_0.8003             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.8003             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.8003            0.389277  -   0.52   +    0.5       False
# True
# Iteration 73 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 74/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7064               -0.738997  -    1.6   +    2.2       False
# background_yield_0.7064             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.7064             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.7064            0.389277  -   0.52   +    0.5       False
# True
# Iteration 74 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 75/300...
# 0
# 50
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.678               -0.738997  -    1.6   +    2.2       False
# background_yield_0.678             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.678             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.678            0.389277  -   0.52   +    0.5       False
# True
# Iteration 75 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 76/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9056               -0.738997  -    1.6   +    2.2       False
# background_yield_0.9056             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.9056             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.9056            0.389277  -   0.52   +    0.5       False
# True
# Iteration 76 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 77/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4446               -0.738997  -    1.6   +    2.2       False
# background_yield_0.4446             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.4446             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.4446            0.389277  -   0.52   +    0.5       False
# True
# Iteration 77 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 78/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.3485               -0.738997  -    1.6   +    2.2       False
# background_yield_0.3485             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.3485             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.3485            0.389277  -   0.52   +    0.5       False
# True
# Iteration 78 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 79/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0731               -0.738997  -    1.6   +    2.2       False
# background_yield_0.0731             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.0731             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.0731            0.389277  -   0.52   +    0.5       False
# True
# Iteration 79 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 80/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4906               -0.738997  -    1.6   +    2.2       False
# background_yield_0.4906             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.4906             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.4906            0.389277  -   0.52   +    0.5       False
# True
# Iteration 80 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 81/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5513               -0.738997  -    1.6   +    2.2       False
# background_yield_0.5513             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.5513             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.5513            0.389277  -   0.52   +    0.5       False
# True
# Iteration 81 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 82/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6362               -0.738997  -    1.6   +    2.2       False
# background_yield_0.6362             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.6362             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.6362            0.389277  -   0.52   +    0.5       False
# True
# Iteration 82 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 83/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2892               -0.738997  -    1.6   +    2.2       False
# background_yield_0.2892             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.2892             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.2892            0.389277  -   0.52   +    0.5       False
# True
# Iteration 83 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 84/300...
# 0
# 50
# name                      value  (rounded)               errors    at limit
# ...
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.9512               -0.738997  -    1.6   +    2.2       False
# background_yield_0.9512             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.9512             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.9512            0.389277  -   0.52   +    0.5       False
# True
# Iteration 273 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 274/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8902               -0.738997  -    1.6   +    2.2       False
# background_yield_0.8902             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.8902             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.8902            0.389277  -   0.52   +    0.5       False
# True
# Iteration 274 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 275/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8774               -0.738997  -    1.6   +    2.2       False
# background_yield_0.8774             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.8774             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.8774            0.389277  -   0.52   +    0.5       False
# True
# Iteration 275 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 276/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.8202               -0.738997  -    1.6   +    2.2       False
# background_yield_0.8202             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.8202             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.8202            0.389277  -   0.52   +    0.5       False
# True
# Iteration 276 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 277/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1712               -0.738997  -    1.6   +    2.2       False
# background_yield_0.1712             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.1712             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.1712            0.389277  -   0.52   +    0.5       False
# True
# Iteration 277 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 278/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4039               -0.738997  -    1.6   +    2.2       False
# background_yield_0.4039             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.4039             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.4039            0.389277  -   0.52   +    0.5       False
# True
# Iteration 278 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 279/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2334               -0.738997  -    1.6   +    2.2       False
# background_yield_0.2334             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.2334             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.2334            0.389277  -   0.52   +    0.5       False
# True
# Iteration 279 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 280/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5279               -0.738997  -    1.6   +    2.2       False
# background_yield_0.5279             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.5279             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.5279            0.389277  -   0.52   +    0.5       False
# True
# Iteration 280 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 281/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2374               -0.738997  -    1.6   +    2.2       False
# background_yield_0.2374             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.2374             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.2374            0.389277  -   0.52   +    0.5       False
# True
# Iteration 281 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 282/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1191               -0.738997  -    1.6   +    2.2       False
# background_yield_0.1191             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.1191             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.1191            0.389277  -   0.52   +    0.5       False
# True
# Iteration 282 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 283/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6741               -0.738997  -    1.6   +    2.2       False
# background_yield_0.6741             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.6741             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.6741            0.389277  -   0.52   +    0.5       False
# True
# Iteration 283 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 284/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2132               -0.738997  -    1.6   +    2.2       False
# background_yield_0.2132             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.2132             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.2132            0.389277  -   0.52   +    0.5       False
# True
# Iteration 284 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 285/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0607               -0.738997  -    1.6   +    2.2       False
# background_yield_0.0607             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.0607             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.0607            0.389277  -   0.52   +    0.5       False
# True
# Iteration 285 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 286/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5199               -0.738997  -    1.6   +    2.2       False
# background_yield_0.5199             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.5199             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.5199            0.389277  -   0.52   +    0.5       False
# True
# Iteration 286 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 287/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1661               -0.738997  -    1.6   +    2.2       False
# background_yield_0.1661             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.1661             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.1661            0.389277  -   0.52   +    0.5       False
# True
# Iteration 287 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 288/300...
# 0
# 50
# name                      value  (rounded)               errors    at limit
# ----------------------  ------------------  -------------------  ----------
# signal_yield_0.224               -0.738997  -    1.6   +    2.2       False
# background_yield_0.224             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.224             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.224            0.389277  -   0.52   +    0.5       False
# True
# Iteration 288 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 289/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7096               -0.738997  -    1.6   +    2.2       False
# background_yield_0.7096             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.7096             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.7096            0.389277  -   0.52   +    0.5       False
# True
# Iteration 289 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 290/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.6132               -0.738997  -    1.6   +    2.2       False
# background_yield_0.6132             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.6132             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.6132            0.389277  -   0.52   +    0.5       False
# True
# Iteration 290 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 291/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.5307               -0.738997  -    1.6   +    2.2       False
# background_yield_0.5307             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.5307             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.5307            0.389277  -   0.52   +    0.5       False
# True
# Iteration 291 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 292/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4397               -0.738997  -    1.6   +    2.2       False
# background_yield_0.4397             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.4397             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.4397            0.389277  -   0.52   +    0.5       False
# True
# Iteration 292 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 293/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.4461               -0.738997  -    1.6   +    2.2       False
# background_yield_0.4461             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.4461             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.4461            0.389277  -   0.52   +    0.5       False
# True
# Iteration 293 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 294/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1301               -0.738997  -    1.6   +    2.2       False
# background_yield_0.1301             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.1301             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.1301            0.389277  -   0.52   +    0.5       False
# True
# Iteration 294 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 295/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.7061               -0.738997  -    1.6   +    2.2       False
# background_yield_0.7061             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.7061             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.7061            0.389277  -   0.52   +    0.5       False
# True
# Iteration 295 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 296/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1347               -0.738997  -    1.6   +    2.2       False
# background_yield_0.1347             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.1347             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.1347            0.389277  -   0.52   +    0.5       False
# True
# Iteration 296 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 297/300...
# 0
# 50
# name                    value  (rounded)               errors    at limit
# --------------------  ------------------  -------------------  ----------
# signal_yield_0.9               -0.738997  -    1.6   +    2.2       False
# background_yield_0.9             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.9             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.9            0.389277  -   0.52   +    0.5       False
# True
# Iteration 297 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 298/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.0686               -0.738997  -    1.6   +    2.2       False
# background_yield_0.0686             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.0686             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.0686            0.389277  -   0.52   +    0.5       False
# True
# Iteration 298 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 299/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.1346               -0.738997  -    1.6   +    2.2       False
# background_yield_0.1346             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.1346             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.1346            0.389277  -   0.52   +    0.5       False
# True
# Iteration 299 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Running iteration 300/300...
# 0
# 50
# name                       value  (rounded)               errors    at limit
# -----------------------  ------------------  -------------------  ----------
# signal_yield_0.2956               -0.738997  -    1.6   +    2.2       False
# background_yield_0.2956             50.7623  -    7.1   +    7.7       False
# frac_Mbc_bkg1_0.2956             -0.0321394  -   0.16   +   0.17       False
# frac_deltaE_bkg1_0.2956            0.389277  -   0.52   +    0.5       False
# True
# Iteration 300 - Signal Yield: -0.7389972323831329 ± 1.9425879842613134
# Signal yields and errors saved to 'Bppi0_q2reg1_decay_ee_signal_yields_and_errors_0.csv'
